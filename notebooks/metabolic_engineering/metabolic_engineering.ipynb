# %% [markdown]
# #### Purpose
#
# Extract and compare the homeostatic metabolite targets from the FBA listener in the metabolic engineering sim to the biomass reaction of the iJO1366 model. This is motivated by the fact that the FBA listener's homeostatic targets are meant to reflect the cell's biomass needs, so we should see significant overlap with the biomass reaction components.

# %%
import pandas as pd
import os, dill
import numpy as np
import cvxpy as cp
from typing import Iterable, Optional, Mapping, cast
from plotly.graph_objects import Scatter, Figure

from ecoli.processes.metabolism_redux import NetworkFlowModel, FlowResult
os.chdir(os.path.expanduser('~/dev/vEcoli'))

# %load_ext autoreload

# %%
# import reaction info from sim result
time = '600'
date = '2026-04-17'
experiment = "metabolism_redux_metabolic_engineering"
condition = 'basal'
entry = f'{experiment}_{time}_{date}'
folder = f'out/metabolic_engineering/{condition}/{entry}/'

output = np.load(folder + '0_output.npy',allow_pickle='TRUE').item()
output = output['agents']['0']
fba = output['listeners']['fba_results']
bulk = pd.DataFrame(output['bulk'])
f = open(folder + 'agent_steps.pkl', 'rb')
agent = dill.load(f)
f.close()

# %%
# get commonly stored variables
metabolism = agent['ecoli-metabolism-redux']
stoichiometry = metabolism.stoichiometry.copy()
reaction_names = metabolism.reaction_names
fba_reaction_ids_to_base_reaction_ids = metabolism.parameters['fba_reaction_ids_to_base_reaction_ids']
metabolites = metabolism.metabolite_names.copy()
exchange_molecules = metabolism.exchange_molecules
kinetic_enzymes = metabolism.parameters['kinetic_constraint_enzymes']

# %%
fba.keys()
# Out:
# dict_keys(['media_id', 'conc_updates', 'base_reaction_fluxes', 'solution_fluxes', 'solution_dmdt', 'time_per_step', 'estimated_fluxes', 'estimated_homeostatic_dmdt', 'target_homeostatic_dmdt', 'target_homeostatic_dmdt_conc', 'estimated_homeostatic_dmdt_conc_raw', 'estimated_homeostatic_dmdt_conc', 'estimated_exchange_dmdt', 'estimated_intermediate_dmdt', 'target_kinetic_fluxes', 'target_kinetic_bounds', 'reaction_catalyst_counts', 'maintenance_target'])

# %%
homeostatic_ids = list(metabolism.homeostatic_metabolites)
assert homeostatic_ids == list(
  np.array(metabolism.network_flow_model.mets)[
      metabolism.network_flow_model.homeostatic_idx
  ]
)

target_homeostatic_counts = pd.DataFrame(fba["target_homeostatic_dmdt"],
                              columns=metabolism.homeostatic_metabolites).mean(axis=0)
estimated_homeostatic_counts = pd.DataFrame(fba["estimated_homeostatic_dmdt"],
                                    columns=metabolism.homeostatic_metabolites).mean(axis=0)
target_homeostatic_conc = pd.DataFrame(fba["target_homeostatic_dmdt_conc"],
                              columns=metabolism.homeostatic_metabolites).mean(axis=0)
estimated_homeostatic_conc = pd.DataFrame(fba["estimated_homeostatic_dmdt_conc"],
                                    columns=metabolism.homeostatic_metabolites).mean(axis=0)
estimated_homeostatic_conc_raw = pd.DataFrame(fba["estimated_homeostatic_dmdt_conc_raw"],
                                    columns=metabolism.homeostatic_metabolites).mean(axis=0)

# %%
estimated_homeostatic_conc
# Out:
# 2-3-DIHYDROXYBENZOATE[c]     0.000035
# 2-KETOGLUTARATE[c]           0.000090
# 2-PG[c]                      0.000023
# 2K-4CH3-PENTANOATE[c]        0.000035
# 4-AMINO-BUTYRATE[c]          0.000078
#                               ...
# WATER[c]                    10.980466
# XYLULOSE-5-PHOSPHATE[c]      0.000043
# ZN+2[c]                      0.000019
# ZN+2[p]                      0.000026
# glycogen-monomer[c]          0.008263
# Length: 172, dtype: float64

# %% [markdown]
# #### FBA - Core

# %%
import requests
import pandas as pd
from cobra.io import load_json_model
import time

model = load_json_model("notebooks/metabolic_engineering/iJO1366.json")
rxn = model.reactions.get_by_id("BIOMASS_Ec_iJO1366_core_53p95M")

rows = []
for met, coeff in rxn.metabolites.items():
    # Strip compartment suffix for the API call (e.g. ala__L_c -> ala__L)
    universal_id = met.id.rsplit("_", 1)[0]

    ecocyc_id = None
    try:
        r = requests.get(
            f"http://bigg.ucsd.edu/api/v2/universal/metabolites/{universal_id}",
            timeout=5
        )
        if r.ok:
            links = r.json().get("database_links", {})
            # BiGG stores EcoCyc under 'BioCyc' key
            biocyc = links.get("BioCyc", [])
            ecocyc_id = biocyc[0]["id"] if biocyc else None
    except Exception:
        pass

    rows.append({
        "bigg_id": met.id,
        "name": met.name,
        "coefficient": coeff,
        "ecocyc_id": ecocyc_id
    })
    time.sleep(0.1)  # (~10 req/sec limit)

df = pd.DataFrame(rows).sort_values("coefficient")

# %%
df
# Out:
#      bigg_id               name  coefficient             ecocyc_id
# 10     atp_c  ATP C10H12N5O13P3   -54.124831              META:ATP
# 31     h2o_c            H2O H2O   -48.601527        META:CPD-15815
# 29     gly_c            Glycine    -0.612638              META:GLY
# 5   ala__L_c          L-Alanine    -0.513689  META:L-ALPHA-ALANINE
# 37  leu__L_c          L-Leucine    -0.450531              META:LEU
# ..       ...                ...          ...                   ...
# 12     btn_c             Biotin    -0.000002           META:BIOTIN
# 56     ppi_c        Diphosphate     0.773903              META:PPI
# 55      pi_c          Phosphate    53.945662        META:CPD-16459
# 4      adp_c  ADP C10H12N5O10P2    53.950000              META:ADP
# 32       h_c                 H+    53.950000           META:PROTON
#
# [72 rows x 4 columns]

# %%
COMPARTMENT_MAP = {"c": "[c]", "p": "[p]", "e": "[p]"}  # vEcoli uses [p] for periplasmic uptake

# Some BiGG entries use MetaCyc generic IDs where EcoCyc has a species-specific frame ID.
# Extend as you spot mismatches.
METACYC_TO_ECOCYC = {
  "CPD-15815": "WATER",
  "CPD-16459": "Pi",
  "CPD-3": "AMMONIUM",  # nh4_c commonly
  "CPD0-1958": "L-ORNITHINE",
}

def to_vecoli_id(row):
  if not row["ecocyc_id"]:
      return None
  frame = row["ecocyc_id"].removeprefix("META:")
  frame = METACYC_TO_ECOCYC.get(frame, frame)
  comp_letter = row["bigg_id"].rsplit("_", 1)[-1]
  return f"{frame}{COMPARTMENT_MAP.get(comp_letter, '[c]')}"

df["vecoli_id"] = df.apply(to_vecoli_id, axis=1)
df["in_homeostatic"] = df["vecoli_id"].isin(metabolism.homeostatic_metabolites)

homeostatic_set = set(metabolism.homeostatic_metabolites)
df["in_homeostatic"] = df["vecoli_id"].isin(homeostatic_set)
print(f"matched {df['in_homeostatic'].sum()} / {len(df)}")
# Out:
# matched 56 / 72

# %%
df[["bigg_id", "ecocyc_id", "vecoli_id", "in_homeostatic"]]
# Out:
#      bigg_id             ecocyc_id           vecoli_id  in_homeostatic
# 10     atp_c              META:ATP              ATP[c]            True
# 31     h2o_c        META:CPD-15815            WATER[c]            True
# 29     gly_c              META:GLY              GLY[c]            True
# 5   ala__L_c  META:L-ALPHA-ALANINE  L-ALPHA-ALANINE[c]            True
# 37  leu__L_c              META:LEU              LEU[c]            True
# ..       ...                   ...                 ...             ...
# 12     btn_c           META:BIOTIN           BIOTIN[c]            True
# 56     ppi_c              META:PPI              PPI[c]            True
# 55      pi_c        META:CPD-16459               Pi[c]            True
# 4      adp_c              META:ADP              ADP[c]            True
# 32       h_c           META:PROTON           PROTON[c]            True
#
# [72 rows x 4 columns]

# %%
frame_to_full = {}
for h in metabolism.homeostatic_metabolites:
  frame_to_full.setdefault(h.rsplit("[", 1)[0], []).append(h)

misses = df[~df["in_homeostatic"] & df["ecocyc_id"].notna()]
for _, r in misses.iterrows():
  frame = r["ecocyc_id"].removeprefix("META:")
  print(f"{r['bigg_id']:<15} -> {frame:<25} candidates: {frame_to_full.get(frame, [])}")
# Out:
# pe161_c         -> CPD-17086                 candidates: []
# pe160_p         -> CPD-12819                 candidates: ['CPD-12819[c]']
# pe161_p         -> CPD-17086                 candidates: []
# kdo2lipid4_e    -> KDO2-LIPID-IVA            candidates: []
# murein5px4p_p   -> CPD0-2278                 candidates: []
# nh4_c           -> AMMONIA                   candidates: []
# fe3_c           -> FE+3                      candidates: ['FE+3[p]']
# so4_c           -> HSO4                      candidates: []
# cu2_c           -> CU+2                      candidates: []
# 4fe4s_c         -> CPD-7                     candidates: []
# 10fthf_c        -> 10-FORMYL-THF             candidates: []
# 2ohph_c         -> 2-OCTAPRENYL-6-HYDROXYPHENOL candidates: []
# udcpdp_c        -> CPD-9649                  candidates: []
# mobd_c          -> CPD-3                     candidates: []

# %%
fba_ids = set(df["vecoli_id"].dropna())
homeo_ids = set(metabolism.homeostatic_metabolites)

in_both      = fba_ids & homeo_ids
only_in_fba  = fba_ids - homeo_ids
only_in_homeo = homeo_ids - fba_ids
unmapped_from_fba = df[df["vecoli_id"].isna()]["bigg_id"].tolist()

print(f"in both: {len(in_both):>4}")
print(f"only in fba: {len(only_in_fba):>4}")
print(f"only in homeo: {len(only_in_homeo):>4}")
print(f"unmapped (no ecocyc_id from BiGG): {len(unmapped_from_fba)}")

print("\nBoth:")
print(sorted(in_both))
print("\nFBA:")
print(sorted(only_in_fba))
print("\nvEcoli homeostatic:")
print(sorted(only_in_homeo))
print("\nFBA unmapped (no ecocyc_id from BiGG):")
print(unmapped_from_fba)
# Out:
# in both:   56
# only in fba:   14
# only in homeo:  116
# unmapped (no ecocyc_id from BiGG): 2
#
# Both:
# ['ADP[c]', 'ARG[c]', 'ASN[c]', 'ATP[c]', 'BIOTIN[c]', 'CA+2[c]', 'CL-[c]', 'CO+2[c]', 'CO-A[c]', 'CPD-12819[c]', 'CTP[c]', 'CYS[c]', 'DATP[c]', 'DCTP[c]', 'DGTP[c]', 'FAD[c]', 'FE+2[c]', 'GLN[c]', 'GLT[c]', 'GLY[c]', 'GTP[c]', 'HIS[c]', 'ILE[c]', 'K+[c]', 'L-ALPHA-ALANINE[c]', 'L-ASPARTATE[c]', 'LEU[c]', 'LYS[c]', 'METHYLENE-THF[c]', 'MET[c]', 'MG+2[c]', 'MN+2[c]', 'NADP[c]', 'NAD[c]', 'NI+2[c]', 'PHE[c]', 'PPI[c]', 'PROTOHEME[c]', 'PROTON[c]', 'PRO[c]', 'PYRIDOXAL_PHOSPHATE[c]', 'Pi[c]', 'RIBOFLAVIN[c]', 'S-ADENOSYLMETHIONINE[c]', 'SER[c]', 'SIROHEME[c]', 'THF[c]', 'THIAMINE-PYROPHOSPHATE[c]', 'THR[c]', 'TRP[c]', 'TTP[c]', 'TYR[c]', 'UTP[c]', 'VAL[c]', 'WATER[c]', 'ZN+2[c]']
#
# FBA:
# ['10-FORMYL-THF[c]', '2-OCTAPRENYL-6-HYDROXYPHENOL[c]', 'AMMONIA[c]', 'AMMONIUM[c]', 'CPD-12819[p]', 'CPD-17086[c]', 'CPD-17086[p]', 'CPD-7[c]', 'CPD-9649[c]', 'CPD0-2278[p]', 'CU+2[c]', 'FE+3[c]', 'HSO4[c]', 'KDO2-LIPID-IVA[p]']
#
# vEcoli homeostatic:
# ['2-3-DIHYDROXYBENZOATE[c]', '2-KETOGLUTARATE[c]', '2-PG[c]', '2K-4CH3-PENTANOATE[c]', '4-AMINO-BUTYRATE[c]', '4-hydroxybenzoate[c]', 'ACETOACETYL-COA[c]', 'ACETYL-COA[c]', 'ACETYL-P[c]', 'ADENINE[c]', 'ADENOSINE[c]', 'ADP-D-GLUCOSE[c]', 'AMP[c]', 'ANTHRANILATE[c]', 'APS[c]', 'CA+2[p]', 'CAMP[c]', 'CARBAMYUL-L-ASPARTATE[c]', 'CARBON-DIOXIDE[c]', 'CDP[c]', 'CHORISMATE[c]', 'CIS-ACONITATE[c]', 'CIT[c]', 'CMP[c]', 'CO+2[p]', 'CPD-12115[c]', 'CPD-12261[p]', 'CPD-12575[c]', 'CPD-12824[c]', 'CPD-13469[c]', 'CPD-2961[c]', 'CPD-8260[c]', 'CPD-9956[c]', 'CPD0-939[c]', 'CYTIDINE[c]', 'CYTOSINE[c]', 'D-ALA-D-ALA[c]', 'D-SEDOHEPTULOSE-7-P[c]', 'DAMP[c]', 'DEOXY-RIBOSE-5P[c]', 'DEOXYADENOSINE[c]', 'DEOXYGUANOSINE[c]', 'DGMP[c]', 'DI-H-OROTATE[c]', 'DIHYDROXY-ACETONE-PHOSPHATE[c]', 'DPG[c]', 'ENTEROBACTIN[c]', 'ERYTHROSE-4P[c]', 'FE+2[p]', 'FE+3[p]', 'FMN[c]', 'FRUCTOSE-16-DIPHOSPHATE[c]', 'FRUCTOSE-6P[c]', 'FUM[c]', 'G3P[c]', 'GDP[c]', 'GLC-6-P[c]', 'GLUCONATE[c]', 'GLUTATHIONE[c]', 'GLYCERATE[c]', 'GLYCEROL-3P[c]', 'GMP[c]', 'GUANINE[c]', 'GUANOSINE[c]', 'HISTIDINOL[c]', 'HOMO-CYS[c]', 'HOMO-SER[c]', 'HYPOXANTHINE[c]', 'IMP[c]', 'INOSINE[c]', 'L-ARGININO-SUCCINATE[c]', 'L-CITRULLINE[c]', 'L-ORNITHINE[c]', 'L-SELENOCYSTEINE[c]', 'LL-DIAMINOPIMELATE[c]', 'MALONYL-COA[c]', 'MAL[c]', 'MN+2[p]', 'N-ACETYL-D-GLUCOSAMINE-1-P[c]', 'N-ALPHA-ACETYLORNITHINE[c]', 'NA+[p]', 'NADH[c]', 'NADPH[c]', 'NI+2[p]', 'OROTATE[c]', 'OXALACETIC_ACID[c]', 'OXIDIZED-GLUTATHIONE[c]', 'OXYGEN-MOLECULE[p]', 'PANTOTHENATE[c]', 'PHENYL-PYRUVATE[c]', 'PHOSPHO-ENOL-PYRUVATE[c]', 'PROPIONYL-COA[c]', 'PRPP[c]', 'PUTRESCINE[c]', 'PYRUVATE[c]', 'Pi[p]', 'QUINOLINATE[c]', 'REDUCED-MENAQUINONE[c]', 'RIBOSE-1P[c]', 'RIBOSE-5P[c]', 'RIBULOSE-5P[c]', 'SHIKIMATE[c]', 'SPERMIDINE[c]', 'SUC-COA[c]', 'SUC[c]', 'TDP[c]', 'THREO-DS-ISO-CITRATE[c]', 'UDP-GLUCURONATE[c]', 'UDP-N-ACETYL-D-GLUCOSAMINE[c]', 'UDP[c]', 'UMP[c]', 'UNDECAPRENYL-DIPHOSPHATE[c]', 'URIDINE[c]', 'XYLULOSE-5-PHOSPHATE[c]', 'ZN+2[p]', 'glycogen-monomer[c]']
#
# FBA unmapped (no ecocyc_id from BiGG):
# ['bmocogdp_c', '2fe2s_c']

# %%
# Bis(molybdopterin guanine dinucleotide)molybdenum
# [2Fe-2S] iron-sulfur cluster

# %% [markdown]
# #### FBA - WT

# %%
import requests
import pandas as pd
from cobra.io import load_json_model
import time

model = load_json_model("notebooks/metabolic_engineering/iJO1366.json")
rxn = model.reactions.get_by_id("BIOMASS_Ec_iJO1366_WT_53p95M")

rows = []
for met, coeff in rxn.metabolites.items():
    # Strip compartment suffix for the API call (e.g. ala__L_c -> ala__L)
    universal_id = met.id.rsplit("_", 1)[0]

    ecocyc_id = None
    try:
        r = requests.get(
            f"http://bigg.ucsd.edu/api/v2/universal/metabolites/{universal_id}",
            timeout=5
        )
        if r.ok:
            links = r.json().get("database_links", {})
            # BiGG stores EcoCyc under 'BioCyc' key
            biocyc = links.get("BioCyc", [])
            ecocyc_id = biocyc[0]["id"] if biocyc else None
    except Exception:
        pass

    rows.append({
        "bigg_id": met.id,
        "name": met.name,
        "coefficient": coeff,
        "ecocyc_id": ecocyc_id
    })
    time.sleep(0.1)  # (~10 req/sec limit)

df = pd.DataFrame(rows).sort_values("coefficient")

# %%
df
# Out:
#      bigg_id               name  coefficient             ecocyc_id
# 13     atp_c  ATP C10H12N5O13P3   -54.119975              META:ATP
# 42     h2o_c            H2O H2O   -48.752916        META:CPD-15815
# 38     gly_c            Glycine    -0.595297              META:GLY
# 8   ala__L_c          L-Alanine    -0.499149  META:L-ALPHA-ALANINE
# 48  leu__L_c          L-Leucine    -0.437778              META:LEU
# ..       ...                ...          ...                   ...
# 15     btn_c             Biotin    -0.000002           META:BIOTIN
# 86     ppi_c        Diphosphate     0.749831              META:PPI
# 85      pi_c          Phosphate    53.945874        META:CPD-16459
# 43       h_c                 H+    53.950000           META:PROTON
# 7      adp_c  ADP C10H12N5O10P2    53.950000              META:ADP
#
# [106 rows x 4 columns]

# %%
COMPARTMENT_MAP = {"c": "[c]", "p": "[p]", "e": "[p]"}  # vEcoli uses [p] for periplasmic uptake

# Some BiGG entries use MetaCyc generic IDs where EcoCyc has a species-specific frame ID.
# Extend as you spot mismatches.
METACYC_TO_ECOCYC = {
  "CPD-15815": "WATER",
  "CPD-16459": "Pi",
  "CPD-3": "AMMONIUM",  # nh4_c commonly
  "CPD0-1958": "L-ORNITHINE",
}

def to_vecoli_id(row):
  if not row["ecocyc_id"]:
      return None
  frame = row["ecocyc_id"].removeprefix("META:")
  frame = METACYC_TO_ECOCYC.get(frame, frame)
  comp_letter = row["bigg_id"].rsplit("_", 1)[-1]
  return f"{frame}{COMPARTMENT_MAP.get(comp_letter, '[c]')}"

df["vecoli_id"] = df.apply(to_vecoli_id, axis=1)
df["in_homeostatic"] = df["vecoli_id"].isin(metabolism.homeostatic_metabolites)

homeostatic_set = set(metabolism.homeostatic_metabolites)
df["in_homeostatic"] = df["vecoli_id"].isin(homeostatic_set)
print(f"matched {df['in_homeostatic'].sum()} / {len(df)}")
# Out:
# matched 70 / 106

# %%
df[["bigg_id", "ecocyc_id", "vecoli_id", "in_homeostatic"]]
# Out:
#      bigg_id             ecocyc_id           vecoli_id  in_homeostatic
# 13     atp_c              META:ATP              ATP[c]            True
# 42     h2o_c        META:CPD-15815            WATER[c]            True
# 38     gly_c              META:GLY              GLY[c]            True
# 8   ala__L_c  META:L-ALPHA-ALANINE  L-ALPHA-ALANINE[c]            True
# 48  leu__L_c              META:LEU              LEU[c]            True
# ..       ...                   ...                 ...             ...
# 15     btn_c           META:BIOTIN           BIOTIN[c]            True
# 86     ppi_c              META:PPI              PPI[c]            True
# 85      pi_c        META:CPD-16459               Pi[c]            True
# 43       h_c           META:PROTON           PROTON[c]            True
# 7      adp_c              META:ADP              ADP[c]            True
#
# [106 rows x 4 columns]

# %%
frame_to_full = {}
for h in metabolism.homeostatic_metabolites:
  frame_to_full.setdefault(h.rsplit("[", 1)[0], []).append(h)

misses = df[~df["in_homeostatic"] & df["ecocyc_id"].notna()]
for _, r in misses.iterrows():
  frame = r["ecocyc_id"].removeprefix("META:")
  print(f"{r['bigg_id']:<15} -> {frame:<25} candidates: {frame_to_full.get(frame, [])}")
# Out:
# glycogen_c      -> Glycogens                 candidates: []
# pe160_p         -> CPD-12819                 candidates: ['CPD-12819[c]']
# pe161_p         -> CPD-17086                 candidates: []
# nh4_c           -> AMMONIA                   candidates: []
# pe161_c         -> CPD-17086                 candidates: []
# colipa_e        -> CPD0-2271                 candidates: []
# fe3_c           -> FE+3                      candidates: ['FE+3[p]']
# murein4p4p_p    -> CPD0-2269                 candidates: []
# pg160_p         -> CPD-8260                  candidates: ['CPD-8260[c]']
# pg161_c         -> CPD0-2330                 candidates: []
# so4_c           -> HSO4                      candidates: []
# pg161_p         -> CPD0-2330                 candidates: []
# clpn160_p       -> CPD-12824                 candidates: ['CPD-12824[c]']
# clpn161_p       -> CPD-19674                 candidates: []
# pg181_c         -> CPD-18396                 candidates: []
# pg181_p         -> CPD-18396                 candidates: []
# clpn181_p       -> CPD-19675                 candidates: []
# cu2_c           -> CU+2                      candidates: []
# murein3px4p_p   -> CPD0-2273                 candidates: []
# 4fe4s_c         -> CPD-7                     candidates: []
# 10fthf_c        -> 10-FORMYL-THF             candidates: []
# adocbl_c        -> ADENOSYLCOBALAMIN         candidates: []
# hemeO_c         -> CPD-17063                 candidates: []
# 5mthf_c         -> 5-METHYL-THF              candidates: []
# udcpdp_c        -> CPD-9649                  candidates: []
# mobd_c          -> CPD-3                     candidates: []

# %%
fba_ids = set(df["vecoli_id"].dropna())
homeo_ids = set(metabolism.homeostatic_metabolites)

in_both      = fba_ids & homeo_ids
only_in_fba  = fba_ids - homeo_ids
only_in_homeo = homeo_ids - fba_ids
unmapped_from_fba = df[df["vecoli_id"].isna()]["bigg_id"].tolist()

print(f"in both: {len(in_both):>4}")
print(f"only in fba: {len(only_in_fba):>4}")
print(f"only in homeo: {len(only_in_homeo):>4}")
print(f"unmapped (no ecocyc_id from BiGG): {len(unmapped_from_fba)}")

print("\nBoth:")
print(sorted(in_both))
print("\nFBA:")
print(sorted(only_in_fba))
print("\nvEcoli homeostatic:")
print(sorted(only_in_homeo))
print("\nFBA unmapped (no ecocyc_id from BiGG):")
print(unmapped_from_fba)
# Out:
# in both:   70
# only in fba:   26
# only in homeo:  102
# unmapped (no ecocyc_id from BiGG): 10
#
# Both:
# ['ACETYL-COA[c]', 'ADP[c]', 'ARG[c]', 'ASN[c]', 'ATP[c]', 'BIOTIN[c]', 'CA+2[c]', 'CHORISMATE[c]', 'CL-[c]', 'CO+2[c]', 'CO-A[c]', 'CPD-12115[c]', 'CPD-12819[c]', 'CPD-8260[c]', 'CPD-9956[c]', 'CTP[c]', 'CYS[c]', 'DATP[c]', 'DCTP[c]', 'DGTP[c]', 'ENTEROBACTIN[c]', 'FAD[c]', 'FE+2[c]', 'GLN[c]', 'GLT[c]', 'GLUTATHIONE[c]', 'GLY[c]', 'GTP[c]', 'HIS[c]', 'ILE[c]', 'K+[c]', 'L-ALPHA-ALANINE[c]', 'L-ASPARTATE[c]', 'LEU[c]', 'LYS[c]', 'MALONYL-COA[c]', 'METHYLENE-THF[c]', 'MET[c]', 'MG+2[c]', 'MN+2[c]', 'NADH[c]', 'NADPH[c]', 'NADP[c]', 'NAD[c]', 'NI+2[c]', 'PHE[c]', 'PPI[c]', 'PROTOHEME[c]', 'PROTON[c]', 'PRO[c]', 'PUTRESCINE[c]', 'PYRIDOXAL_PHOSPHATE[c]', 'Pi[c]', 'REDUCED-MENAQUINONE[c]', 'RIBOFLAVIN[c]', 'S-ADENOSYLMETHIONINE[c]', 'SER[c]', 'SIROHEME[c]', 'SPERMIDINE[c]', 'SUC-COA[c]', 'THF[c]', 'THIAMINE-PYROPHOSPHATE[c]', 'THR[c]', 'TRP[c]', 'TTP[c]', 'TYR[c]', 'UTP[c]', 'VAL[c]', 'WATER[c]', 'ZN+2[c]']
#
# FBA:
# ['10-FORMYL-THF[c]', '5-METHYL-THF[c]', 'ADENOSYLCOBALAMIN[c]', 'AMMONIA[c]', 'AMMONIUM[c]', 'CPD-12819[p]', 'CPD-12824[p]', 'CPD-17063[c]', 'CPD-17086[c]', 'CPD-17086[p]', 'CPD-18396[c]', 'CPD-18396[p]', 'CPD-19674[p]', 'CPD-19675[p]', 'CPD-7[c]', 'CPD-8260[p]', 'CPD-9649[c]', 'CPD0-2269[p]', 'CPD0-2271[p]', 'CPD0-2273[p]', 'CPD0-2330[c]', 'CPD0-2330[p]', 'CU+2[c]', 'FE+3[c]', 'Glycogens[c]', 'HSO4[c]']
#
# vEcoli homeostatic:
# ['2-3-DIHYDROXYBENZOATE[c]', '2-KETOGLUTARATE[c]', '2-PG[c]', '2K-4CH3-PENTANOATE[c]', '4-AMINO-BUTYRATE[c]', '4-hydroxybenzoate[c]', 'ACETOACETYL-COA[c]', 'ACETYL-P[c]', 'ADENINE[c]', 'ADENOSINE[c]', 'ADP-D-GLUCOSE[c]', 'AMP[c]', 'ANTHRANILATE[c]', 'APS[c]', 'CA+2[p]', 'CAMP[c]', 'CARBAMYUL-L-ASPARTATE[c]', 'CARBON-DIOXIDE[c]', 'CDP[c]', 'CIS-ACONITATE[c]', 'CIT[c]', 'CMP[c]', 'CO+2[p]', 'CPD-12261[p]', 'CPD-12575[c]', 'CPD-12824[c]', 'CPD-13469[c]', 'CPD-2961[c]', 'CPD0-939[c]', 'CYTIDINE[c]', 'CYTOSINE[c]', 'D-ALA-D-ALA[c]', 'D-SEDOHEPTULOSE-7-P[c]', 'DAMP[c]', 'DEOXY-RIBOSE-5P[c]', 'DEOXYADENOSINE[c]', 'DEOXYGUANOSINE[c]', 'DGMP[c]', 'DI-H-OROTATE[c]', 'DIHYDROXY-ACETONE-PHOSPHATE[c]', 'DPG[c]', 'ERYTHROSE-4P[c]', 'FE+2[p]', 'FE+3[p]', 'FMN[c]', 'FRUCTOSE-16-DIPHOSPHATE[c]', 'FRUCTOSE-6P[c]', 'FUM[c]', 'G3P[c]', 'GDP[c]', 'GLC-6-P[c]', 'GLUCONATE[c]', 'GLYCERATE[c]', 'GLYCEROL-3P[c]', 'GMP[c]', 'GUANINE[c]', 'GUANOSINE[c]', 'HISTIDINOL[c]', 'HOMO-CYS[c]', 'HOMO-SER[c]', 'HYPOXANTHINE[c]', 'IMP[c]', 'INOSINE[c]', 'L-ARGININO-SUCCINATE[c]', 'L-CITRULLINE[c]', 'L-ORNITHINE[c]', 'L-SELENOCYSTEINE[c]', 'LL-DIAMINOPIMELATE[c]', 'MAL[c]', 'MN+2[p]', 'N-ACETYL-D-GLUCOSAMINE-1-P[c]', 'N-ALPHA-ACETYLORNITHINE[c]', 'NA+[p]', 'NI+2[p]', 'OROTATE[c]', 'OXALACETIC_ACID[c]', 'OXIDIZED-GLUTATHIONE[c]', 'OXYGEN-MOLECULE[p]', 'PANTOTHENATE[c]', 'PHENYL-PYRUVATE[c]', 'PHOSPHO-ENOL-PYRUVATE[c]', 'PROPIONYL-COA[c]', 'PRPP[c]', 'PYRUVATE[c]', 'Pi[p]', 'QUINOLINATE[c]', 'RIBOSE-1P[c]', 'RIBOSE-5P[c]', 'RIBULOSE-5P[c]', 'SHIKIMATE[c]', 'SUC[c]', 'TDP[c]', 'THREO-DS-ISO-CITRATE[c]', 'UDP-GLUCURONATE[c]', 'UDP-N-ACETYL-D-GLUCOSAMINE[c]', 'UDP[c]', 'UMP[c]', 'UNDECAPRENYL-DIPHOSPHATE[c]', 'URIDINE[c]', 'XYLULOSE-5-PHOSPHATE[c]', 'ZN+2[p]', 'glycogen-monomer[c]']
#
# FBA unmapped (no ecocyc_id from BiGG):
# ['pe181_p', 'murein4px4p_p', 'pe181_c', 'murein3p3p_p', 'murein4px4px4p_p', 'bmocogdp_c', '2fe2s_c', 'mococdp_c', 'mocogdp_c', 'lipopb_c']

# %%
# Bis(molybdopterin guanine dinucleotide)molybdenum
# [2Fe-2S] iron-sulfur cluster
