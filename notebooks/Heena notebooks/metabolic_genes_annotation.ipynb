# %%
import numpy as np
import plotly.express as px
import seaborn as sns
import pandas as pd
import os

os.chdir(os.path.expanduser('~/dev/vivarium-ecoli'))

import matplotlib.pyplot as plt
import dill
import requests
import xmltodict
from ecoli.processes.metabolism_redux import NetworkFlowModel, FlowResult, MetabolismRedux
# %matplotlib inline

FREE_RXNS = ["TRANS-RXN-145", "TRANS-RXN0-545", "TRANS-RXN0-474"]

sns.set(style='darkgrid', palette='viridis', context='talk')

# %%
notebook_path = f'notebooks/Heena notebooks/'
df_WCM_gene = pd.read_csv(notebook_path + 'WCM gene.csv')
df_WCM_rxn = pd.read_csv(notebook_path + 'new metabolic reactions.csv')

df_WCM_gene.iloc[200:206,:]
# df_WCM_rxn.head(10)
# Out:
#     Gene ID (EcoCyc) Gene locus ID Gene name RNA type  \
# 200          EG11624         b0864      artP     mRNA
# 201          EG11626         b0862      artQ     mRNA
# 202          EG10085         b2716      ascB     mRNA
# 203          EG10086         b2715      ascF     mRNA
# 204          EG10087         b2714      ascG     mRNA
# 205          EG10088         b3433       asd     mRNA
#
#                      Category  Macklin et al. (2020)  \
# 200                Metabolism                   True
# 201                Metabolism                   True
# 202          Unknown function                  False
# 203                Metabolism                  False
# 204  Transcription regulation                  False
# 205                Metabolism                   True
#
#      Latest version (20220602) Machinery (from column E) Implemented? Comment
# 200                       True                                    NaN     NaN
# 201                       True                                    NaN     NaN
# 202                       True                                    NaN     NaN
# 203                       True                                    NaN     NaN
# 204                      False                                    NaN     NaN
# 205                       True                                    NaN     NaN

# %%
print(df_WCM_gene.shape)
print(df_WCM_rxn.shape)
# Out:
# (4736, 9)
# (4736, 14)

# %%
df_WCM_gene_metabolism = df_WCM_gene[(df_WCM_gene.Category == "Metabolism") & (df_WCM_gene["Macklin et al. (2020)"] == False) & \
                          (df_WCM_gene["Latest version (20220602)"] == True)]
df_WCM_rxn_metabolism  = df_WCM_rxn[(df_WCM_rxn.Category == "Metabolism") & (df_WCM_rxn["Macklin et al. (2020)"] == False) & \
                          (df_WCM_rxn["Latest version (20220602)"] == True) & (df_WCM_rxn["Belongs in metabolism"] != "no")]

# %%
print(df_WCM_gene_metabolism.shape)
print(df_WCM_rxn_metabolism.shape)
# They share the same metabolism genes, the only difference between the two dataframes are the features
# Out:
# (306, 9)
# (306, 14)

# %%
np.all(df_WCM_gene_metabolism["Gene ID (EcoCyc)"].isin(df_WCM_rxn_metabolism["Gene ID (EcoCyc)"]))
# Out:
# True

# %%
df_WCM_gene_metabolism.head(20)
# Out:
#     Gene ID (EcoCyc) Gene locus ID Gene name RNA type    Category  \
# 20           EG10022         b4015      aceA     mRNA  Metabolism
# 21           EG10023         b4014      aceB     mRNA  Metabolism
# 42           EG11942         b4067      actP     mRNA  Metabolism
# 47           EG11724         b3714      adeP     mRNA  Metabolism
# 52           EG12462         b4115      adiC     mRNA  Metabolism
# 57           EG11101         b0476       aes     mRNA  Metabolism
# 66             G7634         b3136      agaS     mRNA  Metabolism
# 69           EG10033         b1002       agp     mRNA  Metabolism
# 72           EG11384         b0605      ahpC     mRNA  Metabolism
# 91             G6275         b0505      allA     mRNA  Metabolism
# 94             G6286         b0517      allD     mRNA  Metabolism
# 114          EG10041         b0110      ampD     mRNA  Metabolism
# 120            G6880         b1640      anmK     mRNA  Metabolism
# 159          EG11159         b2923      argO     mRNA  Metabolism
# 203          EG10086         b2715      ascF     mRNA  Metabolism
# 234          EG11671         b2223      atoE     mRNA  Metabolism
# 259          EG11665         b3057      bacA     mRNA  Metabolism
# 272          EG10108         b2480       bcp     mRNA  Metabolism
# 293             G495         b2901      bglA     mRNA  Metabolism
# 294          EG10114         b3721      bglB     mRNA  Metabolism
#
#      Macklin et al. (2020)  Latest version (20220602)  \
# 20                   False                       True
# 21                   False                       True
# 42                   False                       True
# 47                   False                       True
# 52                   False                       True
# 57                   False                       True
# 66                   False                       True
# 69                   False                       True
# 72                   False                       True
# 91                   False                       True
# 94                   False                       True
# 114                  False                       True
# 120                  False                       True
# 159                  False                       True
# 203                  False                       True
# 234                  False                       True
# 259                  False                       True
# 272                  False                       True
# 293                  False                       True
# 294                  False                       True
#
#     Machinery (from column E) Implemented? Comment
# 20                                     NaN     NaN
# 21                                     NaN     NaN
# 42                                     NaN     NaN
# 47                                     NaN     NaN
# 52                                     NaN     NaN
# 57                                     NaN     NaN
# 66                                     NaN     NaN
# 69                                     NaN     NaN
# 72                                     NaN     NaN
# 91                                     NaN     NaN
# 94                                     NaN     NaN
# 114                                    NaN     NaN
# 120                                    NaN     NaN
# 159                                    NaN     NaN
# 203                                    NaN     NaN
# 234                                    NaN     NaN
# 259                                    NaN     NaN
# 272                                    NaN     NaN
# 293                                    NaN     NaN
# 294                                    NaN     NaN

# %% [markdown]
# ## Connect to EcoCyc to allocate descriptions to each metabolic gene

# %%
# Connect to Ecocyc API
s = requests.Session() # create session
# Post login credentials to session:
s.post('https://websvc.biocyc.org/credentials/login/', data={'email':'cellulararchitect@protonmail.com', 'password':'Cellman0451'})
# Out:
# <Response [200]>

# %%
from tqdm import tqdm
import sys
# Add Multi-Func Term from Ecocyc for each metabolic gene in the rxn dataframe
metabolic_genes = df_WCM_rxn_metabolism["Gene ID (EcoCyc)"]
multifunction_id = []
pathways = []
pathways_parent = []
enzymes = []
products = []
reactions = []

for gene in tqdm(metabolic_genes):
    req_func = f"https://websvc.biocyc.org/getxml?id=ECOLI:{gene}&detail=full"
    req_path = f"https://websvc.biocyc.org/apixml?fn=pathways-of-gene&id=ECOLI:{gene}&detail=full"
    req_enzm = f"https://websvc.biocyc.org/apixml?fn=enzymes-of-gene&id=ECOLI:{gene}&detail=full"
    req_rxns = f"https://websvc.biocyc.org/apixml?fn=reactions-of-gene&id=ECOLI:{gene}&detail=full"
    
    # response_func = s.get(req_func)
    # response_path = s.get(req_path)
    # response_enzm = s.get(req_enzm)
    response_rxns = s.get(req_rxns)
    
    if response_path.status_code != 200:
        sys.exit()
        
    output = xmltodict.parse(response_func.content)['ptools-xml']['Gene'] # can also get product of the gene from this request
    output_path = xmltodict.parse(response_path.content)['ptools-xml']
    output_enzyme = xmltodict.parse(response_enzm.content)['ptools-xml']
    output_rxns = xmltodict.parse(response_rxns.content)['ptools-xml']
    
    # # parse through output for MultiFun ID
    # if isinstance(output['parent'], list):
    #     output_parent = output['parent']
    #     multifun_id_arr = []
    #     for parent in output_parent:
    #         multifun_id_arr.append(parent['Gene']['@frameid'])
    #     multifunction_id.append(multifun_id_arr)
    # else:
    #     multifunction_id.append(output['parent']['Gene']['@frameid'])

    # # parse through output for product

    # if isinstance(output['product']['Protein'], list):
    #     # import ipdb; ipdb.set_trace()
    #     output = output['product']['Protein']
    #     product_arr = []
    #     for product in output:
    #         product_arr.append(product['@frameid'])
    #     products.append(product_arr)
    # else:
    #     products.append(output['product']['Protein']['@frameid'])

    
    # # parse through output for pathway <- gene
    # if "Pathway" in output_path.keys():
    #     output = output_path['Pathway']       
    #     if isinstance(output, list):
    #         pathway_arr = []
    #         pathways_parent_arr = []
    #         for pathway in output:
    #             pathway_arr.append(pathway['@frameid'])      
    #             if isinstance(pathway['parent'], list):
    #                 for parent in pathway['parent']:
    #                     # import ipdb ;ipdb.set_trace()
    #                     pathways_parent_arr.append(parent['Pathway']['@frameid'])
    #             else:
    #                 # if gene == "EG10130": import ipdb; ipdb.set_trace()
    #                 pathways_parent_arr.append(pathway['parent']['Pathway']['@frameid'])
    #         pathways.append(pathway_arr)
    #         pathways_parent.append(pathways_parent_arr)
    #     else:
    #         pathways.append(output['@frameid'])
    #         if isinstance(output['parent'], list):
    #             pathways_parent_arr = []
    #             for parent in output['parent']:
    #                 # import ipdb ;ipdb.set_trace()
    #                 pathways_parent_arr.append(parent['Pathway']['@frameid'])
    #             pathways_parent.append(pathways_parent_arr)
    #         else:
    #             pathways_parent.append(output['parent']['Pathway']['@frameid'])
    # else:
    #     pathways.append(np.nan)
    #     pathways_parent.append(np.nan)

    
    # # parse through output for enzyme <- gene
    # if "Protein" in output_enzyme.keys():
    #     if isinstance(output_enzyme['Protein'], list):
    #         enzyme_arr = []
    #         for protein in output_enzyme['Protein']:
    #             enzyme_arr.append(protein['@frameid'])
    #         enzymes.append(enzyme_arr)
    #     else:
    #         enzymes.append(output_enzyme['Protein']['@frameid'])
    # else:
    #     enzymes.append(np.nan)

    # parse through output for rxns <- gene
    if "Reaction" in output_rxns.keys():
        if isinstance(output_rxns['Reaction'], list):
            reactions_arr = []
            for rxn in output_rxns['Reaction']:
                reactions_arr.append(rxn['@frameid'])
            reactions.append(reactions_arr)
        else:
            reactions.append([output_rxns['Reaction']['@frameid'],])
    else:
        reactions.append(np.nan)
# Out:
# 100%|█████████████████████████████████████████| 306/306 [00:35<00:00,  8.59it/s]

# %%
fun = "reactions-of-gene"
gene = "EG10041"
req = f"https://websvc.biocyc.org/apixml?fn={fun}&id=ECOLI:{gene}&detail=full"
response_func = s.get(req)
output_path = xmltodict.parse(response_func.content)['ptools-xml']['Reaction']

# %%
from IPython.display import display, HTML
def get_multifunc_output(function_id):
    req_func = f"https://websvc.biocyc.org/getxml?id=ECOLI:{function_id}&detail=full"
    response_func = s.get(req_func)
    output = xmltodict.parse(response_func.content)['ptools-xml']['Gene']

    parent = output['parent']['Gene']['@frameid']
    common_name = output['common-name']['#text']
    return parent, common_name

def pretty_print(df):
    return display(HTML(df.to_html().replace("\\n","<br>")))

# %%
# parse through the multifunction id to get multifunction name
# or I can try getting the unique funcs of all multifunction and request multifunction name and map them back
# instead of parsing through a bigger loop. But no biggy, the dataframe isn't that huge. 

multifunction_name = []
for multifunction in tqdm(multifunction_id):
    if isinstance(multifunction, tuple):
        multifunction_name_str = ""
        for function in multifunction:
            parent, common_name = get_multifunc_output(function)
            while parent != 'MultiFun' and common_name != "UNCLASSIFIED":
                parent, common_name_ = get_multifunc_output(parent)
                common_name = common_name_ + " -> " + common_name
            multifunction_name_str = multifunction_name_str + common_name + '\n'
            
        multifunction_name.append(multifunction_name_str)
    else:
        parent, common_name = get_multifunc_output(multifunction)
        # multifunction_name.append(common_name)
        # if multifunction = 'Unclassified-Genes': import ipdb; ipdb.set_trace()
        while parent != 'MultiFun' and common_name != "UNCLASSIFIED":
            parent, common_name_ = get_multifunc_output(parent)
            common_name = common_name_ + " -> " + common_name
        multifunction_name.append(common_name)
# Out:
# 100%|█████████████████████████████████████████| 306/306 [02:18<00:00,  2.21it/s]

# %%
multifunction_name = []
for multifunction in tqdm(multifunction_id):
    if isinstance(multifunction, list):
        multifunction_name_list = []  # Use a list to store multiple functions
        for function in multifunction:
            parent, common_name = get_multifunc_output(function)
            while parent != 'MultiFun' and common_name != "UNCLASSIFIED":
                parent, common_name_ = get_multifunc_output(parent)
                common_name = common_name_ + " -> " + common_name
            multifunction_name_list.append(common_name)  
            
        multifunction_name.append(multifunction_name_list)  # Append the list for each multifunction
    else:
        parent, common_name = get_multifunc_output(multifunction)
        multifunction_name_list = []  # Use a list for single function cases
        while parent != 'MultiFun' and common_name != "UNCLASSIFIED":
            parent, common_name_ = get_multifunc_output(parent)
            common_name = common_name_ + " -> " + common_name
        multifunction_name_list.append(common_name)
        multifunction_name.append(multifunction_name_list)
# Out:
# 100%|█████████████████████████████████████████| 306/306 [02:53<00:00,  1.76it/s]

# %% [markdown]
# ## Visualization

# %%
import csv
# create new dataframe
df_metabolic_gene_annotation = df_WCM_gene_metabolism.iloc[:,:3]
df_metabolic_gene_annotation["Enzyme encoded"] = enzymes
df_metabolic_gene_annotation["Pathways"] = pathways
df_metabolic_gene_annotation["Pathways parent"] = pathways_parent
df_metabolic_gene_annotation["Protein products"] = products
df_metabolic_gene_annotation["MultiFuntional ID"] = multifunction_id
df_metabolic_gene_annotation["MultiFuntional name"] = multifunction_name
df_metabolic_gene_annotation["Reactions"] = reactions
df_metabolic_gene_annotation["Description by Cyrus"] = df_WCM_rxn_metabolism.iloc[:,7]

# pretty_print(df_metabolic_gene_annotation)
df_metabolic_gene_annotation.to_csv('notebooks/Heena notebooks/metabolic_gene_annotation.csv', index=False)
df_metabolic_gene_annotation.to_csv('notebooks/Heena notebooks/metabolic_gene_annotation.tsv', sep="\t", quoting=csv.QUOTE_NONNUMERIC, index=False)
pretty_print(df_metabolic_gene_annotation.head(10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gene ID (EcoCyc)</th>
#       <th>Gene locus ID</th>
#       <th>Gene name</th>
#       <th>Enzyme encoded</th>
#       <th>Pathways</th>
#       <th>Pathways parent</th>
#       <th>Protein products</th>
#       <th>MultiFuntional ID</th>
#       <th>MultiFuntional name</th>
#       <th>Reactions</th>
#       <th>Description by Cyrus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>20</th>
#       <td>EG10022</td>
#       <td>b4015</td>
#       <td>aceA</td>
#       <td>ISOCIT-LYASE</td>
#       <td>GLYOXYLATE-BYPASS</td>
#       <td>Energy-Metabolism</td>
#       <td>ISOCIT-LYASE-MONOMER</td>
#       <td>BC-1.7.2</td>
#       <td>[metabolism -&gt; central intermediary metabolism -&gt; glyoxylate bypass]</td>
#       <td>ISOCIT-CLEAV-RXN</td>
#       <td>acetate transport + metabolism</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>EG10023</td>
#       <td>b4014</td>
#       <td>aceB</td>
#       <td>MALATE-SYNTHASE</td>
#       <td>GLYOXYLATE-BYPASS</td>
#       <td>Energy-Metabolism</td>
#       <td>MALATE-SYNTHASE</td>
#       <td>BC-1.7.2</td>
#       <td>[metabolism -&gt; central intermediary metabolism -&gt; glyoxylate bypass]</td>
#       <td>MALSYN-RXN</td>
#       <td>acetate transport + metabolism</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>EG11942</td>
#       <td>b4067</td>
#       <td>actP</td>
#       <td>CPLX0-7955</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>YJCG-MONOMER</td>
#       <td>[BC-4.2.A, BC-6.1]</td>
#       <td>[transport -&gt; Electrochemical potential driven transporters -&gt; Porters (Uni-, Sym- and Antiporters), cell structure -&gt; membrane]</td>
#       <td>[RXN0-1981, RXN0-5111, TRANS-RXN0-576]</td>
#       <td>acetate transport + metabolism</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>EG11724</td>
#       <td>b3714</td>
#       <td>adeP</td>
#       <td>EG11724-MONOMER</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>EG11724-MONOMER</td>
#       <td>BC-4.2.A</td>
#       <td>[transport -&gt; Electrochemical potential driven transporters -&gt; Porters (Uni-, Sym- and Antiporters)]</td>
#       <td>TRANS-RXN0-447</td>
#       <td>adenine transport</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>EG12462</td>
#       <td>b4115</td>
#       <td>adiC</td>
#       <td>CPLX0-7535</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>YJDE-MONOMER</td>
#       <td>[BC-4.2.A, BC-6.1]</td>
#       <td>[transport -&gt; Electrochemical potential driven transporters -&gt; Porters (Uni-, Sym- and Antiporters), cell structure -&gt; membrane]</td>
#       <td>RXN0-2162</td>
#       <td>transport, acid resistance</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>EG11101</td>
#       <td>b0476</td>
#       <td>aes</td>
#       <td>CPLX0-8033</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>EG11101-MONOMER</td>
#       <td>BC-1.1.1</td>
#       <td>[metabolism -&gt; carbon utilization -&gt; carbon compounds]</td>
#       <td>ACETYLESTERASE-RXN</td>
#       <td>general fatty acid degradation</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>G7634</td>
#       <td>b3136</td>
#       <td>agaS</td>
#       <td>G7634-MONOMER</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>G7634-MONOMER</td>
#       <td>BC-1.1</td>
#       <td>[metabolism -&gt; carbon utilization]</td>
#       <td>RXN-13548</td>
#       <td>enzyme, only in some strains</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>EG10033</td>
#       <td>b1002</td>
#       <td>agp</td>
#       <td>GLUCOSE-1-PHOSPHAT-CPLX</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>GLUCOSE-1-PHOSPHAT-MONOMER</td>
#       <td>BC-1.7.9</td>
#       <td>[metabolism -&gt; central intermediary metabolism -&gt; misc. glucose metabolism]</td>
#       <td>[GLUCOSE-1-PHOSPHAT-RXN, RXN0-1001]</td>
#       <td>periplasmic phosphatase to import g6p</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>EG11384</td>
#       <td>b0605</td>
#       <td>ahpC</td>
#       <td>CPLX0-245</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>EG11384-MONOMER</td>
#       <td>BC-5.6.2</td>
#       <td>[cell processes -&gt; protection -&gt; detoxification]</td>
#       <td>[R4-RXN, RXN-19953, RXN-19954, RXN-20692, RXN-20691]</td>
#       <td>general peroxidase</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>G6275</td>
#       <td>b0505</td>
#       <td>allA</td>
#       <td>G6275-MONOMER</td>
#       <td>PWY-5705</td>
#       <td>[Allantoin-degradation, Super-Pathways]</td>
#       <td>G6275-MONOMER</td>
#       <td>[BC-1.7.26, BC-1.8.3]</td>
#       <td>[metabolism -&gt; central intermediary metabolism -&gt; allantoin assimilation, metabolism -&gt; metabolism of other compounds -&gt; nitrogen metabolism]</td>
#       <td>UREIDOGLYCOLATE-LYASE-RXN</td>
#       <td>allantoin purine utilization nitrogen source</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head()
# Out:
#                                                    0
# 0  metabolism -> central intermediary metabolism ...
# 1  metabolism -> central intermediary metabolism ...
# 2  transport -> Electrochemical potential driven ...
# 3  transport -> Electrochemical potential driven ...
# 4  transport -> Electrochemical potential driven ...

# %%
# Sample dataframe with multiple pathways
data = df_metabolic_gene_annotation["MultiFuntional name"]

# Function to split functional terms into individual pathways and then split those pathways into components
def split_terms(term):
    pathways = term.split('\n')  # Split by newline first
    split_data = []
    for pathway in pathways:
        parts = pathway.split('->')
        split_data.extend(['->'.join(parts[:i+1]) for i in range(len(parts))])
    return split_data

# Create a new dataframe to hold split terms
split_data = []

for term in data:
    split_data.extend([{'id': split_term, 'parent': '->'.join(split_term.split('->')[:-1])} 
                       for split_term in split_terms(term)])

# %%
# Convert to a dataframe
df_split = pd.DataFrame(split_data)

# Count occurrences of each term
df_split_count = df_split.groupby(['id', 'parent']).size().reset_index(name='count')

# Plot the sunburst chart
fig = px.sunburst(
    df_split_count,
    names='id',
    parents='parent',
    values='count',
    title='Hierarchical Functional Terms',
)

# Save the figure as an HTML file
fig.write_html("notebooks/Heena notebooks/sunburst_chart.html")

# %% [markdown]
# # Scratch

# %%
df_metabolic_gene_annotation.head()
# Out:
#    Gene ID (EcoCyc) Gene locus ID Gene name   Enzyme encoded  \
# 20          EG10022         b4015      aceA     ISOCIT-LYASE
# 21          EG10023         b4014      aceB  MALATE-SYNTHASE
# 42          EG11942         b4067      actP       CPLX0-7955
# 47          EG11724         b3714      adeP  EG11724-MONOMER
# 52          EG12462         b4115      adiC       CPLX0-7535
#
#              Pathways    Pathways parent      Protein products  \
# 20  GLYOXYLATE-BYPASS  Energy-Metabolism  ISOCIT-LYASE-MONOMER
# 21  GLYOXYLATE-BYPASS  Energy-Metabolism       MALATE-SYNTHASE
# 42                NaN                NaN          YJCG-MONOMER
# 47                NaN                NaN       EG11724-MONOMER
# 52                NaN                NaN          YJDE-MONOMER
#
#      MultiFuntional ID                                MultiFuntional name  \
# 20            BC-1.7.2  [metabolism -> central intermediary metabolism...
# 21            BC-1.7.2  [metabolism -> central intermediary metabolism...
# 42  [BC-4.2.A, BC-6.1]  [transport -> Electrochemical potential driven...
# 47            BC-4.2.A  [transport -> Electrochemical potential driven...
# 52  [BC-4.2.A, BC-6.1]  [transport -> Electrochemical potential driven...
#
#                                  Reactions            Description by Cyrus
# 20                        ISOCIT-CLEAV-RXN  acetate transport + metabolism
# 21                              MALSYN-RXN  acetate transport + metabolism
# 42  [RXN0-1981, RXN0-5111, TRANS-RXN0-576]  acetate transport + metabolism
# 47                          TRANS-RXN0-447               adenine transport
# 52                               RXN0-2162      transport, acid resistance

# %%
df_metabolic_gene_annotation.to_csv('notebooks/Heena notebooks/metabolic_gene_annotation.csv', index=False)

# %%
NOTEBOOK_DIR = f'notebooks/Heena notebooks/'
metabolic_gene_annotation = pd.read_csv(os.path.join(NOTEBOOK_DIR, "metabolic_gene_annotation.csv"))

# %%
import ast
def string_to_list(s):
    try:
        return np.array(ast.literal_eval(s))  # Safely convert string to list
    except (ValueError, SyntaxError):
        return np.array(s)  # Return as-is if conversion fails (e.g., NaN values)

metabolic_gene_annotation = pd.read_csv(os.path.join(NOTEBOOK_DIR, "metabolic_gene_annotation.csv"), converters={'Reactions': string_to_list})

# %%
temp = metabolic_gene_annotation['Reactions'].to_numpy()
temp
# Out:
# array([array('ISOCIT-CLEAV-RXN', dtype='<U16'),
#        array('MALSYN-RXN', dtype='<U10'),
#        array(['RXN0-1981', 'RXN0-5111', 'TRANS-RXN0-576'], dtype='<U14'),
#        array('TRANS-RXN0-447', dtype='<U14'),
#        array('RXN0-2162', dtype='<U9'),
#        array('ACETYLESTERASE-RXN', dtype='<U18'),
#        array('RXN-13548', dtype='<U9'),
#        array(['GLUCOSE-1-PHOSPHAT-RXN', 'RXN0-1001'], dtype='<U22'),
#        array(['R4-RXN', 'RXN-19953', 'RXN-19954', 'RXN-20692', 'RXN-20691'],
#              dtype='<U9')                                                   ,
#        array('UREIDOGLYCOLATE-LYASE-RXN', dtype='<U25'),
#        array('RXN0-7024', dtype='<U9'), array('RXN0-5225', dtype='<U9'),
#        array('RXN0-4621', dtype='<U9'),
#        array(['RXN66-448', 'TRANS-RXN-325'], dtype='<U13'),
#        array(['TRANS-RXN-155', 'TRANS-RXN-153A', 'TRANS-RXN-153'], dtype='<U14'),
#        array('TRANS-RXN0-281', dtype='<U14'),
#        array(['UNDECAPRENYL-DIPHOSPHATASE-RXN', 'RXN-11776'], dtype='<U30'),
#        array(['1.11.1.15-RXN', 'RXN-19953', 'RXN-19954', 'RXN0-5468'],
#              dtype='<U13')                                            ,
#        array(['RXN0-5295', 'RXN0-6994'], dtype='<U9'),
#        array(['RXN0-5297', 'RXN0-5295', '6-PHOSPHO-BETA-GLUCOSIDASE-RXN'],
#              dtype='<U30')                                                ,
#        array(['RXN-24169', 'RXN-24170', 'RXN-14722', 'BETAGALACTOSID-RXN'],
#              dtype='<U18')                                                 ,
#        array(['RXN0-1565', 'TRANS-RXN0-283'], dtype='<U14'),
#        array(['ABC-5-RXN', 'TRANS-RXN-296'], dtype='<U13'),
#        array(['ABC-5-RXN', 'TRANS-RXN-296'], dtype='<U13'),
#        array(['BTUR2-RXN', 'RXN-19342', 'RXN-19343', 'COBALADENOSYLTRANS-RXN'],
#              dtype='<U22')                                                     ,
#        array('CROBETREDUCT-RXN', dtype='<U16'),
#        array('RXN0-3601', dtype='<U9'),
#        array('LCARNCOALIG-RXN', dtype='<U15'),
#        array('CARNDETRU-RXN', dtype='<U13'),
#        array('TRANS-RXN-100', dtype='<U13'),
#        array('RXN-21408', dtype='<U9'), array('RXN-21408', dtype='<U9'),
#        array('RXN-21407', dtype='<U9'), array('RXN-21407', dtype='<U9'),
#        array('RXN-21407', dtype='<U9'),
#        array(['RXN-21423', 'RXN0-7454'], dtype='<U9'),
#        array(['RXN-21421', 'RXN-21424', 'RXN-21425'], dtype='<U9'),
#        array('RXN-21422', dtype='<U9'),
#        array('2.1.1.79-RXN', dtype='<U12'),
#        array(['TRANS-RXN-155B', 'TRANS-RXN-155'], dtype='<U14'),
#        array(['TRANS-RXN-155B', 'TRANS-RXN-155'], dtype='<U14'),
#        array(['TRANS-RXN-155B', 'TRANS-RXN-155'], dtype='<U14'),
#        array(['RXN0-7392', '6-PHOSPHO-BETA-GLUCOSIDASE-RXN'], dtype='<U30'),
#        array('2.7.8.25-RXN', dtype='<U12'),
#        array('TRANS-RXN0-201', dtype='<U14'),
#        array('2.7.7.61-RXN', dtype='<U12'),
#        array('RXN0-2501', dtype='<U9'),
#        array(['RXN-8770', 'RXN-16788'], dtype='<U9'),
#        array('TRANS-RXN-116', dtype='<U13'),
#        array(['CYCPHOSDIESTER-RXN', '3-NUCLEOTID-RXN', 'RXN-14115', 'RXN-14126',
#               'RXN-14124', 'RXN-14090', 'RXN-14113', 'RXN-14112', 'RXN-14091',
#               'RXN-14064'], dtype='<U18')                                       ,
#        array(['RXN0-6677', 'RXN0-6676'], dtype='<U9'),
#        array(['TRANS-RXN0-280', 'TRANS-RXN-90'], dtype='<U14'),
#        array(['TRANS-RXN0-280', 'TRANS-RXN-90'], dtype='<U14'),
#        array(['TRANS-RXN0-280', 'TRANS-RXN-90'], dtype='<U14'),
#        array('RXN-20148', dtype='<U9'), array('R524-RXN', dtype='<U8'),
#        array('TRANS-RXN-14', dtype='<U12'),
#        array(['RXN-16649', 'BETA-LACTAMASE-RXN', '3.4.17.8-RXN', 'RXN-19249',
#               'RXN-19253'], dtype='<U18')                                    ,
#        array(['RXN-16649', 'RXN0-3461'], dtype='<U9'),
#        array(['RXN-16649', 'RXN-19249', '3.4.17.8-RXN', 'RXN-19256'],
#              dtype='<U12')                                           ,
#        array(['RXN-16649', 'BETA-LACTAMASE-RXN', 'RXN-19249', 'RXN-19253'],
#              dtype='<U18')                                                 ,
#        array(['TRANS-RXN-300', 'TRANS-RXN-106', 'TRANS-RXN-299'], dtype='<U13'),
#        array('RXN0-5359', dtype='<U9'),
#        array('GALACTONDEHYDRAT-RXN', dtype='<U20'),
#        array('DEHYDDEOXGALACTKIN-RXN', dtype='<U22'),
#        array('TRANS-RXN-16', dtype='<U12'),
#        array('RXN0-5359', dtype='<U9'), array('RXN0-4181', dtype='<U9'),
#        array('TRANS-RXN0-495', dtype='<U14'),
#        array(['RXN0-7105', 'RXN0-7046'], dtype='<U9'),
#        array('TRANS-RXN0-496', dtype='<U14'),
#        array('ACETALD-DEHYDROG-RXN', dtype='<U20'),
#        array(['RXN0-1565', 'TRANS-RXN0-283', 'RXN0-1682', 'RXN0-1701',
#               'RXN0-1684', 'RXN0-1702', 'RXN0-1721', 'TRANS-RXN0-629'],
#              dtype='<U14')                                             ,
#        array(['RXN0-1565', 'TRANS-RXN0-283', 'RXN0-1682', 'RXN0-1701',
#               'RXN0-1684', 'RXN0-1702', 'RXN0-1721', 'TRANS-RXN0-629'],
#              dtype='<U14')                                             ,
#        array('DIENOYLCOAREDUCT-RXN', dtype='<U20'),
#        array(['1.1.1.271-RXN', 'FCLEPIM-RXN', 'FCLREDUCT-RXN'], dtype='<U13'),
#        array('RXN0-1684', dtype='<U9'), array('ABC-9-RXN', dtype='<U9'),
#        array('ABC-9-RXN', dtype='<U9'), array('ABC-9-RXN', dtype='<U9'),
#        array('ABC-9-RXN', dtype='<U9'), array('RXN0-1682', dtype='<U9'),
#        array('ABC-10-RXN', dtype='<U10'),
#        array('ABC-10-RXN', dtype='<U10'),
#        array('ABC-10-RXN', dtype='<U10'),
#        array('ABC-10-RXN', dtype='<U10'), array('RXN0-1701', dtype='<U9'),
#        array(['ABC-11-RXN', 'TRANS-RXN-297', 'TRANS-RXN-298'], dtype='<U13'),
#        array(['ABC-11-RXN', 'TRANS-RXN-297', 'TRANS-RXN-298'], dtype='<U13'),
#        array(['ABC-11-RXN', 'TRANS-RXN-297', 'TRANS-RXN-298'], dtype='<U13'),
#        array('RXN0-1702', dtype='<U9'), array('RXN0-1721', dtype='<U9'),
#        array('TRANS-RXN-1', dtype='<U11'),
#        array(['TRANS-RXN0-418', 'TRANS-RXN0-417'], dtype='<U14'),
#        array(['TRANS-RXN0-582', 'TRANS-RXN0-618', 'TRANS-RXN-158'], dtype='<U14'),
#        array(['TRANS-RXN0-582', 'TRANS-RXN0-618', 'TRANS-RXN-158'], dtype='<U14'),
#        array('1PFRUCTPHOSN-RXN', dtype='<U16'),
#        array('GALACTARDEHYDRA-RXN', dtype='<U19'),
#        array(['TRANS-RXN0-204', 'TRANS-RXN0-203', 'TRANS-RXN0-523'], dtype='<U14'),
#        array('RXN-16659', dtype='<U9'),
#        array('GLUC1PURIDYLTRANS-RXN', dtype='<U21'),
#        array('MALSYN-RXN', dtype='<U10'),
#        array('TRANS-RXN-22', dtype='<U12'),
#        array('RXN0-6373', dtype='<U9'),
#        array('TRANS-RXN-122', dtype='<U13'),
#        array('TRANS-RXN0-209', dtype='<U14'),
#        array('TRANS-RXN0-209', dtype='<U14'),
#        array('GDPMANDEHYDRA-RXN', dtype='<U17'),
#        array(['GDPMANMANHYDRO-RXN', 'GDP-GLUCOSIDASE-RXN'], dtype='<U19'),
#        array(['GLUCARDEHYDRA-RXN', 'RXN0-5285'], dtype='<U17'),
#        array(['TRANS-RXN0-204', 'TRANS-RXN0-203', 'TRANS-RXN0-523'], dtype='<U14'),
#        array('GPH-RXN', dtype='<U7'),
#        array(['PRODISULFREDUCT-RXN', 'RXN0-7271', 'RXN-19629', 'RXN-18586'],
#              dtype='<U19')                                                  ,
#        array(['PRODISULFREDUCT-RXN', 'RXN0-7271'], dtype='<U19'),
#        array(['RXN-12071', 'PHENPRODIOLDEHYDROG-RXN'], dtype='<U23'),
#        array(['RXN-12072', 'HCAMULTI-RXN'], dtype='<U12'),
#        array(['RXN-12072', 'HCAMULTI-RXN'], dtype='<U12'),
#        array(['RXN-12072', 'HCAMULTI-RXN'], dtype='<U12'),
#        array(['RXN-12072', 'HCAMULTI-RXN'], dtype='<U12'),
#        array('TRANS-RXN0-282', dtype='<U14'),
#        array(['RXN0-5256', 'RXN-16420'], dtype='<U9'),
#        array(['RXN0-5256', 'RXN-16420'], dtype='<U9'),
#        array('HYDROXYLAMINE-REDUCTASE-RXN', dtype='<U27'),
#        array('RXN0-307', dtype='<U8'),
#        array('PROTOHEMEFERROCHELAT-RXN', dtype='<U24'),
#        array(['R621-RXN', '1.5.1.34-RXN'], dtype='<U12'),
#        array(['SORBITOL-6-PHOSPHATASE-RXN', 'MANNITOL-1-PHOSPHATASE-RXN',
#               '3.1.3.68-RXN'], dtype='<U26')                             ,
#        array(['RXN0-5256', 'RXN-16420'], dtype='<U9'),
#        array('RXN0-7399', dtype='<U9'), array('RXN0-7399', dtype='<U9'),
#        array('RXN0-7399', dtype='<U9'), array('RXN0-7399', dtype='<U9'),
#        array(['TRANS-RXN0-228', 'TRANS-RXN0-209', 'TRANS-RXN-181A'], dtype='<U14'),
#        array('TRANS-RXN-113', dtype='<U13'),
#        array('TRANS-RXN-23', dtype='<U12'),
#        array('RXN-14381', dtype='<U9'), array('RXN0-5229', dtype='<U9'),
#        array('TRANS-RXN0-227', dtype='<U14'),
#        array(['RXN0-1741', 'RXN0-1804'], dtype='<U9'),
#        array(['RXN0-5227', 'RXN0-2061'], dtype='<U9'),
#        array('RXN0-5401', dtype='<U9'), array('RXN-16660', dtype='<U9'),
#        array(['ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503'], dtype='<U14'),
#        array(['ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503'], dtype='<U14'),
#        array(['TRANS-RXN-294', 'TRANS-RXN-295', 'TRANS-RXN-387'], dtype='<U13'),
#        array(['ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503'], dtype='<U14'),
#        array(['ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503'], dtype='<U14'),
#        array(['TRANS-RXN0-575', 'TRANS-RXN0-574'], dtype='<U14'),
#        array(['ALPHAGALACTOSID-RXN', 'RXN-17754'], dtype='<U19'),
#        array(['TRANS-RXN-94', 'RXN-17755', 'TRANS-RXN-94B', 'TRANS-RXN-94A',
#               'TRANS-RXN0-520', 'TRANS-RXN0-519'], dtype='<U14')            ,
#        array(['ABC-18-RXN', 'TRANS-RXN0-541'], dtype='<U14'),
#        array(['ABC-18-RXN', 'TRANS-RXN0-541'], dtype='<U14'),
#        array(['RXN0-5407', 'RXN0-3461'], dtype='<U9'),
#        array(['ABC-18-RXN', 'TRANS-RXN0-541'], dtype='<U14'),
#        array(['MHPHYDROXY-RXN', 'RXN-10040'], dtype='<U14'),
#        array(['1.13.11.16-RXN', 'RXN-12073'], dtype='<U14'),
#        array(['MHPCHYDROL-RXN', 'RXN-12070'], dtype='<U14'),
#        array(['TRANS-RXN0-457', 'TRANS-RXN-61'], dtype='<U14'),
#        array('TRANS-RXN0-486', dtype='<U14'),
#        array(['TRANS-RXN-156', 'TRANS-RXN-169'], dtype='<U13'),
#        array(['RXN0-3501', 'RXN0-7124', 'RXN-15119'], dtype='<U9'),
#        array('RXN-8340', dtype='<U8'), array('RXN-17809', dtype='<U9'),
#        array('RXN-8342', dtype='<U8'), array('RXN-8342', dtype='<U8'),
#        array(['RXN0-262', 'RXN-21601', 'RXN-16457', 'RXN-16456'], dtype='<U9'),
#        array('RXN0-6254', dtype='<U9'), array('ABC-19-RXN', dtype='<U10'),
#        array('ABC-19-RXN', dtype='<U10'),
#        array(['RXN-21563', 'RXN-24141', 'RXN-24142', 'RXN-24143'], dtype='<U9'),
#        array('RXN-11361', dtype='<U9'), array('RXN-8344', dtype='<U8'),
#        array(['RXN-16650', 'RXN-16659', 'RXN-16649'], dtype='<U9'),
#        array(['RXN-16650', 'RXN-16659', 'RXN-16649'], dtype='<U9'),
#        array('RXN-16659', dtype='<U9'),
#        array(['RXN0-3501', 'RXN0-7124', 'RXN-15119'], dtype='<U9'),
#        array(['RXN0-17', 'TRANS-RXN0-587'], dtype='<U14'),
#        array(['RXN-14002', 'RXN-12816', 'RXN-11397', 'RXN-11396'], dtype='<U9'),
#        array('GLUCOSAMINE-6-P-DEAMIN-RXN', dtype='<U26'),
#        array(['TRANS-RXN-167', 'TRANS-RXN-167A'], dtype='<U14'),
#        array('RXN0-5226', dtype='<U9'), array('RXN-14107', dtype='<U9'),
#        array('RXN-18584', dtype='<U9'), array('RXN-18584', dtype='<U9'),
#        array(['RXN0-3501', 'RXN0-7124', 'RXN-15119'], dtype='<U9'),
#        array(['RXN0-3501', 'RXN-15119'], dtype='<U9'),
#        array(['RXN0-3501', 'RXN-15119'], dtype='<U9'),
#        array(['RXN0-3501', 'RXN-15119'], dtype='<U9'),
#        array('RXN-18604', dtype='<U9'), array('RXN-18604', dtype='<U9'),
#        array(['R303-RXN', 'RXN-24048', 'RXN-24049', 'RXN0-7385'], dtype='<U9'),
#        array('RXN0-2721', dtype='<U9'), array('RXN-22001', dtype='<U9'),
#        array('RXN0-7103', dtype='<U9'),
#        array('TRANS-RXN-117', dtype='<U13'),
#        array('ADPSUGPPHOSPHAT-RXN', dtype='<U19'),
#        array(['RXN0-6957', 'RXN-14188', 'RXN0-7291'], dtype='<U9'),
#        array('TRANS-RXN-283', dtype='<U13'), array('', dtype='<U1'),
#        array('', dtype='<U1'),
#        array(['CARBOXYLATE-REDUCTASE-RXN', 'RXN-24042', 'RXN-24038'],
#              dtype='<U25')                                           ,
#        array(['CARBOXYLATE-REDUCTASE-RXN', 'RXN-24042', 'RXN-24038'],
#              dtype='<U25')                                           ,
#        array('RXN0-3461', dtype='<U9'), array('RXN0-4181', dtype='<U9'),
#        array(['1.97.1.4-A-RXN', 'TDCEACT1-RXN'], dtype='<U14'),
#        array(['RXN0-6732', 'RXN-17954'], dtype='<U9'),
#        array(['RXN-17956', 'RXN0-6734'], dtype='<U9'),
#        array('', dtype='<U1'),
#        array(['RXN-17955', 'RXN0-6733'], dtype='<U9'),
#        array('RXN0-6710', dtype='<U9'),
#        array('TRANS-RXN0-481', dtype='<U14'),
#        array('PSEUDOURIDINE-KINASE-RXN', dtype='<U24'),
#        array(['RXN0-6952', 'RXN0-6725', 'RXN-19312', 'RXN-19311'], dtype='<U9'),
#        array('RXN-9590', dtype='<U8'),
#        array(['2.7.3.9-RXN', 'RXN-17354', 'RXN-17355'], dtype='<U11'),
#        array('RXN-19492', dtype='<U9'),
#        array(['THIOSULFATE-SULFURTRANSFERASE-RXN', 'RXN-19033'], dtype='<U33'),
#        array('ABC-28-RXN', dtype='<U10'),
#        array('ABC-28-RXN', dtype='<U10'), array('RXN-12093', dtype='<U9'),
#        array('RXN0-5507', dtype='<U9'), array('RXN0-4022', dtype='<U9'),
#        array('ABC-28-RXN', dtype='<U10'),
#        array('RIBOKIN-RXN', dtype='<U11'),
#        array(['RXN0-6444', 'RXN-20707', 'RXN-12886', 'RXN-22443', 'RXN-20708'],
#              dtype='<U9')                                                      ,
#        array(['RXN0-6460', 'RXN-12896'], dtype='<U9'),
#        array('GLCNACPTRANS-RXN', dtype='<U16'),
#        array('TDPFUCACTRANS-RXN', dtype='<U17'),
#        array('UDPMANACATRANS-RXN', dtype='<U18'),
#        array(['TRANS-RXN-242', 'TRANS-RXN-242A', 'TRANS-RXN0-0244'], dtype='<U15'),
#        array('RXN0-5462', dtype='<U9'), array('RXN0-6452', dtype='<U9'),
#        array('RXN0-5222', dtype='<U9'), array('RXN-8974', dtype='<U8'),
#        array('RXN-9510', dtype='<U8'),
#        array('TRANS-RXN-27', dtype='<U12'),
#        array(['TRANS-RXN-169', 'TRANS-RXN-156'], dtype='<U13'),
#        array('2.9.1.1-RXN', dtype='<U11'),
#        array('2.7.9.3-RXN', dtype='<U11'),
#        array(['TRANS-RXN-169', 'TRANS-RXN-156'], dtype='<U13'),
#        array('SUPEROX-DISMUT-RXN', dtype='<U18'),
#        array('SUPEROX-DISMUT-RXN', dtype='<U18'),
#        array('ARGDECARBOX-RXN', dtype='<U15'),
#        array(['TRANS-RXN-169', 'TRANS-RXN-156'], dtype='<U13'),
#        array('ABC-64-RXN', dtype='<U10'),
#        array('ABC-64-RXN', dtype='<U10'),
#        array(['MERCAPYSTRANS-RXN', 'RXN-18702', 'RXN-18703',
#               'THIOSULFATE-SULFURTRANSFERASE-RXN'], dtype='<U33'),
#        array(['RXN0-5408', 'RXN-7253', 'GLYCEROL-2-PHOSPHATASE-RXN'],
#              dtype='<U26')                                           ,
#        array('RXN0-2441', dtype='<U9'), array('ABC-64-RXN', dtype='<U10'),
#        array('ABC-32-RXN', dtype='<U10'),
#        array('THIKIN-RXN', dtype='<U10'),
#        array(['RXN-9628', 'PALMITOYL-COA-HYDROLASE-RXN',
#               'ACYL-COA-HYDROLASE-RXN', 'RXN-14251', 'RXN-14255', 'RXN0-5390'],
#              dtype='<U27')                                                     ,
#        array(['RXN-23965', 'THIAZOLSYN3-RXN', 'RXN0-7298'], dtype='<U15'),
#        array('ABC-32-RXN', dtype='<U10'),
#        array('ABC-32-RXN', dtype='<U10'),
#        array('TREHALA-RXN', dtype='<U11'),
#        array('TRANS-RXN-168', dtype='<U13'),
#        array(['RXN0-1565', 'TRANS-RXN0-283', 'RXN0-1682', 'RXN0-1701',
#               'RXN0-1684', 'RXN0-1702', 'RXN0-1721', 'TRANS-RXN0-629'],
#              dtype='<U14')                                             ,
#        array(['RXN0-5264', 'RXN-19618'], dtype='<U9'),
#        array('RXN0-5264', dtype='<U9'), array('RXN-19619', dtype='<U9'),
#        array(['1.11.1.15-RXN', 'RXN-19953', 'RXN-19954', 'RXN0-5468'],
#              dtype='<U13')                                            ,
#        array('TRANS-RXN-127', dtype='<U13'),
#        array('RXN0-2461', dtype='<U9'),
#        array(['RXN0-7311', 'RXN-20161'], dtype='<U9'),
#        array('RXN0-2461', dtype='<U9'), array('RXN-16937', dtype='<U9'),
#        array('RXN0-2461', dtype='<U9'), array('RXN0-5214', dtype='<U9'),
#        array('TRANS-RXN-283', dtype='<U13'),
#        array('TRANS-RXN-283', dtype='<U13'),
#        array('TRANS-RXN-283', dtype='<U13'),
#        array(['TRANS-RXN0-492', 'TRANS-RXN0-491'], dtype='<U14'),
#        array(['TRANS-RXN0-492', 'TRANS-RXN0-491'], dtype='<U14'),
#        array(['RXN0-5294', 'RXN-22510'], dtype='<U9'),
#        array('RXN-22216', dtype='<U9'), array('RXN0-7345', dtype='<U9'),
#        array('RXN0-7344', dtype='<U9'), array('RXN0-7343', dtype='<U9'),
#        array('RXN0-7342', dtype='<U9'), array('RXN-22214', dtype='<U9'),
#        array('UDPMANNACADEHYDROG-RXN', dtype='<U22'),
#        array('RXN-22217', dtype='<U9'),
#        array('TRANS-RXN0-279', dtype='<U14'),
#        array('GLUTCYSLIG-RXN', dtype='<U14'),
#        array('ACYLPHOSPHATASE-RXN', dtype='<U19'),
#        array(['RXN-9628', 'PALMITOYL-COA-HYDROLASE-RXN', 'RXN-14251',
#               'RXN-14255', 'ACYL-COA-HYDROLASE-RXN'], dtype='<U27')  ,
#        array('RXN-21532', dtype='<U9'),
#        array(['TRANS-RXN0-492', 'TRANS-RXN0-491'], dtype='<U14'),
#        array('RXN0-313', dtype='<U8'), array('RXN0-313', dtype='<U8'),
#        array('4.3.1.15-RXN', dtype='<U12'),
#        array(['TRANS-RXN-33', 'TRANS-RXN0-502', 'TRANS-RXN0-501',
#               'TRANS-RXN0-534'], dtype='<U14')                   ,
#        array('BETA-GLUCURONID-RXN', dtype='<U19'),
#        array('TRANS-RXN-98', dtype='<U12'),
#        array('TRANS-RXN0-235', dtype='<U14'),
#        array('TRANS-RXN0-235', dtype='<U14'),
#        array('RXN-24479', dtype='<U9'), array('RXN-24479', dtype='<U9'),
#        array('RXN-24479', dtype='<U9'), array('RXN-24479', dtype='<U9'),
#        array('RXN0-5052', dtype='<U9'), array('RXN0-5186', dtype='<U9'),
#        array('TRANS-RXN0-235', dtype='<U14'),
#        array(['RXN0-5001', 'RXN-12402'], dtype='<U9')], dtype=object)

# %%
np.hstack(temp)
# Out:
# array(['ISOCIT-CLEAV-RXN', 'MALSYN-RXN', 'RXN0-1981', 'RXN0-5111',
#        'TRANS-RXN0-576', 'TRANS-RXN0-447', 'RXN0-2162',
#        'ACETYLESTERASE-RXN', 'RXN-13548', 'GLUCOSE-1-PHOSPHAT-RXN',
#        'RXN0-1001', 'R4-RXN', 'RXN-19953', 'RXN-19954', 'RXN-20692',
#        'RXN-20691', 'UREIDOGLYCOLATE-LYASE-RXN', 'RXN0-7024', 'RXN0-5225',
#        'RXN0-4621', 'RXN66-448', 'TRANS-RXN-325', 'TRANS-RXN-155',
#        'TRANS-RXN-153A', 'TRANS-RXN-153', 'TRANS-RXN0-281',
#        'UNDECAPRENYL-DIPHOSPHATASE-RXN', 'RXN-11776', '1.11.1.15-RXN',
#        'RXN-19953', 'RXN-19954', 'RXN0-5468', 'RXN0-5295', 'RXN0-6994',
#        'RXN0-5297', 'RXN0-5295', '6-PHOSPHO-BETA-GLUCOSIDASE-RXN',
#        'RXN-24169', 'RXN-24170', 'RXN-14722', 'BETAGALACTOSID-RXN',
#        'RXN0-1565', 'TRANS-RXN0-283', 'ABC-5-RXN', 'TRANS-RXN-296',
#        'ABC-5-RXN', 'TRANS-RXN-296', 'BTUR2-RXN', 'RXN-19342',
#        'RXN-19343', 'COBALADENOSYLTRANS-RXN', 'CROBETREDUCT-RXN',
#        'RXN0-3601', 'LCARNCOALIG-RXN', 'CARNDETRU-RXN', 'TRANS-RXN-100',
#        'RXN-21408', 'RXN-21408', 'RXN-21407', 'RXN-21407', 'RXN-21407',
#        'RXN-21423', 'RXN0-7454', 'RXN-21421', 'RXN-21424', 'RXN-21425',
#        'RXN-21422', '2.1.1.79-RXN', 'TRANS-RXN-155B', 'TRANS-RXN-155',
#        'TRANS-RXN-155B', 'TRANS-RXN-155', 'TRANS-RXN-155B',
#        'TRANS-RXN-155', 'RXN0-7392', '6-PHOSPHO-BETA-GLUCOSIDASE-RXN',
#        '2.7.8.25-RXN', 'TRANS-RXN0-201', '2.7.7.61-RXN', 'RXN0-2501',
#        'RXN-8770', 'RXN-16788', 'TRANS-RXN-116', 'CYCPHOSDIESTER-RXN',
#        '3-NUCLEOTID-RXN', 'RXN-14115', 'RXN-14126', 'RXN-14124',
#        'RXN-14090', 'RXN-14113', 'RXN-14112', 'RXN-14091', 'RXN-14064',
#        'RXN0-6677', 'RXN0-6676', 'TRANS-RXN0-280', 'TRANS-RXN-90',
#        'TRANS-RXN0-280', 'TRANS-RXN-90', 'TRANS-RXN0-280', 'TRANS-RXN-90',
#        'RXN-20148', 'R524-RXN', 'TRANS-RXN-14', 'RXN-16649',
#        'BETA-LACTAMASE-RXN', '3.4.17.8-RXN', 'RXN-19249', 'RXN-19253',
#        'RXN-16649', 'RXN0-3461', 'RXN-16649', 'RXN-19249', '3.4.17.8-RXN',
#        'RXN-19256', 'RXN-16649', 'BETA-LACTAMASE-RXN', 'RXN-19249',
#        'RXN-19253', 'TRANS-RXN-300', 'TRANS-RXN-106', 'TRANS-RXN-299',
#        'RXN0-5359', 'GALACTONDEHYDRAT-RXN', 'DEHYDDEOXGALACTKIN-RXN',
#        'TRANS-RXN-16', 'RXN0-5359', 'RXN0-4181', 'TRANS-RXN0-495',
#        'RXN0-7105', 'RXN0-7046', 'TRANS-RXN0-496', 'ACETALD-DEHYDROG-RXN',
#        'RXN0-1565', 'TRANS-RXN0-283', 'RXN0-1682', 'RXN0-1701',
#        'RXN0-1684', 'RXN0-1702', 'RXN0-1721', 'TRANS-RXN0-629',
#        'RXN0-1565', 'TRANS-RXN0-283', 'RXN0-1682', 'RXN0-1701',
#        'RXN0-1684', 'RXN0-1702', 'RXN0-1721', 'TRANS-RXN0-629',
#        'DIENOYLCOAREDUCT-RXN', '1.1.1.271-RXN', 'FCLEPIM-RXN',
#        'FCLREDUCT-RXN', 'RXN0-1684', 'ABC-9-RXN', 'ABC-9-RXN',
#        'ABC-9-RXN', 'ABC-9-RXN', 'RXN0-1682', 'ABC-10-RXN', 'ABC-10-RXN',
#        'ABC-10-RXN', 'ABC-10-RXN', 'RXN0-1701', 'ABC-11-RXN',
#        'TRANS-RXN-297', 'TRANS-RXN-298', 'ABC-11-RXN', 'TRANS-RXN-297',
#        'TRANS-RXN-298', 'ABC-11-RXN', 'TRANS-RXN-297', 'TRANS-RXN-298',
#        'RXN0-1702', 'RXN0-1721', 'TRANS-RXN-1', 'TRANS-RXN0-418',
#        'TRANS-RXN0-417', 'TRANS-RXN0-582', 'TRANS-RXN0-618',
#        'TRANS-RXN-158', 'TRANS-RXN0-582', 'TRANS-RXN0-618',
#        'TRANS-RXN-158', '1PFRUCTPHOSN-RXN', 'GALACTARDEHYDRA-RXN',
#        'TRANS-RXN0-204', 'TRANS-RXN0-203', 'TRANS-RXN0-523', 'RXN-16659',
#        'GLUC1PURIDYLTRANS-RXN', 'MALSYN-RXN', 'TRANS-RXN-22', 'RXN0-6373',
#        'TRANS-RXN-122', 'TRANS-RXN0-209', 'TRANS-RXN0-209',
#        'GDPMANDEHYDRA-RXN', 'GDPMANMANHYDRO-RXN', 'GDP-GLUCOSIDASE-RXN',
#        'GLUCARDEHYDRA-RXN', 'RXN0-5285', 'TRANS-RXN0-204',
#        'TRANS-RXN0-203', 'TRANS-RXN0-523', 'GPH-RXN',
#        'PRODISULFREDUCT-RXN', 'RXN0-7271', 'RXN-19629', 'RXN-18586',
#        'PRODISULFREDUCT-RXN', 'RXN0-7271', 'RXN-12071',
#        'PHENPRODIOLDEHYDROG-RXN', 'RXN-12072', 'HCAMULTI-RXN',
#        'RXN-12072', 'HCAMULTI-RXN', 'RXN-12072', 'HCAMULTI-RXN',
#        'RXN-12072', 'HCAMULTI-RXN', 'TRANS-RXN0-282', 'RXN0-5256',
#        'RXN-16420', 'RXN0-5256', 'RXN-16420',
#        'HYDROXYLAMINE-REDUCTASE-RXN', 'RXN0-307',
#        'PROTOHEMEFERROCHELAT-RXN', 'R621-RXN', '1.5.1.34-RXN',
#        'SORBITOL-6-PHOSPHATASE-RXN', 'MANNITOL-1-PHOSPHATASE-RXN',
#        '3.1.3.68-RXN', 'RXN0-5256', 'RXN-16420', 'RXN0-7399', 'RXN0-7399',
#        'RXN0-7399', 'RXN0-7399', 'TRANS-RXN0-228', 'TRANS-RXN0-209',
#        'TRANS-RXN-181A', 'TRANS-RXN-113', 'TRANS-RXN-23', 'RXN-14381',
#        'RXN0-5229', 'TRANS-RXN0-227', 'RXN0-1741', 'RXN0-1804',
#        'RXN0-5227', 'RXN0-2061', 'RXN0-5401', 'RXN-16660', 'ABC-16-RXN',
#        'TRANS-RXN0-504', 'TRANS-RXN0-503', 'ABC-16-RXN', 'TRANS-RXN0-504',
#        'TRANS-RXN0-503', 'TRANS-RXN-294', 'TRANS-RXN-295',
#        'TRANS-RXN-387', 'ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503',
#        'ABC-16-RXN', 'TRANS-RXN0-504', 'TRANS-RXN0-503', 'TRANS-RXN0-575',
#        'TRANS-RXN0-574', 'ALPHAGALACTOSID-RXN', 'RXN-17754',
#        'TRANS-RXN-94', 'RXN-17755', 'TRANS-RXN-94B', 'TRANS-RXN-94A',
#        'TRANS-RXN0-520', 'TRANS-RXN0-519', 'ABC-18-RXN', 'TRANS-RXN0-541',
#        'ABC-18-RXN', 'TRANS-RXN0-541', 'RXN0-5407', 'RXN0-3461',
#        'ABC-18-RXN', 'TRANS-RXN0-541', 'MHPHYDROXY-RXN', 'RXN-10040',
#        '1.13.11.16-RXN', 'RXN-12073', 'MHPCHYDROL-RXN', 'RXN-12070',
#        'TRANS-RXN0-457', 'TRANS-RXN-61', 'TRANS-RXN0-486',
#        'TRANS-RXN-156', 'TRANS-RXN-169', 'RXN0-3501', 'RXN0-7124',
#        'RXN-15119', 'RXN-8340', 'RXN-17809', 'RXN-8342', 'RXN-8342',
#        'RXN0-262', 'RXN-21601', 'RXN-16457', 'RXN-16456', 'RXN0-6254',
#        'ABC-19-RXN', 'ABC-19-RXN', 'RXN-21563', 'RXN-24141', 'RXN-24142',
#        'RXN-24143', 'RXN-11361', 'RXN-8344', 'RXN-16650', 'RXN-16659',
#        'RXN-16649', 'RXN-16650', 'RXN-16659', 'RXN-16649', 'RXN-16659',
#        'RXN0-3501', 'RXN0-7124', 'RXN-15119', 'RXN0-17', 'TRANS-RXN0-587',
#        'RXN-14002', 'RXN-12816', 'RXN-11397', 'RXN-11396',
#        'GLUCOSAMINE-6-P-DEAMIN-RXN', 'TRANS-RXN-167', 'TRANS-RXN-167A',
#        'RXN0-5226', 'RXN-14107', 'RXN-18584', 'RXN-18584', 'RXN0-3501',
#        'RXN0-7124', 'RXN-15119', 'RXN0-3501', 'RXN-15119', 'RXN0-3501',
#        'RXN-15119', 'RXN0-3501', 'RXN-15119', 'RXN-18604', 'RXN-18604',
#        'R303-RXN', 'RXN-24048', 'RXN-24049', 'RXN0-7385', 'RXN0-2721',
#        'RXN-22001', 'RXN0-7103', 'TRANS-RXN-117', 'ADPSUGPPHOSPHAT-RXN',
#        'RXN0-6957', 'RXN-14188', 'RXN0-7291', 'TRANS-RXN-283', '', '',
#        'CARBOXYLATE-REDUCTASE-RXN', 'RXN-24042', 'RXN-24038',
#        'CARBOXYLATE-REDUCTASE-RXN', 'RXN-24042', 'RXN-24038', 'RXN0-3461',
#        'RXN0-4181', '1.97.1.4-A-RXN', 'TDCEACT1-RXN', 'RXN0-6732',
#        'RXN-17954', 'RXN-17956', 'RXN0-6734', '', 'RXN-17955',
#        'RXN0-6733', 'RXN0-6710', 'TRANS-RXN0-481',
#        'PSEUDOURIDINE-KINASE-RXN', 'RXN0-6952', 'RXN0-6725', 'RXN-19312',
#        'RXN-19311', 'RXN-9590', '2.7.3.9-RXN', 'RXN-17354', 'RXN-17355',
#        'RXN-19492', 'THIOSULFATE-SULFURTRANSFERASE-RXN', 'RXN-19033',
#        'ABC-28-RXN', 'ABC-28-RXN', 'RXN-12093', 'RXN0-5507', 'RXN0-4022',
#        'ABC-28-RXN', 'RIBOKIN-RXN', 'RXN0-6444', 'RXN-20707', 'RXN-12886',
#        'RXN-22443', 'RXN-20708', 'RXN0-6460', 'RXN-12896',
#        'GLCNACPTRANS-RXN', 'TDPFUCACTRANS-RXN', 'UDPMANACATRANS-RXN',
#        'TRANS-RXN-242', 'TRANS-RXN-242A', 'TRANS-RXN0-0244', 'RXN0-5462',
#        'RXN0-6452', 'RXN0-5222', 'RXN-8974', 'RXN-9510', 'TRANS-RXN-27',
#        'TRANS-RXN-169', 'TRANS-RXN-156', '2.9.1.1-RXN', '2.7.9.3-RXN',
#        'TRANS-RXN-169', 'TRANS-RXN-156', 'SUPEROX-DISMUT-RXN',
#        'SUPEROX-DISMUT-RXN', 'ARGDECARBOX-RXN', 'TRANS-RXN-169',
#        'TRANS-RXN-156', 'ABC-64-RXN', 'ABC-64-RXN', 'MERCAPYSTRANS-RXN',
#        'RXN-18702', 'RXN-18703', 'THIOSULFATE-SULFURTRANSFERASE-RXN',
#        'RXN0-5408', 'RXN-7253', 'GLYCEROL-2-PHOSPHATASE-RXN', 'RXN0-2441',
#        'ABC-64-RXN', 'ABC-32-RXN', 'THIKIN-RXN', 'RXN-9628',
#        'PALMITOYL-COA-HYDROLASE-RXN', 'ACYL-COA-HYDROLASE-RXN',
#        'RXN-14251', 'RXN-14255', 'RXN0-5390', 'RXN-23965',
#        'THIAZOLSYN3-RXN', 'RXN0-7298', 'ABC-32-RXN', 'ABC-32-RXN',
#        'TREHALA-RXN', 'TRANS-RXN-168', 'RXN0-1565', 'TRANS-RXN0-283',
#        'RXN0-1682', 'RXN0-1701', 'RXN0-1684', 'RXN0-1702', 'RXN0-1721',
#        'TRANS-RXN0-629', 'RXN0-5264', 'RXN-19618', 'RXN0-5264',
#        'RXN-19619', '1.11.1.15-RXN', 'RXN-19953', 'RXN-19954',
#        'RXN0-5468', 'TRANS-RXN-127', 'RXN0-2461', 'RXN0-7311',
#        'RXN-20161', 'RXN0-2461', 'RXN-16937', 'RXN0-2461', 'RXN0-5214',
#        'TRANS-RXN-283', 'TRANS-RXN-283', 'TRANS-RXN-283',
#        'TRANS-RXN0-492', 'TRANS-RXN0-491', 'TRANS-RXN0-492',
#        'TRANS-RXN0-491', 'RXN0-5294', 'RXN-22510', 'RXN-22216',
#        'RXN0-7345', 'RXN0-7344', 'RXN0-7343', 'RXN0-7342', 'RXN-22214',
#        'UDPMANNACADEHYDROG-RXN', 'RXN-22217', 'TRANS-RXN0-279',
#        'GLUTCYSLIG-RXN', 'ACYLPHOSPHATASE-RXN', 'RXN-9628',
#        'PALMITOYL-COA-HYDROLASE-RXN', 'RXN-14251', 'RXN-14255',
#        'ACYL-COA-HYDROLASE-RXN', 'RXN-21532', 'TRANS-RXN0-492',
#        'TRANS-RXN0-491', 'RXN0-313', 'RXN0-313', '4.3.1.15-RXN',
#        'TRANS-RXN-33', 'TRANS-RXN0-502', 'TRANS-RXN0-501',
#        'TRANS-RXN0-534', 'BETA-GLUCURONID-RXN', 'TRANS-RXN-98',
#        'TRANS-RXN0-235', 'TRANS-RXN0-235', 'RXN-24479', 'RXN-24479',
#        'RXN-24479', 'RXN-24479', 'RXN0-5052', 'RXN0-5186',
#        'TRANS-RXN0-235', 'RXN0-5001', 'RXN-12402'], dtype='<U33')
