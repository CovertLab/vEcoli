# %%
import numpy as np
import ast
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt
import dill
import requests
import xmltodict
import cvxpy as cp
import itertools
import networkx as nx

from scipy.special import logsumexp

# %matplotlib inline
# sns.set(style='darkgrid', palette='viridis', context='talk')

os.chdir(os.path.expanduser('~/dev/vivarium-ecoli'))

from ecoli.processes.metabolism_redux_classic import NetworkFlowModel, FlowResult
from ecoli.library.schema import numpy_schema, bulk_name_to_idx, listener_schema, counts
from ecoli.processes.registries import topology_registry
TOPOLOGY = topology_registry.access("ecoli-metabolism-redux")

# %%
# create a function to deal with non-homogeous dtype of columns. mixture of strings and lists
def string_to_list(s):
    try:
        return np.array(ast.literal_eval(s))  # Safely convert string to array
    except (ValueError, SyntaxError):
        return np.array(s)  # Return as array if object is not a list and conversion fails (e.g., NaN values)

# %% [markdown]
# ### Load Experiments

# %%
time = '400'
date = '2025-01-13'
experiment = 'metabolism-redux-classic-BASAL_NEW-modified_process_new_rxn_name'
entry = f'{experiment}_{time}_{date}'
folder = f'out/cofactors/{entry}/'

output = np.load(folder + '0_output.npy',allow_pickle='TRUE').item()
# output = np.load(r"out/geneRxnVerifData/output_glc.npy", allow_pickle=True, encoding='ASCII').tolist()
output = output['agents']['0']
fba = output['listeners']['fba_results']
mass = output['listeners']['mass']
bulk = pd.DataFrame(output['bulk'])

# %%
f = open(folder + 'agent_steps.pkl', 'rb')
agent = dill.load(f)
f.close()

# %% [markdown]
# ### Create Dataframe

# %%
# create simulation flux dataframe - OLD
self = agent['ecoli-metabolism-redux-classic'] #self of metabolism_redux_classic class
reaction_names = self.reaction_names

sim_fluxes = pd.DataFrame(fba["estimated_fluxes"])
target_fluxes = pd.DataFrame(fba["target_kinetic_fluxes"])

sim_fluxes.columns = reaction_names
sim_fluxes = sim_fluxes.iloc[1:,] # remove first row (NAs) of the dataframe
target_fluxes = target_fluxes.iloc[1:,] # remove first row (NAs) of the dataframe

# %%
fba_new_reaction_ids = self.parameters["fba_new_reaction_ids"]
fba_reaction_ids_to_base_reaction_ids = self._parameters['fba_reaction_ids_to_base_reaction_ids']

# %%
#### ALL REACTION FLUX #####

# take average of flux through time -- should I normalize by cell mass? 
sim_fluxes_avg = sim_fluxes.mean(axis=0)

# set up plotly df
df = pd.DataFrame({'sim_fluxes_avg': sim_fluxes_avg, 'sim_fluxes_avg_log':sim_fluxes_avg})
df['is_new'] = 'Old Reactions'
df.loc[fba_new_reaction_ids, 'is_new'] = 'New Reactions'  

# log flux and + e-6
df.sim_fluxes_avg_log += 10**-6
df.sim_fluxes_avg_log = np.log10(df.sim_fluxes_avg_log)

# %% [markdown]
# ### Search for dead-ends by parsing through the S (stoichiometry) matrix and find metabolites (row) with no usage (negative entry)

# %%
S = self.stoichiometry
metabolites = self.metabolite_names
reactions = self.reaction_names
metabolite_idx_to_name = {i:metabolite for i, metabolite in enumerate(metabolites)}
rxn_idx_to_id = {i: reaction for i, reaction in enumerate(reactions)}
rxn_id_to_idx = {reaction: i for i, reaction in enumerate(reactions)}

# %%
S = self.stoichiometry
dead_end_met = []
dead_end_met_rxn = {}
for row in np.arange(0,S.shape[0]):
    if not np.any(S[row,] <0): # if the metabolite doesn't have an outlet
        met = metabolite_idx_to_name[row]
        dead_end_met.append(met)
        
        rxn_idxs = np.where(S[row,] != 0)[0]
        rxn_ids =  [rxn_idx_to_id[idx] for idx in rxn_idxs]
        dead_end_met_rxn[met]=rxn_ids

# %%
print(f'There are a total of {len(dead_end_met)} metabolites that are only being created but not used')
dead_end_met_rxn 

#TODO: RNAs probably don't need to considered dead-ends because they are used in other parts of the model and have their own degradation module
# Out:
# There are a total of 632 metabolites that are only being created but not used
# {'1-2-Diglycerides[c]': ['RXN-17700'],
#  '1-Lyso-phospholipids[p]': ['RXN-17363'],
#  '1-Lysophosphatidylglycerols[p]': ['RXN-20915'],
#  '1-Lysophosphatidylserines[p]': ['RXN-20913'],
#  '16S-rRNA-2-O-methylcytidine1402[c]': ['RXN-11637'],
#  '16S-rRNA-5-O-methylcytosine1407[c]': ['RXN-11593'],
#  '16S-rRNA-5-O-methylcytosine967[c]': ['RXN-11591'],
#  '16S-rRNA-N2-methylguanine1207[c]': ['RXN-11576'],
#  '16S-rRNA-N2-methylguanine966[c]': ['RXN0-6515'],
#  '16S-rRNA-N2methylguanine1516[c]': ['RXN0-6731'],
#  '16S-rRNA-N3-methyluracil1498[c]': ['RXN-11598'],
#  '16S-rRNA-N4-methylcytidine1402[c]': ['RXN-11638'],
#  '16S-rRNA-N6-dimethyladenine1518-1519[c]': ['RXN-11633'],
#  '16S-rRNA-N7-methylguanine527[c]': ['RXN-11578'],
#  '16S-rRNA-pseudouridine516[c]': ['RXN-11833'],
#  '2-Acyl-sn-glycerol-3-phosphates[p]': ['RXN-20916'],
#  '2-Acylglycero-Phosphocholines[c]': ['RXN0-1842'],
#  '2-CARBOXYMUCONATE[p]': ['RXN0-2943'],
#  '2-DEOXY-D-GLUCOSE[c]': ['3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-PHOSPHATE/WATER//2-DEOXY-D-GLUCOSE/Pi.71.',
#   '3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-PHOSPHATE/WATER//2-DEOXY-D-GLUCOSE/Pi.71.__G6932-MONOMER'],
#  '2-HYDROXYGLUTARIC_ACID[c]': ['HYDGLUTSYN-RXN'],
#  '2-O-Methylcytidine-32-tRNAs[c]': ['RXN-11866'],
#  '2-O-Methylcytidine-34-tRNAs[c]': ['RXN-11860'],
#  '2-O-Methylguanosine18[c]': ['2.1.1.34-RXN'],
#  '2-O-Methyluridine32-tRNA[c]': ['RXN-11867'],
#  '2-PROTOCATECHUOYLPHLOROGLUCINOLCARBOXYLA[c]': ['QUERCETIN-23-DIOXYGENASE-RXN'],
#  '2-Prime-Phosphate-Terminated-RNAs[c]': ['RXN-15952'],
#  '2-THIOURIDINE[c]': ['TRANS-RXN-108-2-THIOURIDINE/PROTON//2-THIOURIDINE/PROTON.43.'],
#  '2-Thiocytosine-32-In-tRNAs[c]': ['RXN-21236', 'TRNA-S-TRANSFERASE-RXN'],
#  '23S-RRNA-N2-METHYLGUANINE2445[c]': ['RXN-11574'],
#  '23S-rRNA-2-O-methylcytidine2498[c]': ['RXN-11589'],
#  '23S-rRNA-2-O-methylguanosine2251[c]': ['RXN-11588'],
#  '23S-rRNA-2-O-methyluridine2552[c]': ['RXN-11845'],
#  '23S-rRNA-2-methyladenine2503[c]': ['RXN-11586'],
#  '23S-rRNA-5-methylcytosine1962[c]': ['RXN-11602'],
#  '23S-rRNA-5-methyluracil1939[c]': ['RXN-11601'],
#  '23S-rRNA-5-methyluracil747[c]': ['RXN-11600'],
#  '23S-rRNA-N1-methylguanine745[c]': ['RXN-11573'],
#  '23S-rRNA-N2-methylguanine1835[c]': ['RXN-11635'],
#  '23S-rRNA-N3-methylpseudouridine1915[c]': ['RXN-11592'],
#  '23S-rRNA-N6-m-adenine1618[c]': ['RXN-11596'],
#  '23S-rRNA-N6-methyladenine-2030[c]': ['RXN0-6998'],
#  '23S-rRNA-N7-methylguanine-2069[c]': ['RXN0-6950'],
#  '23S-rRNA-pseudouridine1911-1915-1917[c]': ['RXN-11837'],
#  '23S-rRNA-pseudouridine2457[c]': ['RXN-11834'],
#  '23S-rRNA-pseudouridine2604[c]': ['RXN-11835'],
#  '23S-rRNA-pseudouridine2605[c]': ['RXN-11836'],
#  '23S-rRNA-pseudouridine746[c]': ['RXN-11843'],
#  '23S-rRNA-pseudouridine955-2504-2580[c]': ['RXN-11838'],
#  '3-HYDROXY-PROPIONATE[p]': ['TRANS-RXN0-465'],
#  '3-HYDROXYBENZOATE[c]': ['RXN0-7046'],
#  '3-METHYL-CROTONYL-COA[c]': ['RXN0-2301'],
#  '3-N-3-carboxypropyl-uridine47-tRNAPhe[c]': ['2.5.1.25-RXN'],
#  '3-oxo-behenoyl-ACPs[c]': ['3-OXOACYL-ACP-SYNTH-RXN-MALONYL-ACP/Arachidoyl-ACPs/PROTON//ACP/3-oxo-behenoyl-ACPs/CARBON-DIOXIDE.75.'],
#  '3-terminal-unsaturated-sugars[c]': ['4.2.99.18-RXN'],
#  '4-HYDROXY-BUTYRATE[c]': ['4-HYDROXYBUTYRATE-DEHYDROGENASE-RXN (reverse)'],
#  '4-NITROANILINE[p]': ['RXN-18093'],
#  '5-CarboxyMeAmMe-2-O-MeU34-tRNALeu[c]': ['RXN-11865'],
#  '5-Hydroxy-23S-rRNA-Cytosines2501[c]': ['RXN-21990'],
#  '5-L-GLUTAMYL-AMINO-ACID[p]': ['GAMMA-GLUTAMYLTRANSFERASE-RXN'],
#  '5-METHYLAMINOMETHYL-2-SELENOURIDINE[c]': ['TRANS-RXN-108-5-METHYLAMINOMETHYL-2-SELENOURIDINE/PROTON//5-METHYLAMINOMETHYL-2-SELENOURIDINE/PROTON.87.'],
#  '5-METHYLAMINOMETHYL-2-THIOURIDINE[c]': ['TRANS-RXN-108-5-METHYLAMINOMETHYL-2-THIOURIDINE/PROTON//5-METHYLAMINOMETHYL-2-THIOURIDINE/PROTON.83.'],
#  '5-Methylcytosine-DNA[c]': ['DNA-CYTOSINE-5--METHYLTRANSFERASE-RXN'],
#  '5-prime-phospho-adenosine-RNA[c]': ['RXN0-7346'],
#  '50S-Ribo-protein-L16-Hydroxylarginine[c]': ['RXN0-7090'],
#  '6-Acetyl-Beta-D-Galactosides[c]': ['GALACTOACETYLTRAN-RXN'],
#  '7-METHYLGUANOSINE-5-PHOSPHATE[c]': ['RXN0-7079'],
#  'A-5-prime-Ap4-capped-RNA[c]': ['RXN0-7397'],
#  'A-5-prime-PP-5-prime-RNA[c]': ['RXN-17916'],
#  'A-PEPTIDOGLYCAN-MDAP-TRIPEPTIDE[p]': ['RXN-22575', 'RXN-22576', 'RXN0-5407'],
#  'A-REDUCED-TORY-PROTEIN[c]': ['RXN-12876-an-oxidized-TorY-protein/ASCORBATE//L-DEHYDRO-ASCORBATE/A-REDUCED-TORY-PROTEIN/PROTON.86.'],
#  'ACEF-LIPOATE[c]': ['RXN0-1139', 'RXN0-7424'],
#  'ACETYLMALTOSE[e]': ['TRANS-RXN0-473'],
#  'ACETYLMURAMYL-ALANYL-ISOGLUTAMINE[c]': ['3.6.3.23-RXN-ACETYLMURAMYL-ALANYL-ISOGLUTAMINE/ATP/WATER//ACETYLMURAMYL-ALANYL-ISOGLUTAMINE/ADP/Pi/PROTON.93.',
#   'ABC-22-RXN-ATP/ACETYLMURAMYL-ALANYL-ISOGLUTAMINE/WATER//ADP/ACETYLMURAMYL-ALANYL-ISOGLUTAMINE/Pi/PROTON.93.'],
#  'ACP[p]': ['RXN-9550', 'RXN-9555'],
#  'ADENOSINE5TRIPHOSPHO5ADENOSINE[c]': ['RXN0-5209',
#   'TRANS-RXN-108-ADENOSINE5TRIPHOSPHO5ADENOSINE/PROTON//ADENOSINE5TRIPHOSPHO5ADENOSINE/PROTON.77.'],
#  'ADENOSYLCOBALAMIN[c]': ['RXN-19366', 'RXN-8770'],
#  'ADP[p]': ['BIS5-ADENOSYL-TRIPHOSPHATASE-RXN'],
#  'ALA-tRNAs[c]': ['RXN-19726', 'RXN0-7433'],
#  'ALLANTOIN[c]': ['TRANS-RXN0-557'],
#  'ALPHA-RIBAZOLE[c]': ['RXN-16788'],
#  'AMINO-ACETONE[c]': ['RXN-14249', 'RXN-16001', 'THREOSPON-RXN'],
#  'ARCB-CPLX[c]': ['RXN0-312', 'RXN0-7084'],
#  'ASP-tRNAs[c]': ['RXN-19728'],
#  'Acetylated-S18-N-terminal-L-alanine[c]': ['2.3.1.128-RXN'],
#  'Acetylated-S5-N-terminal-L-alanine[c]': ['RXN-18434'],
#  'Alcohols[c]': ['1.11.1.15-RXN',
#   '3.2.1.52-RXN',
#   'BETA-GLUCURONID-RXN',
#   'CARBOXYLESTERASE-RXN'],
#  'Alcohols[p]': ['ACID-PHOSPHATASE-RXN', 'ALKAPHOSPHA-RXN'],
#  'Alkaloine-Phosphatase-With-Cleaved-Arg[p]': ['RXN0-3261'],
#  'Alpha-D-aldose-1-phosphates[c]': ['ADPSUGPPHOSPHAT-RXN'],
#  'Alpha-D-aldose-1-phosphates[p]': ['UDPSUGARHYDRO-RXN'],
#  'Amino-Acids-20[c]': ['3.4.11.1-RXN',
#   '3.4.11.9-RXN',
#   '3.4.13.21-RXN',
#   'RXN0-3241',
#   'RXN0-5051',
#   'RXN0-5052',
#   'RXN0-5204'],
#  'Apocytochromes-c[p]': ['TRANS-RXN-403'],
#  'BUTANOL[c]': ['R4-RXN-BUTYL-HYDROPEROXIDE/NADH/PROTON//BUTANOL/NAD/WATER.51.',
#   'RXN-19953-Reduced-Cys2-Peroxiredoxins/BUTYL-HYDROPEROXIDE//2Cys-Peroxiredoxins-With-HydroxyCys/BUTANOL.93.'],
#  'CARDIOLIPIN[c]': ['RXN0-7012'],
#  'CARNOSINE[c]': ['3.6.3.23-RXN-CARNOSINE/ATP/WATER//CARNOSINE/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CARNOSINE/WATER//ADP/CARNOSINE/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CARNOSINE/WATER//ADP/CARNOSINE/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CARNOSINE/PROTON//CARNOSINE/PROTON.35.'],
#  'CDP-2-3-4-Saturated-Diacylglycerols[c]': ['RXN0-5515'],
#  'CGMP[c]': ['GUANYLCYC-RXN'],
#  'CH4[p]': ['TRANS-RXN0-526'],
#  'CHLORAMPHENICOL[p]': ['TRANS-RXN-341'],
#  'CHOLANATE2[c]': ['7-ALPHA-HYDROXYSTEROID-DEH-RXN'],
#  'CL-[c]': ['RXN-19573', 'RXN0-2501'],
#  'CO-A[p]': ['THIOESTER-RXN-BUTYRYL-COA/WATER//BUTYRIC_ACID/CO-A/PROTON.44.',
#   'THIOESTER-RXN-CPD-196/WATER//CPD-195/CO-A/PROTON.35.',
#   'THIOESTER-RXN-HEXANOYL-COA/WATER//HEXANOATE/CO-A/PROTON.42.',
#   'THIOESTER-RXN-LAUROYLCOA-CPD/WATER//DODECANOATE/CO-A/PROTON.46.',
#   'THIOESTER-RXN-PROPIONYL-COA/WATER//PROPIONATE/CO-A/PROTON.44.',
#   'THIOESTER-RXN-STEAROYL-COA/WATER//STEARIC_ACID/CO-A/PROTON.45.',
#   'THIOESTER-RXN-TETRADECANOYL-COA/WATER//CPD-7836/CO-A/PROTON.46.'],
#  'COPROPORPHYRIN_III[c]': ['RXN0-7325'],
#  'CPD-10205[c]': ['RXN-9559'],
#  'CPD-10206[c]': ['RXN-9560'],
#  'CPD-10208[c]': ['RXN-9562'],
#  'CPD-10246[c]': ['ABC-56-RXN-ATP/CPD-10246/WATER//CPD-10246/ADP/Pi/PROTON.45.'],
#  'CPD-10247[c]': ['TRANS-RXN0-580'],
#  'CPD-10723[c]': ['RXN-17726-CPD-3561/WATER//GALACTOSE/CPD-10723.36.'],
#  'CPD-10776[c]': ['RXN-10018'],
#  'CPD-11444[c]': ['RXN-14396'],
#  'CPD-11592[c]': ['RXN-14481',
#   'RXN0-5063',
#   'TRANS-RXN-108-CPD-11592/PROTON//CPD-11592/PROTON.35.'],
#  'CPD-11643[c]': ['RXN-19245'],
#  'CPD-11725[c]': ['ABC-56-RXN-ATP/CPD-11725/WATER//CPD-11725/ADP/Pi/PROTON.45.'],
#  'CPD-12115[i]': ['RXN0-7235-ETF-Reduced/DEMETHYLMENAQUINONE//ETF-Oxidized/CPD-12115/PROTON.63.'],
#  'CPD-12115[m]': ['RXN-20056-DSBBPROT-MONOMER/DEMETHYLMENAQUINONE//MONOMER0-4142/CPD-12115.62.',
#   'RXN-20056-a--reduced-DsbB-protein/DEMETHYLMENAQUINONE//an-oxidized-DsbB-protein/CPD-12115.80.'],
#  'CPD-12261[p]': ['RXN-11302'],
#  'CPD-12284[c]': ['RXN-11326'],
#  'CPD-12301[c]': ['3.6.3.23-RXN-CPD-12301/ATP/WATER//CPD-12301/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD-12301/WATER//ADP/CPD-12301/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD-12301/PROTON//CPD-12301/PROTON.35.'],
#  'CPD-12365[c]': ['RXN-11396', 'RXN-12816'],
#  'CPD-12367[c]': ['RXN-11397', 'RXN-14002'],
#  'CPD-12427[c]': ['RXN-18435'],
#  'CPD-12521[c]': ['TRANS-RXN-35-CPD-12521/PROTON//CPD-12521/PROTON.35.'],
#  'CPD-12523[c]': ['TRANS-RXN-123-CPD-12523/PROTON//CPD-12523/PROTON.35.'],
#  'CPD-12524[c]': ['TRANS-RXN-123-CPD-12524/PROTON//CPD-12524/PROTON.35.'],
#  'CPD-12587[c]': ['RXN-11776'],
#  'CPD-12693[c]': ['ABC-56-RXN-ATP/CPD-12693/WATER//CPD-12693/ADP/Pi/PROTON.45.',
#   'RXN-15299 (reverse)'],
#  'CPD-12824[c]': ['CARDIOLIPSYN-RXN-CPD-8260//CPD-12824/GLYCEROL.29.'],
#  'CPD-13158[e]': ['TRANS-RXN-378-CPD-13158/ATP/WATER//CPD-13158/ADP/Pi/PROTON.45.'],
#  'CPD-13227[p]': ['TRANS-RXN-481'],
#  'CPD-13243[c]': ['RXN-17104'],
#  'CPD-13315[c]': ['RXN0-6677'],
#  'CPD-13428[c]': ['RXN0-7222-CPD-13428/PROTON//CPD-13428/PROTON.35.'],
#  'CPD-13595[c]': ['RXN-8638-CPD-13595/ATP/WATER//CPD-13595/ADP/Pi/PROTON.45.'],
#  'CPD-13852[c]': ['RXN0-6957'],
#  'CPD-13908[c]': ['RXN-12864'],
#  'CPD-13910[c]': ['RXN-12872'],
#  'CPD-13918[c]': ['TRANS-RXN-108-CPD-13918/PROTON//CPD-13918/PROTON.35.'],
#  'CPD-13992[c]': ['RXN-11813'],
#  'CPD-13993[c]': ['RXN-11813'],
#  'CPD-14442[c]': ['RXN-13460'],
#  'CPD-14488[c]': ['TRANS-RXN-35-CPD-14488/PROTON//CPD-14488/PROTON.35.'],
#  'CPD-14545[p]': ['TRANS-RXN-273'],
#  'CPD-15016[c]': ['RXN-13990 (reverse)'],
#  'CPD-15158[c]': ['RXN-14188'],
#  'CPD-15189[c]': ['TRANS-RXN0-591'],
#  'CPD-15189[e]': ['TRANS-RXN0-592'],
#  'CPD-15237[c]': ['RXN-14361'],
#  'CPD-15384[c]': ['3.6.3.23-RXN-CPD-15384/ATP/WATER//CPD-15384/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD-15384/WATER//ADP/CPD-15384/Pi/PROTON.45.'],
#  'CPD-15417[e]': ['TRANS-RXN-353'],
#  'CPD-15544[c]': ['TRANS-RXN-108-CPD-15544/PROTON//CPD-15544/PROTON.35.'],
#  'CPD-15629[i]': ['ABC-42-RXN-CPD-15629/ATP/WATER//CPD-15629/ADP/Pi/PROTON.45.'],
#  'CPD-15868[c]': ['RXN-14968', 'RXN-14968-L-LYXOSE//CPD-15868.20.'],
#  'CPD-16020[c]': ['RXN-15140',
#   'TRANS-RXN-108-CPD-16020/PROTON//CPD-16020/PROTON.35.'],
#  'CPD-16154[c]': ['TRANS-RXN-158-BETA-D-FRUCTOSE/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.60.',
#   'TRANS-RXN-158-CPD-10723/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.54.',
#   'TRANS-RXN-158-Fructofuranose/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.59.',
#   'TRANS-RXN0-582-BETA-D-FRUCTOSE/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.60.',
#   'TRANS-RXN0-582-CPD-10723/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.54.',
#   'TRANS-RXN0-582-CPD-10725/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.54.',
#   'TRANS-RXN0-582-CPD-10726/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.54.',
#   'TRANS-RXN0-582-CPD-15382/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.54.',
#   'TRANS-RXN0-582-FRU/PTSI-PHOSPHORYLATED//CPD-16154/PTSI-MONOMER.48.'],
#  'CPD-16401[p]': ['RXN-15210'],
#  'CPD-16444[e]': ['TRANS-RXN-378-CPD-16444/ATP/WATER//CPD-16444/ADP/Pi/PROTON.45.'],
#  'CPD-16461[e]': ['TRANS-RXN-378-CPD-16461/ATP/WATER//CPD-16461/ADP/Pi/PROTON.45.'],
#  'CPD-16462[e]': ['TRANS-RXN-378-CPD-16462/ATP/WATER//CPD-16462/ADP/Pi/PROTON.45.'],
#  'CPD-16463[e]': ['TRANS-RXN-378-CPD-16463/ATP/WATER//CPD-16463/ADP/Pi/PROTON.45.'],
#  'CPD-16491[c]': ['3.2.2.23-RXN'],
#  'CPD-16500[c]': ['RXN-15292', 'RXN-15293', 'RXN-15294'],
#  'CPD-16549[c]': ['RXN-15341'],
#  'CPD-16618[c]': ['RXN-5921-CARNITINE/NADH/OXYGEN-MOLECULE/PROTON//CPD-16618/TRIMETHYLAMINE/NAD/WATER.74.',
#   'RXN-5921-CARNITINE/NADPH/OXYGEN-MOLECULE/PROTON//CPD-16618/TRIMETHYLAMINE/NADP/WATER.76.'],
#  'CPD-16720[c]': ['RXN0-7010'],
#  'CPD-16843[c]': ['RXN-15607'],
#  'CPD-17063[c]': ['HEMEOSYN-RXN'],
#  'CPD-17087[c]': ['PHOSPHASERDECARB-RXN-CPD-18401/PROTON//CPD-17087/CARBON-DIOXIDE.43.'],
#  'CPD-173[c]': ['RXN0-5297'],
#  'CPD-17574[c]': ['RXN-16312'],
#  'CPD-1772[c]': ['RXN-16002', 'RXN-16003', 'RXN0-299'],
#  'CPD-17985[p]': ['RXN-16685'],
#  'CPD-17986[p]': ['RXN-16687', 'RXN-17392', 'RXN-17393', 'RXN0-3461'],
#  'CPD-17987[p]': ['RXN-16688'],
#  'CPD-17988[p]': ['RXN-16690'],
#  'CPD-18012[c]': ['RXN-20478'],
#  'CPD-18085[c]': ['RXN-16765'],
#  'CPD-18259[p]': ['RXN-16938'],
#  'CPD-18260[c]': ['RXN-16937'],
#  'CPD-18374[c]': ['CARDIOLIPSYN-RXN-CPD-18362//CPD-18374/GLYCEROL.30.'],
#  'CPD-18375[c]': ['CARDIOLIPSYN-RXN-CPD-18373//CPD-18375/GLYCEROL.30.'],
#  'CPD-1843[c]': ['RXN-14251'],
#  'CPD-18529[c]': ['MALTACETYLTRAN-RXN'],
#  'CPD-18719[c]': ['TRANS-RXN-158A',
#   'TRANS-RXN-158A-BETA-D-FRUCTOSE/PTSH-PHOSPHORYLATED//CPD-18719/PTSH-MONOMER.60.',
#   'TRANS-RXN-158A-CPD-10723/PTSH-PHOSPHORYLATED//CPD-18719/PTSH-MONOMER.54.',
#   'TRANS-RXN-158A-Fructofuranose/PTSH-PHOSPHORYLATED//CPD-18719/PTSH-MONOMER.59.',
#   'TRANS-RXN0-501'],
#  'CPD-18805[p]': ['RXN-17392'],
#  'CPD-18808[p]': ['RXN-17393'],
#  'CPD-18809[p]': ['RXN-16691'],
#  'CPD-19233[c]': ['RXN-17944'],
#  'CPD-19237[c]': ['RXN-17956'],
#  'CPD-19240[c]': ['RXN-17960',
#   'TRANS-RXN-238-CPD-19240/ATP/WATER//CPD-19240/ADP/Pi/PROTON.45.'],
#  'CPD-19242[c]': ['RXN-17961',
#   'TRANS-RXN-238-CPD-19242/ATP/WATER//CPD-19242/ADP/Pi/PROTON.45.'],
#  'CPD-19243[c]': ['RXN-17962',
#   'TRANS-RXN-238-CPD-19243/ATP/WATER//CPD-19243/ADP/Pi/PROTON.45.'],
#  'CPD-19319[c]': ['ABC-22-RXN-ATP/CPD-19319/WATER//ADP/CPD-19319/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD-19319/PROTON//CPD-19319/PROTON.35.'],
#  'CPD-19353[c]': ['ABC-22-RXN-ATP/CPD-19353/WATER//ADP/CPD-19353/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD-19353/PROTON//CPD-19353/PROTON.35.'],
#  'CPD-19353[e]': ['TRANS-RXN-377-CPD-19353/ATP/WATER//CPD-19353/ADP/Pi/PROTON.45.'],
#  'CPD-19395[p]': ['RXN-18092', 'RXN-18093'],
#  'CPD-19513[c]': ['TRANS-RXN-108-CPD-19513/PROTON//CPD-19513/PROTON.35.'],
#  'CPD-19542[c]': ['RXN-8638-CPD-19542/ATP/WATER//CPD-19542/ADP/Pi/PROTON.45.'],
#  'CPD-19659[p]': ['RXN0-1802-CPD-19659//CPD-19659.21.'],
#  'CPD-19745[c]': ['RXN-21304'],
#  'CPD-20058[e]': ['TRANS-RXN-378-CPD-20058/ATP/WATER//CPD-20058/ADP/Pi/PROTON.45.'],
#  'CPD-20059[e]': ['TRANS-RXN-378-CPD-20059/ATP/WATER//CPD-20059/ADP/Pi/PROTON.45.'],
#  'CPD-20060[e]': ['TRANS-RXN-378-CPD-20060/ATP/WATER//CPD-20060/ADP/Pi/PROTON.45.'],
#  'CPD-20061[e]': ['TRANS-RXN-378-CPD-20061/ATP/WATER//CPD-20061/ADP/Pi/PROTON.45.'],
#  'CPD-20062[e]': ['TRANS-RXN-378-CPD-20062/ATP/WATER//CPD-20062/ADP/Pi/PROTON.45.'],
#  'CPD-20340[c]': ['3.6.3.23-RXN-CPD-20340/ATP/WATER//CPD-20340/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD-20340/WATER//ADP/CPD-20340/Pi/PROTON.45.',
#   'TRANS-RXN0-267-CPD-20340/PROTON//CPD-20340/PROTON.35.'],
#  'CPD-20735[c]': ['RXN-19242'],
#  'CPD-20746[c]': ['3.4.11.4-RXN-CPD0-1965/WATER//CPD-20746/L-ALPHA-ALANINE.43.',
#   '3.6.3.23-RXN-CPD-20746/ATP/WATER//CPD-20746/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD-20746/WATER//ADP/CPD-20746/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD-20746/WATER//ADP/CPD-20746/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD-20746/PROTON//CPD-20746/PROTON.35.'],
#  'CPD-20750[c]': ['3.6.3.23-RXN-CPD-20750/ATP/WATER//CPD-20750/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD-20750/WATER//ADP/CPD-20750/Pi/PROTON.45.'],
#  'CPD-20757[p]': ['RXN-19256'],
#  'CPD-20861[c]': ['RXN-8638-CPD-20861/ATP/WATER//CPD-20861/ADP/Pi/PROTON.45.'],
#  'CPD-20889[c]': ['RXN-8638-CPD-20889/ATP/WATER//CPD-20889/ADP/Pi/PROTON.45.'],
#  'CPD-20890[p]': ['TRANS-RXN-348'],
#  'CPD-20894[p]': ['TRANS-RXN-337'],
#  'CPD-20897[p]': ['RXN0-2561-CPD-20897/NA+//CPD-20897/NA+.29.',
#   'TRANS-RXN-44-CPD-20897/PROTON//CPD-20897/PROTON.35.',
#   'TRANS-RXN0-596-CPD-20897//CPD-20897.21.',
#   'TRANS-RXN0-628-CPD-20897/PROTON//CPD-20897/PROTON.35.'],
#  'CPD-20898[p]': ['RXN0-2561-CPD-20898/NA+//CPD-20898/NA+.29.',
#   'TRANS-RXN-44-CPD-20898/PROTON//CPD-20898/PROTON.35.',
#   'TRANS-RXN0-596-CPD-20898//CPD-20898.21.',
#   'TRANS-RXN0-628-CPD-20898/PROTON//CPD-20898/PROTON.35.'],
#  'CPD-20921[p]': ['RXN0-2561-CPD-20921/NA+//CPD-20921/NA+.29.',
#   'TRANS-RXN-340',
#   'TRANS-RXN-44-CPD-20921/PROTON//CPD-20921/PROTON.35.',
#   'TRANS-RXN0-596-CPD-20921//CPD-20921.21.',
#   'TRANS-RXN0-628-CPD-20921/PROTON//CPD-20921/PROTON.35.'],
#  'CPD-20966[c]': ['2.4.1.78-RXN'],
#  'CPD-20969[c]': ['RXN-19407',
#   'RXN-19407-CPD-602/WATER//CPD-20969/CPD-15318.35.',
#   'RXN-19407-CPD-602/WATER//CPD-20969/CPD-16551.35.'],
#  'CPD-21015[p]': ['TRANS-RXN-347'],
#  'CPD-21070[e]': ['TRANS-RXN-354'],
#  'CPD-21221[c]': ['3.2.2.23-RXN', 'RXN-18435'],
#  'CPD-21342[c]': ['RXN-8638-CPD-21342/ATP/WATER//CPD-21342/ADP/Pi/PROTON.45.'],
#  'CPD-21406[p]': ['RXN-19793'],
#  'CPD-21407[p]': ['RXN-19793'],
#  'CPD-21519[p]': ['RXN0-2561-CPD-21519/NA+//CPD-21519/NA+.29.',
#   'TRANS-RXN-44-CPD-21519/PROTON//CPD-21519/PROTON.35.',
#   'TRANS-RXN0-596-CPD-21519//CPD-21519.21.',
#   'TRANS-RXN0-628-CPD-21519/PROTON//CPD-21519/PROTON.35.'],
#  'CPD-21605[c]': ['RXN-24050'],
#  'CPD-21702[c]': ['RXN-20077'],
#  'CPD-21703[c]': ['RXN-20079'],
#  'CPD-22115[c]': ['RXN-20428'],
#  'CPD-22332[c]': ['RXN-12895', 'RXN-12896'],
#  'CPD-22373[c]': ['RXN-20756', 'RXN0-2281'],
#  'CPD-22519[c]': ['RXN-20897'],
#  'CPD-22538[p]': ['RXN-20919'],
#  'CPD-22658[c]': ['RXN-21019'],
#  'CPD-22805[c]': ['ABC-22-RXN-ATP/CPD-22805/WATER//ADP/CPD-22805/Pi/PROTON.45.',
#   'RXN-21204',
#   'TRANS-RXN-205A-CPD-22805/PROTON//CPD-22805/PROTON.35.'],
#  'CPD-22841[c]': ['RXN-23923', 'RXN-23924'],
#  'CPD-22978[c]': ['RXN-21279'],
#  'CPD-23251[c]': ['RXN-21350'],
#  'CPD-23305[c]': ['TRANS-RXN-123-CPD-23305/PROTON//CPD-23305/PROTON.35.'],
#  'CPD-23445[c]': ['RXN0-6254'],
#  'CPD-23449[c]': ['RXN-21550'],
#  'CPD-23504[c]': ['ABC-22-RXN-ATP/CPD-23504/WATER//ADP/CPD-23504/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD-23504/PROTON//CPD-23504/PROTON.35.'],
#  'CPD-23[c]': ['RXN0-5063', 'RXN0-6366'],
#  'CPD-2482[c]': ['RXN0-5203'],
#  'CPD-24859[p]': ['RXN0-5407'],
#  'CPD-24871[c]': ['RXN-22643'],
#  'CPD-25003[c]': ['RXN0-7222-CPD-25003/PROTON//CPD-25003/PROTON.35.'],
#  'CPD-25444[c]': ['RXN-22964'],
#  'CPD-25891[c]': ['ABC-11-RXN-ATP/CPD-25891/WATER//ADP/CPD-25891/Pi/PROTON.45.'],
#  'CPD-26475[c]': ['RXN-23919', 'RXN-23921'],
#  'CPD-26565[c]': ['ABC-22-RXN-ATP/CPD-26565/WATER//ADP/CPD-26565/Pi/PROTON.45.',
#   'RXN-24020'],
#  'CPD-26594[p]': ['RXN0-1802-CPD-26594//CPD-26594.21.'],
#  'CPD-26609[c]': ['RXN-24046'],
#  'CPD-26635[c]': ['ABC-22-RXN-ATP/CPD-26635/WATER//ADP/CPD-26635/Pi/PROTON.45.'],
#  'CPD-26748[c]': ['TRANS-RXN-1571'],
#  'CPD-316[c]': ['NADPH-DEHYDROGENASE-FLAVIN-RXN (reverse)',
#   'RXN-12445-CPD-316/NAD//RIBOFLAVIN/NADH/PROTON.36. (reverse)'],
#  'CPD-330[c]': ['RXN-11152[CCO-CYTOSOL]-CPD-330/WATER//CPD0-1083/PROTON.45. (reverse)',
#   'RXN-15925'],
#  'CPD-3344[c]': ['RXN-3482'],
#  'CPD-335[c]': ['RXN-14255'],
#  'CPD-3462[c]': ['RXN0-7165'],
#  'CPD-3565[c]': ['TRANS-RXN0-519'],
#  'CPD-3611[c]': ['TRANS-RXN-98-CPD-3611/PROTON//CPD-3611/PROTON.33.'],
#  'CPD-389[c]': ['OXAMATE-CARBAMOYLTRANSFERASE-RXN',
#   'R165-RXN-CPD-1091/NADP//CPD-389/NADPH/PROTON.36.',
#   'RXN0-7024'],
#  'CPD-43[p]': ['RXN0-2561-CPD-43/NA+//CPD-43/NA+.23.',
#   'TRANS-RXN-44-CPD-43/PROTON//CPD-43/PROTON.29.',
#   'TRANS-RXN0-596-CPD-43//CPD-43.15.',
#   'TRANS-RXN0-628-CPD-43/PROTON//CPD-43/PROTON.29.'],
#  'CPD-444[c]': ['5-METHYLTHIOADENOSINE-PHOSPHORYLASE-RXN',
#   'TRANS-RXN-108-CPD-444/PROTON//CPD-444/PROTON.31.'],
#  'CPD-524[p]': ['RXN0-2561-CPD-524/NA+//CPD-524/NA+.25.',
#   'TRANS-RXN-44-CPD-524/PROTON//CPD-524/PROTON.31.',
#   'TRANS-RXN0-596-CPD-524//CPD-524.17.',
#   'TRANS-RXN0-628-CPD-524/PROTON//CPD-524/PROTON.31.'],
#  'CPD-543[c]': ['RXN-8638-CPD-543/ATP/WATER//CPD-543/ADP/Pi/PROTON.41.'],
#  'CPD-568[c]': ['SPERMACTRAN-RXN'],
#  'CPD-5821[p]': ['3.5.2.17-RXN'],
#  'CPD-582[c]': ['RXN0-262'],
#  'CPD-609[c]': ['TRANS-RXN-108-CPD-609/PROTON//CPD-609/PROTON.31.'],
#  'CPD-6982[c]': ['RXN-7632-CPD-6982/NAD//34-DIHYDROXYPHENYLPYRUVATE/NADH/PROTON.53. (reverse)',
#   'RXN-7632-CPD-6982/NADP//34-DIHYDROXYPHENYLPYRUVATE/NADPH/PROTON.55. (reverse)'],
#  'CPD-69[e]': ['RXN-17753[CCO-EXTRACELLULAR]-CARBAMOYL-P//CPD-69/Pi/PROTON.49.'],
#  'CPD-702[c]': ['RXN0-5141 (reverse)'],
#  'CPD-7249[c]': ['RXN0-7385-CPD-7248/NADPH/PROTON//CPD-7249/NADP.37.',
#   'RXN0-7386-CPD-7248/NADH/PROTON//CPD-7249/NAD.35.',
#   'RXN0-7386-CPD-7248/NADPH/PROTON//CPD-7249/NADP.37.'],
#  'CPD-782[c]': ['RXN0-5065'],
#  'CPD-7836[p]': ['RXN-19312-CPD0-2147/WATER//CPD-7836/L-1-GLYCEROPHOSPHORYLETHANOL-AMINE/PROTON.68.',
#   'RXN0-1802-CPD-7836//CPD-7836.19.',
#   'THIOESTER-RXN-TETRADECANOYL-COA/WATER//CPD-7836/CO-A/PROTON.46.'],
#  'CPD-8363[c]': ['TRANS-RXN-295-CPD-8363//CPD-8363.19.'],
#  'CPD-8490[c]': ['RXN0-280-CPD0-2546/FMNH2/OXYGEN-MOLECULE//CPD-8490/SO3/FMN/WATER/PROTON.63.'],
#  'CPD-8539[c]': ['RXN-21179'],
#  'CPD-8550[p]': ['BETA-LACTAMASE-RXN[CCO-PERI-BAC]-Beta-Lactams/WATER//CPD-8550/PROTON.50.'],
#  'CPD-8625[c]': ['PEPTIDYLPROLYL-ISOMERASE-RXN[CCO-CYTOSOL]-CPD-8624//CPD-8625.32.'],
#  'CPD-8625[p]': ['PEPTIDYLPROLYL-ISOMERASE-RXN[CCO-PERI-BAC]-CPD-8624//CPD-8625.33.'],
#  'CPD-8670[c]': ['RXN-8487'],
#  'CPD-8891[p]': ['TRANS-RXN0-467'],
#  'CPD-9053[c]': ['RXN0-280-CPD0-2075/FMNH2/OXYGEN-MOLECULE//CPD-9053/SO3/FMN/WATER/PROTON.63.'],
#  'CPD-9247[p]': ['RXN-9555', 'RXN0-1802-CPD-9247//CPD-9247.19.'],
#  'CPD-9288[e]': ['TRANS-RXN-355'],
#  'CPD-9646[p]': ['RXN-16281',
#   'RXN0-2001',
#   'RXN0-5383',
#   'UNDECAPRENYL-DIPHOSPHATASE-RXN[CCI-PERI-BAC-GN]-UNDECAPRENYL-DIPHOSPHATE/WATER//CPD-9646/Pi/PROTON.68.'],
#  'CPD-9956[c]': ['DHHB-METHYLTRANSFER-RXN',
#   'RXN-18549',
#   'RXN-19950-DISULFOXRED-MONOMER/UBIQUINONE-8//MONOMER0-4152/CPD-9956.57.',
#   'RXN-19950-Reduced-Disulfide-Carrier-Proteins/UBIQUINONE-8//Oxidized-Disulfide-Carrier-Proteins/CPD-9956.94.',
#   'RXN0-7319-CPD-381/UBIQUINONE-8//2-KETOGLUTARATE/CPD-9956.47.',
#   'RXN0-7385-UBIQUINONE-8/NADPH/PROTON//CPD-9956/NADP.41.',
#   'RXN0-7386-UBIQUINONE-8/NADH/PROTON//CPD-9956/NAD.39.',
#   'RXN0-7386-UBIQUINONE-8/NADPH/PROTON//CPD-9956/NADP.41.'],
#  'CPD-9956[m]': ['RXN-20056-a--reduced-DsbB-protein/UBIQUINONE-8//an-oxidized-DsbB-protein/CPD-9956.72.'],
#  'CPD0-1040[c]': ['TRANS-RXN-108-CPD0-1040/PROTON//CPD0-1040/PROTON.35.'],
#  'CPD0-1042[c]': ['TRANS-RXN-108-CPD0-1042/PROTON//CPD0-1042/PROTON.35.'],
#  'CPD0-1043[c]': ['TRANS-RXN-108-CPD0-1043/PROTON//CPD0-1043/PROTON.35.'],
#  'CPD0-1049[c]': ['RXN0-5210'],
#  'CPD0-1065[c]': ['RXN0-5217'],
#  'CPD0-1075[c]': ['ABC-23-RXN-ATP/CPD0-1075/WATER//ADP/CPD0-1075/Pi/PROTON.45.'],
#  'CPD0-1076[c]': ['ABC-23-RXN-ATP/CPD0-1076/WATER//ADP/CPD0-1076/Pi/PROTON.45.'],
#  'CPD0-1085[c]': ['3.6.3.23-RXN-CPD0-1085/ATP/WATER//CPD0-1085/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1085/WATER//ADP/CPD0-1085/Pi/PROTON.45.'],
#  'CPD0-1101[p]': ['RXN0-5294'],
#  'CPD0-1129[c]': ['ABC-22-RXN-ATP/CPD0-1129/WATER//ADP/CPD0-1129/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD0-1129/PROTON//CPD0-1129/PROTON.35.'],
#  'CPD0-1137[c]': ['TRANS-RXN-108-CPD0-1137/PROTON//CPD0-1137/PROTON.35.'],
#  'CPD0-1157[c]': ['RXN0-5387'],
#  'CPD0-1159[p]': ['RXN0-1802-CPD0-1159//CPD0-1159.21.', 'TRANS-RXN0-525'],
#  'CPD0-1192[p]': ['TRANS-RXN0-549'],
#  'CPD0-1193[c]': ['RXN0-5414'],
#  'CPD0-1193[e]': ['TRANS-RXN0-275'],
#  'CPD0-1221[c]': ['RXN0-7436'],
#  'CPD0-1277[e]': ['TRANS-RXN-378-CPD0-1277/ATP/WATER//CPD0-1277/ADP/Pi/PROTON.45.'],
#  'CPD0-1311[c]': ['TRANS-RXN-108-CPD0-1311/PROTON//CPD0-1311/PROTON.35.'],
#  'CPD0-1312[c]': ['TRANS-RXN-108-CPD0-1312/PROTON//CPD0-1312/PROTON.35.'],
#  'CPD0-1319[c]': ['TRANS-RXN-108-CPD0-1319/PROTON//CPD0-1319/PROTON.35.'],
#  'CPD0-1320[c]': ['TRANS-RXN-108-CPD0-1320/PROTON//CPD0-1320/PROTON.35.'],
#  'CPD0-1321[c]': ['TRANS-RXN-108-CPD0-1321/PROTON//CPD0-1321/PROTON.35.'],
#  'CPD0-1322[c]': ['TRANS-RXN-108-CPD0-1322/PROTON//CPD0-1322/PROTON.35.'],
#  'CPD0-1395[c]': ['RXN-23276'],
#  'CPD0-1470[p]': ['TRANS-RXN-369'],
#  'CPD0-1620[c]': ['3.6.3.23-RXN-CPD0-1620/ATP/WATER//CPD0-1620/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1620/WATER//ADP/CPD0-1620/Pi/PROTON.45.'],
#  'CPD0-1719[c]': ['RXN0-5522'],
#  'CPD0-1906[c]': ['3.6.3.23-RXN-CPD0-1906/ATP/WATER//CPD0-1906/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1906/WATER//ADP/CPD0-1906/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1906/WATER//ADP/CPD0-1906/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1906/PROTON//CPD0-1906/PROTON.35.'],
#  'CPD0-1907[c]': ['3.6.3.23-RXN-CPD0-1907/ATP/WATER//CPD0-1907/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1907/WATER//ADP/CPD0-1907/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1907/WATER//ADP/CPD0-1907/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1907/PROTON//CPD0-1907/PROTON.35.'],
#  'CPD0-1908[c]': ['3.6.3.23-RXN-CPD0-1908/ATP/WATER//CPD0-1908/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1908/WATER//ADP/CPD0-1908/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1908/WATER//ADP/CPD0-1908/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1908/PROTON//CPD0-1908/PROTON.35.'],
#  'CPD0-1909[c]': ['3.6.3.23-RXN-CPD0-1909/ATP/WATER//CPD0-1909/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1909/WATER//ADP/CPD0-1909/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1909/WATER//ADP/CPD0-1909/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1909/PROTON//CPD0-1909/PROTON.35.'],
#  'CPD0-1910[c]': ['3.6.3.23-RXN-CPD0-1910/ATP/WATER//CPD0-1910/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1910/WATER//ADP/CPD0-1910/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1910/WATER//ADP/CPD0-1910/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1910/PROTON//CPD0-1910/PROTON.35.'],
#  'CPD0-1911[c]': ['3.6.3.23-RXN-CPD0-1911/ATP/WATER//CPD0-1911/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1911/WATER//ADP/CPD0-1911/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1911/WATER//ADP/CPD0-1911/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1911/PROTON//CPD0-1911/PROTON.35.'],
#  'CPD0-1913[c]': ['3.6.3.23-RXN-CPD0-1913/ATP/WATER//CPD0-1913/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1913/WATER//ADP/CPD0-1913/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1913/WATER//ADP/CPD0-1913/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1913/PROTON//CPD0-1913/PROTON.35.'],
#  'CPD0-1915[c]': ['3.6.3.23-RXN-CPD0-1915/ATP/WATER//CPD0-1915/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1915/WATER//ADP/CPD0-1915/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1915/WATER//ADP/CPD0-1915/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1915/PROTON//CPD0-1915/PROTON.35.'],
#  'CPD0-1938[e]': ['TRANS-RXN-359'],
#  'CPD0-1944[c]': ['3.6.3.23-RXN-CPD0-1944/ATP/WATER//CPD0-1944/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-1944/WATER//ADP/CPD0-1944/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-1944/WATER//ADP/CPD0-1944/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-1944/PROTON//CPD0-1944/PROTON.35.'],
#  'CPD0-1966[c]': ['ABC-22-RXN-ATP/CPD0-1966/WATER//ADP/CPD0-1966/Pi/PROTON.45.'],
#  'CPD0-2056[c]': ['3.6.3.23-RXN-CPD0-2056/ATP/WATER//CPD0-2056/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-2056/WATER//ADP/CPD0-2056/Pi/PROTON.45.',
#   'TRANS-RXN0-267-CPD0-2056/PROTON//CPD0-2056/PROTON.35.'],
#  'CPD0-2061[c]': ['RXN-19950-DISULFOXRED-MONOMER/CPD0-1118//MONOMER0-4152/CPD0-2061.55.',
#   'RXN-19950-Reduced-Disulfide-Carrier-Proteins/CPD0-1118//Oxidized-Disulfide-Carrier-Proteins/CPD0-2061.92.',
#   'RXN0-7319-CPD-381/CPD0-1118//2-KETOGLUTARATE/CPD0-2061.45.',
#   'RXN0-7385-CPD0-1118/NADPH/PROTON//CPD0-2061/NADP.39.',
#   'RXN0-7386-CPD0-1118/NADH/PROTON//CPD0-2061/NAD.37.',
#   'RXN0-7386-CPD0-1118/NADPH/PROTON//CPD0-2061/NADP.39.'],
#  'CPD0-2061[i]': ['RXN0-7235-ETF-Reduced/CPD0-1118//ETF-Oxidized/CPD0-2061/PROTON.53.'],
#  'CPD0-2061[m]': ['RXN-20056-DSBBPROT-MONOMER/CPD0-1118//MONOMER0-4142/CPD0-2061.52.',
#   'RXN-20056-a--reduced-DsbB-protein/CPD0-1118//an-oxidized-DsbB-protein/CPD0-2061.70.'],
#  'CPD0-2064[p]': ['RXN0-1802-CPD0-2064//CPD0-2064.21.'],
#  'CPD0-2073[c]': ['3.6.3.23-RXN-CPD0-2073/ATP/WATER//CPD0-2073/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-2073/WATER//ADP/CPD0-2073/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-2073/WATER//ADP/CPD0-2073/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-2073/PROTON//CPD0-2073/PROTON.35.'],
#  'CPD0-2101[c]': ['RXN0-6367 (reverse)'],
#  'CPD0-2113[c]': ['RXN-1381-STEAROYL-COA/GLYCEROL-3P//CPD0-2113/CO-A.41.'],
#  'CPD0-2114[c]': ['ABC-11-RXN-ATP/CPD0-2114/WATER//ADP/CPD0-2114/Pi/PROTON.45.'],
#  'CPD0-2134[c]': ['TRANS-RXN-295-CPD0-2134//CPD0-2134.21.'],
#  'CPD0-2167[c]': ['RXN0-6550'],
#  'CPD0-2173[c]': ['TRANS-RXN-295-CPD0-2173//CPD0-2173.21.'],
#  'CPD0-2200[c]': ['RXN-1381-LAUROYLCOA-CPD/GLYCEROL-3P//CPD0-2200/CO-A.43.'],
#  'CPD0-2207[c]': ['TRANS-RXN-295-CPD0-2207//CPD0-2207.21.'],
#  'CPD0-2229[c]': ['TRANS-RXN-295-CPD0-2229//CPD0-2229.21.'],
#  'CPD0-2241[c]': ['ABC-11-RXN-ATP/CPD0-2241/WATER//ADP/CPD0-2241/Pi/PROTON.45.',
#   'TRANS-RXN-298'],
#  'CPD0-2367[c]': ['RXN-21067'],
#  'CPD0-2377[c]': ['RXN-21728'],
#  'CPD0-2381[c]': ['RXN0-6576'],
#  'CPD0-2471[c]': ['RXN0-6726'],
#  'CPD0-2485[c]': ['TRANS-RXN0-492'],
#  'CPD0-2486[c]': ['TRANS-RXN0-491'],
#  'CPD0-2555[c]': ['3.6.3.23-RXN-CPD0-2555/ATP/WATER//CPD0-2555/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-2555/WATER//ADP/CPD0-2555/Pi/PROTON.45.',
#   'ABC-8-RXN-ATP/CPD0-2555/WATER//ADP/CPD0-2555/Pi/PROTON.45.',
#   'TRANS-RXN0-288-CPD0-2555/PROTON//CPD0-2555/PROTON.35.'],
#  'CPD0-2556[p]': ['RXN0-2561-CPD0-2556/NA+//CPD0-2556/NA+.29.',
#   'TRANS-RXN-44-CPD0-2556/PROTON//CPD0-2556/PROTON.35.',
#   'TRANS-RXN0-596-CPD0-2556//CPD0-2556.21.',
#   'TRANS-RXN0-628-CPD0-2556/PROTON//CPD0-2556/PROTON.35.'],
#  'CPD0-2559[c]': ['RXN0-7103'],
#  'CPD0-2583[c]': ['TRANS-RXN-1570'],
#  'CPD0-2603[c]': ['ABC-22-RXN-ATP/CPD0-2603/WATER//ADP/CPD0-2603/Pi/PROTON.45.',
#   'TRANS-RXN-205A-CPD0-2603/PROTON//CPD0-2603/PROTON.35.'],
#  'CPD0-2629[c]': ['RXN-8638-CPD0-2629/ATP/WATER//CPD0-2629/ADP/Pi/PROTON.45.'],
#  'CPD0-2630[c]': ['RXN-8638-CPD0-2630/ATP/WATER//CPD0-2630/ADP/Pi/PROTON.45.'],
#  'CPD0-2633[c]': ['TRANS-RXN-108-CPD0-2633/PROTON//CPD0-2633/PROTON.35.'],
#  'CPD0-2650[c]': ['3.6.3.23-RXN-CPD0-2650/ATP/WATER//CPD0-2650/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-2650/WATER//ADP/CPD0-2650/Pi/PROTON.45.',
#   'TRANS-RXN0-267-CPD0-2650/PROTON//CPD0-2650/PROTON.35.'],
#  'CPD0-2651[c]': ['3.6.3.23-RXN-CPD0-2651/ATP/WATER//CPD0-2651/ADP/Pi/PROTON.45.',
#   'ABC-22-RXN-ATP/CPD0-2651/WATER//ADP/CPD0-2651/Pi/PROTON.45.',
#   'TRANS-RXN0-267-CPD0-2651/PROTON//CPD0-2651/PROTON.35.'],
#  'CPD0-2714[c]': ['TRANS-RXN0-630'],
#  'CPD0-621[c]': ['ABC-11-RXN-ATP/CPD0-621/WATER//ADP/CPD0-621/Pi/PROTON.43.',
#   'TRANS-RXN-297'],
#  'CPD8J2-27[c]': ['RXN-22606'],
#  'CPLX0-7721[c]': ['RXN0-6459'],
#  'CPLX0-7754[c]': ['RXN0-6499'],
#  'CPLX0-8265[i]': ['RXN0-6518'],
#  'CPLX0-8307[m]': ['RXN0-6459'],
#  'CPLX0-8570[c]': ['RXN0-801'],
#  'CPLX0-9041[i]': ['RXN0-7406'],
#  'CREATINE[p]': ['PHOSPHOAMIDASE-RXN'],
#  'CROTONO-BETAINE[c]': ['RXN-8638-CROTONO-BETAINE/ATP/WATER//CROTONO-BETAINE/ADP/Pi/PROTON.57.'],
#  'Carboxylates[c]': ['ACYL-COA-HYDROLASE-RXN',
#   'ALDEHYDE-DEHYDROGENASE-NADP+-RXN',
#   'CARBOXYLESTERASE-RXN'],
#  'Carboxylates[p]': ['CARBOXYLATE-REDUCTASE-RXN',
#   'LYSOPHOSPHOLIPASE-RXN',
#   'RXN-16225',
#   'RXN-19311'],
#  'CcmABCD-Complex[c]': ['RXN-21408'],
#  'CcmCDE-Complex-Heme[p]': ['RXN-21407'],
#  'CcmE-Protein-Heme-Ox[p]': ['RXN0-7454'],
#  'CcmE-Proteins[c]': ['RXN-21424'],
#  'Charged-SEC-tRNAs[c]': ['2.9.1.1-RXN'],
#  'Cleaved-Type-IV-Prepillins[c]': ['3.4.23.43-RXN'],
#  'Cyclic-N6-threonylcarbamoyl-A37-tRNAs[c]': ['RXN0-7115'],
#  'Cytochromes-B-Oxidized[c]': ['CYTD-RED-RXN'],
#  'Cytochromes-B561-Ox[c]': ['CYTD-RED-RXN-Cytochromes-B561-Red/Cytochromes-D-Oxidized//Cytochromes-B561-Ox/Cytochromes-D-Reduced.87.'],
#  'Cytochromes-C-Reduced[c]': ['RXN-12876'],
#  'Cytochromes-C550-Red[c]': ['RXN-12876-Cytochromes-C550-Ox/ASCORBATE//L-DEHYDRO-ASCORBATE/Cytochromes-C550-Red/PROTON.79.'],
#  'Cytochromes-C552-Red[c]': ['RXN-12876-Cytochromes-C552-Ox/ASCORBATE//L-DEHYDRO-ASCORBATE/Cytochromes-C552-Red/PROTON.79.'],
#  'Cytochromes-C554-Red[c]': ['RXN-12876-Cytochromes-C554-Ox/ASCORBATE//L-DEHYDRO-ASCORBATE/Cytochromes-C554-Red/PROTON.79.'],
#  'Cytochromes-CL-Red[c]': ['RXN-12876-Cytochromes-CL-Ox/ASCORBATE//L-DEHYDRO-ASCORBATE/Cytochromes-CL-Red/PROTON.75.'],
#  'Cytochromes-D-Reduced[c]': ['CYTD-RED-RXN',
#   'CYTD-RED-RXN-Cytochromes-B561-Red/Cytochromes-D-Oxidized//Cytochromes-B561-Ox/Cytochromes-D-Reduced.87.',
#   'CYTD-RED-RXN-FERROCYTOCHROME-B5/Cytochromes-D-Oxidized//FERRICYTOCHROME-B5/Cytochromes-D-Reduced.84.'],
#  'Cytochromes-c[c]': ['RXN-21424'],
#  'D-ARABINOSE[c]': ['RXN0-7219',
#   'RXN0-7219-CPD-3785/WATER//ALPHA-D-GALACTOSE/D-ARABINOSE.46.',
#   'RXN0-7219-CPD-3785/WATER//GALACTOSE/D-ARABINOSE.38.',
#   'RXN0-7221',
#   'RXN0-7221-CPD-12043/PROTON//D-ARABINOSE/PROTON.37.',
#   'RXN0-7221-CPD-12044/PROTON//D-ARABINOSE/PROTON.37.',
#   'RXN0-7221-CPD-12047/PROTON//D-ARABINOSE/PROTON.37.',
#   'RXN0-7221-CPD-12049/PROTON//D-ARABINOSE/PROTON.37.',
#   'RXN0-7221-CPD-15700/PROTON//D-ARABINOSE/PROTON.37.',
#   'RXN0-7221-D-ARABINOSE/PROTON//D-ARABINOSE/PROTON.39.'],
#  'D-Amino-Acids[c]': ['RXN-15041'],
#  'D-CARNITINE[c]': ['RXN-8638-D-CARNITINE/ATP/WATER//D-CARNITINE/ADP/Pi/PROTON.49.'],
#  'D-GALACTURONATE[c]': ['TRANS-RXN-123'],
#  'D-Glucose[c]': ['RXN0-7077',
#   'RXN0-7077-ALPHA-GLUCOSE/PROTON//D-Glucose/PROTON.39.',
#   'RXN0-7077-CPD-15374/PROTON//D-Glucose/PROTON.35.',
#   'RXN0-7077-D-Glucose/PROTON//D-Glucose/PROTON.35.',
#   'RXN0-7077-GLC/PROTON//D-Glucose/PROTON.29.'],
#  'D-Xylose[c]': ['ABC-33-RXN',
#   'ABC-33-RXN-ATP/BETA-D-XYLOSE/WATER//ADP/D-Xylose/Pi/PROTON.48.',
#   'ABC-33-RXN-ATP/CPD-15377/WATER//ADP/D-Xylose/Pi/PROTON.44.',
#   'ABC-33-RXN-ATP/CPD-25028/WATER//ADP/D-Xylose/Pi/PROTON.44.',
#   'ABC-33-RXN-ATP/D-Xylose/WATER//ADP/D-Xylose/Pi/PROTON.43.',
#   'TRANS-RXN-30',
#   'TRANS-RXN-30-BETA-D-XYLOSE/PROTON//D-Xylose/PROTON.38.',
#   'TRANS-RXN-30-CPD-15377/PROTON//D-Xylose/PROTON.34.',
#   'TRANS-RXN-30-CPD-25028/PROTON//D-Xylose/PROTON.34.',
#   'TRANS-RXN-30-D-Xylose/PROTON//D-Xylose/PROTON.33.'],
#  'D-alanine-carrier-protein[c]': ['RXN-20428'],
#  'D-fructofuranose-1-phosphate[c]': ['TRANS-RXN-158',
#   'TRANS-RXN-158-BETA-D-FRUCTOSE/PTSI-PHOSPHORYLATED//D-fructofuranose-1-phosphate/PTSI-MONOMER.79.',
#   'TRANS-RXN-158-CPD-10723/PTSI-PHOSPHORYLATED//D-fructofuranose-1-phosphate/PTSI-MONOMER.73.',
#   'TRANS-RXN-158-Fructofuranose/PTSI-PHOSPHORYLATED//D-fructofuranose-1-phosphate/PTSI-MONOMER.78.'],
#  'D-fructopyranose-1-phosphate[c]': ['TRANS-RXN0-618-PTSI-PHOSPHORYLATED/CPD-10725//PTSI-MONOMER/D-fructopyranose-1-phosphate.73.',
#   'TRANS-RXN0-618-PTSI-PHOSPHORYLATED/CPD-10726//PTSI-MONOMER/D-fructopyranose-1-phosphate.73.',
#   'TRANS-RXN0-618-PTSI-PHOSPHORYLATED/D-Fructopyranose//PTSI-MONOMER/D-fructopyranose-1-phosphate.80.'],
#  'DE-O-K-GLUCONATE[c]': ['KDUD-RXN'],
#  'DEOXYCHOLATE[e]': ['TRANS-RXN-352', 'TRANS-RXN-365'],
#  'DIHYDROFOLATE-GLU-N[c]': ['RXN-18710', 'RXN0-7068', 'RXN0-7083'],
#  'DIPEPTIDES[c]': ['ABC-8-RXN', 'TRANS-RXN0-288'],
#  'DNA-Containing-N6-Methyladenine[c]': ['2.1.1.72-RXN'],
#  'DNA-Cytidines[c]': ['DEOXYRIBODIPYRIMIDINE-PHOTOLYASE-RXN', 'RXN-19026'],
#  'DNA-Guanines[c]': ['2.1.1.63-RXN'],
#  'DNA-N[c]': ['DNA-LIGASE-NAD+-RXN', 'RXN-17823', 'RXN-17919'],
#  'DNA-thymidines[c]': ['DEOXYRIBODIPYRIMIDINE-PHOTOLYASE-RXN', 'RXN-19025'],
#  'DNA-with-Uracils[c]': ['RXN-22577'],
#  'DSBBPROT-MONOMER[i]': ['RXN-20000-DISULFOXRED-MONOMER/MONOMER0-4142//MONOMER0-4152/DSBBPROT-MONOMER.66.',
#   'RXN-20000-a-reduced-DsbA-protein/MONOMER0-4142//an-oxidized-DsbA-protein/DSBBPROT-MONOMER.80.'],
#  'DTDP-RHAMNOSE[c]': ['DTDPDEHYRHAMREDUCT-RXN (reverse)'],
#  'Der-GTPase[c]': ['RXN-21992'],
#  'Diacylglycerol-Prolipoproteins[c]': ['RXN-17362'],
#  'Donor-H1[i]': ['RXN-21407'],
#  'EF-P-beta-lysyl-L-lysine[c]': ['RXN0-6531'],
#  'EF-P-lysyl-hydroxylysine[c]': ['RXN0-7000'],
#  'ENTB-CPLX[c]': ['RXN0-7105'],
#  'ETHYL-2R-METHYL-3S-HYDROXYBUTANOATE[c]': ['RXN0-1941 (reverse)'],
#  'ETR-Quinones[i]': ['RXN-17652 (reverse)', 'RXN-17663 (reverse)'],
#  'ETR-Semiquinones[c]': ['RXN-21424'],
#  'Elongator-tRNAMet-acetylcytidine[c]': ['RXN0-5418'],
#  'FADH2[c]': ['RXN-8506 (reverse)'],
#  'FERRIC-CITRATE-COMPLEX[c]': ['ABC-9-RXN'],
#  'FERRICYTOCHROME-B5[c]': ['CYTD-RED-RXN-FERROCYTOCHROME-B5/Cytochromes-D-Oxidized//FERRICYTOCHROME-B5/Cytochromes-D-Reduced.84.'],
#  'Fatty-Acids[p]': ['RXN0-6952'],
#  'FeS-Cluster-Chaperones-ATP[c]': ['RXN-14391'],
#  'Flavodoxins-Semiquinones[c]': ['RNTRACTIV-RXN'],
#  'Fructofuranose[c]': ['RXN-17726'],
#  'GDP[p]': ['RXN0-5462[CCI-PERI-BAC-GN]-GTP/WATER//GDP/Pi/PROTON.42.'],
#  'GLUCURONATE[c]': ['TRANS-RXN-35'],
#  'Gentamycins[e]': ['TRANS-RXN-360'],
#  'GlcNAc-1-6-anhydro-MurNAc-pentapeptide[c]': ['RXN0-5190[CCO-CYTOSOL]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.117.'],
#  'GlcNAc-1-6-anhydro-MurNAc-pentapeptide[p]': ['RXN0-5190[CCI-PERI-BAC-GN]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.121.',
#   'RXN0-5190[CCO-PERI-BAC]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.118.'],
#  'Glucosides[c]': ['RXN-20682 (reverse)'],
#  'Grx-GSH-dithiol[c]': ['RXN-21026', 'RXN-982'],
#  'HEME_D[c]': ['RXN-8073'],
#  'HEPTA-ACYLATED-LIPID-A[c]': ['RXN0-1842'],
#  'HEPTOSYL-KDO2-LIPID-IVA[c]': ['RXN0-5057'],
#  'HEXANAL[c]': ['RXN0-280-CPD0-2074/FMNH2/OXYGEN-MOLECULE//HEXANAL/SO3/FMN/WATER/PROTON.62.'],
#  'HIPA-P[c]': ['RXN0-5211'],
#  'HISTIDINOL[p]': ['HISTIDPHOS-RXN[CCO-PERI-BAC]-L-HISTIDINOL-P/WATER//HISTIDINOL/Pi.50.'],
#  'HYDROQUINONE[c]': ['RXN0-5295'],
#  'HYPOTAURINE[c]': ['TRANS-RXN0-509'],
#  'HyCE-Ni-Fe-CO-CN2[c]': ['RXN-22650'],
#  'HypA[c]': ['RXN-22650'],
#  'HypCDE[c]': ['RXN-22649'],
#  'HypC[c]': ['RXN-22646'],
#  'ILE-tRNAs[c]': ['RXN0-7431'],
#  'IMIDAZOLE-PYRUVATE[c]': ['2.6.1.57-RXN/HIS.4.'],
#  'ISOBUTANOL[c]': ['RXN0-7119 (reverse)'],
#  'Iron-Sulfur-Cluster-Scaffold-Proteins[c]': ['RXN0-949'],
#  'KDO2-LIPID-IVA-COLD[c]': ['MYRPALMTRAN-RXN'],
#  'KETOBUTFORMLY-MONOMER[c]': ['TDCEACT1-RXN'],
#  'KYNURENATE[c]': ['RXN-21858'],
#  'L-1-LECITHIN[c]': ['RXN-8638-L-1-LECITHIN/ATP/WATER//L-1-LECITHIN/ADP/Pi/PROTON.51.'],
#  'L-Amino-Acids[c]': ['RXN-23884'],
#  'L-CYSTINE[i]': ['TRANS-RXN0-593'],
#  'L-CYSTINE[p]': ['RXN0-6990', 'TRANS-RXN-285'],
#  'L-DI-GMP[c]': ['RXN0-4181'],
#  'L-Galactose[c]': ['RXN0-7222'],
#  'L-Methionine-sulfoxides[c]': ['RXN0-6721', 'TRANS-RXN0-511'],
#  'L-PHOSPHATIDATE[c]': ['1-ACYLGLYCEROL-3-P-ACYLTRANSFER-RXN',
#   'DIACYLGLYKIN-RXN',
#   'RXN-1623'],
#  'L-PHOSPHATIDATE[p]': ['RXN-11277'],
#  'L-fucoses[c]': ['TRANS-RXN-20',
#   'TRANS-RXN-20-CPD-10329/PROTON//L-fucoses/PROTON.35.',
#   'TRANS-RXN-20-CPD-15619/PROTON//L-fucoses/PROTON.35.',
#   'TRANS-RXN-20-CPD0-1107/PROTON//L-fucoses/PROTON.35.',
#   'TRANS-RXN-20-L-fucoses/PROTON//L-fucoses/PROTON.35.'],
#  'L-leucyl-L-arginyl-Protein[c]': ['RXN-17846'],
#  'L-leucyl-L-lysyl-Protein[c]': ['LEUCYLTRANSFERASE-RXN'],
#  'L-phenylalanyl-L-arginyl-Protein[c]': ['RXN-17847'],
#  'L-phenylalanyl-L-lysyl-Protein[c]': ['RXN-17848'],
#  'L-rhamnose[c]': ['TRANS-RXN-112'],
#  'L-seryl-NRPS[c]': ['RXN-19472', 'RXN-19473'],
#  'LEU-tRNAs[c]': ['LEUCYLTRANSFERASE-RXN', 'RXN-17846'],
#  'LYS-tRNAs[c]': ['RXN0-7429', 'RXN0-7432', 'RXN0-7434'],
#  'Lipoprotein-signal-peptide[c]': ['RXN-17362'],
#  'Long-Chain-3-oxo-ACPs[c]': ['2.3.1.41-RXN'],
#  'Long-Chain-Fatty-Acids[p]': ['RXN0-1802'],
#  'Lysidine-tRNA-Ile2[c]': ['RXN-1961'],
#  'MALEATE[c]': ['TRANS-RXN0-517-MALEATE/PROTON//MALEATE/PROTON.31.'],
#  'MANNOSE[c]': ['GDPMANMANHYDRO-RXN'],
#  'MANNOSE[p]': ['RXN-17724',
#   'RXN-17724-CPD-15711/WATER//MANNOSE/Pi.28.',
#   'RXN-17724-MANNOSE-6P/WATER//MANNOSE/Pi.29.',
#   'RXN-17725'],
#  'MENADIOL[c]': ['NADH-DEHYDROGENASE-QUINONE-RXN',
#   'RXN0-7385-CPD-3766/NADPH/PROTON//MENADIOL/NADP.37.',
#   'RXN0-7386-CPD-3766/NADPH/PROTON//MENADIOL/NADP.37.'],
#  'METHIONYL-PEPTIDE[c]': ['3.5.1.88-RXN'],
#  'METHYL-BETA-D-GALACTOSIDE[c]': ['TRANS-RXN0-520', 'TRANS-RXN0-541'],
#  'MG+2[c]': ['TRANS-RXN-141', 'TRANS-RXN-250'],
#  'MONOMER0-2741[c]': ['RXN0-5177'],
#  'MONOMER0-4142[c]': ['RXN-18549', 'RXN-18550'],
#  'MONOMER0-4147[c]': ['RXN0-6389'],
#  'MONOMER0-4152[e]': ['RXN-20160-DISULFOXRED-MONOMER/MONOMER0-4142//MONOMER0-4152/DSBBPROT-MONOMER.66.',
#   'RXN-20160-DISULFOXRED-MONOMER/an-oxidized-DsbB-protein//MONOMER0-4152/a--reduced-DsbB-protein.84.'],
#  'MONOMER0-4152[i]': ['RXN-19988', 'RXN-19998'],
#  'MONOMER0-4180[c]': ['RXN0-6464'],
#  'MONOMER0-4288[c]': ['RXN0-7040'],
#  'MONOMER0-4565[c]': ['RXN0-7444'],
#  'MONOMETHYL-ESTER-OF-TRANS-ACONITATE[c]': ['RXN0-2441'],
#  'MPT-Synthases[c]': ['RXN0-7198'],
#  'MYO-INOSITOL[c]': ['RXN-7253', 'RXN0-5408'],
#  'Methylated-Ribosomal-Protein-L11s[c]': ['RXN0-5419'],
#  'Methylketones[c]': ['RXN-13248'],
#  'Mnm5Se2U-containing-tRNAs[c]': ['RXN-20757', 'RXN0-2281'],
#  'N-23-DIHYDROXYBENZOYL-L-SERINE[e]': ['TRANS-RXN0-449'],
#  'N-Acetoxy-Arylamines[c]': ['2.3.1.118-RXN'],
#  'N-Substituted-Amino-Acids[c]': ['AMINOCYL-TRNA-HYDROLASE-RXN',
#   'AMINOCYL-TRNA-HYDROLASE-RXN__EG10785-MONOMER'],
#  'N-acetyl-beta-D-hexosamines[c]': ['3.2.1.52-RXN'],
#  'N-formyl-L-methionyl-tRNAfmet[c]': ['METHIONYL-TRNA-FORMYLTRANSFERASE-RXN-10-FORMYL-THF/L-methionyl-tRNAfmet//THF/N-formyl-L-methionyl-tRNAfmet/PROTON.77.',
#   'RXN0-7422-CPD-14932/L-methionyl-tRNAfmet//DIHYDROFOLATE/N-formyl-L-methionyl-tRNAfmet/PROTON.83.'],
#  'N-terminal-N-Ac-L-Serine-L7[c]': ['RXN0-5231'],
#  'N1-ACETYLSPERMINE[c]': ['DIAMACTRANS-RXN-SPERMINE/ACETYL-COA//N1-ACETYLSPERMINE/CO-A/PROTON.51.'],
#  'N6-met-threonylcarbamoyl-A37-tRNAs[c]': ['RXN0-7114'],
#  'N6N6-Dimethyladenine-Containing-rRNAs[c]': ['RXN0-5437'],
#  'NAD[p]': ['RXN-5822[CCO-PERI-BAC]-NADP/WATER//NAD/Pi.33.'],
#  'NARX-CPLX[m]': ['NARPX-RXN'],
#  'NAcMur-Peptide-NAcGlc-Undecaprenols[c]': ['RXN0-5190[CCO-CYTOSOL]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.117.'],
#  'NAcMur-Peptide-NAcGlc-Undecaprenols[p]': ['RXN0-5190[CCI-PERI-BAC-GN]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.121.',
#   'RXN0-5190[CCO-PERI-BAC]-Nascent-peptidoglycan-dimer//NAcMur-Peptide-NAcGlc-Undecaprenols/GlcNAc-1-6-anhydro-MurNAc-pentapeptide.118.'],
#  'NITROUS-OXIDE[c]': ['RXN0-2721'],
#  'NMNH[c]': ['RXN0-4401'],
#  'Ni_HypB[c]': ['RXN-22956'],
#  'Non-Glucosylated-Glucose-Acceptors[p]': ['3.2.1.21-RXN',
#   '3.2.1.21-RXN-Beta-D-glucosides/WATER//Non-Glucosylated-Glucose-Acceptors/ALPHA-GLUCOSE.74.',
#   '3.2.1.21-RXN-Beta-D-glucosides/WATER//Non-Glucosylated-Glucose-Acceptors/GLC.64.'],
#  'Nucleobases-in-DNA[c]': ['RXN-12353'],
#  'Nucleosides[c]': ['TRANS-RXN-108'],
#  'Ox-Prx-Disulfide-Reductases[c]': ['RXN-20691 (reverse)', 'RXN-20692'],
#  'Oxidized-Disulfide-Carrier-Proteins[e]': ['RXN-20160-Reduced-Disulfide-Carrier-Proteins/MONOMER0-4142//Oxidized-Disulfide-Carrier-Proteins/DSBBPROT-MONOMER.103.',
#   'RXN-20160-Reduced-Disulfide-Carrier-Proteins/an-oxidized-DsbB-protein//Oxidized-Disulfide-Carrier-Proteins/a--reduced-DsbB-protein.121.'],
#  'PALMITATE[p]': ['RXN-19312-CPD-8353/WATER//PALMITATE/L-1-GLYCEROPHOSPHORYLETHANOL-AMINE/PROTON.68.',
#   'RXN0-1802-PALMITATE//PALMITATE.21.'],
#  'PHE-tRNAs[c]': ['RXN-17847', 'RXN-17848'],
#  'PHOSPHO-ATOC[c]': ['ATOC-RXN'],
#  'PHOSPHO-BAER[c]': ['BAER-RXN'],
#  'PHOSPHO-CREB[c]': ['CREB-RXN'],
#  'PHOSPHO-DPIA[c]': ['RXN0-6272'],
#  'PHOSPHO-EVGA[c]': ['EVGA-RXN'],
#  'PHOSPHO-HYDG[c]': ['HYDG-RXN'],
#  'PHOSPHO-NARP[c]': ['NARPQ-RXN', 'NARPX-RXN'],
#  'PHOSPHO-RCSB[c]': ['RXN0-6509'],
#  'PHOSPHO-RSTA[c]': ['RSTA-RXN'],
#  'PHOSPHO-UHPB[i]': ['UHPB-RXN'],
#  'PHTHALATE[c]': ['RXN-11813'],
#  'PQQ[p]': ['TRANS-RXN0-629'],
#  'PRO-tRNAs[c]': ['RXN-21072', 'RXN-21077'],
#  'PROT-CYS[p]': ['RXN-20018', 'RXN-20019'],
#  'PROTEIN-L-BETA-ISOSPARTATE-METHYL-ESTERS[c]': ['2.1.1.77-RXN'],
#  'PYRUVFORMLY-MONOMER[c]': ['1.97.1.4-A-RXN'],
#  'Peptide-C-terminal-Glycines[c]': ['3.4.23.43-RXN'],
#  'Peptide-Holder-Alternative[c]': ['3.4.11.18-RXN',
#   '3.4.11.2-RXN',
#   'RXN0-5052',
#   'RXN0-5204'],
#  'Peptide-Peptidoglycan-NAcMur[c]': ['3.2.1.17-RXN'],
#  'Peptides-holder[c]': ['3.4.21.53-RXN-General-Protein-Substrates/ATP/WATER//Peptides-holder/ADP/Pi/PROTON.68.',
#   '3.4.21.92-RXN-General-Protein-Substrates/ATP/WATER//Peptides-holder/ADP/Pi/PROTON.68.',
#   '3.4.24.55-RXN-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.',
#   'RXN-21204',
#   'RXN-21299-General-Protein-Substrates/ATP/WATER//Peptides-holder/ADP/Pi/PROTON.68.',
#   'RXN0-3221-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.',
#   'RXN0-5051',
#   'RXN0-5103-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.',
#   'RXN0-5195-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.'],
#  'Peptides-holder[p]': ['3.4.15.5-RXN',
#   '3.4.21.102-RXN-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.',
#   '3.4.21.107-RXN-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.',
#   'GAMMA-GLUTAMYLTRANSFERASE-RXN',
#   'RXN0-3182-General-Protein-Substrates/WATER//Peptides-holder/PROTON.57.'],
#  'Peptides[c]': ['ABC-22-RXN'],
#  'Peptidoglycan-GlcNAC[c]': ['3.2.1.17-RXN'],
#  'Phenoxyl-rad-of-phenolic-donors[c]': ['PEROXID-RXN[CCO-CYTOSOL]-Phenolic-Donors/HYDROGEN-PEROXIDE//Phenoxyl-rad-of-phenolic-donors/WATER.86.'],
#  'Phenoxyl-rad-of-phenolic-donors[p]': ['PEROXID-RXN[CCO-PERI-BAC]-Phenolic-Donors/HYDROGEN-PEROXIDE//Phenoxyl-rad-of-phenolic-donors/WATER.87.'],
#  'Prolipoprotein-Cysteines[i]': ['RXN-22554'],
#  'Protein-Arginine-MGH1[c]': ['RXN-17636'],
#  'Protein-L-Aspartates[c]': ['RXN-19780'],
#  'Protein-L-methionine[c]': ['1.8.4.12-RXN (reverse)', 'RXN-8668 (reverse)'],
#  'Protein-L-methionine[p]': ['RXN-17652 (reverse)', 'RXN-17663 (reverse)'],
#  'Protein-S-methyl-L-cysteine[c]': ['2.1.1.63-RXN', 'RXN-17823', 'RXN-17824'],
#  'Protein-Ser-or-Thr-adenylate[c]': ['RXN0-7371'],
#  'Protein-With-N-Terminal-Pro[c]': ['3.4.11.1-RXN', '3.4.11.9-RXN'],
#  'Protein-flavinated-threonines[p]': ['RXN-14461'],
#  'Protein-tauphospho-L-histidines[c]': ['2.7.13.2-RXN'],
#  'Purine-Nucleosides[c]': ['TRANS-RXN0-631'],
#  'Quaternary-Amines[c]': ['RXN-8638'],
#  'R--ALLANTOIN[c]': ['TRANS-RXN0-557-R--ALLANTOIN/PROTON//R--ALLANTOIN/PROTON.41.'],
#  'REDUCED-MENAQUINONE[c]': ['ADOMET-DMK-METHYLTRANSFER-RXN',
#   'RXN-18550',
#   'RXN-19950-DISULFOXRED-MONOMER/CPD-9728//MONOMER0-4152/REDUCED-MENAQUINONE.64.',
#   'RXN-19950-Reduced-Disulfide-Carrier-Proteins/CPD-9728//Oxidized-Disulfide-Carrier-Proteins/REDUCED-MENAQUINONE.101.',
#   'RXN0-7319-CPD-381/CPD-9728//2-KETOGLUTARATE/REDUCED-MENAQUINONE.54.',
#   'RXN0-7385-CPD-9728/NADPH/PROTON//REDUCED-MENAQUINONE/NADP.48.',
#   'RXN0-7386-CPD-9728/NADH/PROTON//REDUCED-MENAQUINONE/NAD.46.',
#   'RXN0-7386-CPD-9728/NADPH/PROTON//REDUCED-MENAQUINONE/NADP.48.'],
#  'REDUCED-MENAQUINONE[m]': ['RXN-20056-a--reduced-DsbB-protein/CPD-9728//an-oxidized-DsbB-protein/REDUCED-MENAQUINONE.79.'],
#  'RNA-Adenines[c]': ['RXN-21233'],
#  'RNA-Cytosines[c]': ['RXN-21235'],
#  'RNA-with-3-prime-pp-5-prime-G-cap[c]': ['RXN-17936'],
#  'Red-Hybrid-Cluster-Proteins[c]': ['RXN0-307 (reverse)'],
#  'Reduced-CcmG-Proteins[p]': ['RXN-21410-an-oxidized-DsbD-protein/Reduced-CcmG-Proteins//a-reduced-DsbD-protein/Oxidized-CcmG-Proteins.94. (reverse)'],
#  'Reduced-Disulfide-Isomerases[c]': ['RXN-19952',
#   'RXN-19952-Disulfide-Isomerase-with-Disulfide-Bond/DISULFOXRED-MONOMER//Reduced-Disulfide-Isomerases/MONOMER0-4152.104.'],
#  'Reduced-Disulfide-Isomerases[p]': ['RXN-19949 (reverse)'],
#  'Reduced-Hydrogenases[c]': ['RXN-12274'],
#  'Reduced-NapC-proteins[c]': ['RXN-12876-Oxidized-NapC-proteins/ASCORBATE//L-DEHYDRO-ASCORBATE/Reduced-NapC-proteins/PROTON.83.'],
#  'Reduced-cytochromes-c2[c]': ['RXN-12876-Oxidized-cytochromes-c2/ASCORBATE//L-DEHYDRO-ASCORBATE/Reduced-cytochromes-c2/PROTON.85.'],
#  'Reduced-cytochromes-c553[c]': ['RXN-12876-Oxidized-cytochromes-c553/ASCORBATE//L-DEHYDRO-ASCORBATE/Reduced-cytochromes-c553/PROTON.89.'],
#  'Release-factor-N5-Methyl-L-glutamine[c]': ['RXN-14992'],
#  'Ribonuc-tri-P-reductases-active[c]': ['RNTRACTIV-RXN'],
#  'Ribosomal-protein-L3-N5M-L-glutamine[c]': ['RXN0-1241'],
#  'Ribosomal-protein-S12-3-methylthio-Asp89[c]': ['RXN0-6366'],
#  'S-ADENOSYL-4-METHYLTHIO-2-OXOBUTANOATE[c]': ['DAPASYN-RXN'],
#  'S-METHYLGLUTATHIONE[c]': ['RXN-19922'],
#  'SIROHEME[c]': ['SIROHEME-FERROCHELAT-RXN'],
#  'STEARIC_ACID[p]': ['RXN-19312-CPD0-2152/WATER//STEARIC_ACID/L-1-GLYCEROPHOSPHORYLETHANOL-AMINE/PROTON.72.',
#   'RXN0-1802-STEARIC_ACID//STEARIC_ACID.27.',
#   'RXN0-6725-CPD-12818/WATER//STEARIC_ACID/CPD0-2152/PROTON.47.',
#   'THIOESTER-RXN-STEAROYL-COA/WATER//STEARIC_ACID/CO-A/PROTON.45.'],
#  'Selenium-Carrier-Protein-S-selanyl-L-Cysteine[c]': ['RXN0-7441',
#   'RXN0-7442'],
#  'Semiquinones[c]': ['QOR-RXN', 'RXN0-6722'],
#  'Siderophore[c]': ['RXN-14960', 'RXN0-6555 (reverse)'],
#  'SufB-L-cysteine-Persulfide[c]': ['RXN0-7443'],
#  'TETRAHYDROTHIOPHENE[p]': ['THTOREDUCT-RXN'],
#  'THR-tRNAs[c]': ['RXN0-7435'],
#  'TOPAQUINONE[c]': ['RXN-16454'],
#  'TRIMETHYLAMINE[c]': ['RXN-18258-GAMMA-BUTYROBETAINE/NADH/OXYGEN-MOLECULE/PROTON//SUCC-S-ALD/TRIMETHYLAMINE/NAD/WATER.85.',
#   'RXN-18258-GAMMA-BUTYROBETAINE/NADPH/OXYGEN-MOLECULE/PROTON//SUCC-S-ALD/TRIMETHYLAMINE/NADP/WATER.87.',
#   'RXN-18376-CHOLINE/NADH/OXYGEN-MOLECULE/PROTON//GLYCOLALDEHYDE/TRIMETHYLAMINE/NAD/WATER.77.',
#   'RXN-18376-CHOLINE/NADPH/OXYGEN-MOLECULE/PROTON//GLYCOLALDEHYDE/TRIMETHYLAMINE/NADP/WATER.79.',
#   'RXN-5921-CARNITINE/NADH/OXYGEN-MOLECULE/PROTON//CPD-16618/TRIMETHYLAMINE/NAD/WATER.74.',
#   'RXN-5921-CARNITINE/NADPH/OXYGEN-MOLECULE/PROTON//CPD-16618/TRIMETHYLAMINE/NADP/WATER.76.'],
#  'TRP-tRNAs[c]': ['RXN-19729'],
#  'TYR-tRNAs[c]': ['RXN-19727'],
#  'UHPB-MONOMER[c]': ['RXN0-6499'],
#  'Ubiquitin-C-Terminal-Glycine[c]': ['3.4.19.12-RXN'],
#  'VAL-tRNAs[c]': ['RXN0-7430'],
#  'Val-tRNA1-N6-MeAdenine37[c]': ['RXN-12480'],
#  'a--reduced-DsbB-protein[i]': ['RXN-20000-DISULFOXRED-MONOMER/an-oxidized-DsbB-protein//MONOMER0-4152/a--reduced-DsbB-protein.84.',
#   'RXN-20000-a-reduced-DsbA-protein/an-oxidized-DsbB-protein//an-oxidized-DsbA-protein/a--reduced-DsbB-protein.98.'],
#  'a-5-alpha-deoxyadenosine-5-phosphate-DNA[c]': ['RXN-21308'],
#  'a-DNA-3-alpha-beta-unsaturated-aldehyde[c]': ['RXN-20478', 'RXN-21261'],
#  'a-hepta-acylated-core-oligosaccharide-li[p]': ['RXN-20913',
#   'RXN-20914',
#   'RXN-20915',
#   'RXN-20916'],
#  'a-mature-triacylated-lipoprotein[o]': ['RXN-22553'],
#  'a-mature-triacylated-lipoprotein[p]': ['RXN-17363', 'RXN-19774'],
#  'a-murein-lipoprotein[p]': ['RXN-22575'],
#  'a-reduced-DsbA-protein[c]': ['RXN-21426'],
#  'a-reduced-NrfB-protein[c]': ['RXN-12876-an-oxidized-NrfB-protein/ASCORBATE//L-DEHYDRO-ASCORBATE/a-reduced-NrfB-protein/PROTON.86.'],
#  'a-reduced-SoxR-protein[c]': ['RXN0-7453-an-oxidized-SoxR-protein/NADH//a-reduced-SoxR-protein/NAD/PROTON.65.',
#   'RXN0-7453-an-oxidized-SoxR-protein/NADPH//a-reduced-SoxR-protein/NADP/PROTON.67.'],
#  'a-reduced-TorC-protein[c]': ['RXN-12876-an-oxidized-TorC-protein/ASCORBATE//L-DEHYDRO-ASCORBATE/a-reduced-TorC-protein/PROTON.86.'],
#  'a-single-stranded-DNA-YedK-thiazolidine-[c]': ['RXN-21016'],
#  'a-thymine-in-DNA[c]': ['RXN-17824'],
#  'a-type-II-secretion-system-substrate[e]': ['TRANS-RXN-510'],
#  'an-oxidized-DsbD-protein[p]': ['RXN-19949 (reverse)'],
#  'cystine[p]': ['TRANS-RXN-267'],
#  'glycogen-monomer[c]': ['glycogen-monomer-extension'],
#  'mRNAs-with-5-monophosphate[c]': ['RXN0-5510', 'RXN0-7283'],
#  'mcmo5U34m-tRNA[c]': ['RXN0-7168'],
#  'phosphoethanolamine-cellulose[c]': ['RXN-19630'],
#  'tRNA-2methyladenine-37[c]': ['RXN0-7007'],
#  'tRNA-4-thiouridine[c]': ['RXN-18388'],
#  'tRNA-Arg-inosine34[c]': ['RXN0-1081'],
#  'tRNA-Containing-N1-Methylguanine-37[c]': ['RXN-12458'],
#  'tRNA-Containing-N7-Methylguanine-46[c]': ['TRNA-GUANINE-N7--METHYLTRANSFERASE-RXN'],
#  'tRNA-Dihydrouridines[c]': ['RXN0-1281 (reverse)'],
#  'tRNA-containing-5-CarbMeAminome-uridine[c]': ['RXN0-7068'],
#  'tRNA-containing-5Me-uridine54[c]': ['TRNA-URACIL-5--METHYLTRANSFERASE-RXN'],
#  'tRNA-pseudouridine-38-40[c]': ['TRNA-PSEUDOURIDINE-SYNTHASE-I-RXN'],
#  'tRNA-pseudouridine13[c]': ['RXN-11841'],
#  'tRNA-pseudouridine32[c]': ['RXN-11842'],
#  'tRNA-pseudouridine35[c]': ['RXN0-7253'],
#  'tRNA-pseudouridine55[c]': ['RXN-11839'],
#  'tRNA-pseudouridine65[c]': ['RXN-11840'],
#  'tRNAs-with-glutamylated-queuosine[c]': ['RXN0-5422'],
#  'tRNAs-with-queuine[c]': ['RXN-12104 (reverse)'],
#  'tRNAs[c]': ['AMINOCYL-TRNA-HYDROLASE-RXN',
#   'AMINOCYL-TRNA-HYDROLASE-RXN__EG10785-MONOMER',
#   'RXN-15041',
#   'RXN-23884']}

# %% [markdown]
# ### Dead-end Reactions/metabolites in new reactions

# %%
new_reaction_dead_end = {}
temp = [] # np.unique(temp) = new dead-end reactions
reaction_dead_end_pct = {} # only metabolites w/ 100% new reactions are considered. or else: it had been dead-end before the incorporation of new reactions

# find metabolite with no outlet that goes through new reactions
for met, rxn_id in dead_end_met_rxn.items():
    count = 0
    for id in rxn_id:
        if id in fba_new_reaction_ids:
            new_reaction_dead_end[met] = rxn_id
            temp.append(id)
            count +=1
        reaction_dead_end_pct[met] = count/len(rxn_id)

print(f'Number of Dead-end metabolites going through new reactions: {len(new_reaction_dead_end)}')
print(f'Number of Dead-end new reactions: {len(np.unique(temp))}')
print(f'Number of Dead-end reactions: {len(np.unique(np.hstack(list(new_reaction_dead_end.values()))))}')
# Out:
# Number of Dead-end metabolites going through new reactions: 83
# Number of Dead-end new reactions: 103
# Number of Dead-end reactions: 161

# %%
# closer look at the dead-end metabolites using only new reactions
new_reaction_dead_end_met = [met for met, pct in reaction_dead_end_pct.items() if pct == 1]
# extracting dead-end metabolites from new_reactions_dead_end. Should be extactly the same as new_reaction_dead_end_met
temp = [met for met, rxn_id in new_reaction_dead_end.items() if all(np.isin(rxn_id, fba_new_reaction_ids))]

print(f'Does new_reaction_dead_end_met and temp have same length: {len(new_reaction_dead_end_met) == len(temp)}')
print(f'Are new_reaction_dead_end_met and temp the same: {np.all(np.isin(new_reaction_dead_end_met, temp))}')

# %%
new_reaction_dead_end_met #TODO: pick a metabolite and trace
# Out:
# ['2-DEOXY-D-GLUCOSE[c]',
#  '3-HYDROXYBENZOATE[c]',
#  'ALPHA-RIBAZOLE[c]',
#  'Alpha-D-aldose-1-phosphates[c]',
#  'BUTANOL[c]',
#  'CPD-12365[c]',
#  'CPD-12367[c]',
#  'CPD-12587[c]',
#  'CPD-13315[c]',
#  'CPD-13852[c]',
#  'CPD-15158[c]',
#  'CPD-16154[c]',
#  'CPD-173[c]',
#  'CPD-18260[c]',
#  'CPD-1843[c]',
#  'CPD-19237[c]',
#  'CPD-20757[p]',
#  'CPD-23445[c]',
#  'CPD-24859[p]',
#  'CPD-25891[c]',
#  'CPD-335[c]',
#  'CPD-3565[c]',
#  'CPD-3611[c]',
#  'CPD-582[c]',
#  'CPD-8363[c]',
#  'CPD-8550[p]',
#  'CPD0-1101[p]',
#  'CPD0-2114[c]',
#  'CPD0-2134[c]',
#  'CPD0-2173[c]',
#  'CPD0-2207[c]',
#  'CPD0-2229[c]',
#  'CPD0-2241[c]',
#  'CPD0-2485[c]',
#  'CPD0-2486[c]',
#  'CPD0-2559[c]',
#  'CPD0-621[c]',
#  'CcmABCD-Complex[c]',
#  'CcmCDE-Complex-Heme[p]',
#  'CcmE-Protein-Heme-Ox[p]',
#  'CcmE-Proteins[c]',
#  'Charged-SEC-tRNAs[c]',
#  'Cytochromes-c[c]',
#  'D-fructofuranose-1-phosphate[c]',
#  'D-fructopyranose-1-phosphate[c]',
#  'Donor-H1[i]',
#  'ENTB-CPLX[c]',
#  'ETR-Semiquinones[c]',
#  'FERRIC-CITRATE-COMPLEX[c]',
#  'Fatty-Acids[p]',
#  'HYDROQUINONE[c]',
#  'KETOBUTFORMLY-MONOMER[c]',
#  'L-DI-GMP[c]',
#  'MANNOSE[c]',
#  'METHYL-BETA-D-GALACTOSIDE[c]',
#  'MONOMETHYL-ESTER-OF-TRANS-ACONITATE[c]',
#  'MYO-INOSITOL[c]',
#  'NITROUS-OXIDE[c]',
#  'Ox-Prx-Disulfide-Reductases[c]',
#  'PQQ[p]',
#  'PYRUVFORMLY-MONOMER[c]',
#  'Red-Hybrid-Cluster-Proteins[c]']

# %% [markdown]
# #### BUTANOL seems interesting

# %%
# BUTANOL seems interesting
# get butanol met index and S matrix involvement
met_of_interest = 'BUTANOL[c]'
butanol_idx = np.where(np.isin(metabolites, met_of_interest)) [0]

# slice S matrix to get only reactions involving butanol and related reactions
first = S[butanol_idx, :].copy()
butanol_rxn_idx = np.where(first!=0)[1]
butanol_rxn_id = [rxn_idx_to_id[idx] for idx in butanol_rxn_idx]

# get metabolites involved in other Butanol reactions
seconds = S[:, butanol_rxn_idx].copy()
sec_met_idx = np.unique(np.where(seconds!=0)[0])
sec_met_id = [metabolite_idx_to_name[idx] for idx in sec_met_idx]

temp = S[np.ix_(sec_met_idx,butanol_rxn_idx)]
df_temp = pd.DataFrame(temp, index=sec_met_id, columns=butanol_rxn_id)
sec_met_id

# expand to get how key metabolites are involved in other reactions
no_interest = ['NADH[c]', 'NAD[c]', 'PROTON[c]', 'WATER[c]']
sec_key_met = sec_met_id.copy()
[sec_key_met.remove(remove)  for remove in no_interest]
sec_key_met

sec_key_met_idx = [metabolite_to_idx[id] for id in sec_key_met]
idx =  np.nonzero(np.any(S[sec_key_met_idx,:] != 0, axis=0))[0] ##check columns to remove rxns with no sec_key_met involvement

##given expanded rxn idx, get metabolites involved in those reactions as well 
S_sec_key_met = S[:, idx].copy()
r_idx =  np.nonzero(np.any(S_sec_key_met != 0, axis=1))[0]
S_sec_key_met = S[np.ix_(r_idx, idx)].copy()

met_id = [metabolite_idx_to_name[ix] for ix in r_idx]
rxn_id = [rxn_idx_to_id[ix] for ix in idx]

df_temp2 = pd.DataFrame(S_sec_key_met, index=met_id, columns=rxn_id)

# %%
df_temp2
# Out:
#                                         R4-RXN-BUTYL-HYDROPEROXIDE/NADH/PROTON//BUTANOL/NAD/WATER.51.  \
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]                                                              0
# BUTANOL[c]                                                                                          1
# BUTYL-HYDROPEROXIDE[c]                                                                             -1
# Cys2-Peroxiredoxin-Disulfide[c]                                                                     0
# NADH[c]                                                                                            -1
# NAD[c]                                                                                              1
# Ox-Prx-Disulfide-Reductases[c]                                                                      0
# Ox-Thioredoxin[c]                                                                                   0
# Ox-thioredoxins-1[c]                                                                                0
# Oxidized-CcmG-Proteins[c]                                                                           0
# Oxidized-CcmH-Proteins[c]                                                                           0
# PROTON[c]                                                                                          -1
# Red-Prx-Disulfide-Reductases[c]                                                                     0
# Red-Thioredoxin[c]                                                                                  0
# Red-thioredoxins-1[c]                                                                               0
# Reduced-CcmG-Proteins[c]                                                                            0
# Reduced-CcmH-Proteins[c]                                                                            0
# Reduced-Cys2-Peroxiredoxins[c]                                                                      0
# WATER[c]                                                                                            1
#
#                                         RXN-19953-Reduced-Cys2-Peroxiredoxins/BUTYL-HYDROPEROXIDE//2Cys-Peroxiredoxins-With-HydroxyCys/BUTANOL.93.  \
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]                                                                                                           1
# BUTANOL[c]                                                                                                                                       1
# BUTYL-HYDROPEROXIDE[c]                                                                                                                          -1
# Cys2-Peroxiredoxin-Disulfide[c]                                                                                                                  0
# NADH[c]                                                                                                                                          0
# NAD[c]                                                                                                                                           0
# Ox-Prx-Disulfide-Reductases[c]                                                                                                                   0
# Ox-Thioredoxin[c]                                                                                                                                0
# Ox-thioredoxins-1[c]                                                                                                                             0
# Oxidized-CcmG-Proteins[c]                                                                                                                        0
# Oxidized-CcmH-Proteins[c]                                                                                                                        0
# PROTON[c]                                                                                                                                        0
# Red-Prx-Disulfide-Reductases[c]                                                                                                                  0
# Red-Thioredoxin[c]                                                                                                                               0
# Red-thioredoxins-1[c]                                                                                                                            0
# Reduced-CcmG-Proteins[c]                                                                                                                         0
# Reduced-CcmH-Proteins[c]                                                                                                                         0
# Reduced-Cys2-Peroxiredoxins[c]                                                                                                                  -1
# WATER[c]                                                                                                                                         0
#
#                                         RXN-19954  RXN-20692  RXN0-5468  \
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]         -1          0          0
# BUTANOL[c]                                      0          0          0
# BUTYL-HYDROPEROXIDE[c]                          0          0          0
# Cys2-Peroxiredoxin-Disulfide[c]                 1         -1         -1
# NADH[c]                                         0          0          0
# NAD[c]                                          0          0          0
# Ox-Prx-Disulfide-Reductases[c]                  0          1          0
# Ox-Thioredoxin[c]                               0          0          1
# Ox-thioredoxins-1[c]                            0          0          0
# Oxidized-CcmG-Proteins[c]                       0          0          0
# Oxidized-CcmH-Proteins[c]                       0          0          0
# PROTON[c]                                       0          0          0
# Red-Prx-Disulfide-Reductases[c]                 0         -1          0
# Red-Thioredoxin[c]                              0          0         -1
# Red-thioredoxins-1[c]                           0          0          0
# Reduced-CcmG-Proteins[c]                        0          0          0
# Reduced-CcmH-Proteins[c]                        0          0          0
# Reduced-Cys2-Peroxiredoxins[c]                  0          1          1
# WATER[c]                                        1          0          0
#
#                                         RXN0-5468-Red-thioredoxins-1/Cys2-Peroxiredoxin-Disulfide//Ox-thioredoxins-1/Reduced-Cys2-Peroxiredoxins.95.  \
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]                                                                                                             0
# BUTANOL[c]                                                                                                                                         0
# BUTYL-HYDROPEROXIDE[c]                                                                                                                             0
# Cys2-Peroxiredoxin-Disulfide[c]                                                                                                                   -1
# NADH[c]                                                                                                                                            0
# NAD[c]                                                                                                                                             0
# Ox-Prx-Disulfide-Reductases[c]                                                                                                                     0
# Ox-Thioredoxin[c]                                                                                                                                  0
# Ox-thioredoxins-1[c]                                                                                                                               1
# Oxidized-CcmG-Proteins[c]                                                                                                                          0
# Oxidized-CcmH-Proteins[c]                                                                                                                          0
# PROTON[c]                                                                                                                                          0
# Red-Prx-Disulfide-Reductases[c]                                                                                                                    0
# Red-Thioredoxin[c]                                                                                                                                 0
# Red-thioredoxins-1[c]                                                                                                                             -1
# Reduced-CcmG-Proteins[c]                                                                                                                           0
# Reduced-CcmH-Proteins[c]                                                                                                                           0
# Reduced-Cys2-Peroxiredoxins[c]                                                                                                                     1
# WATER[c]                                                                                                                                           0
#
#                                         RXN0-5468-Reduced-CcmG-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmG-Proteins/Reduced-Cys2-Peroxiredoxins.103.  \
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]                                                                                                                      0
# BUTANOL[c]                                                                                                                                                  0
# BUTYL-HYDROPEROXIDE[c]                                                                                                                                      0
# Cys2-Peroxiredoxin-Disulfide[c]                                                                                                                            -1
# NADH[c]                                                                                                                                                     0
# NAD[c]                                                                                                                                                      0
# Ox-Prx-Disulfide-Reductases[c]                                                                                                                              0
# Ox-Thioredoxin[c]                                                                                                                                           0
# Ox-thioredoxins-1[c]                                                                                                                                        0
# Oxidized-CcmG-Proteins[c]                                                                                                                                   1
# Oxidized-CcmH-Proteins[c]                                                                                                                                   0
# PROTON[c]                                                                                                                                                   0
# Red-Prx-Disulfide-Reductases[c]                                                                                                                             0
# Red-Thioredoxin[c]                                                                                                                                          0
# Red-thioredoxins-1[c]                                                                                                                                       0
# Reduced-CcmG-Proteins[c]                                                                                                                                   -1
# Reduced-CcmH-Proteins[c]                                                                                                                                    0
# Reduced-Cys2-Peroxiredoxins[c]                                                                                                                              1
# WATER[c]                                                                                                                                                    0
#
#                                         RXN0-5468-Reduced-CcmH-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmH-Proteins/Reduced-Cys2-Peroxiredoxins.103.
# 2Cys-Peroxiredoxins-With-HydroxyCys[c]                                                                                                                      0
# BUTANOL[c]                                                                                                                                                  0
# BUTYL-HYDROPEROXIDE[c]                                                                                                                                      0
# Cys2-Peroxiredoxin-Disulfide[c]                                                                                                                            -1
# NADH[c]                                                                                                                                                     0
# NAD[c]                                                                                                                                                      0
# Ox-Prx-Disulfide-Reductases[c]                                                                                                                              0
# Ox-Thioredoxin[c]                                                                                                                                           0
# Ox-thioredoxins-1[c]                                                                                                                                        0
# Oxidized-CcmG-Proteins[c]                                                                                                                                   0
# Oxidized-CcmH-Proteins[c]                                                                                                                                   1
# PROTON[c]                                                                                                                                                   0
# Red-Prx-Disulfide-Reductases[c]                                                                                                                             0
# Red-Thioredoxin[c]                                                                                                                                          0
# Red-thioredoxins-1[c]                                                                                                                                       0
# Reduced-CcmG-Proteins[c]                                                                                                                                    0
# Reduced-CcmH-Proteins[c]                                                                                                                                   -1
# Reduced-Cys2-Peroxiredoxins[c]                                                                                                                              1
# WATER[c]                                                                                                                                                    0

# %%
df.loc[rxn_id,]
# Out:
#                                                                                                                        sim_fluxes_avg  \
# R4-RXN-BUTYL-HYDROPEROXIDE/NADH/PROTON//BUTANOL/NAD/WATER.51.                                                                     0.0
# RXN-19953-Reduced-Cys2-Peroxiredoxins/BUTYL-HYDROPEROXIDE//2Cys-Peroxiredoxins-With-HydroxyCys/BUTANOL.93.                        0.0
# RXN-19954                                                                                                                         0.0
# RXN-20692                                                                                                                         0.0
# RXN0-5468                                                                                                                         0.0
# RXN0-5468-Red-thioredoxins-1/Cys2-Peroxiredoxin-Disulfide//Ox-thioredoxins-1/Reduced-Cys2-Peroxiredoxins.95.                      0.0
# RXN0-5468-Reduced-CcmG-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmG-Proteins/Reduced-Cys2-Peroxiredoxins.103.             0.0
# RXN0-5468-Reduced-CcmH-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmH-Proteins/Reduced-Cys2-Peroxiredoxins.103.             0.0
#
#                                                                                                                        sim_fluxes_avg_log  \
# R4-RXN-BUTYL-HYDROPEROXIDE/NADH/PROTON//BUTANOL/NAD/WATER.51.                                                                        -6.0
# RXN-19953-Reduced-Cys2-Peroxiredoxins/BUTYL-HYDROPEROXIDE//2Cys-Peroxiredoxins-With-HydroxyCys/BUTANOL.93.                           -6.0
# RXN-19954                                                                                                                            -6.0
# RXN-20692                                                                                                                            -6.0
# RXN0-5468                                                                                                                            -6.0
# RXN0-5468-Red-thioredoxins-1/Cys2-Peroxiredoxin-Disulfide//Ox-thioredoxins-1/Reduced-Cys2-Peroxiredoxins.95.                         -6.0
# RXN0-5468-Reduced-CcmG-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmG-Proteins/Reduced-Cys2-Peroxiredoxins.103.                -6.0
# RXN0-5468-Reduced-CcmH-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmH-Proteins/Reduced-Cys2-Peroxiredoxins.103.                -6.0
#
#                                                                                                                               is_new
# R4-RXN-BUTYL-HYDROPEROXIDE/NADH/PROTON//BUTANOL/NAD/WATER.51.                                                          New Reactions
# RXN-19953-Reduced-Cys2-Peroxiredoxins/BUTYL-HYDROPEROXIDE//2Cys-Peroxiredoxins-With-HydroxyCys/BUTANOL.93.             New Reactions
# RXN-19954                                                                                                              New Reactions
# RXN-20692                                                                                                              New Reactions
# RXN0-5468                                                                                                              New Reactions
# RXN0-5468-Red-thioredoxins-1/Cys2-Peroxiredoxin-Disulfide//Ox-thioredoxins-1/Reduced-Cys2-Peroxiredoxins.95.           New Reactions
# RXN0-5468-Reduced-CcmG-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmG-Proteins/Reduced-Cys2-Peroxiredoxins.103.  New Reactions
# RXN0-5468-Reduced-CcmH-Proteins/Cys2-Peroxiredoxin-Disulfide//Oxidized-CcmH-Proteins/Reduced-Cys2-Peroxiredoxins.103.  New Reactions

# %% [markdown]
# ### Give COBRA a shot

# %%
met_ids = met_id
rxn_ids = rxn_id

metabolites_c = [cobra.Metabolite(met) for met in met_ids]
reactions_c   = [cobra.Reaction(rxn) for rxn in rxn_ids]

# Add metabolites and reactions to the model
model = cobra.Model("Custom_Pathway")
for i, reaction in enumerate(reactions_c):
    # Add metabolites to reactions based on stoichiometry
    for j, metabolite in enumerate(metabolites_c):
        if S_sec_key_met[j][i] != 0:
            reaction.add_metabolites({metabolite: S_sec_key_met[j][i]})
    model.add_reactions([reaction])
    
for reaction in model.reactions:
    print(reaction.build_reaction_string())
# Out:
# BUTYL-HYDROPEROXIDE[c] + NADH[c] + PROTON[c] --> BUTANOL[c] + NAD[c] + WATER[c]
# BUTYL-HYDROPEROXIDE[c] + Reduced-Cys2-Peroxiredoxins[c] --> 2Cys-Peroxiredoxins-With-HydroxyCys[c] + BUTANOL[c]
# 2Cys-Peroxiredoxins-With-HydroxyCys[c] --> Cys2-Peroxiredoxin-Disulfide[c] + WATER[c]
# Cys2-Peroxiredoxin-Disulfide[c] + Red-Prx-Disulfide-Reductases[c] --> Ox-Prx-Disulfide-Reductases[c] + Reduced-Cys2-Peroxiredoxins[c]
# Cys2-Peroxiredoxin-Disulfide[c] + Red-Thioredoxin[c] --> Ox-Thioredoxin[c] + Reduced-Cys2-Peroxiredoxins[c]
# Cys2-Peroxiredoxin-Disulfide[c] + Red-thioredoxins-1[c] --> Ox-thioredoxins-1[c] + Reduced-Cys2-Peroxiredoxins[c]
# Cys2-Peroxiredoxin-Disulfide[c] + Reduced-CcmG-Proteins[c] --> Oxidized-CcmG-Proteins[c] + Reduced-Cys2-Peroxiredoxins[c]
# Cys2-Peroxiredoxin-Disulfide[c] + Reduced-CcmH-Proteins[c] --> Oxidized-CcmH-Proteins[c] + Reduced-Cys2-Peroxiredoxins[c]

# %%
from escher import Builder

# Build an Escher visualization for the model
builder = Builder(model=model)
# builder
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[319], line 4
#       1 from escher import Builder
#       3 # Build an Escher visualization for the model
# ----> 4 builder = Builder(model=model)
#       5 # builder
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/escher/plots.py:547, in Builder.__init__(self, map_name, map_json, model, model_name, model_json, **kwargs)
#     545     if model_json:
#     546         warn('model overrides model_json')
# --> 547     self.model = model
#     548 elif model_json:
#     549     if model_name:
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:701, in notify_change(self, change)
#     696 @contextmanager
#     697 def _lock_property(self, **properties):
#     698     """Lock a property-value pair.
#     699
#     700     The value should be the JSON state of the property.
# --> 701
#     702     NOTE: This, in addition to the single lock for all state changes, is
#     703     flawed.  In the future we may want to look into buffering state changes
#     704     back to the front-end."""
#     705     self._property_lock = properties
#     706     try:
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/escher/plots.py:357, in Builder._observe_model(self, change)
#     354 @observe('model')
#     355 def _observe_model(self, change):
#     356     if change.new:
# --> 357         self._loaded_model_json = cobra.io.to_json(change.new)
#     358     else:
#     359         self._loaded_model_json = None
#
# File ~/.pyenv/versions/3.11.3/envs/viv-ecoli/lib/python3.11/site-packages/cobra/io/json.py:43, in to_json(model, sort, **kwargs)
#      41 obj = model_to_dict(model, sort=sort)
#      42 obj["version"] = JSON_SPEC
# ---> 43 return json.dumps(obj, allow_nan=False, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type int8 is not JSON serializable

# %%
import cobra

# Define metabolites
metabolites_c = [
    cobra.Metabolite("2Cys-Peroxiredoxins-With-HydroxyCys[c]"),
    cobra.Metabolite("BUTANOL[c]"),
    cobra.Metabolite("BUTYL-HYDROPEROXIDE[c]"),
    cobra.Metabolite("NADH[c]"),
    cobra.Metabolite("NAD[c]"),
    cobra.Metabolite("PROTON[c]"),
    cobra.Metabolite("Reduced-Cys2-Peroxiredoxins[c]"),
    cobra.Metabolite("WATER[c]")
]

# Define reactions
reactions = [
    cobra.Reaction("R4-RXN-BUTYL-HYDROPEROXIDE"),
    cobra.Reaction("RXN-19953-Reduced-Cys2-Peroxiredoxins")
]

# Define stoichiometry (rows: metabolites, columns: reactions)
stoichiometry = [
    [0, 1],  # 2Cys-Peroxiredoxins-With-HydroxyCys[c]
    [1, 1],  # BUTANOL[c]
    [-1, -1],  # BUTYL-HYDROPEROXIDE[c]
    [-1, 0],  # NADH[c]
    [1, 0],  # NAD[c]
    [-1, 0],  # PROTON[c]
    [0, -1],  # Reduced-Cys2-Peroxiredoxins[c]
    [1, 0]    # WATER[c]
]

# Add metabolites and reactions to the model
model = cobra.Model("Custom_Pathway")
for i, reaction in enumerate(reactions):
    # Add metabolites to reactions based on stoichiometry
    for j, metabolite in enumerate(metabolites_c):
        if stoichiometry[j][i] != 0:
            reaction.add_metabolites({metabolite: stoichiometry[j][i]})
    model.add_reactions([reaction])

# Print summary of the model
print(model.summary())
# Out:
# WARNING:cobra.summary.model_summary:Non-linear or non-reaction model objective. Falling back to minimal display.
# Objective
# =========
# nan Expression = nan
#
# Uptake
# ------
# Empty DataFrame
# Columns: [Metabolite, Reaction, Flux, C-Number, C-Flux]
# Index: []
#
# Secretion
# ---------
# Empty DataFrame
# Columns: [Metabolite, Reaction, Flux, C-Number, C-Flux]
# Index: []

# %%
for reaction in model.reactions:
    print(reaction.build_reaction_string())
# Out:
# BUTYL-HYDROPEROXIDE[c] + NADH[c] + PROTON[c] --> BUTANOL[c] + NAD[c] + WATER[c]
# BUTYL-HYDROPEROXIDE[c] + Reduced-Cys2-Peroxiredoxins[c] --> 2Cys-Peroxiredoxins-With-HydroxyCys[c] + BUTANOL[c]

# %%
from escher import Builder

# Build an Escher visualization for the model
builder = Builder(model=model)
# builder

# %%
for reaction in model.reactions:
    print(reaction.build_reaction_string())
# Out:
# BUTYL-HYDROPEROXIDE[c] + NADH[c] + PROTON[c] --> BUTANOL[c] + NAD[c] + WATER[c]
# BUTYL-HYDROPEROXIDE[c] + Reduced-Cys2-Peroxiredoxins[c] --> 2Cys-Peroxiredoxins-With-HydroxyCys[c] + BUTANOL[c]

# %%
solution = model.optimize()
solution
# Out:
# <Solution 0.000 at 0x2f254cf10>
