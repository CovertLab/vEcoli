# %%
import numpy as np
import ast
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt
import dill
import requests
import xmltodict
import cvxpy as cp
import itertools
from scipy.special import logsumexp

# %matplotlib inline
# sns.set(style='darkgrid', palette='viridis', context='talk')

os.chdir(os.path.expanduser('~/dev/vivarium-ecoli'))

from ecoli.processes.metabolism_redux_classic import NetworkFlowModel, FlowResult
from ecoli.library.schema import numpy_schema, bulk_name_to_idx, listener_schema, counts
from ecoli.processes.registries import topology_registry
TOPOLOGY = topology_registry.access("ecoli-metabolism-redux")

# %%
# create a function to deal with non-homogeous dtype of columns. mixture of strings and lists
def string_to_list(s):
    try:
        return np.array(ast.literal_eval(s))  # Safely convert string to array
    except (ValueError, SyntaxError):
        return np.array(s)  # Return as array if object is not a list and conversion fails (e.g., NaN values)

# %% [markdown]
# ### Load Experiments

# %%
time = '400'
date = '2025-01-13'
experiment = 'metabolism-redux-classic-BASAL_OLD-modified_process_new_rxn_name'
entry = f'{experiment}_{time}_{date}'
folder = f'out/cofactors/{entry}/'

output = np.load(folder + '0_output.npy',allow_pickle='TRUE').item()
# output = np.load(r"out/geneRxnVerifData/output_glc.npy", allow_pickle=True, encoding='ASCII').tolist()
output = output['agents']['0']
fba = output['listeners']['fba_results']
mass = output['listeners']['mass']
bulk = pd.DataFrame(output['bulk'])

# %%
f = open(folder + 'agent_steps.pkl', 'rb')
agent = dill.load(f)
f.close()

# %% [markdown]
# ### Create Dataframe

# %%
# create simulation flux dataframe - OLD
self = agent['ecoli-metabolism-redux-classic'] #self of metabolism_redux_classic class
reaction_names = self.reaction_names

sim_fluxes = pd.DataFrame(fba["estimated_fluxes"])
target_fluxes = pd.DataFrame(fba["target_kinetic_fluxes"])

sim_fluxes.columns = reaction_names
sim_fluxes = sim_fluxes.iloc[1:,] # remove first row (NAs) of the dataframe
target_fluxes = target_fluxes.iloc[1:,] # remove first row (NAs) of the dataframe

# %%
fba_new_reaction_ids = self.parameters["fba_new_reaction_ids"]
fba_reaction_ids_to_base_reaction_ids = self._parameters['fba_reaction_ids_to_base_reaction_ids']

# %%
#### ALL REACTION FLUX #####

# take average of flux through time -- should I normalize by cell mass? 
sim_fluxes_avg = sim_fluxes.mean(axis=0)

# set up plotly df
df = pd.DataFrame({'sim_fluxes_avg': sim_fluxes_avg, 'sim_fluxes_avg_log':sim_fluxes_avg})
df['is_new'] = 'Old Reactions'
df.loc[fba_new_reaction_ids, 'is_new'] = 'New Reactions'  

# log flux and + e-6
df.sim_fluxes_avg_log += 10**-6
df.sim_fluxes_avg_log = np.log10(df.sim_fluxes_avg_log)


#### KINETICALLY CONSTRAINED REACTION FLUX #####
# get target flux for the kinetically constrained reactions
target_kinetic_flux = fba['target_kinetic_fluxes'][1:] #atoms/second
kinetic_reactions = self.kinetic_constraint_reactions

# get average target flux for the kinetically constrained reactions
target_kinetic_flux = np.array(target_kinetic_flux).mean(axis=0)

# get estimated flux for the kinetically constrained reactions
df_kinetic = df.loc[kinetic_reactions].copy()
df_kinetic['target'] = target_kinetic_flux

# deal with 0 fluxes and math.log10 on all fluxes
df_kinetic.target  += 10**-6
df_kinetic.target   = np.log10(df_kinetic.target)

# set up plotly parameters
category_colors = {
    'Old Reactions': 'purple',
    'New Reactions': 'orange',
}

# %% [markdown]
# ### New Reactions

# %%
# Extract target flux of new reactions - 43 reactions total
df_kinetic_constrained_new = df_kinetic[df_kinetic['is_new'] == 'New Reactions']
df_kinetic[df_kinetic['is_new'] == 'New Reactions']
# Out:
#                                                     sim_fluxes_avg  \
# 1.13.11.16-RXN                                                 0.0
# 2.1.1.79-RXN-CPD-18361/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.1.1.79-RXN-CPD-18362/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.1.1.79-RXN-CPD-18367/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.1.1.79-RXN-CPD-18369/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.1.1.79-RXN-CPD-18392/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.1.1.79-RXN-CPD-18403/S-ADENOSYLMETHIONINE//CP...             0.0
# 2.9.1.1-RXN                                                    0.0
# 3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-P...             0.0
# 4.3.1.15-RXN                                                   0.0
# ACETALD-DEHYDROG-RXN__MHPF-MONOMER                             0.0
# GLUCARDEHYDRA-RXN                                              0.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...             0.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...             0.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...             0.0
# GPH-RXN[CCO-CYTOSOL]-CPD-67/WATER//GLYCOLLATE/P...             0.0
# GPH-RXN[CCO-PERI-BAC]-CPD-67/WATER//GLYCOLLATE/...             0.0
# MHPCHYDROL-RXN                                                 0.0
# R621-RXN-NITRIC-OXIDE/NADH/OXYGEN-MOLECULE//NIT...             0.0
# RXN-12070                                                      0.0
# RXN-12402                                                      0.0
# RXN-14090[CCO-PERI-BAC]-CPD-3711/WATER//CYTIDIN...             0.0
# RXN-14126[CCO-PERI-BAC]-CPD-3706/WATER//ADENOSI...             0.0
# RXN0-1001                                                      0.0
# RXN0-313__CPLX0-201 (reverse)                                  0.0
# RXN0-5186__G7408-MONOMER                                       0.0
# RXN0-5229                                                      0.0
# RXN0-5390__G6244-MONOMER                                       0.0
# RXN0-5408                                                      0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-6254                                                      0.0
# RXN0-6373-GLC/UBIQUINONE-8//GLC-D-LACTONE/CPD-9...             0.0
# RXN0-6732__CPLX0-7958                                          0.0
# RXN0-6733                                                      0.0
# RXN0-7024                                                      0.0
# RXN0-7046                                                      0.0
# RXN0-7105                                                      0.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...             0.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-PERI-BAC]...             0.0
# TREHALA-RXN[CCO-PERI-BAC]-TREHALOSE/WATER//GLC/...             0.0
#
#                                                     sim_fluxes_avg_log  \
# 1.13.11.16-RXN                                                    -6.0
# 2.1.1.79-RXN-CPD-18361/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.1.1.79-RXN-CPD-18362/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.1.1.79-RXN-CPD-18367/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.1.1.79-RXN-CPD-18369/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.1.1.79-RXN-CPD-18392/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.1.1.79-RXN-CPD-18403/S-ADENOSYLMETHIONINE//CP...                -6.0
# 2.9.1.1-RXN                                                       -6.0
# 3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-P...                -6.0
# 4.3.1.15-RXN                                                      -6.0
# ACETALD-DEHYDROG-RXN__MHPF-MONOMER                                -6.0
# GLUCARDEHYDRA-RXN                                                 -6.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...                -6.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...                -6.0
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...                -6.0
# GPH-RXN[CCO-CYTOSOL]-CPD-67/WATER//GLYCOLLATE/P...                -6.0
# GPH-RXN[CCO-PERI-BAC]-CPD-67/WATER//GLYCOLLATE/...                -6.0
# MHPCHYDROL-RXN                                                    -6.0
# R621-RXN-NITRIC-OXIDE/NADH/OXYGEN-MOLECULE//NIT...                -6.0
# RXN-12070                                                         -6.0
# RXN-12402                                                         -6.0
# RXN-14090[CCO-PERI-BAC]-CPD-3711/WATER//CYTIDIN...                -6.0
# RXN-14126[CCO-PERI-BAC]-CPD-3706/WATER//ADENOSI...                -6.0
# RXN0-1001                                                         -6.0
# RXN0-313__CPLX0-201 (reverse)                                     -6.0
# RXN0-5186__G7408-MONOMER                                          -6.0
# RXN0-5229                                                         -6.0
# RXN0-5390__G6244-MONOMER                                          -6.0
# RXN0-5408                                                         -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-6254                                                         -6.0
# RXN0-6373-GLC/UBIQUINONE-8//GLC-D-LACTONE/CPD-9...                -6.0
# RXN0-6732__CPLX0-7958                                             -6.0
# RXN0-6733                                                         -6.0
# RXN0-7024                                                         -6.0
# RXN0-7046                                                         -6.0
# RXN0-7105                                                         -6.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...                -6.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-PERI-BAC]...                -6.0
# TREHALA-RXN[CCO-PERI-BAC]-TREHALOSE/WATER//GLC/...                -6.0
#
#                                                            is_new  \
# 1.13.11.16-RXN                                      New Reactions
# 2.1.1.79-RXN-CPD-18361/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.1.1.79-RXN-CPD-18362/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.1.1.79-RXN-CPD-18367/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.1.1.79-RXN-CPD-18369/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.1.1.79-RXN-CPD-18392/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.1.1.79-RXN-CPD-18403/S-ADENOSYLMETHIONINE//CP...  New Reactions
# 2.9.1.1-RXN                                         New Reactions
# 3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-P...  New Reactions
# 4.3.1.15-RXN                                        New Reactions
# ACETALD-DEHYDROG-RXN__MHPF-MONOMER                  New Reactions
# GLUCARDEHYDRA-RXN                                   New Reactions
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  New Reactions
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  New Reactions
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  New Reactions
# GPH-RXN[CCO-CYTOSOL]-CPD-67/WATER//GLYCOLLATE/P...  New Reactions
# GPH-RXN[CCO-PERI-BAC]-CPD-67/WATER//GLYCOLLATE/...  New Reactions
# MHPCHYDROL-RXN                                      New Reactions
# R621-RXN-NITRIC-OXIDE/NADH/OXYGEN-MOLECULE//NIT...  New Reactions
# RXN-12070                                           New Reactions
# RXN-12402                                           New Reactions
# RXN-14090[CCO-PERI-BAC]-CPD-3711/WATER//CYTIDIN...  New Reactions
# RXN-14126[CCO-PERI-BAC]-CPD-3706/WATER//ADENOSI...  New Reactions
# RXN0-1001                                           New Reactions
# RXN0-313__CPLX0-201 (reverse)                       New Reactions
# RXN0-5186__G7408-MONOMER                            New Reactions
# RXN0-5229                                           New Reactions
# RXN0-5390__G6244-MONOMER                            New Reactions
# RXN0-5408                                           New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-6254                                           New Reactions
# RXN0-6373-GLC/UBIQUINONE-8//GLC-D-LACTONE/CPD-9...  New Reactions
# RXN0-6732__CPLX0-7958                               New Reactions
# RXN0-6733                                           New Reactions
# RXN0-7024                                           New Reactions
# RXN0-7046                                           New Reactions
# RXN0-7105                                           New Reactions
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...  New Reactions
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-PERI-BAC]...  New Reactions
# TREHALA-RXN[CCO-PERI-BAC]-TREHALOSE/WATER//GLC/...  New Reactions
#
#                                                           target
# 1.13.11.16-RXN                                      2.000000e+00
# 2.1.1.79-RXN-CPD-18361/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.1.1.79-RXN-CPD-18362/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.1.1.79-RXN-CPD-18367/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.1.1.79-RXN-CPD-18369/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.1.1.79-RXN-CPD-18392/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.1.1.79-RXN-CPD-18403/S-ADENOSYLMETHIONINE//CP...  2.003148e+00
# 2.9.1.1-RXN                                        -6.000000e+00
# 3.1.3.68-RXN[CCO-CYTOSOL]-2-DEOXY-D-GLUCOSE-6-P...  4.522923e+00
# 4.3.1.15-RXN                                        2.673021e+00
# ACETALD-DEHYDROG-RXN__MHPF-MONOMER                  2.645422e+00
# GLUCARDEHYDRA-RXN                                   2.530200e+00
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  3.803450e+00
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  3.803450e+00
# GLUCOSE-1-PHOSPHAT-RXN[CCO-PERI-BAC]-GLC-1-P/WA...  3.803450e+00
# GPH-RXN[CCO-CYTOSOL]-CPD-67/WATER//GLYCOLLATE/P...  4.523221e+00
# GPH-RXN[CCO-PERI-BAC]-CPD-67/WATER//GLYCOLLATE/...  4.523221e+00
# MHPCHYDROL-RXN                                      2.460898e+00
# R621-RXN-NITRIC-OXIDE/NADH/OXYGEN-MOLECULE//NIT...  5.198183e+00
# RXN-12070                                           9.542426e-01
# RXN-12402                                           1.886491e+00
# RXN-14090[CCO-PERI-BAC]-CPD-3711/WATER//CYTIDIN...  2.980311e+00
# RXN-14126[CCO-PERI-BAC]-CPD-3706/WATER//ADENOSI...  2.539211e+00
# RXN0-1001                                           2.822569e+00
# RXN0-313__CPLX0-201 (reverse)                       1.623249e+00
# RXN0-5186__G7408-MONOMER                            3.582787e+00
# RXN0-5229                                           4.342943e-07
# RXN0-5390__G6244-MONOMER                            2.833147e+00
# RXN0-5408                                           3.282267e+00
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON... -6.000000e+00
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON... -6.000000e+00
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  4.342943e-07
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  3.010302e-01
# RXN0-6254                                          -6.000000e+00
# RXN0-6373-GLC/UBIQUINONE-8//GLC-D-LACTONE/CPD-9...  6.210580e+00
# RXN0-6732__CPLX0-7958                              -6.000000e+00
# RXN0-6733                                           1.995635e+00
# RXN0-7024                                           3.220108e+00
# RXN0-7046                                           3.810714e+00
# RXN0-7105                                           1.943507e+00
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...  4.606629e+00
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-PERI-BAC]...  5.008706e+00
# TREHALA-RXN[CCO-PERI-BAC]-TREHALOSE/WATER//GLC/...  3.590639e+00

# %%
len(df_kinetic[df_kinetic['is_new'] == 'New Reactions'])
# Out:
# 43

# %% [markdown]
# ### Confirm: Are All New Reactions included in the model? Short Answer: No

# %%
# Use metabolic_gene_annotation.tsv to convert reactions back to Ecocyc Gene IDs
FLAT_DIR = f'reconstruction/ecoli/flat/'
NOTEBOOK_DIR = f'notebooks/Heena notebooks/Metabolism_New Genes'

new_metabolic_gene_annotation = pd.read_csv(os.path.join(NOTEBOOK_DIR, "new_metabolic_gene_annotation.csv"), converters={'Reactions': string_to_list})
metabolic_reactions = pd.read_csv(os.path.join(FLAT_DIR, "metabolic_reactions.tsv"), sep='\t', skiprows=4, converters={'catalyzed_by': string_to_list})

# %% [markdown]
# #### Quick check to see if I have all the new reactions.
# #### i.e. fba_rxn (565) -> metabolic_reactions.tsv -> base_reactions(365)

# %%
total_base_reactions = len(np.unique(np.hstack(new_metabolic_gene_annotation.Reactions)))-1
print(f'Total Number of New Reaction Base IDs: {total_base_reactions}')
# Out:
# Total Number of New Reaction Base IDs: 365

# %%
base_new_reaction_ids = []
for id in fba_new_reaction_ids:
    base_new_reaction_ids.append(fba_reaction_ids_to_base_reaction_ids[id])
base_new_reaction_ids = np.sort(np.unique(base_new_reaction_ids))
print(f'Simulation Number of New Reaction Base IDs: {len(base_new_reaction_ids)}')
print(f'Number of Missing New Reaction Base IDs: {total_base_reactions-len(base_new_reaction_ids)}')
# Out:
# Simulation Number of New Reaction Base IDs: 349
# Number of Missing New Reaction Base IDs: 16

# %% [markdown]
# <p> <span style='background :#fcd1d7' color = 'b' > By transposing fba_new_reaction_ids back to base_ids, we can tell that there are a totall of 16 new reactions not being incorporated into the wc model </span>

# %%
# calculate the number of NEW fba reactions the metabolic_reactions.tsv should make
len_new_metabolic_reactions = len(metabolic_reactions[(metabolic_reactions.is_new == 1)])
add_reversible_reactions = len(metabolic_reactions[(metabolic_reactions.is_new == 1) & (metabolic_reactions.direction == 'BOTH')])
add_kinetic_reactions = sum(1 for id in fba_new_reaction_ids if '__' in id)

print(f'The number of new FBA_reaction_ids should be: {len_new_metabolic_reactions+add_reversible_reactions+add_kinetic_reactions}')
print(f'The number of new FBA_reaction_ids in sim: {len(fba_new_reaction_ids)}')
# Out:
# The number of new FBA_reaction_ids should be: 565
# The number of new FBA_reaction_ids in sim: 565

# %% [markdown]
# ### More info on the 16 missing new reactions

# %%
df.loc[fba_new_reaction_ids]
# Out:
#                                                     sim_fluxes_avg  \
# 1.1.1.271-RXN (reverse)                                        0.0
# 1.11.1.15-RXN                                                  0.0
# 1.13.11.16-RXN                                                 0.0
# 1.97.1.4-A-RXN                                                 0.0
# 1PFRUCTPHOSN-RXN                                               0.0
# ...                                                            ...
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...             0.0
# RXN0-6732__CPLX0-7958                                          0.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...             0.0
#
#                                                     sim_fluxes_avg_log  \
# 1.1.1.271-RXN (reverse)                                           -6.0
# 1.11.1.15-RXN                                                     -6.0
# 1.13.11.16-RXN                                                    -6.0
# 1.97.1.4-A-RXN                                                    -6.0
# 1PFRUCTPHOSN-RXN                                                  -6.0
# ...                                                                ...
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...                -6.0
# RXN0-6732__CPLX0-7958                                             -6.0
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...                -6.0
#
#                                                            is_new
# 1.1.1.271-RXN (reverse)                             New Reactions
# 1.11.1.15-RXN                                       New Reactions
# 1.13.11.16-RXN                                      New Reactions
# 1.97.1.4-A-RXN                                      New Reactions
# 1PFRUCTPHOSN-RXN                                    New Reactions
# ...                                                           ...
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-5462[CCO-CYTOSOL]-GTP/WATER//GDP/Pi/PROTON...  New Reactions
# RXN0-6732__CPLX0-7958                               New Reactions
# THIOSULFATE-SULFURTRANSFERASE-RXN[CCO-CYTOSOL]-...  New Reactions
#
# [565 rows x 3 columns]
