# %%
import numpy as np

# %%
b = np.load('geneRxnVerifDataoutput.npy', allow_pickle=True, encoding='ASCII')

# %%
c = b.tolist()['agents']['0']['listeners']['fba_results']['reactionFluxes']

# %%
len(c)
# Out:
# 3

# %%
d = b.tolist()['agents']['0']['bulk']

# %%
d
# Out:
# {'CPLX-125[c]': [0, 10, 9],
#  'CPLX-172[c]': [0, 0, 0],
#  'CPLX0-226[c]': [0, 120, 51],
#  'CPLX0-228[c]': [0, 25, 5],
#  'CPLX0-7669[c]': [208, 104, 116],
#  'CPLX0-7705[c]': [4206, 4206, 4207],
#  'CPLX0-7740[c]': [16, 16, 15],
#  'CPLX0-7796[c]': [0, 453, 434],
#  'CPLX0-7916[c]': [373, 373, 373],
#  'EG12123-MONOMER[c]': [178, 178, 178],
#  'FNR-4FE-4S-CPLX[c]': [0, 0, 0],
#  'MONOMER0-155[c]': [0, 1252, 1092],
#  'MONOMER0-160[c]': [0, 97, 80],
#  'MONOMER0-162[c]': [0, 134, 120],
#  'PC00010[c]': [90, 90, 90],
#  'PC00027[c]': [3282, 3282, 3285],
#  'PD00288[c]': [46198, 46219, 46236],
#  'PD00519[c]': [0, 0, 0],
#  'PHOSPHO-ARCA[c]': [0, 0, 0],
#  'PHOSPHO-BAER[c]': [0, 0, 0],
#  'PHOSPHO-BASR[c]': [0, 0, 0],
#  'PHOSPHO-DCUR[c]': [0, 0, 0],
#  'PHOSPHO-NARL[c]': [0, 0, 0],
#  'PUTA-CPLX[c]': [16, 8, 9],
#  'PC00007[c]': [121, 111, 111],
#  'PC00003[c]': [15, 15, 15],
#  'PC00004[c]': [1577, 1457, 1458],
#  'PC00005[c]': [117, 92, 92],
#  'CPLX0-7670[c]': [0, 104, 104],
# ...
