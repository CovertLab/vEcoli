# %%
# %%html
# <style>
# /* Any CSS style can go in here. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* Any CSS style can go in here. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import polars as pl

cols = ['Experiment', 'study', 'condition_id', 'rep_id', 'creator', 'run_date', 'Strain Description', 
 'Base Media', 'Carbon Source (g/L)', 'Nitrogen Source (g/L)', 'Electron Acceptor', 'Trace Element Mixture', 
 'Supplement', 'Temperature (C)', 'pH', 'Growth Rate (1/hr)']

sns.set(style="ticks", palette="Set2")

pl.Config(tbl_rows=30)

# %%
m = pl.read_csv("external_data/PRECISE2_metadata.tsv", separator="\t")
d = pl.read_csv("external_data/PRECISE2_counts.csv")
d
# Out:
# shape: (4_355, 821)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Geneid ┆ ecoli_0017 ┆ ecoli_0018 ┆ ecoli_008 ┆ … ┆ ecoli_005 ┆ ecoli_007 ┆ ecoli_005 ┆ ecoli_003 │
# │ ---    ┆ 8          ┆ 8          ┆ 25        ┆   ┆ 67        ┆ 84        ┆ 44        ┆ 38        │
# │ str    ┆ ---        ┆ ---        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │        ┆ i64        ┆ i64        ┆ i64       ┆   ┆ i64       ┆ i64       ┆ i64       ┆ i64       │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ b0001  ┆ 1033       ┆ 64         ┆ 1079      ┆ … ┆ 677       ┆ 101       ┆ 48        ┆ 385       │
# │ b0002  ┆ 4831       ┆ 47376      ┆ 29852     ┆ … ┆ 32192     ┆ 19660     ┆ 1827      ┆ 56611     │
# │ b0003  ┆ 1216       ┆ 14035      ┆ 8113      ┆ … ┆ 7113      ┆ 4766      ┆ 719       ┆ 16584     │
# │ b0004  ┆ 1201       ┆ 18761      ┆ 10339     ┆ … ┆ 9795      ┆ 7853      ┆ 821       ┆ 20620     │
# │ b0005  ┆ 77         ┆ 250        ┆ 161       ┆ … ┆ 424       ┆ 295       ┆ 98        ┆ 257       │
# │ b0006  ┆ 299        ┆ 848        ┆ 550       ┆ … ┆ 501       ┆ 519       ┆ 1709      ┆ 2146      │
# │ b0007  ┆ 160        ┆ 269        ┆ 91        ┆ … ┆ 438       ┆ 169       ┆ 175       ┆ 138       │
# │ b0008  ┆ 7288       ┆ 23266      ┆ 11841     ┆ … ┆ 17123     ┆ 14180     ┆ 4129      ┆ 13308     │
# │ b0009  ┆ 336        ┆ 591        ┆ 149       ┆ … ┆ 534       ┆ 625       ┆ 227       ┆ 256       │
# │ b0010  ┆ 224        ┆ 232        ┆ 61        ┆ … ┆ 86        ┆ 74        ┆ 80        ┆ 133       │
# │ b0011  ┆ 37         ┆ 46         ┆ 22        ┆ … ┆ 22        ┆ 11        ┆ 12        ┆ 35        │
# │ b0012  ┆ 2          ┆ 5          ┆ 2         ┆ … ┆ 10        ┆ 1         ┆ 7         ┆ 2         │
# │ b0013  ┆ 1          ┆ 9          ┆ 0         ┆ … ┆ 14        ┆ 3         ┆ 6         ┆ 6         │
# │ b0014  ┆ 10654      ┆ 30131      ┆ 16033     ┆ … ┆ 7838      ┆ 17175     ┆ 11183     ┆ 16104     │
# │ b0015  ┆ 2800       ┆ 3897       ┆ 1947      ┆ … ┆ 1184      ┆ 2222      ┆ 2110      ┆ 1952      │
# │ …      ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ b4389  ┆ 1170       ┆ 1702       ┆ 759       ┆ … ┆ 648       ┆ 1069      ┆ 342       ┆ 1127      │
# │ b4390  ┆ 1149       ┆ 1509       ┆ 727       ┆ … ┆ 1119      ┆ 936       ┆ 465       ┆ 1018      │
# │ b4391  ┆ 4456       ┆ 9286       ┆ 4245      ┆ … ┆ 4066      ┆ 3019      ┆ 1922      ┆ 3377      │
# │ b4392  ┆ 1638       ┆ 1806       ┆ 920       ┆ … ┆ 2061      ┆ 595       ┆ 652       ┆ 676       │
# │ b4393  ┆ 325        ┆ 758        ┆ 214       ┆ … ┆ 225       ┆ 249       ┆ 168       ┆ 309       │
# │ b4394  ┆ 325        ┆ 461        ┆ 325       ┆ … ┆ 437       ┆ 170       ┆ 240       ┆ 380       │
# │ b4395  ┆ 716        ┆ 1239       ┆ 458       ┆ … ┆ 432       ┆ 485       ┆ 307       ┆ 574       │
# │ b4396  ┆ 3216       ┆ 3248       ┆ 1232      ┆ … ┆ 2919      ┆ 1838      ┆ 559       ┆ 1397      │
# │ b4397  ┆ 270        ┆ 741        ┆ 347       ┆ … ┆ 240       ┆ 266       ┆ 117       ┆ 752       │
# │ b4398  ┆ 276        ┆ 549        ┆ 247       ┆ … ┆ 171       ┆ 295       ┆ 62        ┆ 456       │
# │ b4399  ┆ 212        ┆ 336        ┆ 127       ┆ … ┆ 156       ┆ 154       ┆ 74        ┆ 258       │
# │ b4400  ┆ 90         ┆ 141        ┆ 48        ┆ … ┆ 130       ┆ 16        ┆ 50        ┆ 90        │
# │ b4401  ┆ 9583       ┆ 12507      ┆ 4117      ┆ … ┆ 5409      ┆ 4864      ┆ 4090      ┆ 3605      │
# │ b4402  ┆ 18         ┆ 4          ┆ 16        ┆ … ┆ 71        ┆ 7         ┆ 26        ┆ 15        │
# │ b4403  ┆ 165        ┆ 298        ┆ 127       ┆ … ┆ 383       ┆ 118       ┆ 120       ┆ 237       │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# select only ICA
# m = m.filter((pl.col("study") == "ICA") & pl.col("condition_id").is_in(["wt_glc", "no3_anaero"]))
# m.select("condition_id").unique().to_numpy()

# %%
# melt data
dm = d.melt(id_vars="Geneid", variable_name="Experiment", value_name="Gene_count")
dj = dm.join(m, on="Experiment", how="left", coalesce=True)

cols = ['Experiment', 'Geneid', 'Gene_count', 'study', 'condition_id', 'rep_id', 'creator', 'run_date', 'Strain Description', 
 'Base Media', 'Carbon Source (g/L)', 'Nitrogen Source (g/L)', 'Electron Acceptor', 'Trace Element Mixture', 
 'Supplement', 'Temperature (C)', 'pH', 'Growth Rate (1/hr)']

dj.select(cols)
# Out:
# /var/folders/dx/0239zgvj0tgf46b5h8l7v_fc0000gn/T/ipykernel_86618/1637534321.py:2: DeprecationWarning: `DataFrame.melt` is deprecated; use `DataFrame.unpivot` instead, with `index` instead of `id_vars` and `on` instead of `value_vars`
#   dm = d.melt(id_vars="Geneid", variable_name="Experiment", value_name="Gene_count")
# shape: (3_571_100, 18)
# ┌─────────────┬────────┬────────────┬──────────┬───┬─────────────┬─────────────┬─────┬─────────────┐
# │ Experiment  ┆ Geneid ┆ Gene_count ┆ study    ┆ … ┆ Supplement  ┆ Temperature ┆ pH  ┆ Growth Rate │
# │ ---         ┆ ---    ┆ ---        ┆ ---      ┆   ┆ ---         ┆ (C)         ┆ --- ┆ (1/hr)      │
# │ str         ┆ str    ┆ i64        ┆ str      ┆   ┆ str         ┆ ---         ┆ f64 ┆ ---         │
# │             ┆        ┆            ┆          ┆   ┆             ┆ i64         ┆     ┆ f64         │
# ╞═════════════╪════════╪════════════╪══════════╪═══╪═════════════╪═════════════╪═════╪═════════════╡
# │ ecoli_00178 ┆ b0001  ┆ 1033       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0002  ┆ 4831       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0003  ┆ 1216       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0004  ┆ 1201       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0005  ┆ 77         ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0006  ┆ 299        ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0007  ┆ 160        ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0008  ┆ 7288       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0009  ┆ 336        ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0010  ┆ 224        ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0011  ┆ 37         ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0012  ┆ 2          ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0013  ┆ 1          ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0014  ┆ 10654      ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ ecoli_00178 ┆ b0015  ┆ 2800       ┆ ICA      ┆ … ┆ glutathione ┆ 37          ┆ 7.0 ┆ 0.07        │
# │             ┆        ┆            ┆          ┆   ┆ (1mM)       ┆             ┆     ┆             │
# │ …           ┆ …      ┆ …          ┆ …        ┆ … ┆ …           ┆ …           ┆ …   ┆ …           │
# │ ecoli_00338 ┆ b4389  ┆ 1127       ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4390  ┆ 1018       ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4391  ┆ 3377       ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4392  ┆ 676        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4393  ┆ 309        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4394  ┆ 380        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4395  ┆ 574        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4396  ┆ 1397       ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4397  ┆ 752        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4398  ┆ 456        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4399  ┆ 258        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4400  ┆ 90         ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4401  ┆ 3605       ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4402  ┆ 15         ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# │ ecoli_00338 ┆ b4403  ┆ 237        ┆ OxyR ALE ┆ … ┆ H2O2(2mM)   ┆ 37          ┆ 7.0 ┆ null        │
# └─────────────┴────────┴────────────┴──────────┴───┴─────────────┴─────────────┴─────┴─────────────┘

# %%
dj.filter(pl.col('Geneid')=='b3916').to_pandas()
# Out:
#     Geneid   Experiment  Gene_count                    sample_id  \
# 0    b3916  ecoli_00178        6592                  ica__gth__2
# 1    b3916  ecoli_00188        6708              ica__thm_gal__2
# 2    b3916  ecoli_00825        4425            ytf2__yfeC_glc__2
# 3    b3916  ecoli_00057        1084              omics__bw_ac__2
# 4    b3916  ecoli_00471        1256        tcs__del_cpxR_etoh__1
# ..     ...          ...         ...                          ...
# 815  b3916  ecoli_00419        4764    hot_tale__hot_ale8_37c__1
# 816  b3916  ecoli_00567       15346       ros_tale__16_32_0pq__2
# 817  b3916  ecoli_00784        6990  acid_tale__acid_ale2_pH5__2
# 818  b3916  ecoli_00544       11515      ros_tale__9_77_750pq__1
# 819  b3916  ecoli_00338       10724     oxyR__oxyR_ale18_h2o2__2
#
#                      study project_id     condition_id  rep_id  \
# 0                      ICA        ica              gth       2
# 1                      ICA        ica          thm_gal       2
# 2                    yTF 2       ytf2         yfeC_glc       2
# 3                    Omics      omics            bw_ac       2
# 4    Two Component Systems        tcs    del_cpxR_etoh       1
# ..                     ...        ...              ...     ...
# 815                HOT ALE   hot_tale     hot_ale8_37c       1
# 816               ROS TALE   ros_tale        16_32_0pq       2
# 817                 pH ALE  acid_tale    acid_ale2_pH5       2
# 818               ROS TALE   ros_tale       9_77_750pq       1
# 819               OxyR ALE       oxyR  oxyR_ale18_h2o2       2
#
#               contact           creator  ... Sequencing Machine  \
# 0        Anand Sastry       Ying Hefner  ...         HiSeq 4000
# 1        Anand Sastry       Ying Hefner  ...         HiSeq 4000
# 2              Ye Gao            Ye Gao  ...            NovaSeq
# 3        Donghyuk Kim      Donghyuk Kim  ...              MiSeq
# 4    Katherine Decker  Julia Kleinmanns  ...               None
# ..                ...               ...  ...                ...
# 815           Ke Chen           Ke Chen  ...              HiSeq
# 816      Kevin Rychel        Justin Tan  ...            NextSeq
# 817            Bin Du    Richard Szubin  ...              HiSeq
# 818      Kevin Rychel        Justin Tan  ...            NextSeq
# 819     Amitesh Anand     Amitesh Anand  ...         HiSeq 4000
#
#     Additional Details Biological Replicates  \
# 0                 None                     2
# 1                 None                     2
# 2                 None                     2
# 3                 None                     2
# 4                 None                     2
# ..                 ...                   ...
# 815               None                     2
# 816               None                     4
# 817               None                     2
# 818               None                     2
# 819               None                     2
#
#                                        DOI        GEO Published         SRX  \
# 0                                     None  GSE122295       1.0  SRX4993789
# 1                                     None  GSE122295       1.0  SRX4993799
# 2                                     None       None       NaN        None
# 3              doi.org/10.1038/ncomms13091   GSE59759       1.0   SRX661388
# 4                                     None       None       0.0        None
# ..                                     ...        ...       ...         ...
# 815                                   None       None       0.0        None
# 816                                   None       None       0.0        None
# 817                                   None       None       0.0        None
# 818                                   None       None       0.0        None
# 819  https://doi.org/10.1093/molbev/msz251       None       1.0        None
#
#             Run LibraryLayout  Platform
# 0    SRR8173236        PAIRED  ILLUMINA
# 1    SRR8173246        PAIRED  ILLUMINA
# 2          None        PAIRED  ILLUMINA
# 3    SRR1525099        PAIRED  ILLUMINA
# 4          None        PAIRED  ILLUMINA
# ..          ...           ...       ...
# 815        None        PAIRED  ILLUMINA
# 816        None        PAIRED  ILLUMINA
# 817        None        SINGLE  ILLUMINA
# 818        None        PAIRED  ILLUMINA
# 819        None        PAIRED  ILLUMINA
#
# [820 rows x 36 columns]

# %%
plt.figure(figsize=(6, 3))

sns.stripplot(y='Geneid', x="Gene_count", 
              data = dj.filter((pl.col('Geneid').is_in(["b3988", "b3942"])) & (pl.col("Gene_count") > 0))
              .with_columns(pl.col("Geneid").replace({"b3988": "rpoC", "b3942": "katG"}))
              .to_pandas(), 
            log_scale=True,  
            size=3,
            # common_norm=False, legend=True, 
            # kind="hist"
              )

# Set the x-axis label
plt.ylabel('Gene ID')
plt.xlabel('Transcript per million (TPM)')

# set x axis limit to 10^3 to 10^6
plt.xlim(10**2, 10**6)

# save as svg
plt.savefig("figures/katG_rpoC_expression.svg", dpi=300, bbox_inches='tight')

# save as png
plt.savefig("figures/katG_rpoC_expression.png", dpi=300, bbox_inches='tight')
#

# %%
dj.filter(pl.col("Geneid") == "b3772").sort(pl.col("Gene_count")).head(20)
# Out:
# shape: (20, 36)
# ┌────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Geneid ┆ Experiment ┆ Gene_count ┆ sample_id  ┆ … ┆ SRX       ┆ Run       ┆ LibraryLa ┆ Platform │
# │ ---    ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ ---       ┆ yout      ┆ ---      │
# │ str    ┆ str        ┆ i64        ┆ str        ┆   ┆ str       ┆ str       ┆ ---       ┆ str      │
# │        ┆            ┆            ┆            ┆   ┆           ┆           ┆ str       ┆          │
# ╞════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ b3772  ┆ ecoli_0015 ┆ 4          ┆ ssw__glc_a ┆ … ┆ SRX274480 ┆ SRR545673 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 6          ┆            ┆ c_glc2__1  ┆   ┆ 4         ┆ 5         ┆           ┆          │
# │ b3772  ┆ ecoli_0072 ┆ 23         ┆ cck_pgi__p ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 6          ┆            ┆ gi_ale2__1 ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0009 ┆ 61         ┆ rpoB__wt_l ┆ … ┆ SRX651938 ┆ SRR151429 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 4          ┆            ┆ b__1       ┆   ┆           ┆ 1         ┆           ┆          │
# │ b3772  ┆ ecoli_0036 ┆ 65         ┆ abx_media_ ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 5          ┆            ┆ _rpmi_ctrl ┆   ┆           ┆           ┆           ┆          │
# │        ┆            ┆            ┆ __1        ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0037 ┆ 78         ┆ abx_media_ ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 2          ┆            ┆ _rpmi_mero ┆   ┆           ┆           ┆           ┆          │
# │        ┆            ┆            ┆ __2        ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0009 ┆ 83         ┆ rpoB__rpoB ┆ … ┆ SRX651942 ┆ SRR151429 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 8          ┆            ┆ E546V_lb__ ┆   ┆           ┆ 6         ┆           ┆          │
# │        ┆            ┆            ┆ 1          ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0050 ┆ 86         ┆ tcs__wt_lb ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 6          ┆            ┆ __2        ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0037 ┆ 89         ┆ abx_media_ ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 1          ┆            ┆ _rpmi_mero ┆   ┆           ┆           ┆           ┆          │
# │        ┆            ┆            ┆ __1        ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0036 ┆ 90         ┆ abx_media_ ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 7          ┆            ┆ _camhb_ctr ┆   ┆           ┆           ┆           ┆          │
# │        ┆            ┆            ┆ l__1       ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0010 ┆ 99         ┆ rpoB__rpoB ┆ … ┆ SRX651946 ┆ SRR151430 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 3          ┆            ┆ E672K_lb__ ┆   ┆           ┆ 2         ┆           ┆          │
# │        ┆            ┆            ┆ 1          ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0014 ┆ 106        ┆ ssw__wt_ac ┆ … ┆ SRX274480 ┆ SRR545673 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 2          ┆            ┆ __1        ┆   ┆ 0         ┆ 1         ┆           ┆          │
# │ b3772  ┆ ecoli_0009 ┆ 109        ┆ rpoB__wt_l ┆ … ┆ SRX651938 ┆ SRR151429 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 5          ┆            ┆ b__2       ┆   ┆           ┆ 2         ┆           ┆          │
# │ b3772  ┆ ecoli_0050 ┆ 110        ┆ tcs__wt_lb ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 5          ┆            ┆ __1        ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0046 ┆ 131        ┆ tcs__del_b ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 3          ┆            ┆ aeR_lb__1  ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0046 ┆ 133        ┆ tcs__del_b ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 4          ┆            ┆ aeR_lb__2  ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0038 ┆ 135        ┆ abx_media_ ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 4          ┆            ┆ _rpmi_cef_ ┆   ┆           ┆           ┆           ┆          │
# │        ┆            ┆            ┆ _2         ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0049 ┆ 136        ┆ tcs__del_r ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 0          ┆            ┆ csB_lb__2  ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0047 ┆ 138        ┆ tcs__del_c ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 4          ┆            ┆ pxR_lb__2  ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0010 ┆ 147        ┆ rpoB__rpoB ┆ … ┆ SRX651946 ┆ SRR151430 ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 4          ┆            ┆ E672K_lb__ ┆   ┆           ┆ 3         ┆           ┆          │
# │        ┆            ┆            ┆ 2          ┆   ┆           ┆           ┆           ┆          │
# │ b3772  ┆ ecoli_0047 ┆ 152        ┆ tcs__del_c ┆ … ┆ null      ┆ null      ┆ PAIRED    ┆ ILLUMINA │
# │        ┆ 3          ┆            ┆ pxR_lb__1  ┆   ┆           ┆           ┆           ┆          │
# └────────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
sns.displot(x='Gene_count', data = dj.filter(pl.col('Geneid')=='b1604').to_pandas(), 
            kind='kde', log_scale=[10,False], hue='Base Media', common_norm=False)

# %% [markdown]
# # Li 2014

# %%
li = pl.read_csv("external_data/Li_2014_profiling.csv")
li.head(5)
# Out:
# shape: (5, 4)
# ┌──────┬───────────────┬──────────────┬─────────────────────────────────┐
# │ Gene ┆ MOPS complete ┆ MOPS minimal ┆ MOPS complete without methioni… │
# │ ---  ┆ ---           ┆ ---          ┆ ---                             │
# │ str  ┆ i64           ┆ i64          ┆ i64                             │
# ╞══════╪═══════════════╪══════════════╪═════════════════════════════════╡
# │ aaeA ┆ 62            ┆ 5            ┆ 21                              │
# │ aaeB ┆ 16            ┆ 2            ┆ 0                               │
# │ aaeR ┆ 203           ┆ 79           ┆ 141                             │
# │ aaeX ┆ 28            ┆ 5            ┆ 11                              │
# │ aas  ┆ 188           ┆ 80           ┆ 162                             │
# └──────┴───────────────┴──────────────┴─────────────────────────────────┘

# %%
li = li.with_columns( ( (pl.col("MOPS complete without methionine") + 10) / (10 + pl.col("MOPS complete"))).alias("dropout FC") )
li = li.with_columns( ( (pl.col("MOPS minimal") + 10) / (10 + pl.col("MOPS complete"))).alias("minimal FC") )
li.head(5)
# Out:
# shape: (5, 6)
# ┌──────┬───────────────┬──────────────┬──────────────────────────────────┬────────────┬────────────┐
# │ Gene ┆ MOPS complete ┆ MOPS minimal ┆ MOPS complete without methionine ┆ dropout FC ┆ minimal FC │
# │ ---  ┆ ---           ┆ ---          ┆ ---                              ┆ ---        ┆ ---        │
# │ str  ┆ i64           ┆ i64          ┆ i64                              ┆ f64        ┆ f64        │
# ╞══════╪═══════════════╪══════════════╪══════════════════════════════════╪════════════╪════════════╡
# │ aaeA ┆ 62            ┆ 5            ┆ 21                               ┆ 0.430556   ┆ 0.208333   │
# │ aaeB ┆ 16            ┆ 2            ┆ 0                                ┆ 0.384615   ┆ 0.461538   │
# │ aaeR ┆ 203           ┆ 79           ┆ 141                              ┆ 0.70892    ┆ 0.41784    │
# │ aaeX ┆ 28            ┆ 5            ┆ 11                               ┆ 0.552632   ┆ 0.394737   │
# │ aas  ┆ 188           ┆ 80           ┆ 162                              ┆ 0.868687   ┆ 0.454545   │
# └──────┴───────────────┴──────────────┴──────────────────────────────────┴────────────┴────────────┘

# %%
li.sort("dropout FC").tail(40)
# Out:
# shape: (40, 6)
# ┌──────┬───────────────┬──────────────┬───────────────────────┬─────────────┬────────────┐
# │ Gene ┆ MOPS complete ┆ MOPS minimal ┆ MOPS complete without ┆ dropout FC  ┆ minimal FC │
# │ ---  ┆ ---           ┆ ---          ┆ methionine            ┆ ---         ┆ ---        │
# │ str  ┆ i64           ┆ i64          ┆ ---                   ┆ f64         ┆ f64        │
# │      ┆               ┆              ┆ i64                   ┆             ┆            │
# ╞══════╪═══════════════╪══════════════╪═══════════════════════╪═════════════╪════════════╡
# │ gsiB ┆ 71            ┆ 574          ┆ 686                   ┆ 8.592593    ┆ 7.209877   │
# │ ilvX ┆ 102           ┆ 972          ┆ 1022                  ┆ 9.214286    ┆ 8.767857   │
# │ iaaA ┆ 74            ┆ 257          ┆ 809                   ┆ 9.75        ┆ 3.178571   │
# │ metL ┆ 972           ┆ 581          ┆ 9779                  ┆ 9.968432    ┆ 0.601833   │
# │ metC ┆ 596           ┆ 1256         ┆ 7277                  ┆ 12.024752   ┆ 2.089109   │
# │ …    ┆ …             ┆ …            ┆ …                     ┆ …           ┆ …          │
# │ cysP ┆ 24            ┆ 2281         ┆ 8037                  ┆ 236.676471  ┆ 67.382353  │
# │ metE ┆ 571           ┆ 63552        ┆ 282818                ┆ 486.795181  ┆ 109.401033 │
# │ cysN ┆ 16            ┆ 3066         ┆ 13629                 ┆ 524.576923  ┆ 118.307692 │
# │ cysD ┆ 10            ┆ 4115         ┆ 22588                 ┆ 1129.9      ┆ 206.25     │
# │ sbp  ┆ 7             ┆ 831          ┆ 28069                 ┆ 1651.705882 ┆ 49.470588  │
# └──────┴───────────────┴──────────────┴───────────────────────┴─────────────┴────────────┘

# %%
li.sum()
# Out:
# shape: (1, 6)
# ┌──────┬───────────────┬──────────────┬───────────────────────┬─────────────┬─────────────┐
# │ Gene ┆ MOPS complete ┆ MOPS minimal ┆ MOPS complete without ┆ dropout FC  ┆ minimal FC  │
# │ ---  ┆ ---           ┆ ---          ┆ methionine            ┆ ---         ┆ ---         │
# │ str  ┆ i64           ┆ i64          ┆ ---                   ┆ f64         ┆ f64         │
# │      ┆               ┆              ┆ i64                   ┆             ┆             │
# ╞══════╪═══════════════╪══════════════╪═══════════════════════╪═════════════╪═════════════╡
# │ null ┆ 18051444      ┆ 5627623      ┆ 10452920              ┆ 9375.465686 ┆ 6772.563954 │
# └──────┴───────────────┴──────────────┴───────────────────────┴─────────────┴─────────────┘
