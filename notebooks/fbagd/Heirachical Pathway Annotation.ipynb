# %% [markdown]
# ### Imports

# %%
import requests
import pandas as pd
import numpy as np
from xml.etree import ElementTree
from collections import defaultdict
import time
from tqdm import tqdm

# %% [markdown]
# ### Set up API Environment

# %%
s = requests.Session() # create session
# Po`st login credentials to session:
s.post('https://websvc.biocyc.org/credentials/login/', data={'email':'aniketh@stanford.edu', 'password':'dcy*BWEfAm'})
# Out:
# <Response [200]>

# %% [markdown]
# ### Helper Functions

# %%
def etree_to_dict(t):
    d = {t.tag: {} if t.attrib else None}
    children = list(t)
    if children:
        dd = defaultdict(list)
        for dc in map(etree_to_dict, children):
            for k, v in dc.items():
                dd[k].append(v)
        d = {t.tag: {k: v[0] if len(v) == 1 else v
                     for k, v in dd.items()}}
    if t.attrib:
        d[t.tag].update(('@' + k, v)
                        for k, v in t.attrib.items())
    if t.text:
        text = t.text.strip()
        if children or t.attrib:
            if text:
                d[t.tag]['#text'] = text
        else:
            d[t.tag] = text
    return d

# %% [markdown]
# ### Get Data

# %%
flows = pd.read_csv("whole_cell_flow_data.csv")
stoichiometry = pd.read_csv("whole_cell_s_matrix (1).csv")
metabolite_names = list(stoichiometry['Unnamed: 0'])
reaction_names = list(stoichiometry.columns[1:])
n_mets = len(metabolite_names)
n_rxns = len(reaction_names)
S = stoichiometry.iloc[:, 1:].to_numpy()

# %%
metabolites_processed = {}
for meta in metabolite_names:
    new = meta.split('[', 1)[0]
    metabolites_processed[meta] = new

# %%
reactions_processed = {}

for rxn in reaction_names:
    new = rxn
    
    if "(reverse)" in new:
        idx = new.find("(reverse)")
        new = new[:idx - 1]
    
    if "__" in new:
        idx = new.find("__")
        new = new[:idx]
    
    if "-RXN" in new:
        idx = new.find("-RXN")
        new = new[:idx + 4]
    
    reactions_processed[rxn] = new

# %% [markdown]
# ### Get Hierarchy for Reactions

# %%
def bfs_pathways(ID):
    
    # Initialize Variables
    pathway_tree = {}
    issue = {}
    queue = [(ID, 0)]
        
    # Loop
    while len(queue) > 0:
        
        # New Value
        ID, curr_lvl = queue.pop(0)
        
        # API
        request = "https://websvc.biocyc.org/getxml?id=ECOLI:" + ID
        response = s.get(request)
        if response.status_code == 200:
            tree = ElementTree.fromstring(response.content)
            r = etree_to_dict(tree)
            
        # Error
        else:
            if curr_lvl not in issue:
                issue[curr_lvl] = []
            issue[curr_lvl].append((ID, response.status_code))
            continue
            
        curr = r['ptools-xml']
        
        if 'Pathway' in curr and 'parent' in curr['Pathway']:
            parents = curr['Pathway']['parent']

            if type(parents) is list:
                for parent in parents:
                    try:
                        queue.append((parent['Pathway']['@frameid'], curr_lvl + 1))
                    except KeyError:
                        if curr_lvl not in issue:
                            issue[curr_lvl] = []
                        issue[curr_lvl].append((parent, KeyError))
            else:
                try:
                    queue.append((parents['Pathway']['@frameid'], curr_lvl + 1))
                except KeyError:
                    if curr_lvl not in issue:
                        issue[curr_lvl] = []
                    issue[curr_lvl].append((parents, KeyError))   
            
        elif 'Reaction' in curr and 'in-pathway' in curr['Reaction']:
            if 'Pathway' in curr['Reaction']['in-pathway']:
                parents = curr['Reaction']['in-pathway']['Pathway']
            else:
                parents = curr['Reaction']['in-pathway']['Reaction']
        
            if type(parents) is list:
                for parent in parents:
                    try:
                        queue.append((parent['@frameid'], curr_lvl + 1))
                    except KeyError:
                        if curr_lvl not in issue:
                            issue[curr_lvl] = []
                        issue[curr_lvl].append((parent, KeyError))
            else:
                try:
                    queue.append((parents['@frameid'], curr_lvl + 1))
                except KeyError:
                    if curr_lvl not in issue:
                        issue[curr_lvl] = []
                    issue[curr_lvl].append((parents, KeyError)) 
        
            
            
        if curr_lvl not in pathway_tree:
            pathway_tree[ID] = -1 * float("inf")
        pathway_tree[ID] = max(curr_lvl, pathway_tree[ID])
        
    result = {}
    
    for key in pathway_tree:
        value = pathway_tree[key]
        
        if value not in result:
            result[value] = []
        result[value].append(key)
        
    return result, issue

# %%
print(bfs_pathways('Purine-Deoxyribonuc-De-Novo-Biosynthesis'))
# Out:
# ({0: ['Purine-Deoxyribonuc-De-Novo-Biosynthesis'], 1: ['Deoxyribonucleotide-Biosynthesis', 'Purine-Nucleotide-De-Novo-Biosynthesis'], 3: ['Nucleotide-Biosynthesis'], 2: ['PUR-NUC-SYN'], 4: ['Biosynthesis']}, {})

# %%
not_found = {}
pathway_forests = {}
for reaction in tqdm(reaction_names):
    ID = reactions_processed[reaction]
    pathway_forests[reaction], not_found[reaction] = bfs_pathways(ID)
# Out:
# 100%|█████████████████████████████████████████| 470/470 [05:21<00:00,  1.46it/s]

# %%
pathway_forests
# Out:
# {'1.5.1.20-RXN-5-METHYL-THF/NAD//METHYLENE-THF/NADH/PROTON.44. (reverse)': {0: ['1.5.1.20-RXN']},
#  '1.5.1.20-RXN-CPD-1302/NAD//CPD-12996/NADH/PROTON.36. (reverse)': {0: ['1.5.1.20-RXN']},
#  '1PFRUCTPHOSN-RXN': {0: ['1PFRUCTPHOSN-RXN'],
#   1: ['PWY0-1314'],
#   2: ['Sugars-And-Polysaccharides-Degradation'],
#   3: ['Carbohydrates-Degradation'],
#   4: ['Degradation']},
#  '1TRANSKETO-RXN (reverse)': {0: ['1TRANSKETO-RXN'],
#   1: ['NONOXIPENT-PWY'],
#   2: ['Pentose-Phosphate-Cycle'],
#   3: ['Energy-Metabolism']},
#  '2-DEHYDROPANTOATE-REDUCT-RXN (reverse)': {0: ['2-DEHYDROPANTOATE-REDUCT-RXN'],
#   1: ['PANTO-PWY'],
#   2: ['Pantothenate-Biosynthesis'],
#   3: ['CoA-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  '2-ISOPROPYLMALATESYN-RXN': {0: ['2-ISOPROPYLMALATESYN-RXN'],
#   1: ['LEUSYN-PWY'],
#   2: ['LEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  '2-OCTAPRENYL-6-METHOXYPHENOL-HYDROX-RXN': {0: ['2-OCTAPRENYL-6-METHOXYPHENOL-HYDROX-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2-OCTAPRENYL-6-OHPHENOL-METHY-RXN': {0: ['2-OCTAPRENYL-6-OHPHENOL-METHY-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2-OCTAPRENYL-METHOXY-BENZOQ-METH-RXN': {0: ['2-OCTAPRENYL-METHOXY-BENZOQ-METH-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2-OCTAPRENYLPHENOL-HYDROX-RXN': {0: ['2-OCTAPRENYLPHENOL-HYDROX-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2.3.1.157-RXN': {0: ['2.3.1.157-RXN'],
#   1: ['PWY0-1261', 'UDPNAGSYN-PWY'],
#   2: ['Anhydromuropeptides-Recycling', 'UDP-NAc-Glucosamine-Biosynthesis'],
#   3: ['Other-Degradation', 'UDP-Sugar-Biosynthesis'],
#   4: ['Degradation', 'SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2.5.1.19-RXN': {0: ['2.5.1.19-RXN'],
#   1: ['PWY-6163'],
#   2: ['Chorismate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  '2.5.1.64-RXN': {0: ['2.5.1.64-RXN'],
#   1: ['PWY-5837'],
#   2: ['DHNA-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '2.7.1.148-RXN': {0: ['2.7.1.148-RXN'],
#   1: ['NONMEVIPP-PWY'],
#   2: ['MEP-Pathways'],
#   3: ['Isopentenyl-Diphosphate-Biosynthesis'],
#   4: ['ISOPRENOIDS'],
#   5: ['Terpenoid-Biosynthesis'],
#   6: ['SECONDARY-METABOLITE-BIOSYNTHESIS'],
#   7: ['Biosynthesis']},
#  '2.7.7.60-RXN': {0: ['2.7.7.60-RXN'],
#   1: ['NONMEVIPP-PWY'],
#   2: ['MEP-Pathways'],
#   3: ['Isopentenyl-Diphosphate-Biosynthesis'],
#   4: ['ISOPRENOIDS'],
#   5: ['Terpenoid-Biosynthesis'],
#   6: ['SECONDARY-METABOLITE-BIOSYNTHESIS'],
#   7: ['Biosynthesis']},
#  '2.8.1.6-RXN': {0: ['2.8.1.6-RXN']},
#  '2OXOGLUTARATEDEH-RXN': {0: ['2OXOGLUTARATEDEH-RXN'],
#   1: ['TCA'],
#   2: ['TCA-VARIANTS'],
#   3: ['Energy-Metabolism']},
#  '2PGADEHYDRAT-RXN': {0: ['2PGADEHYDRAT-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  '2TRANSKETO-RXN (reverse)': {0: ['2TRANSKETO-RXN'],
#   1: ['NONOXIPENT-PWY'],
#   2: ['Pentose-Phosphate-Cycle'],
#   3: ['Energy-Metabolism']},
#  '3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-RXN-CPD-12996/2-KETO-ISOVALERATE/WATER//2-DEHYDROPANTOATE/CPD-1301.63.': {0: ['3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-RXN'],
#   1: ['PANTO-PWY'],
#   2: ['Pantothenate-Biosynthesis'],
#   3: ['CoA-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  '3-DEHYDROQUINATE-DEHYDRATASE-RXN': {0: ['3-DEHYDROQUINATE-DEHYDRATASE-RXN'],
#   1: ['PWY-6163'],
#   2: ['Chorismate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  '3-DEHYDROQUINATE-SYNTHASE-RXN': {0: ['3-DEHYDROQUINATE-SYNTHASE-RXN'],
#   1: ['PWY-6164'],
#   2: ['3-Dehydroquinate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  '3-OCTAPRENYL-4-OHBENZOATE-DECARBOX-RXN': {0: ['3-OCTAPRENYL-4-OHBENZOATE-DECARBOX-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '3.2.2.10-RXN-CMP/WATER//RIBOSE-5P/CYTOSINE.30.': {0: ['3.2.2.10-RXN']},
#  '3.2.2.10-RXN-UMP/WATER//RIBOSE-5P/URACIL.28.': {0: ['3.2.2.10-RXN']},
#  '325-BISPHOSPHATE-NUCLEOTIDASE-RXN': {0: ['325-BISPHOSPHATE-NUCLEOTIDASE-RXN']},
#  '3PGAREARR-RXN (reverse)': {0: ['3PGAREARR-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  '4OHBENZOATE-OCTAPRENYLTRANSFER-RXN': {0: ['4OHBENZOATE-OCTAPRENYLTRANSFER-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '5.1.3.20-RXN': {0: ['5.1.3.20-RXN'],
#   1: ['PWY0-1241'],
#   2: ['ADP-Sugar-Biosynthesis'],
#   3: ['SUGAR-NUCLEOTIDES'],
#   4: ['CARBO-BIOSYNTHESIS'],
#   5: ['Carbohydrates-Biosynthesis'],
#   6: ['Biosynthesis']},
#  '5.4.2.10-RXN-CPD-13469//GLUCOSAMINE-1P.26.': {0: ['5.4.2.10-RXN'],
#   1: ['PWY0-1261', 'UDPNAGSYN-PWY'],
#   2: ['Anhydromuropeptides-Recycling', 'UDP-NAc-Glucosamine-Biosynthesis'],
#   3: ['Other-Degradation', 'UDP-Sugar-Biosynthesis'],
#   4: ['Degradation', 'SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  '6PGLUCONOLACT-RXN': {0: ['6PGLUCONOLACT-RXN'],
#   1: ['OXIDATIVEPENT-PWY', 'GLYCOLYSIS-E-D'],
#   2: ['Pentose-Phosphate-Cycle', 'Super-Pathways'],
#   3: ['Energy-Metabolism']},
#  'ACECOATRANS-RXN-PROPIONYL-COA/ACET//PROPIONATE/ACETYL-COA.42.': {0: ['ACECOATRANS-RXN']},
#  'ACETATEKIN-RXN': {0: ['ACETATEKIN-RXN'],
#   1: ['FERMENTATION-PWY', 'PWY-5485', 'PWY0-1477', 'PWY0-1312'],
#   4: ['Fermentation-to-Acids'],
#   2: ['Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways',
#    'Pyruvate-Acetate-Fermentation',
#    'AMINE-DEG'],
#   3: ['Acetate-Formation',
#    'Alcohol-Biosynthesis',
#    'Pyruvate-Degradation',
#    'Degradation'],
#   5: ['Fermentation'],
#   6: ['Energy-Metabolism']},
#  'ACETOLACTREDUCTOISOM-RXN (reverse)': {0: ['ACETOLACTREDUCTOISOM-RXN'],
#   1: ['VALSYN-PWY'],
#   2: ['VALINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETOLACTSYN-RXN': {0: ['ACETOLACTSYN-RXN'],
#   1: ['VALSYN-PWY'],
#   2: ['VALINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETOOHBUTREDUCTOISOM-RXN (reverse)': {0: ['ACETOOHBUTREDUCTOISOM-RXN'],
#   1: ['ILEUSYN-PWY'],
#   2: ['ISOLEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETOOHBUTSYN-RXN': {0: ['ACETOOHBUTSYN-RXN'],
#   1: ['ILEUSYN-PWY'],
#   2: ['ISOLEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETYL-COA-ACETYLTRANSFER-RXN': {0: ['ACETYL-COA-ACETYLTRANSFER-RXN'],
#   1: ['PWY0-1337', 'ACETOACETATE-DEG-PWY'],
#   2: ['Fatty-Acid-Degradation', 'Other-Degradation'],
#   3: ['Fatty-Acid-and-Lipid-Degradation'],
#   4: ['Degradation']},
#  'ACETYLGLUTKIN-RXN': {0: ['ACETYLGLUTKIN-RXN'],
#   1: ['GLUTORN-PWY'],
#   2: ['L-Ornithine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETYLORNDEACET-RXN': {0: ['ACETYLORNDEACET-RXN'],
#   1: ['GLUTORN-PWY'],
#   2: ['L-Ornithine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACETYLORNTRANSAM-RXN (reverse)': {0: ['ACETYLORNTRANSAM-RXN'],
#   1: ['GLUTORN-PWY'],
#   2: ['L-Ornithine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ACONITATEDEHYDR-RXN': {0: ['ACONITATEDEHYDR-RXN'],
#   1: ['FERMENTATION-PWY', 'TCA', 'GLYOXYLATE-BYPASS'],
#   2: ['Fermentation-to-Acids',
#    'Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways',
#    'TCA-VARIANTS'],
#   5: ['Energy-Metabolism'],
#   4: ['Fermentation'],
#   3: ['Alcohol-Biosynthesis', 'Pyruvate-Degradation']},
#  'ACSERLY-RXN': {0: ['ACSERLY-RXN'],
#   1: ['CYSTSYN-PWY'],
#   2: ['CYSTEINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ADCLY-RXN': {0: ['ADCLY-RXN'],
#   1: ['PWY-6543'],
#   2: ['4-Aminobenzoate-Biosynthesis'],
#   3: ['AROMATIC-COMPOUNDS-BIOSYN'],
#   4: ['Biosynthesis']},
#  'ADENOSYLHOMOCYSTEINE-NUCLEOSIDASE-RXN': {0: ['ADENOSYLHOMOCYSTEINE-NUCLEOSIDASE-RXN'],
#   1: ['PWY-6151', 'PWY-6153'],
#   2: ['S-adenosyl-L-methionine-Biosynthesis', 'Autoinducer-Biosynthesis'],
#   3: ['C1-Carrier-Biosynthesis',
#    'Enzyme-Cofactor-Biosynthesis',
#    'SECONDARY-METABOLITE-BIOSYNTHESIS'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'ADENPRIBOSYLTRAN-RXN (reverse)': {0: ['ADENPRIBOSYLTRAN-RXN'],
#   1: ['PWY-7805', 'PWY-6605'],
#   2: ['Phosphonate-Degradation', 'Adenine-Adenosine-Salvage'],
#   3: ['Phophonate-Metabolism', 'Purine-Nucleotides-Salvage'],
#   4: ['Phosphorus-Compounds', 'PUR-NUC-SYN'],
#   5: ['Noncarbon-Nutrients', 'Nucleotide-Biosynthesis'],
#   6: ['Degradation', 'Biosynthesis']},
#  'ADENYL-KIN-RXN': {0: ['ADENYL-KIN-RXN'],
#   1: ['PWY-7219'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'ADENYLOSUCCINATE-SYNTHASE-RXN': {0: ['ADENYLOSUCCINATE-SYNTHASE-RXN'],
#   1: ['PWY-7219'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'ADENYLYLSULFKIN-RXN': {0: ['ADENYLYLSULFKIN-RXN'],
#   1: ['PWY-5340'],
#   2: ['Activation', 'Sulfur-Metabolism'],
#   3: ['Activation-Inactivation-Interconversion', 'Noncarbon-Nutrients'],
#   4: ['Degradation']},
#  'ADOMET-DMK-METHYLTRANSFER-RXN': {0: ['ADOMET-DMK-METHYLTRANSFER-RXN'],
#   1: ['MENAQUINONESYN-PWY'],
#   2: ['Menaquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'AICARSYN-RXN': {0: ['AICARSYN-RXN'],
#   1: ['PWY-6123'],
#   2: ['IMP-Biosynthesis'],
#   3: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   4: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'AICARTRANSFORM-RXN-10-FORMYL-THF/AICAR//THF/PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE.62.': {0: ['AICARTRANSFORM-RXN'],
#   1: ['PWY-6123'],
#   2: ['IMP-Biosynthesis'],
#   3: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   4: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'AIRS-RXN': {0: ['AIRS-RXN'],
#   1: ['PWY-6122', 'PWY-6121', 'PWY-6277'],
#   2: ['AIR-Biosynthesis', 'Super-Pathways'],
#   3: ['PUR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ALANINE-AMINOTRANSFERASE-RXN (reverse)': {0: ['ALANINE-AMINOTRANSFERASE-RXN'],
#   1: ['ALANINE-SYN2-PWY'],
#   2: ['ALANINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ALARACECAT-RXN': {0: ['ALARACECAT-RXN'],
#   1: ['PWY-8072', 'ALADEG-PWY'],
#   2: ['Other-Amino-Acid-Biosynthesis', 'ALANINE-DEG'],
#   3: ['Amino-Acid-Biosynthesis', 'Proteinogenic-Amino-Acids-Degradation'],
#   4: ['Biosynthesis', 'Amino-Acid-Degradation'],
#   5: ['Degradation']},
#  'AMPSYN-RXN': {0: ['AMPSYN-RXN'],
#   1: ['PWY-7219'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'ANTHRANSYN-RXN': {0: ['ANTHRANSYN-RXN'],
#   1: ['TRPSYN-PWY'],
#   2: ['TRYPTOPHAN-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ARGSUCCINLYA-RXN': {0: ['ARGSUCCINLYA-RXN'],
#   1: ['ARGSYN-PWY'],
#   2: ['ARGININE-SYN', 'Super-Pathways'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ARGSUCCINSYN-RXN': {0: ['ARGSUCCINSYN-RXN'],
#   1: ['ARGSYN-PWY'],
#   2: ['ARGININE-SYN', 'Super-Pathways'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ASNSYNA-RXN': {0: ['ASNSYNA-RXN'],
#   1: ['ASPARAGINESYN-PWY'],
#   2: ['ASPARAGINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ASPAMINOTRANS-RXN': {0: ['ASPAMINOTRANS-RXN'],
#   1: ['GLUTDEG-PWY', 'ASPARTATESYN-PWY'],
#   2: ['GLUTAMATE-DEG', 'ASPARTATE-SYN'],
#   3: ['Proteinogenic-Amino-Acids-Degradation', 'IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Degradation', 'Amino-Acid-Biosynthesis'],
#   5: ['Degradation', 'Biosynthesis']},
#  'ASPARTASE-RXN (reverse)': {0: ['ASPARTASE-RXN'],
#   1: ['PWY-8294', 'PWY-8291', 'ASPASN-PWY', 'GLUTDEG-PWY'],
#   2: ['ASPARTATE-DEG',
#    'Amino-Acid-Biosynthesis',
#    'Super-Pathways',
#    'GLUTAMATE-DEG'],
#   3: ['Proteinogenic-Amino-Acids-Degradation', 'Biosynthesis'],
#   4: ['Amino-Acid-Degradation'],
#   5: ['Degradation']},
#  'ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN (reverse)': {0: ['ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN'],
#   1: ['DAPLYSINESYN-PWY', 'HOMOSERSYN-PWY'],
#   2: ['LYSINE-SYN', 'Other-Amino-Acid-Biosynthesis'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ASPARTATEKIN-RXN': {0: ['ASPARTATEKIN-RXN'],
#   1: ['DAPLYSINESYN-PWY', 'HOMOSERSYN-PWY'],
#   2: ['LYSINE-SYN', 'Other-Amino-Acid-Biosynthesis'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ASPCARBTRANS-RXN': {0: ['ASPCARBTRANS-RXN'],
#   1: ['PWY-5686'],
#   2: ['UMP-Biosynthesis'],
#   3: ['Pyrimid-Ribonucleot-De-Novo-Biosyn'],
#   4: ['Pyrimidine-De-Novo-Biosyn'],
#   5: ['PYR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'ASPDECARBOX-RXN': {0: ['ASPDECARBOX-RXN'],
#   1: ['PWY-5155'],
#   2: ['Beta-Alanine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ATPPHOSPHORIBOSYLTRANS-RXN (reverse)': {0: ['ATPPHOSPHORIBOSYLTRANS-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ATPSYN-RXN (reverse)': {0: ['ATPSYN-RXN'],
#   1: ['PWY-7980'],
#   2: ['Energy-Metabolism']},
#  'BRANCHED-CHAINAMINOTRANSFERILEU-RXN (reverse)': {0: ['BRANCHED-CHAINAMINOTRANSFERILEU-RXN'],
#   1: ['ILEUSYN-PWY'],
#   2: ['ISOLEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'BRANCHED-CHAINAMINOTRANSFERLEU-RXN (reverse)': {0: ['BRANCHED-CHAINAMINOTRANSFERLEU-RXN'],
#   1: ['LEUSYN-PWY'],
#   2: ['LEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'BRANCHED-CHAINAMINOTRANSFERVAL-RXN (reverse)': {0: ['BRANCHED-CHAINAMINOTRANSFERVAL-RXN'],
#   1: ['ALANINE-VALINESYN-PWY', 'VALSYN-PWY'],
#   2: ['ALANINE-SYN', 'VALINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'CARDIOLIPSYN-RXN-CPD-8260//CPD-12824/GLYCEROL.29.': {0: ['CARDIOLIPSYN-RXN'],
#   1: ['PWY-5668'],
#   2: ['Cardiolipin-Biosynthesis'],
#   3: ['Phospholipid-Biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'CDPDIGLYSYN-RXN-CTP/CPD0-1422/PROTON//CPD-12815/PPI.36.': {0: ['CDPDIGLYSYN-RXN'],
#   1: ['PWY-5667', 'PWY0-1319'],
#   2: ['CDP-diacylglycerol-Biosynthesis'],
#   3: ['Phospholipid-Biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'CDPKIN-RXN': {0: ['CDPKIN-RXN'],
#   1: ['PWY-7205', 'PWY0-163'],
#   2: ['Pyrimidine-Nucleotide-Salvage'],
#   3: ['PYR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'CHORISMATE-SYNTHASE-RXN': {0: ['CHORISMATE-SYNTHASE-RXN'],
#   1: ['PWY-6163'],
#   2: ['Chorismate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'CHORPYRLY-RXN': {0: ['CHORPYRLY-RXN'],
#   1: ['PWY-5755'],
#   2: ['4-Hydroxybenzoate-Biosynthesis'],
#   3: ['AROMATIC-COMPOUNDS-BIOSYN'],
#   4: ['Biosynthesis']},
#  'CITSYN-RXN': {0: ['CITSYN-RXN'],
#   1: ['FERMENTATION-PWY', 'TCA', 'GLYOXYLATE-BYPASS'],
#   2: ['Fermentation-to-Acids',
#    'Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways',
#    'TCA-VARIANTS'],
#   5: ['Energy-Metabolism'],
#   4: ['Fermentation'],
#   3: ['Alcohol-Biosynthesis', 'Pyruvate-Degradation']},
#  'CPM-KDOSYNTH-RXN': {0: ['CPM-KDOSYNTH-RXN'],
#   1: ['PWY-1269'],
#   2: ['CMP-KDO-Biosynthesis'],
#   3: ['CMP-Sugar-Biosynthesis'],
#   4: ['SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'CYSTATHIONINE-BETA-LYASE-RXN': {0: ['CYSTATHIONINE-BETA-LYASE-RXN'],
#   1: ['HOMOSER-METSYN-PWY'],
#   2: ['Methionine-De-novo-Biosynthesis'],
#   3: ['METHIONINE-SYN'],
#   4: ['IND-AMINO-ACID-SYN'],
#   5: ['Amino-Acid-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'D-PPENTOMUT-RXN (reverse)': {0: ['D-PPENTOMUT-RXN'],
#   1: ['PWY-7180'],
#   2: ['Sugar-Derivatives'],
#   3: ['Sugars-And-Polysaccharides-Degradation'],
#   4: ['Carbohydrates-Degradation'],
#   5: ['Degradation']},
#  'DAPASYN-RXN': {0: ['DAPASYN-RXN'],
#   1: ['PWY0-1507'],
#   2: ['BIOTIN-SYN'],
#   3: ['Enzyme-Cofactor-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DEOXYADENPHOSPHOR-RXN (reverse)': {0: ['DEOXYADENPHOSPHOR-RXN'],
#   1: ['PWY-7179'],
#   2: ['Purine-Degradation'],
#   3: ['NUCLEO-DEG'],
#   4: ['Degradation']},
#  'DEOXYGUANPHOSPHOR-RXN (reverse)': {0: ['DEOXYGUANPHOSPHOR-RXN'],
#   1: ['PWY-7179'],
#   2: ['Purine-Degradation'],
#   3: ['NUCLEO-DEG'],
#   4: ['Degradation']},
#  'DEOXYRIBOSE-P-ALD-RXN (reverse)': {0: ['DEOXYRIBOSE-P-ALD-RXN'],
#   1: ['PWY-7180'],
#   2: ['Sugar-Derivatives'],
#   3: ['Sugars-And-Polysaccharides-Degradation'],
#   4: ['Carbohydrates-Degradation'],
#   5: ['Degradation']},
#  'DEPHOSPHOCOAKIN-RXN': {0: ['DEPHOSPHOCOAKIN-RXN'],
#   1: ['COA-PWY'],
#   2: ['CoA-Biosynthesis'],
#   3: ['Carriers-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DETHIOBIOTIN-SYN-RXN': {0: ['DETHIOBIOTIN-SYN-RXN'],
#   1: ['PWY0-1507'],
#   2: ['BIOTIN-SYN'],
#   3: ['Enzyme-Cofactor-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DHBDEHYD-RXN': {0: ['DHBDEHYD-RXN'],
#   1: ['PWY-5901'],
#   2: ['AROMATIC-COMPOUNDS-BIOSYN'],
#   3: ['Biosynthesis']},
#  'DHHB-METHYLTRANSFER-RXN': {0: ['DHHB-METHYLTRANSFER-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'DIAMINOPIMDECARB-RXN': {0: ['DIAMINOPIMDECARB-RXN'],
#   1: ['DAPLYSINESYN-PWY'],
#   2: ['LYSINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DIAMINOPIMEPIM-RXN': {0: ['DIAMINOPIMEPIM-RXN'],
#   1: ['DAPLYSINESYN-PWY'],
#   2: ['LYSINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DIHYDRODIPICSYN-RXN': {0: ['DIHYDRODIPICSYN-RXN'],
#   1: ['DAPLYSINESYN-PWY'],
#   2: ['LYSINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DIHYDROFOLATESYNTH-RXN': {0: ['DIHYDROFOLATESYNTH-RXN'],
#   1: ['PWY-6614'],
#   2: ['Folate-Biosynthesis'],
#   3: ['C1-Carrier-Biosynthesis', 'Vitamin-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'DIHYDRONEOPTERIN-MONO-P-DEPHOS-RXN': {0: ['DIHYDRONEOPTERIN-MONO-P-DEPHOS-RXN'],
#   1: ['PWY-6147'],
#   2: ['6-HM-Dihydropterin-PP-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'DIHYDROOROT-RXN (reverse)': {0: ['DIHYDROOROT-RXN'],
#   1: ['PWY-5686'],
#   2: ['UMP-Biosynthesis'],
#   3: ['Pyrimid-Ribonucleot-De-Novo-Biosyn'],
#   4: ['Pyrimidine-De-Novo-Biosyn'],
#   5: ['PYR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'DIHYDROOROTATE-DEHYDROGENASE-RXN-DI-H-OROTATE/UBIQUINONE-8//OROTATE/CPD-9956.44.': {0: ['DIHYDROOROTATE-DEHYDROGENASE-RXN'],
#   1: ['PWY-5686'],
#   2: ['UMP-Biosynthesis'],
#   3: ['Pyrimid-Ribonucleot-De-Novo-Biosyn'],
#   4: ['Pyrimidine-De-Novo-Biosyn'],
#   5: ['PYR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'DIHYDROXYISOVALDEHYDRAT-RXN': {0: ['DIHYDROXYISOVALDEHYDRAT-RXN'],
#   1: ['VALSYN-PWY'],
#   2: ['VALINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DIHYDROXYMETVALDEHYDRAT-RXN': {0: ['DIHYDROXYMETVALDEHYDRAT-RXN'],
#   1: ['ILEUSYN-PWY'],
#   2: ['ISOLEUCINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DIMETHUROPORDEHYDROG-RXN': {0: ['DIMETHUROPORDEHYDROG-RXN'],
#   1: ['PWY-5194'],
#   2: ['Porphyrin-Compounds-Biosynthesis'],
#   3: ['Tetrapyrrole-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'DIOHBUTANONEPSYN-RXN': {0: ['DIOHBUTANONEPSYN-RXN'],
#   1: ['RIBOSYN2-PWY'],
#   2: ['Flavin-Biosynthesis'],
#   3: ['Electron-Carrier-Biosynthesis', 'Enzyme-Cofactor-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'DMK-RXN': {0: ['DMK-RXN'],
#   1: ['PWY-5852'],
#   2: ['Demethylmenaquinol-8-Biosynthesis'],
#   3: ['Demethylmenaquinone-Biosynthesis'],
#   4: ['Quinone-Biosynthesis'],
#   5: ['Electron-Carrier-Biosynthesis'],
#   6: ['Carriers-Biosynthesis'],
#   7: ['Cofactor-Biosynthesis'],
#   8: ['Biosynthesis']},
#  'DTDPKIN-RXN': {0: ['DTDPKIN-RXN'],
#   1: ['PWY-7187', 'PWY-7197', 'PWY-7184', 'PWY0-166'],
#   2: ['Pyrimid-Deoxyribonucleot-De-Novo-Biosyn',
#    'Metabolic-Clusters',
#    'Pyrimidine-Nucleotide-Salvage',
#    'Super-Pathways'],
#   3: ['Deoxyribonucleotide-Biosynthesis', 'Pyrimidine-De-Novo-Biosyn'],
#   4: ['PYR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'DTMPKI-RXN': {0: ['DTMPKI-RXN'],
#   1: ['PWY-7187', 'PWY-7197', 'PWY-7184', 'PWY0-166'],
#   2: ['Pyrimid-Deoxyribonucleot-De-Novo-Biosyn',
#    'Metabolic-Clusters',
#    'Pyrimidine-Nucleotide-Salvage',
#    'Super-Pathways'],
#   3: ['Deoxyribonucleotide-Biosynthesis', 'Pyrimidine-De-Novo-Biosyn'],
#   4: ['PYR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'DURIDKI-RXN': {0: ['DURIDKI-RXN'],
#   1: ['PWY0-181'],
#   2: ['Pyrimidine-Nucleotide-Salvage'],
#   3: ['PYR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DXPREDISOM-RXN (reverse)': {0: ['DXPREDISOM-RXN'],
#   1: ['NONMEVIPP-PWY'],
#   2: ['MEP-Pathways'],
#   3: ['Isopentenyl-Diphosphate-Biosynthesis'],
#   4: ['ISOPRENOIDS'],
#   5: ['Terpenoid-Biosynthesis'],
#   6: ['SECONDARY-METABOLITE-BIOSYNTHESIS'],
#   7: ['Biosynthesis']},
#  'DXS-RXN': {0: ['DXS-RXN'],
#   1: ['PWY-6892', 'PYRIDOXSYN-PWY', 'NONMEVIPP-PWY'],
#   2: ['Thiazole-Biosynthesis', 'Vitamin-B6-Biosynthesis', 'MEP-Pathways'],
#   3: ['Thiamine-Biosynthesis', 'Isopentenyl-Diphosphate-Biosynthesis'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis', 'ISOPRENOIDS'],
#   5: ['Cofactor-Biosynthesis', 'Terpenoid-Biosynthesis'],
#   7: ['Biosynthesis'],
#   6: ['SECONDARY-METABOLITE-BIOSYNTHESIS']},
#  'ENTMULTI-RXN': {0: ['ENTMULTI-RXN']},
#  'ERYTH4PDEHYDROG-RXN': {0: ['ERYTH4PDEHYDROG-RXN'],
#   1: ['PYRIDOXSYN-PWY'],
#   2: ['Vitamin-B6-Biosynthesis'],
#   3: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ERYTHRON4PDEHYDROG-RXN': {0: ['ERYTHRON4PDEHYDROG-RXN'],
#   1: ['PYRIDOXSYN-PWY'],
#   2: ['Vitamin-B6-Biosynthesis'],
#   3: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'FADSYN-RXN': {0: ['FADSYN-RXN'],
#   1: ['RIBOSYN2-PWY'],
#   2: ['Flavin-Biosynthesis'],
#   3: ['Electron-Carrier-Biosynthesis', 'Enzyme-Cofactor-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'FGAMSYN-RXN': {0: ['FGAMSYN-RXN'],
#   1: ['PWY-6122', 'PWY-6121', 'PWY-6277'],
#   2: ['AIR-Biosynthesis', 'Super-Pathways'],
#   3: ['PUR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'FPPSYN-RXN': {0: ['FPPSYN-RXN'],
#   1: ['PWY-5123'],
#   2: ['All-Trans-Farnesyl-PP-Biosynthesis'],
#   3: ['All-Trans-Polyprenyl-Biosynthesis'],
#   4: ['Polyprenyl-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'FRUCTOKINASE-RXN': {0: ['FRUCTOKINASE-RXN']},
#  'GAPOXNPHOSPHN-RXN': {0: ['GAPOXNPHOSPHN-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GART-RXN-10-FORMYL-THF/5-PHOSPHO-RIBOSYL-GLYCINEAMIDE//THF/5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE/PROTON.90.': {0: ['GART-RXN'],
#   1: ['PWY-6121'],
#   2: ['AIR-Biosynthesis'],
#   3: ['PUR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GDPKIN-RXN': {0: ['GDPKIN-RXN'],
#   1: ['PWY-7221', 'PPGPPMET-PWY'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis', 'Metabolic-Regulators'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   6: ['Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis']},
#  'GDPPYPHOSKIN-RXN': {0: ['GDPPYPHOSKIN-RXN'],
#   1: ['PPGPPMET-PWY'],
#   2: ['Metabolic-Regulators'],
#   3: ['Biosynthesis']},
#  'GLU6PDEHYDROG-RXN-GLC-6-P/NADP//D-6-P-GLUCONO-DELTA-LACTONE/NADPH/PROTON.55.': {0: ['GLU6PDEHYDROG-RXN'],
#   1: ['OXIDATIVEPENT-PWY', 'GLYCOLYSIS-E-D'],
#   2: ['Pentose-Phosphate-Cycle', 'Super-Pathways'],
#   3: ['Energy-Metabolism']},
#  'GLUC1PADENYLTRANS-RXN': {0: ['GLUC1PADENYLTRANS-RXN'],
#   1: ['GLYCOGENSYNTH-PWY'],
#   2: ['GLYCOGEN-BIOSYN'],
#   3: ['Polysaccharides-Biosynthesis'],
#   4: ['Carbohydrates-Biosynthesis', 'Glycan-Pathways'],
#   5: ['Biosynthesis']},
#  'GLUC1PURIDYLTRANS-RXN': {0: ['GLUC1PURIDYLTRANS-RXN'],
#   1: ['PWY-7343', 'GALACTMETAB-PWY'],
#   2: ['UDP-Sugar-Biosynthesis', 'GALACTOSE-DEGRADATION'],
#   3: ['SUGAR-NUCLEOTIDES', 'Sugars-And-Polysaccharides-Degradation'],
#   4: ['CARBO-BIOSYNTHESIS', 'Carbohydrates-Degradation'],
#   5: ['Carbohydrates-Biosynthesis', 'Degradation'],
#   6: ['Biosynthesis']},
#  'GLUCOSAMINE-6-P-DEAMIN-RXN (reverse)': {0: ['GLUCOSAMINE-6-P-DEAMIN-RXN'],
#   1: ['GLUAMCAT-PWY'],
#   2: ['N-Acetylglucosamine-Degradation'],
#   3: ['AMINE-DEG', 'Sugar-Derivatives'],
#   6: ['Degradation'],
#   4: ['Sugars-And-Polysaccharides-Degradation'],
#   5: ['Carbohydrates-Degradation']},
#  'GLUTAMINESYN-RXN': {0: ['GLUTAMINESYN-RXN'],
#   1: ['AMMASSIM-PWY', 'PWY-8294', 'PWY-8291', 'GLNSYN-PWY'],
#   2: ['Ammonia-Assimilation', 'ASPARTATE-DEG', 'GLUTAMINE-SYN'],
#   3: ['NITROGEN-DEG',
#    'Proteinogenic-Amino-Acids-Degradation',
#    'IND-AMINO-ACID-SYN'],
#   4: ['Noncarbon-Nutrients',
#    'Amino-Acid-Degradation',
#    'Amino-Acid-Biosynthesis'],
#   5: ['Degradation', 'Biosynthesis']},
#  'GLUTATHIONE-SYN-RXN': {0: ['GLUTATHIONE-SYN-RXN'],
#   1: ['GLUTATHIONESYN-PWY'],
#   2: ['Reductants'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'GLUTCYSLIG-RXN': {0: ['GLUTCYSLIG-RXN'],
#   1: ['GLUTATHIONESYN-PWY'],
#   2: ['Reductants'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'GLUTDEHYD-RXN (reverse)': {0: ['GLUTDEHYD-RXN'],
#   1: ['GLUTSYNIII-PWY'],
#   2: ['GLUTAMATE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLUTKIN-RXN': {0: ['GLUTKIN-RXN'],
#   1: ['PROSYN-PWY'],
#   2: ['PROLINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLUTRACE-RXN': {0: ['GLUTRACE-RXN'],
#   1: ['PWY-6387'],
#   2: ['Acetylmuramoyl-Pentapeptide-Biosynthesis'],
#   3: ['Cell-Wall-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLUTRNAREDUCT-RXN (reverse)': {0: ['GLUTRNAREDUCT-RXN'],
#   1: ['PWY-5188'],
#   2: ['Tetrapyrrole-Biosynthesis'],
#   3: ['Biosynthesis']},
#  'GLUTSEMIALDEHYDROG-RXN (reverse)': {0: ['GLUTSEMIALDEHYDROG-RXN'],
#   1: ['PROSYN-PWY'],
#   2: ['PROLINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLYC3PDEHYDROGBIOSYN-RXN-GLYCEROL-3P/NAD//DIHYDROXY-ACETONE-PHOSPHATE/NADH/PROTON.57. (reverse)': {0: ['GLYC3PDEHYDROGBIOSYN-RXN'],
#   1: ['PWY-5667', 'PWY0-1319'],
#   2: ['CDP-diacylglycerol-Biosynthesis'],
#   3: ['Phospholipid-Biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLYCDEH-RXN': {0: ['GLYCDEH-RXN'],
#   1: ['GLYCEROLMETAB-PWY'],
#   2: ['GLYCEROL-DEG'],
#   3: ['SUGAR-ALCOHOLS-DEG'],
#   4: ['Alcohol-Degradation', 'Carbohydrates-Degradation'],
#   5: ['Degradation']},
#  'GLYCOLALD-DEHYDROG-RXN': {0: ['GLYCOLALD-DEHYDROG-RXN'],
#   1: ['DARABCATK12-PWY', 'PWY0-1280'],
#   2: ['D-Arabinose-Degradation', 'Alcohol-Degradation'],
#   3: ['Sugars-And-Polysaccharides-Degradation'],
#   5: ['Degradation'],
#   4: ['Carbohydrates-Degradation']},
#  'GLYCOLATEDEHYDRO-RXN': {0: ['GLYCOLATEDEHYDRO-RXN']},
#  'GLYOHMETRANS-RXN-SER/CPD-1301//GLY/CPD-12996/WATER.34.': {0: ['GLYOHMETRANS-RXN'],
#   1: ['1CMET2-PWY', 'PWY-2161', 'GLYSYN-PWY'],
#   2: ['Folate-Transformations', 'GLYCINE-SYN'],
#   3: ['Folate-Biosynthesis', 'IND-AMINO-ACID-SYN'],
#   4: ['C1-Carrier-Biosynthesis',
#    'Vitamin-Biosynthesis',
#    'Amino-Acid-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'GLYOHMETRANS-RXN-SER/THF//GLY/METHYLENE-THF/WATER.33.': {0: ['GLYOHMETRANS-RXN'],
#   1: ['1CMET2-PWY', 'PWY-2161', 'GLYSYN-PWY'],
#   2: ['Folate-Transformations', 'GLYCINE-SYN'],
#   3: ['Folate-Biosynthesis', 'IND-AMINO-ACID-SYN'],
#   4: ['C1-Carrier-Biosynthesis',
#    'Vitamin-Biosynthesis',
#    'Amino-Acid-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'GLYRIBONUCSYN-RXN': {0: ['GLYRIBONUCSYN-RXN'],
#   1: ['PWY-6122', 'PWY-6121', 'PWY-6277'],
#   2: ['AIR-Biosynthesis', 'Super-Pathways'],
#   3: ['PUR-NUC-SYN'],
#   4: ['Nucleotide-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GMKALT-RXN (reverse)': {0: ['GMKALT-RXN']},
#  'GMP-SYN-NH3-RXN': {0: ['GMP-SYN-NH3-RXN'],
#   1: ['GMP-SYN-GLUT-RXN'],
#   2: ['PWY-7221'],
#   3: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   4: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'GPPSYN-RXN': {0: ['GPPSYN-RXN'],
#   1: ['PWY-5123'],
#   2: ['All-Trans-Farnesyl-PP-Biosynthesis'],
#   3: ['All-Trans-Polyprenyl-Biosynthesis'],
#   4: ['Polyprenyl-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GSAAMINOTRANS-RXN': {0: ['GSAAMINOTRANS-RXN'],
#   1: ['PWY-5188'],
#   2: ['Tetrapyrrole-Biosynthesis'],
#   3: ['Biosynthesis']},
#  'GTP-CYCLOHYDRO-I-RXN': {0: ['GTP-CYCLOHYDRO-I-RXN'],
#   1: ['PWY0-1433', 'PWY-6703', 'PWY-6147'],
#   2: ['Signaling-Compound-Biosynthesis',
#    'SECONDARY-METABOLITE-BIOSYNTHESIS',
#    '6-HM-Dihydropterin-PP-Biosynthesis'],
#   3: ['HORMONE-SYN', 'Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'GTP-CYCLOHYDRO-II-RXN': {0: ['GTP-CYCLOHYDRO-II-RXN'],
#   1: ['RIBOSYN2-PWY'],
#   2: ['Flavin-Biosynthesis'],
#   3: ['Electron-Carrier-Biosynthesis', 'Enzyme-Cofactor-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'GUANYL-KIN-RXN': {0: ['GUANYL-KIN-RXN'],
#   1: ['PWY-7221'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'H2NEOPTERINALDOL-RXN': {0: ['H2NEOPTERINALDOL-RXN'],
#   1: ['PWY-6147'],
#   2: ['6-HM-Dihydropterin-PP-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'H2NEOPTERINP3PYROPHOSPHOHYDRO-RXN': {0: ['H2NEOPTERINP3PYROPHOSPHOHYDRO-RXN'],
#   1: ['PWY-6147'],
#   2: ['6-HM-Dihydropterin-PP-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'H2PTERIDINEPYROPHOSPHOKIN-RXN': {0: ['H2PTERIDINEPYROPHOSPHOKIN-RXN'],
#   1: ['PWY-6147'],
#   2: ['6-HM-Dihydropterin-PP-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'H2PTEROATESYNTH-RXN': {0: ['H2PTEROATESYNTH-RXN'],
#   1: ['PWY-6614'],
#   2: ['Folate-Biosynthesis'],
#   3: ['C1-Carrier-Biosynthesis', 'Vitamin-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'HISTAMINOTRANS-RXN (reverse)': {0: ['HISTAMINOTRANS-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'HISTCYCLOHYD-RXN': {0: ['HISTCYCLOHYD-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'HISTIDPHOS-RXN[CCO-CYTOSOL]-L-HISTIDINOL-P/WATER//HISTIDINOL/Pi.49.': {0: ['HISTIDPHOS-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'HISTPRATPHYD-RXN': {0: ['HISTPRATPHYD-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'HOMOCYSMET-RXN': {0: ['HOMOCYSMET-RXN'],
#   1: ['PWY-6151', 'HOMOSER-METSYN-PWY'],
#   2: ['S-adenosyl-L-methionine-Biosynthesis',
#    'Methionine-De-novo-Biosynthesis'],
#   3: ['C1-Carrier-Biosynthesis',
#    'Enzyme-Cofactor-Biosynthesis',
#    'METHIONINE-SYN'],
#   4: ['Carriers-Biosynthesis', 'IND-AMINO-ACID-SYN'],
#   5: ['Cofactor-Biosynthesis', 'Amino-Acid-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'HOMOCYSMETB12-RXN-HOMO-CYS/5-METHYL-THF//MET/THF.31.': {0: ['HOMOCYSMETB12-RXN'],
#   1: ['1CMET2-PWY', 'HOMOSER-METSYN-PWY'],
#   2: ['Folate-Transformations', 'Methionine-De-novo-Biosynthesis'],
#   3: ['Folate-Biosynthesis', 'METHIONINE-SYN'],
#   4: ['C1-Carrier-Biosynthesis', 'Vitamin-Biosynthesis', 'IND-AMINO-ACID-SYN'],
#   5: ['Carriers-Biosynthesis', 'Amino-Acid-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'HOMOSERDEHYDROG-RXN-HOMO-SER/NAD//L-ASPARTATE-SEMIALDEHYDE/NADH/PROTON.51. (reverse)': {0: ['HOMOSERDEHYDROG-RXN'],
#   1: ['HOMOSERSYN-PWY'],
#   2: ['Other-Amino-Acid-Biosynthesis'],
#   3: ['Amino-Acid-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'HOMSUCTRAN-RXN': {0: ['HOMSUCTRAN-RXN'],
#   1: ['HOMOSER-METSYN-PWY'],
#   2: ['Methionine-De-novo-Biosynthesis'],
#   3: ['METHIONINE-SYN'],
#   4: ['IND-AMINO-ACID-SYN'],
#   5: ['Amino-Acid-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'IGPSYN-RXN': {0: ['IGPSYN-RXN'],
#   1: ['TRPSYN-PWY'],
#   2: ['TRYPTOPHAN-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'IMIDPHOSDEHYD-RXN': {0: ['IMIDPHOSDEHYD-RXN'],
#   1: ['HISTSYN-PWY'],
#   2: ['HISTIDINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'IMP-DEHYDROG-RXN': {0: ['IMP-DEHYDROG-RXN'],
#   1: ['PWY-7221'],
#   2: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   3: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'IMPCYCLOHYDROLASE-RXN (reverse)': {0: ['IMPCYCLOHYDROLASE-RXN'],
#   1: ['PWY-6123'],
#   2: ['IMP-Biosynthesis'],
#   3: ['Purine-Ribonuc-De-Novo-Biosynthesis'],
#   4: ['Purine-Nucleotide-De-Novo-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'INOPHOSPHOR-RXN (reverse)': {0: ['INOPHOSPHOR-RXN'],
#   1: ['PWY0-1296', 'PWY-6609', 'SALVADEHYPOX-PWY'],
#   3: ['Purine-Degradation', 'Purine-Nucleotides-Salvage'],
#   2: ['Adenine-Adenosine-Salvage', 'Adenosine-Nucleotides-Degradation'],
#   4: ['NUCLEO-DEG', 'PUR-NUC-SYN'],
#   5: ['Degradation', 'Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'INORGPYROPHOSPHAT-RXN[CCO-CYTOSOL]-PPI/WATER//Pi/PROTON.34.': {0: ['INORGPYROPHOSPHAT-RXN'],
#   1: ['PWY-7805'],
#   2: ['Phosphonate-Degradation'],
#   3: ['Phophonate-Metabolism'],
#   4: ['Phosphorus-Compounds'],
#   5: ['Noncarbon-Nutrients'],
#   6: ['Degradation']},
#  'INOSINEKIN-RXN': {0: ['INOSINEKIN-RXN'],
#   1: ['PWY-6611'],
#   2: ['Adenine-Adenosine-Salvage'],
#   3: ['Purine-Nucleotides-Salvage'],
#   4: ['PUR-NUC-SYN'],
#   5: ['Nucleotide-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'ISOCHORMAT-RXN': {0: ['ISOCHORMAT-RXN'],
#   1: ['PWY-5901'],
#   2: ['AROMATIC-COMPOUNDS-BIOSYN'],
#   3: ['Biosynthesis']},
#  'ISOCIT-CLEAV-RXN': {0: ['ISOCIT-CLEAV-RXN'],
#   1: ['GLYOXYLATE-BYPASS'],
#   2: ['Energy-Metabolism']},
#  'ISOCITDEH-RXN': {0: ['ISOCITDEH-RXN'],
#   1: ['FERMENTATION-PWY', 'TCA'],
#   2: ['Fermentation-to-Acids',
#    'Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways',
#    'TCA-VARIANTS'],
#   4: ['Fermentation'],
#   3: ['Alcohol-Biosynthesis', 'Pyruvate-Degradation'],
#   5: ['Energy-Metabolism']},
#  'ISPH2-RXN (reverse)': {0: ['ISPH2-RXN'],
#   1: ['NONMEVIPP-PWY'],
#   2: ['MEP-Pathways'],
#   3: ['Isopentenyl-Diphosphate-Biosynthesis'],
#   4: ['ISOPRENOIDS'],
#   5: ['Terpenoid-Biosynthesis'],
#   6: ['SECONDARY-METABOLITE-BIOSYNTHESIS'],
#   7: ['Biosynthesis']},
#  'KDO-8PPHOSPHAT-RXN': {0: ['KDO-8PPHOSPHAT-RXN'],
#   1: ['PWY-1269'],
#   2: ['CMP-KDO-Biosynthesis'],
#   3: ['CMP-Sugar-Biosynthesis'],
#   4: ['SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'KDO-8PSYNTH-RXN': {0: ['KDO-8PSYNTH-RXN'],
#   1: ['PWY-1269'],
#   2: ['CMP-KDO-Biosynthesis'],
#   3: ['CMP-Sugar-Biosynthesis'],
#   4: ['SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'KDOTRANS-RXN': {0: ['KDOTRANS-RXN'],
#   1: ['KDOSYN-PWY'],
#   2: ['KDO-Lipid-IV-Transfer'],
#   3: ['Lipopolysaccharide-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways'],
#   5: ['Biosynthesis']},
#  'KDOTRANS2-RXN': {0: ['KDOTRANS2-RXN'],
#   1: ['KDOSYN-PWY'],
#   2: ['KDO-Lipid-IV-Transfer'],
#   3: ['Lipopolysaccharide-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways'],
#   5: ['Biosynthesis']},
#  'LIPIDADISACCHARIDESYNTH-RXN': {0: ['LIPIDADISACCHARIDESYNTH-RXN'],
#   1: ['NAGLIPASYN-PWY'],
#   2: ['Lipid-IV-A-Biosynthesis'],
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  'LIPIDXSYNTHESIS-RXN': {0: ['LIPIDXSYNTHESIS-RXN'],
#   1: ['NAGLIPASYN-PWY'],
#   2: ['Lipid-IV-A-Biosynthesis'],
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  'LUMAZINESYN-RXN': {0: ['LUMAZINESYN-RXN'],
#   1: ['RIBOSYN2-PWY'],
#   2: ['Flavin-Biosynthesis'],
#   3: ['Electron-Carrier-Biosynthesis', 'Enzyme-Cofactor-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'MALSYN-RXN': {0: ['MALSYN-RXN'],
#   1: ['GLYOXDEG-PWY', 'GLYOXYLATE-BYPASS'],
#   2: ['Glycolate-Degradation', 'Energy-Metabolism'],
#   3: ['CARBOXYLATES-DEG'],
#   4: ['Degradation']},
#  'METHENYLTHFCYCLOHYDRO-RXN-5-10-METHENYL-THF/WATER//10-FORMYL-THF/PROTON.46.': {0: ['METHENYLTHFCYCLOHYDRO-RXN'],
#   1: ['1CMET2-PWY'],
#   2: ['Folate-Transformations'],
#   3: ['Folate-Biosynthesis'],
#   4: ['C1-Carrier-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'METHYLENETHFDEHYDROG-NADP-RXN-METHYLENE-THF/NADP//5-10-METHENYL-THF/NADPH.44.': {0: ['METHYLENETHFDEHYDROG-NADP-RXN'],
#   1: ['1CMET2-PWY'],
#   2: ['Folate-Transformations'],
#   3: ['Folate-Biosynthesis'],
#   4: ['C1-Carrier-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'METHYLMALONYL-COA-MUT-RXN (reverse)': {0: ['METHYLMALONYL-COA-MUT-RXN'],
#   1: ['PROPIONMET-PWY', 'PWY0-43'],
#   2: ['Propionate-Degradation', 'SUCC-DEG'],
#   3: ['CARBOXYLATES-DEG'],
#   4: ['Degradation']},
#  'METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN': {0: ['METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN'],
#   1: ['PWY0-1391'],
#   2: ['Methylthioadenosine-Degradation'],
#   3: ['NUCLEO-DEG'],
#   4: ['Degradation']},
#  'N-ACETYLGLUTPREDUCT-RXN (reverse)': {0: ['N-ACETYLGLUTPREDUCT-RXN'],
#   1: ['GLUTORN-PWY'],
#   2: ['L-Ornithine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'N-ACETYLTRANSFER-RXN': {0: ['N-ACETYLTRANSFER-RXN'],
#   1: ['GLUTORN-PWY'],
#   2: ['L-Ornithine-Biosynthesis'],
#   3: ['Other-Amino-Acid-Biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'NACGLCTRANS-RXN': {0: ['NACGLCTRANS-RXN'],
#   1: ['PEPTIDOGLYCANSYN-PWY'],
#   2: ['Peptidoglycan-Biosynthesis', 'Super-Pathways'],
#   3: ['Cell-Wall-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'NAD-KIN-RXN': {0: ['NAD-KIN-RXN'],
#   1: ['NADPHOS-DEPHOS-PWY'],
#   2: ['NAD-Metabolism'],
#   3: ['Electron-Carrier-Biosynthesis', 'Enzyme-Cofactor-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'NAD-SYNTH-NH3-RXN': {0: ['NAD-SYNTH-NH3-RXN'],
#   1: ['PWY-7761', 'PYRIDNUCSAL-PWY', 'PYRIDNUCSYN-PWY'],
#   2: ['NAD-SYN'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Electron-Carrier-Biosynthesis'],
#   3: ['NAD-Metabolism'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis'],
#   5: ['Carriers-Biosynthesis']},
#  'NADH-DEHYDROG-A-RXN-NADH/UBIQUINONE-8/PROTON//NAD/CPD-9956/PROTON.46.': {0: ['NADH-DEHYDROG-A-RXN'],
#   1: ['PWY0-1334', 'PWY0-1335'],
#   2: ['AEROBIC-RESPIRATION', 'Electron-Transfer'],
#   3: ['Respiration'],
#   4: ['Energy-Metabolism']},
#  'NAG1P-URIDYLTRANS-RXN': {0: ['NAG1P-URIDYLTRANS-RXN'],
#   1: ['PWY0-1261', 'UDPNAGSYN-PWY'],
#   2: ['Anhydromuropeptides-Recycling', 'UDP-NAc-Glucosamine-Biosynthesis'],
#   3: ['Other-Degradation', 'UDP-Sugar-Biosynthesis'],
#   4: ['Degradation', 'SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'NAPHTHOATE-SYN-RXN': {0: ['NAPHTHOATE-SYN-RXN'],
#   1: ['PWY-5837'],
#   2: ['DHNA-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'NICONUCADENYLYLTRAN-RXN': {0: ['NICONUCADENYLYLTRAN-RXN'],
#   1: ['PWY-7761', 'PYRIDNUCSAL-PWY', 'PYRIDNUCSYN-PWY'],
#   2: ['NAD-SYN'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Electron-Carrier-Biosynthesis'],
#   3: ['NAD-Metabolism'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis'],
#   5: ['Carriers-Biosynthesis']},
#  'NUCLEOSIDE-DIPHOSPHATASE-RXN-DUDP/WATER//DUMP/Pi/PROTON.27.': {0: ['NUCLEOSIDE-DIPHOSPHATASE-RXN']},
#  'O-SUCCHOMOSERLYASE-RXN': {0: ['O-SUCCHOMOSERLYASE-RXN'],
#   1: ['HOMOSER-METSYN-PWY'],
#   2: ['Methionine-De-novo-Biosynthesis'],
#   3: ['METHIONINE-SYN'],
#   4: ['IND-AMINO-ACID-SYN'],
#   5: ['Amino-Acid-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'O-SUCCINYLBENZOATE-COA-LIG-RXN': {0: ['O-SUCCINYLBENZOATE-COA-LIG-RXN'],
#   1: ['PWY-5837'],
#   2: ['DHNA-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'O-SUCCINYLBENZOATE-COA-SYN-RXN': {0: ['O-SUCCINYLBENZOATE-COA-SYN-RXN'],
#   1: ['PWY-5837'],
#   2: ['DHNA-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-RXN': {0: ['OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-RXN'],
#   1: ['PWY-6708'],
#   2: ['Ubiquinone-Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'OHMETHYLBILANESYN-RXN': {0: ['OHMETHYLBILANESYN-RXN'],
#   1: ['PWY-5188'],
#   2: ['Tetrapyrrole-Biosynthesis'],
#   3: ['Biosynthesis']},
#  'ORNCARBAMTRANSFER-RXN': {0: ['ORNCARBAMTRANSFER-RXN'],
#   1: ['ARGSYN-PWY'],
#   2: ['ARGININE-SYN', 'Super-Pathways'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ORNDECARBOX-RXN': {0: ['ORNDECARBOX-RXN'],
#   1: ['ORNDEG-PWY', 'PWY-46'],
#   2: ['AMINE-DEG', 'Super-Pathways', 'Putrescine-Biosynthesis'],
#   3: ['Degradation', 'Polyamine-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'OROPRIBTRANS-RXN (reverse)': {0: ['OROPRIBTRANS-RXN'],
#   1: ['PWY-5686'],
#   2: ['UMP-Biosynthesis'],
#   3: ['Pyrimid-Ribonucleot-De-Novo-Biosyn'],
#   4: ['Pyrimidine-De-Novo-Biosyn'],
#   5: ['PYR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'OROTPDECARB-RXN': {0: ['OROTPDECARB-RXN'],
#   1: ['PWY-5686'],
#   2: ['UMP-Biosynthesis'],
#   3: ['Pyrimid-Ribonucleot-De-Novo-Biosyn'],
#   4: ['Pyrimidine-De-Novo-Biosyn'],
#   5: ['PYR-NUC-SYN'],
#   6: ['Nucleotide-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'P-PANTOCYSDECARB-RXN': {0: ['P-PANTOCYSDECARB-RXN'],
#   1: ['COA-PWY'],
#   2: ['CoA-Biosynthesis'],
#   3: ['Carriers-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'P-PANTOCYSLIG-RXN': {0: ['P-PANTOCYSLIG-RXN'],
#   1: ['COA-PWY'],
#   2: ['CoA-Biosynthesis'],
#   3: ['Carriers-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PABASYN-RXN': {0: ['PABASYN-RXN'],
#   1: ['PWY-6543'],
#   2: ['4-Aminobenzoate-Biosynthesis'],
#   3: ['AROMATIC-COMPOUNDS-BIOSYN'],
#   4: ['Biosynthesis']},
#  'PANTEPADENYLYLTRAN-RXN': {0: ['PANTEPADENYLYLTRAN-RXN'],
#   1: ['COA-PWY'],
#   2: ['CoA-Biosynthesis'],
#   3: ['Carriers-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PANTOATE-BETA-ALANINE-LIG-RXN': {0: ['PANTOATE-BETA-ALANINE-LIG-RXN'],
#   1: ['PANTO-PWY'],
#   2: ['Pantothenate-Biosynthesis'],
#   3: ['CoA-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'PANTOTHENATE-KIN-RXN': {0: ['PANTOTHENATE-KIN-RXN'],
#   1: ['PANTO-PWY'],
#   2: ['Pantothenate-Biosynthesis'],
#   3: ['CoA-Biosynthesis'],
#   4: ['Carriers-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'PDXJ-RXN': {0: ['PDXJ-RXN'],
#   1: ['PYRIDOXSYN-PWY'],
#   2: ['Vitamin-B6-Biosynthesis'],
#   3: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   4: ['Cofactor-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PEPCARBOX-RXN (reverse)': {0: ['PEPCARBOX-RXN'],
#   1: ['FERMENTATION-PWY'],
#   2: ['Fermentation-to-Acids',
#    'Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways'],
#   4: ['Fermentation'],
#   3: ['Alcohol-Biosynthesis', 'Pyruvate-Degradation'],
#   5: ['Energy-Metabolism']},
#  'PEPDEPHOS-RXN (reverse)': {0: ['PEPDEPHOS-RXN'],
#   1: ['FERMENTATION-PWY', 'GLYCOLYSIS', 'PWY-5484'],
#   2: ['Fermentation-to-Acids',
#    'Pyruvate-Ethanol-Fermentation',
#    'Super-Pathways',
#    'GLYCOLYSIS-VARIANTS'],
#   4: ['Fermentation'],
#   3: ['Alcohol-Biosynthesis', 'Pyruvate-Degradation'],
#   5: ['Energy-Metabolism']},
#  'PGLUCISOM-RXN-GLC-6-P//FRUCTOSE-6P.21. (reverse)': {0: ['PGLUCISOM-RXN'],
#   1: ['GLYCOLYSIS', 'UDPNAGSYN-PWY', 'GLUCONEO-PWY', 'PWY-5659'],
#   2: ['GLYCOLYSIS-VARIANTS',
#    'UDP-NAc-Glucosamine-Biosynthesis',
#    'Gluconeogenesis',
#    'GDP-Sugar-Biosynthesis'],
#   3: ['Energy-Metabolism', 'UDP-Sugar-Biosynthesis'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   4: ['SUGAR-NUCLEOTIDES'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'PGLYCDEHYDROG-RXN': {0: ['PGLYCDEHYDROG-RXN'],
#   1: ['SERSYN-PWY-1'],
#   2: ['SERINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PGPPHOSPHA-RXN-CPD-12821/WATER//CPD-8260/Pi.29.': {0: ['PGPPHOSPHA-RXN'],
#   1: ['PWY-5668', 'PWY0-1545'],
#   2: ['Cardiolipin-Biosynthesis'],
#   3: ['Phospholipid-Biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PHOSGLYPHOS-RXN (reverse)': {0: ['PHOSGLYPHOS-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
# ...
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  'MALONYL-COA-ACP-TRANSACYL-RXN': {0: ['MALONYL-COA-ACP-TRANSACYL-RXN'],
#   1: ['PWY-4381'],
#   2: ['Fatty-Acid-Biosyn-Initiation'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'MYRISTOYLACYLTRAN-RXN': {0: ['MYRISTOYLACYLTRAN-RXN'],
#   1: ['KDO-LIPASYN-PWY', 'KDO-NAGLIPASYN-PWY'],
#   2: ['Kdo-lipid-A-Biosynthesis', 'Super-Pathways'],
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  'PRODISULFREDUCT-A-RXN-GLUTATHIONE/Oxidized-NrdH-Proteins//OXIDIZED-GLUTATHIONE/Reduced-NrdH-Proteins.79.': {0: ['PRODISULFREDUCT-A-RXN'],
#   1: ['PWY-7870', 'GLUT-REDOX-PWY'],
#   2: ['CYSTEINE-SYN', 'Reductants'],
#   3: ['IND-AMINO-ACID-SYN', 'Other-biosynthesis'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'PYFLAVOXRE-RXN': {0: ['PYFLAVOXRE-RXN']},
#  'PYRUFLAVREDUCT-RXN': {0: ['PYRUFLAVREDUCT-RXN']},
#  'RXN-11474': {0: ['RXN-11474'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11476 (reverse)': {0: ['RXN-11476'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11477': {0: ['RXN-11477'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11478 (reverse)': {0: ['RXN-11478'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11479': {0: ['RXN-11479'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11480 (reverse)': {0: ['RXN-11480'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11481': {0: ['RXN-11481'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11482 (reverse)': {0: ['RXN-11482'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-11483': {0: ['RXN-11483'],
#   1: ['PWY-6519'],
#   2: ['7-Keto-8-aminopelargonate-Biosynthesis'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'RXN-17018': {0: ['RXN-17018']},
#  'RXN-9516': {0: ['RXN-9516'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9518 (reverse)': {0: ['RXN-9518'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9520': {0: ['RXN-9520'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9523': {0: ['RXN-9523'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9531': {0: ['RXN-9531'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9532 (reverse)': {0: ['RXN-9532'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9533': {0: ['RXN-9533'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9535': {0: ['RXN-9535'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9536 (reverse)': {0: ['RXN-9536'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9537': {0: ['RXN-9537'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9539': {0: ['RXN-9539'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9655': {0: ['RXN-9655'],
#   1: ['PWY-5971', 'PWY0-862'],
#   2: ['Palmitate-Biosynthesis', '5Z-Dodec-5-enoate-Biosynthesis'],
#   4: ['Fatty-acid-biosynthesis'],
#   3: ['Unsaturated-Fatty-Acids-Biosynthesis'],
#   5: ['Lipid-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'RXN-9658 (reverse)': {0: ['RXN-9658'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9660 (reverse)': {0: ['RXN-9660'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9661 (reverse)': {0: ['RXN-9661'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9662 (reverse)': {0: ['RXN-9662'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9663 (reverse)': {0: ['RXN-9663'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN-9787': {0: ['RXN-9787'],
#   1: ['PWY-6892'],
#   2: ['Thiazole-Biosynthesis'],
#   3: ['Thiamine-Biosynthesis'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'RXN-9788': {0: ['RXN-9788'],
#   1: ['PWY-6892'],
#   2: ['Thiazole-Biosynthesis'],
#   3: ['Thiamine-Biosynthesis'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'RXN-9789': {0: ['RXN-9789'],
#   1: ['PWY-6892'],
#   2: ['Thiazole-Biosynthesis'],
#   3: ['Thiamine-Biosynthesis'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'RXN0-5055': {0: ['RXN0-5055'],
#   1: ['PWY-4381', 'PWY0-1264'],
#   2: ['Fatty-Acid-Biosyn-Initiation'],
#   4: ['Lipid-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN0-6705': {0: ['RXN0-6705']},
#  'RXN0-6717': {0: ['RXN0-6717'], 1: ['RXN0-7166']},
#  'RXN0-722 (reverse)': {0: ['RXN0-722'],
#   1: ['PWY0-166'],
#   2: ['Pyrimid-Deoxyribonucleot-De-Novo-Biosyn', 'Super-Pathways'],
#   3: ['Deoxyribonucleotide-Biosynthesis', 'Pyrimidine-De-Novo-Biosyn'],
#   5: ['Nucleotide-Biosynthesis'],
#   4: ['PYR-NUC-SYN'],
#   6: ['Biosynthesis']},
#  'RXN0-723': {0: ['RXN0-723'],
#   1: ['PWY-7187', 'PWY0-166'],
#   2: ['Pyrimid-Deoxyribonucleot-De-Novo-Biosyn', 'Super-Pathways'],
#   3: ['Deoxyribonucleotide-Biosynthesis', 'Pyrimidine-De-Novo-Biosyn'],
#   5: ['Nucleotide-Biosynthesis'],
#   4: ['PYR-NUC-SYN'],
#   6: ['Biosynthesis']},
#  'RXN0-745': {0: ['RXN0-745'],
#   1: ['PWY-7220'],
#   2: ['Adenosine-Deoxy-Denovo-Bbiosynthesis'],
#   3: ['Purine-Deoxyribonuc-De-Novo-Biosynthesis'],
#   4: ['Deoxyribonucleotide-Biosynthesis',
#    'Purine-Nucleotide-De-Novo-Biosynthesis'],
#   6: ['Nucleotide-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   7: ['Biosynthesis']},
#  'RXN0-746': {0: ['RXN0-746'],
#   1: ['PWY-7222'],
#   2: ['Guanosine-Deoxy-Denovo-Biosynthesis'],
#   3: ['Purine-Deoxyribonuc-De-Novo-Biosynthesis'],
#   4: ['Deoxyribonucleotide-Biosynthesis',
#    'Purine-Nucleotide-De-Novo-Biosynthesis'],
#   6: ['Nucleotide-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   7: ['Biosynthesis']},
#  'RXN0-748 (reverse)': {0: ['RXN0-748'],
#   1: ['PWY-7222'],
#   2: ['Guanosine-Deoxy-Denovo-Biosynthesis'],
#   3: ['Purine-Deoxyribonuc-De-Novo-Biosynthesis'],
#   4: ['Deoxyribonucleotide-Biosynthesis',
#    'Purine-Nucleotide-De-Novo-Biosynthesis'],
#   6: ['Nucleotide-Biosynthesis'],
#   5: ['PUR-NUC-SYN'],
#   7: ['Biosynthesis']},
#  'THIAZOLSYN2-RXN': {0: ['THIAZOLSYN2-RXN'],
#   1: ['PWY-6892'],
#   2: ['Thiazole-Biosynthesis'],
#   3: ['Thiamine-Biosynthesis'],
#   4: ['Enzyme-Cofactor-Biosynthesis', 'Vitamin-Biosynthesis'],
#   5: ['Cofactor-Biosynthesis'],
#   6: ['Biosynthesis']},
#  'THIOREDOXIN-REDUCT-NADPH-RXN (reverse)': {0: ['THIOREDOXIN-REDUCT-NADPH-RXN'],
#   1: ['THIOREDOX-PWY'],
#   2: ['Reductants'],
#   3: ['Other-biosynthesis'],
#   4: ['Biosynthesis']},
#  'TRANS-RXN0-582-FRU/PTSI-PHOSPHORYLATED//FRU1P/PTSI-MONOMER.44.': {},
#  'UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-RXN': {0: ['UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-RXN'],
#   1: ['NAGLIPASYN-PWY'],
#   2: ['Lipid-IV-A-Biosynthesis'],
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  'UDPNACETYLGLUCOSAMACYLTRANS-RXN': {0: ['UDPNACETYLGLUCOSAMACYLTRANS-RXN'],
#   1: ['NAGLIPASYN-PWY'],
#   2: ['Lipid-IV-A-Biosynthesis'],
#   3: ['Lipid-Biosynthesis', 'Lipopolysaccharide-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis', 'Glycan-Pathways']},
#  '325-BISPHOSPHATE-NUCLEOTIDASE-RXN__EG10043-MONOMER': {0: ['325-BISPHOSPHATE-NUCLEOTIDASE-RXN']},
#  'ACETOLACTSYN-RXN__ACETOLACTSYNI-CPLX': {0: ['ACETOLACTSYN-RXN'],
#   1: ['VALSYN-PWY'],
#   2: ['VALINE-BIOSYNTHESIS'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ALARACECAT-RXN__CPLX0-8202': {0: ['ALARACECAT-RXN'],
#   1: ['PWY-8072', 'ALADEG-PWY'],
#   2: ['Other-Amino-Acid-Biosynthesis', 'ALANINE-DEG'],
#   3: ['Amino-Acid-Biosynthesis', 'Proteinogenic-Amino-Acids-Degradation'],
#   4: ['Biosynthesis', 'Amino-Acid-Degradation'],
#   5: ['Degradation']},
#  'ASNSYNA-RXN__ASNSYNB-CPLX': {0: ['ASNSYNA-RXN'],
#   1: ['ASPARAGINESYN-PWY'],
#   2: ['ASPARAGINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'ASPARTATEKIN-RXN__ASPKINIHOMOSERDEHYDROGI-CPLX': {0: ['ASPARTATEKIN-RXN'],
#   1: ['DAPLYSINESYN-PWY', 'HOMOSERSYN-PWY'],
#   2: ['LYSINE-SYN', 'Other-Amino-Acid-Biosynthesis'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'CATAL-RXN__HYDROPEROXIDI-CPLX': {0: ['CATAL-RXN'],
#   1: ['DETOX1-PWY'],
#   2: ['REACTIVE-OXYGEN-SPECIES-DEGRADATION'],
#   3: ['Detoxification']},
#  'CHORISMATEMUT-RXN__CHORISMUTPREPHENDEHYDROG-CPLX': {0: ['CHORISMATEMUT-RXN'],
#   1: ['TYRSYN', 'PHESYN'],
#   2: ['TYROSINE-SYN', 'PHENYLALANINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DAHPSYN-RXN__AROG-CPLX': {0: ['DAHPSYN-RXN'],
#   1: ['PWY-6164'],
#   2: ['3-Dehydroquinate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'DAHPSYN-RXN__AROF-CPLX': {0: ['DAHPSYN-RXN'],
#   1: ['PWY-6164'],
#   2: ['3-Dehydroquinate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'DAHPSYN-RXN__AROH-CPLX': {0: ['DAHPSYN-RXN'],
#   1: ['PWY-6164'],
#   2: ['3-Dehydroquinate-Biosynthesis'],
#   3: ['Carboxylate-Biosynthesis'],
#   4: ['Biosynthesis']},
#  'DALADALALIG-RXN__DALADALALIGB-CPLX': {0: ['DALADALALIG-RXN'],
#   1: ['PWY-6387'],
#   2: ['Acetylmuramoyl-Pentapeptide-Biosynthesis'],
#   3: ['Cell-Wall-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DALADALALIG-RXN__DALADALALIGA-MONOMER': {0: ['DALADALALIG-RXN'],
#   1: ['PWY-6387'],
#   2: ['Acetylmuramoyl-Pentapeptide-Biosynthesis'],
#   3: ['Cell-Wall-Biosynthesis'],
#   4: ['Cell-Structure-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'DARAB5PISOM-RXN__CPLX0-1262 (reverse)': {0: ['DARAB5PISOM-RXN'],
#   1: ['PWY-1269'],
#   2: ['CMP-KDO-Biosynthesis'],
#   3: ['CMP-Sugar-Biosynthesis'],
#   4: ['SUGAR-NUCLEOTIDES'],
#   5: ['CARBO-BIOSYNTHESIS'],
#   6: ['Carbohydrates-Biosynthesis'],
#   7: ['Biosynthesis']},
#  'F16ALDOLASE-RXN__FRUCBISALD-CLASSII': {0: ['F16ALDOLASE-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'F16ALDOLASE-RXN__FRUCBISALD-CLASSI': {0: ['F16ALDOLASE-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__F16B-CPLX': {0: ['F16BDEPHOS-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__EG11239-MONOMER': {0: ['F16BDEPHOS-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__CPLX0-303': {0: ['F16BDEPHOS-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__CPLX0-7776': {0: ['F16BDEPHOS-RXN'],
#   1: ['GLYCOLYSIS', 'PWY-5484', 'GLUCONEO-PWY'],
#   2: ['GLYCOLYSIS-VARIANTS', 'Gluconeogenesis'],
#   3: ['Energy-Metabolism', 'CARBO-BIOSYNTHESIS'],
#   4: ['Carbohydrates-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'GLUTDECARBOX-RXN__GLUTDECARBOXB-CPLX': {0: ['GLUTDECARBOX-RXN'],
#   1: ['PWY0-1305'],
#   2: ['Acid-Resistance', 'GLUTAMATE-DEG'],
#   3: ['Detoxification', 'Proteinogenic-Amino-Acids-Degradation'],
#   4: ['Amino-Acid-Degradation'],
#   5: ['Degradation']},
#  'ISOCHORSYN-RXN__ENTC-MONOMER': {0: ['ISOCHORSYN-RXN'],
#   1: ['PWY-5901', 'PWY-5837'],
#   2: ['AROMATIC-COMPOUNDS-BIOSYN', 'DHNA-Biosynthesis'],
#   7: ['Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis']},
#  'ISOCHORSYN-RXN__MENF-CPLX': {0: ['ISOCHORSYN-RXN'],
#   1: ['PWY-5901', 'PWY-5837'],
#   2: ['AROMATIC-COMPOUNDS-BIOSYN', 'DHNA-Biosynthesis'],
#   7: ['Biosynthesis'],
#   3: ['Quinone-Biosynthesis'],
#   4: ['Electron-Carrier-Biosynthesis'],
#   5: ['Carriers-Biosynthesis'],
#   6: ['Cofactor-Biosynthesis']},
#  'RXN-9535__FABB-CPLX': {0: ['RXN-9535'],
#   1: ['PWY-5971'],
#   2: ['Palmitate-Biosynthesis'],
#   3: ['Fatty-acid-biosynthesis'],
#   4: ['Lipid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'RXN0-313__CPLX0-201 (reverse)': {0: ['RXN0-313']},
#  'RXN0-384__H2NEOPTERINP3PYROPHOSPHOHYDRO-MONOMER': {0: ['RXN0-384']},
#  'RXN0-5186__G7408-MONOMER': {0: ['RXN0-5186']},
#  'SERINE-O-ACETTRAN-RXN__CPLX0-237': {0: ['SERINE-O-ACETTRAN-RXN'],
#   1: ['PWY-7870', 'CYSTSYN-PWY'],
#   2: ['CYSTEINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'SERINE-O-ACETTRAN-RXN__CYSSYNMULTI-CPLX': {0: ['SERINE-O-ACETTRAN-RXN'],
#   1: ['PWY-7870', 'CYSTSYN-PWY'],
#   2: ['CYSTEINE-SYN'],
#   3: ['IND-AMINO-ACID-SYN'],
#   4: ['Amino-Acid-Biosynthesis'],
#   5: ['Biosynthesis']},
#  'UNDECAPRENYL-DIPHOSPHATASE-RXN[CCO-CYTOSOL]-UNDECAPRENYL-DIPHOSPHATE/WATER//CPD-9646/Pi/PROTON.64.__PGPPHOSPHAB-MONOMER': {0: ['UNDECAPRENYL-DIPHOSPHATASE-RXN'],
#   1: ['PWY-5785'],
#   2: ['Lipid-Anchor-Biosynthesis', 'Polyprenyl-Biosynthesis'],
#   3: ['Carriers-Biosynthesis'],
#   5: ['Biosynthesis'],
#   4: ['Cofactor-Biosynthesis']},
#  'URPHOS-RXN__URPHOS-CPLX': {0: ['URPHOS-RXN'],
#   1: ['PWY0-163', 'PWY0-1295'],
#   2: ['Pyrimidine-Nucleotide-Salvage',
#    'Pyrimidine-Ribonucleosides-Degradation'],
#   3: ['PYR-NUC-SYN', 'Pyrimidine-Degradation'],
#   4: ['Nucleotide-Biosynthesis', 'NUCLEO-DEG'],
#   5: ['Biosynthesis', 'Degradation']},
#  'maintenance_reaction': {}}

# %%
response = s.get("https://websvc.biocyc.org/getxml?id=ECOLI:2.3.1.157-RXN")
    
tree = ElementTree.fromstring(response.content)
r = etree_to_dict(tree)

# %%
not_found
# Out:
# {'1.5.1.20-RXN-5-METHYL-THF/NAD//METHYLENE-THF/NADH/PROTON.44. (reverse)': {},
#  '1.5.1.20-RXN-CPD-1302/NAD//CPD-12996/NADH/PROTON.36. (reverse)': {},
#  '1PFRUCTPHOSN-RXN': {},
#  '1TRANSKETO-RXN (reverse)': {},
#  '2-DEHYDROPANTOATE-REDUCT-RXN (reverse)': {},
#  '2-ISOPROPYLMALATESYN-RXN': {},
#  '2-OCTAPRENYL-6-METHOXYPHENOL-HYDROX-RXN': {},
#  '2-OCTAPRENYL-6-OHPHENOL-METHY-RXN': {},
#  '2-OCTAPRENYL-METHOXY-BENZOQ-METH-RXN': {},
#  '2-OCTAPRENYLPHENOL-HYDROX-RXN': {},
#  '2.3.1.157-RXN': {},
#  '2.5.1.19-RXN': {},
#  '2.5.1.64-RXN': {},
#  '2.7.1.148-RXN': {},
#  '2.7.7.60-RXN': {},
#  '2.8.1.6-RXN': {},
#  '2OXOGLUTARATEDEH-RXN': {},
#  '2PGADEHYDRAT-RXN': {},
#  '2TRANSKETO-RXN (reverse)': {},
#  '3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-RXN-CPD-12996/2-KETO-ISOVALERATE/WATER//2-DEHYDROPANTOATE/CPD-1301.63.': {},
#  '3-DEHYDROQUINATE-DEHYDRATASE-RXN': {},
#  '3-DEHYDROQUINATE-SYNTHASE-RXN': {},
#  '3-OCTAPRENYL-4-OHBENZOATE-DECARBOX-RXN': {},
#  '3.2.2.10-RXN-CMP/WATER//RIBOSE-5P/CYTOSINE.30.': {},
#  '3.2.2.10-RXN-UMP/WATER//RIBOSE-5P/URACIL.28.': {},
#  '325-BISPHOSPHATE-NUCLEOTIDASE-RXN': {},
#  '3PGAREARR-RXN (reverse)': {},
#  '4OHBENZOATE-OCTAPRENYLTRANSFER-RXN': {},
#  '5.1.3.20-RXN': {},
#  '5.4.2.10-RXN-CPD-13469//GLUCOSAMINE-1P.26.': {},
#  '6PGLUCONOLACT-RXN': {},
#  'ACECOATRANS-RXN-PROPIONYL-COA/ACET//PROPIONATE/ACETYL-COA.42.': {},
#  'ACETATEKIN-RXN': {},
#  'ACETOLACTREDUCTOISOM-RXN (reverse)': {},
#  'ACETOLACTSYN-RXN': {},
#  'ACETOOHBUTREDUCTOISOM-RXN (reverse)': {},
#  'ACETOOHBUTSYN-RXN': {},
#  'ACETYL-COA-ACETYLTRANSFER-RXN': {},
#  'ACETYLGLUTKIN-RXN': {},
#  'ACETYLORNDEACET-RXN': {},
#  'ACETYLORNTRANSAM-RXN (reverse)': {},
#  'ACONITATEDEHYDR-RXN': {},
#  'ACSERLY-RXN': {},
#  'ADCLY-RXN': {},
#  'ADENOSYLHOMOCYSTEINE-NUCLEOSIDASE-RXN': {},
#  'ADENPRIBOSYLTRAN-RXN (reverse)': {},
#  'ADENYL-KIN-RXN': {},
#  'ADENYLOSUCCINATE-SYNTHASE-RXN': {},
#  'ADENYLYLSULFKIN-RXN': {},
#  'ADOMET-DMK-METHYLTRANSFER-RXN': {},
#  'AICARSYN-RXN': {},
#  'AICARTRANSFORM-RXN-10-FORMYL-THF/AICAR//THF/PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE.62.': {},
#  'AIRS-RXN': {},
#  'ALANINE-AMINOTRANSFERASE-RXN (reverse)': {},
#  'ALARACECAT-RXN': {},
#  'AMPSYN-RXN': {},
#  'ANTHRANSYN-RXN': {},
#  'ARGSUCCINLYA-RXN': {},
#  'ARGSUCCINSYN-RXN': {},
#  'ASNSYNA-RXN': {},
#  'ASPAMINOTRANS-RXN': {},
#  'ASPARTASE-RXN (reverse)': {},
#  'ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN (reverse)': {},
#  'ASPARTATEKIN-RXN': {},
#  'ASPCARBTRANS-RXN': {},
#  'ASPDECARBOX-RXN': {},
#  'ATPPHOSPHORIBOSYLTRANS-RXN (reverse)': {},
#  'ATPSYN-RXN (reverse)': {},
#  'BRANCHED-CHAINAMINOTRANSFERILEU-RXN (reverse)': {},
#  'BRANCHED-CHAINAMINOTRANSFERLEU-RXN (reverse)': {},
#  'BRANCHED-CHAINAMINOTRANSFERVAL-RXN (reverse)': {},
#  'CARDIOLIPSYN-RXN-CPD-8260//CPD-12824/GLYCEROL.29.': {},
#  'CDPDIGLYSYN-RXN-CTP/CPD0-1422/PROTON//CPD-12815/PPI.36.': {},
#  'CDPKIN-RXN': {},
#  'CHORISMATE-SYNTHASE-RXN': {},
#  'CHORPYRLY-RXN': {},
#  'CITSYN-RXN': {},
#  'CPM-KDOSYNTH-RXN': {},
#  'CYSTATHIONINE-BETA-LYASE-RXN': {},
#  'D-PPENTOMUT-RXN (reverse)': {},
#  'DAPASYN-RXN': {},
#  'DEOXYADENPHOSPHOR-RXN (reverse)': {},
#  'DEOXYGUANPHOSPHOR-RXN (reverse)': {},
#  'DEOXYRIBOSE-P-ALD-RXN (reverse)': {},
#  'DEPHOSPHOCOAKIN-RXN': {},
#  'DETHIOBIOTIN-SYN-RXN': {},
#  'DHBDEHYD-RXN': {},
#  'DHHB-METHYLTRANSFER-RXN': {},
#  'DIAMINOPIMDECARB-RXN': {},
#  'DIAMINOPIMEPIM-RXN': {},
#  'DIHYDRODIPICSYN-RXN': {},
#  'DIHYDROFOLATESYNTH-RXN': {},
#  'DIHYDRONEOPTERIN-MONO-P-DEPHOS-RXN': {},
#  'DIHYDROOROT-RXN (reverse)': {},
#  'DIHYDROOROTATE-DEHYDROGENASE-RXN-DI-H-OROTATE/UBIQUINONE-8//OROTATE/CPD-9956.44.': {},
#  'DIHYDROXYISOVALDEHYDRAT-RXN': {},
#  'DIHYDROXYMETVALDEHYDRAT-RXN': {},
#  'DIMETHUROPORDEHYDROG-RXN': {},
#  'DIOHBUTANONEPSYN-RXN': {},
#  'DMK-RXN': {},
#  'DTDPKIN-RXN': {},
#  'DTMPKI-RXN': {},
#  'DURIDKI-RXN': {},
#  'DXPREDISOM-RXN (reverse)': {},
#  'DXS-RXN': {},
#  'ENTMULTI-RXN': {},
#  'ERYTH4PDEHYDROG-RXN': {},
#  'ERYTHRON4PDEHYDROG-RXN': {},
#  'FADSYN-RXN': {},
#  'FGAMSYN-RXN': {},
#  'FPPSYN-RXN': {},
#  'FRUCTOKINASE-RXN': {},
#  'GAPOXNPHOSPHN-RXN': {},
#  'GART-RXN-10-FORMYL-THF/5-PHOSPHO-RIBOSYL-GLYCINEAMIDE//THF/5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE/PROTON.90.': {},
#  'GDPKIN-RXN': {},
#  'GDPPYPHOSKIN-RXN': {},
#  'GLU6PDEHYDROG-RXN-GLC-6-P/NADP//D-6-P-GLUCONO-DELTA-LACTONE/NADPH/PROTON.55.': {},
#  'GLUC1PADENYLTRANS-RXN': {},
#  'GLUC1PURIDYLTRANS-RXN': {},
#  'GLUCOSAMINE-6-P-DEAMIN-RXN (reverse)': {},
#  'GLUTAMINESYN-RXN': {},
#  'GLUTATHIONE-SYN-RXN': {},
#  'GLUTCYSLIG-RXN': {},
#  'GLUTDEHYD-RXN (reverse)': {},
#  'GLUTKIN-RXN': {},
#  'GLUTRACE-RXN': {},
#  'GLUTRNAREDUCT-RXN (reverse)': {},
#  'GLUTSEMIALDEHYDROG-RXN (reverse)': {},
#  'GLYC3PDEHYDROGBIOSYN-RXN-GLYCEROL-3P/NAD//DIHYDROXY-ACETONE-PHOSPHATE/NADH/PROTON.57. (reverse)': {},
#  'GLYCDEH-RXN': {},
#  'GLYCOLALD-DEHYDROG-RXN': {},
#  'GLYCOLATEDEHYDRO-RXN': {},
#  'GLYOHMETRANS-RXN-SER/CPD-1301//GLY/CPD-12996/WATER.34.': {},
#  'GLYOHMETRANS-RXN-SER/THF//GLY/METHYLENE-THF/WATER.33.': {},
#  'GLYRIBONUCSYN-RXN': {},
#  'GMKALT-RXN (reverse)': {},
#  'GMP-SYN-NH3-RXN': {},
#  'GPPSYN-RXN': {},
#  'GSAAMINOTRANS-RXN': {},
#  'GTP-CYCLOHYDRO-I-RXN': {},
#  'GTP-CYCLOHYDRO-II-RXN': {},
#  'GUANYL-KIN-RXN': {},
#  'H2NEOPTERINALDOL-RXN': {},
#  'H2NEOPTERINP3PYROPHOSPHOHYDRO-RXN': {},
#  'H2PTERIDINEPYROPHOSPHOKIN-RXN': {},
#  'H2PTEROATESYNTH-RXN': {},
#  'HISTAMINOTRANS-RXN (reverse)': {},
#  'HISTCYCLOHYD-RXN': {},
#  'HISTIDPHOS-RXN[CCO-CYTOSOL]-L-HISTIDINOL-P/WATER//HISTIDINOL/Pi.49.': {},
#  'HISTPRATPHYD-RXN': {},
#  'HOMOCYSMET-RXN': {},
#  'HOMOCYSMETB12-RXN-HOMO-CYS/5-METHYL-THF//MET/THF.31.': {},
#  'HOMOSERDEHYDROG-RXN-HOMO-SER/NAD//L-ASPARTATE-SEMIALDEHYDE/NADH/PROTON.51. (reverse)': {},
#  'HOMSUCTRAN-RXN': {},
#  'IGPSYN-RXN': {},
#  'IMIDPHOSDEHYD-RXN': {},
#  'IMP-DEHYDROG-RXN': {},
#  'IMPCYCLOHYDROLASE-RXN (reverse)': {},
#  'INOPHOSPHOR-RXN (reverse)': {},
#  'INORGPYROPHOSPHAT-RXN[CCO-CYTOSOL]-PPI/WATER//Pi/PROTON.34.': {},
#  'INOSINEKIN-RXN': {},
#  'ISOCHORMAT-RXN': {},
#  'ISOCIT-CLEAV-RXN': {},
#  'ISOCITDEH-RXN': {},
#  'ISPH2-RXN (reverse)': {},
#  'KDO-8PPHOSPHAT-RXN': {},
#  'KDO-8PSYNTH-RXN': {},
#  'KDOTRANS-RXN': {},
#  'KDOTRANS2-RXN': {},
#  'LIPIDADISACCHARIDESYNTH-RXN': {},
#  'LIPIDXSYNTHESIS-RXN': {},
#  'LUMAZINESYN-RXN': {},
#  'MALSYN-RXN': {},
#  'METHENYLTHFCYCLOHYDRO-RXN-5-10-METHENYL-THF/WATER//10-FORMYL-THF/PROTON.46.': {},
#  'METHYLENETHFDEHYDROG-NADP-RXN-METHYLENE-THF/NADP//5-10-METHENYL-THF/NADPH.44.': {},
#  'METHYLMALONYL-COA-MUT-RXN (reverse)': {},
#  'METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN': {},
#  'N-ACETYLGLUTPREDUCT-RXN (reverse)': {},
#  'N-ACETYLTRANSFER-RXN': {},
#  'NACGLCTRANS-RXN': {},
#  'NAD-KIN-RXN': {},
#  'NAD-SYNTH-NH3-RXN': {},
#  'NADH-DEHYDROG-A-RXN-NADH/UBIQUINONE-8/PROTON//NAD/CPD-9956/PROTON.46.': {},
#  'NAG1P-URIDYLTRANS-RXN': {},
#  'NAPHTHOATE-SYN-RXN': {},
#  'NICONUCADENYLYLTRAN-RXN': {},
#  'NUCLEOSIDE-DIPHOSPHATASE-RXN-DUDP/WATER//DUMP/Pi/PROTON.27.': {},
#  'O-SUCCHOMOSERLYASE-RXN': {},
#  'O-SUCCINYLBENZOATE-COA-LIG-RXN': {},
#  'O-SUCCINYLBENZOATE-COA-SYN-RXN': {},
#  'OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-RXN': {},
#  'OHMETHYLBILANESYN-RXN': {},
#  'ORNCARBAMTRANSFER-RXN': {},
#  'ORNDECARBOX-RXN': {},
#  'OROPRIBTRANS-RXN (reverse)': {},
#  'OROTPDECARB-RXN': {},
#  'P-PANTOCYSDECARB-RXN': {},
#  'P-PANTOCYSLIG-RXN': {},
#  'PABASYN-RXN': {},
#  'PANTEPADENYLYLTRAN-RXN': {},
#  'PANTOATE-BETA-ALANINE-LIG-RXN': {},
#  'PANTOTHENATE-KIN-RXN': {},
#  'PDXJ-RXN': {},
#  'PEPCARBOX-RXN (reverse)': {},
#  'PEPDEPHOS-RXN (reverse)': {},
#  'PGLUCISOM-RXN-GLC-6-P//FRUCTOSE-6P.21. (reverse)': {},
#  'PGLYCDEHYDROG-RXN': {},
#  'PGPPHOSPHA-RXN-CPD-12821/WATER//CPD-8260/Pi.29.': {},
#  'PHOSGLYPHOS-RXN (reverse)': {},
#  'PHOSNACMURPENTATRANS-RXN': {},
#  'PHOSPHAGLYPSYN-RXN-CPD-12815/GLYCEROL-3P//CMP/CPD-12821/PROTON.44.': {},
#  'PHOSPHASERDECARB-RXN-CPD-12817/PROTON//CPD-12819/CARBON-DIOXIDE.43.': {},
#  'PHOSPHASERSYN-RXN-CPD-12815/SER//CMP/CPD-12817/PROTON.36.': {},
#  'PHOSPHOGLUCMUT-RXN-GLC-1-P//GLC-6-P.17. (reverse)': {},
#  'PNPOXI-RXN': {},
#  'PORPHOBILSYNTH-RXN': {},
#  'PRAISOM-RXN': {},
#  'PREPHENATEDEHYDRAT-RXN': {},
#  'PREPHENATEDEHYDROG-RXN': {},
#  'PRIBFAICARPISOM-RXN': {},
#  'PROTOHEMEFERROCHELAT-RXN[CCO-CYTOSOL]-PROTOHEME/PROTON//PROTOPORPHYRIN_IX/FE+2.54. (reverse)': {},
#  'PRPPAMIDOTRANS-RXN (reverse)': {},
#  'PRPPSYN-RXN': {},
#  'PRTRANS-RXN (reverse)': {},
#  'PSERTRANSAM-RXN (reverse)': {},
#  'PSERTRANSAMPYR-RXN (reverse)': {},
#  'PYRIMSYN1-RXN': {},
#  'PYRIMSYN3-RXN': {},
#  'PYRROLINECARBREDUCT-RXN-PRO/NAD//L-DELTA1-PYRROLINE_5-CARBOXYLATE/NADH/PROTON.54. (reverse)': {},
#  'PYRUVDEH-RXN': {},
#  'QUINOLINATE-SYNTHA-RXN': {},
#  'QUINOPRIBOTRANS-RXN (reverse)': {},
#  'R15-RXN-MET/2-KETOGLUTARATE//CPD-479/GLT.33. (reverse)': {},
#  'R15-RXN-MET/GLYOX//CPD-479/GLY.23.': {},
#  'RIB5PISOM-RXN (reverse)': {},
#  'RIBOFLAVIN-SYN-RXN': {},
#  'RIBOFLAVINKIN-RXN': {},
#  'RIBOFLAVINSYNDEAM-RXN': {},
#  'RIBOFLAVINSYNREDUC-RXN (reverse)': {},
#  'RIBOPHOSPHAT-RXN': {},
#  'RIBOSYLHOMOCYSTEINASE-RXN': {},
#  'RIBULP3EPIM-RXN (reverse)': {},
#  'RXN-10814 (reverse)': {},
#  'RXN-11032 (reverse)': {},
#  'RXN-11319': {},
#  'RXN-11475': {},
#  'RXN-11484': {},
#  'RXN-11832': {},
#  'RXN-12002': {},
#  'RXN-12588': {},
#  'RXN-12611': {},
#  'RXN-13158': {},
#  'RXN-13163 (reverse)': {},
#  'RXN-13179': {},
#  'RXN-13202': {},
#  'RXN-13403': {},
#  'RXN-14014-DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE/NAD/WATER//CPD-14443/NADH/PROTON.70. (reverse)': {0: [('RXN-14014-DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE/NAD/WATER//CPD-14443/NADH/PROTON.70.',
#     404)]},
#  'RXN-14025[CCO-CYTOSOL]-UMP/WATER//URIDINE/Pi.35.': {0: [('RXN-14025[CCO-CYTOSOL]-UMP/WATER//URIDINE/Pi.35.',
#     404)]},
#  'RXN-14026[CCO-CYTOSOL]-CMP/WATER//CYTIDINE/Pi.36.': {0: [('RXN-14026[CCO-CYTOSOL]-CMP/WATER//CYTIDINE/Pi.36.',
#     404)]},
#  'RXN-14047': {},
#  'RXN-14325': {},
#  'RXN-15216': {},
#  'RXN-15878 (reverse)': {},
#  'RXN-15943 (reverse)': {},
#  'RXN-16804': {},
#  'RXN-17900': {},
#  'RXN-19329 (reverse)': {},
#  'RXN-19737': {},
#  'RXN-21483-PROTOPORPHYRINOGEN/UBIQUINONE-8//PROTOPORPHYRIN_IX/CPD-9956.60.': {0: [('RXN-21483-PROTOPORPHYRINOGEN/UBIQUINONE-8//PROTOPORPHYRIN_IX/CPD-9956.60.',
#     404)]},
#  'RXN-21817-CPD-9956/PROTON/OXYGEN-MOLECULE//UBIQUINONE-8/PROTON/WATER.59.': {0: [('RXN-21817-CPD-9956/PROTON/OXYGEN-MOLECULE//UBIQUINONE-8/PROTON/WATER.59.',
#     404)]},
#  'RXN-6081': {},
#  'RXN-6161': {},
#  'RXN-8001': {},
#  'RXN-8992': {},
#  'RXN-8999': {},
#  'RXN-9310': {},
#  'RXN-9311': {},
#  'RXN-9772': {},
#  'RXN-9952': {},
#  'RXN0-12': {},
#  'RXN0-1461': {},
#  'RXN0-16': {},
#  'RXN0-2421': {},
#  'RXN0-2501': {},
#  'RXN0-268 (reverse)': {},
#  'RXN0-302': {},
#  'RXN0-305': {},
#  'RXN0-310': {},
#  'RXN0-313 (reverse)': {},
#  'RXN0-4301': {},
#  'RXN0-4341': {},
#  'RXN0-4342': {},
#  'RXN0-4361': {},
#  'RXN0-5038': {},
#  'RXN0-5061': {},
#  'RXN0-5114[CCO-CYTOSOL]-3-P-SERINE/WATER//SER/Pi.38.': {0: [('RXN0-5114[CCO-CYTOSOL]-3-P-SERINE/WATER//SER/Pi.38.',
#     404)]},
#  'RXN0-5118': {},
#  'RXN0-5120': {},
#  'RXN0-5121': {},
#  'RXN0-5122': {},
#  'RXN0-5123': {},
#  'RXN0-5124': {},
#  'RXN0-5125': {},
#  'RXN0-5126': {},
#  'RXN0-5127': {},
#  'RXN0-5185[CCO-CYTOSOL]-CPD-2961/WATER//GLUCONATE/Pi.42.': {0: [('RXN0-5185[CCO-CYTOSOL]-CPD-2961/WATER//GLUCONATE/Pi.42.',
#     404)]},
#  'RXN0-5186': {},
#  'RXN0-5224 (reverse)': {},
#  'RXN0-5289 (reverse)': {},
#  'RXN0-5461': {},
#  'RXN0-6550': {},
#  'RXN0-6562': {},
#  'RXN0-7352': {},
#  'RXN0-742': {},
#  'RXN0-743': {},
#  'RXN0-884 (reverse)': {},
#  'RXN3O-470-ACETALD//CPD-255.17. (reverse)': {0: [('RXN3O-470-ACETALD//CPD-255.17.',
#     404)]},
#  'S-ADENMETSYN-RXN': {},
#  'SAICARSYN-RXN': {},
#  'SAMDECARB-RXN': {},
#  'SHIKIMATE-5-DEHYDROGENASE-RXN (reverse)': {},
#  'SHIKIMATE-KINASE-RXN': {},
#  'SIROHEME-FERROCHELAT-RXN': {},
#  'SPERMIDINESYN-RXN': {},
#  'SPONTPRO-RXN (reverse)': {},
#  'SUCCCOASYN-RXN (reverse)': {},
#  'SUCCDIAMINOPIMDESUCC-RXN': {},
#  'SUCCINATE-DEHYDROGENASE-UBIQUINONE-RXN-SUC/UBIQUINONE-8//FUM/CPD-9956.31.': {},
#  'SUCCINYLDIAMINOPIMTRANS-RXN (reverse)': {},
#  'SULFATE-ADENYLYLTRANS-RXN': {},
#  'SULFITE-REDUCT-RXN (reverse)': {},
#  'TETHYDPICSUCC-RXN': {},
#  'TETRAACYLDISACC4KIN-RXN': {},
#  'THI-P-KIN-RXN': {},
#  'THREDEHYD-RXN': {},
#  'THREONINE-ALDOLASE-RXN (reverse)': {},
#  'THYMIDYLATESYN-RXN-METHYLENE-THF/DUMP//TMP/DIHYDROFOLATE.38.': {},
#  'TRANS-RXN-1': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-114': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-141': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-141A': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-141B': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-145': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-3': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN-62A': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-277 (reverse)': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-286': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-459': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-461': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-474': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-497': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-500': {0: [('TRANS-RXN', 404)]},
#  'TRANS-RXN0-545[CCO-PM-BAC-NEG]-CARBON-DIOXIDE//CARBON-DIOXIDE.47. (reverse)': {0: [('TRANS-RXN',
#     404)]},
#  'TRANS-RXN0-556[CCO-PM-BAC-NEG]-CARBON-MONOXIDE//CARBON-MONOXIDE.49. (reverse)': {0: [('TRANS-RXN',
#     404)]},
#  'TRANS-RXN0-586': {0: [('TRANS-RXN', 404)]},
#  'TRIOSEPISOMERIZATION-RXN (reverse)': {},
#  'TRYPSYN-RXN': {},
#  'TYROSINE-AMINOTRANSFERASE-RXN (reverse)': {},
#  'UDP-NACMUR-ALA-LIG-RXN': {},
#  'UDP-NACMURALA-GLU-LIG-RXN': {},
#  'UDP-NACMURALGLDAPAALIG-RXN': {},
#  'UDP-NACMURALGLDAPLIG-RXN': {},
#  'UDPACYLGLCNACDEACETYL-RXN': {},
#  'UDPGLUCEPIM-RXN': {},
#  'UDPKIN-RXN': {},
#  'UDPNACETYLGLUCOSAMENOLPYRTRANS-RXN': {},
#  'UDPNACETYLMURAMATEDEHYDROG-RXN (reverse)': {},
#  'UGD-RXN': {},
#  'UNDECAPRENYL-DIPHOSPHATASE-RXN[CCO-CYTOSOL]-UNDECAPRENYL-DIPHOSPHATE/WATER//CPD-9646/Pi/PROTON.64.': {},
#  'URA-PHOSPH-RXN (reverse)': {},
#  'UROGENDECARBOX-RXN': {},
#  'UROGENIIISYN-RXN': {},
#  'glycogen-monomer-extension': {0: [('glycogen-monomer-extension', 404)]},
#  'GLURS-RXN-GLT-tRNAs/GLT/ATP/PROTON//Charged-GLT-tRNAs/AMP/PPI.52.': {},
#  'RXN0-5405': {0: [('RXN0-5405', 404)]},
#  'RXN-11302': {0: [('RXN-11302', 404)]},
#  '1.8.4.8-RXN (reverse)': {},
#  '2.3.1.180-RXN': {},
#  '3-HYDROXYDECANOYL-ACP-DEHYDR-RXN-POLYMER-INST-OH-ACYL-ACP-C0-H0//POLYMER-INST-TRANS-D2-ENOYL-ACP-C0-H0/WATER.76.': {},
#  '3-HYDROXYDECANOYL-ACP-DEHYDR-RXN-POLYMER-INST-OH-ACYL-ACP-C12-H24//2-Hexadecenoyl-ACPs/WATER.60.': {},
#  '3-HYDROXYDECANOYL-ACP-DEHYDR-RXN-POLYMER-INST-OH-ACYL-ACP-C4-H8//POLYMER-INST-TRANS-D2-ENOYL-ACP-C4-H8/WATER.76.': {},
#  '3-OXOACYL-ACP-REDUCT-RXN-Beta-hydroxydecanoyl-ACPs/NADP//POLYMER-INST-B-KETOACYL-ACP-C6-H12/NADPH/PROTON.80. (reverse)': {},
#  '3-OXOACYL-ACP-REDUCT-RXN-POLYMER-INST-OH-ACYL-ACP-C0-H0/NADP//Acetoacetyl-ACPs/NADPH/PROTON.67. (reverse)': {},
#  '3-OXOACYL-ACP-REDUCT-RXN-POLYMER-INST-OH-ACYL-ACP-C12-H24/NADP//3-oxo-palmitoyl-ACPs/NADPH/PROTON.73. (reverse)': {},
#  '3-OXOACYL-ACP-REDUCT-RXN-POLYMER-INST-OH-ACYL-ACP-C4-H8/NADP//3-Oxo-octanoyl-ACPs/NADPH/PROTON.70. (reverse)': {},
#  '3-OXOACYL-ACP-SYNTH-RXN-MALONYL-ACP/POLYMER-INST-Saturated-Fatty-Acyl-ACPs-C4-H8/PROTON//ACP/POLYMER-INST-B-KETOACYL-ACP-C6-H12/CARBON-DIOXIDE.119.': {},
#  'BIOTIN-CARBOXYL-RXN': {},
#  'ENOYL-ACP-REDUCT-NADH-RXN-Butanoyl-ACPs/NAD//POLYMER-INST-TRANS-D2-ENOYL-ACP-C0-H0/NADH/PROTON.69. (reverse)': {},
#  'ENOYL-ACP-REDUCT-NADH-RXN-POLYMER-INST-Saturated-Fatty-Acyl-ACPs-C4-H8/NAD//POLYMER-INST-TRANS-D2-ENOYL-ACP-C4-H8/NADH/PROTON.100. (reverse)': {},
#  'FERREDOXIN--NAD+-REDUCTASE-RXN (reverse)': {0: [('FERREDOXIN--NAD+-REDUCTASE-RXN',
#     404)]},
#  'LAUROYLACYLTRAN-RXN': {},
#  'MALONYL-COA-ACP-TRANSACYL-RXN': {},
#  'MYRISTOYLACYLTRAN-RXN': {},
#  'PRODISULFREDUCT-A-RXN-GLUTATHIONE/Oxidized-NrdH-Proteins//OXIDIZED-GLUTATHIONE/Reduced-NrdH-Proteins.79.': {},
#  'PYFLAVOXRE-RXN': {},
#  'PYRUFLAVREDUCT-RXN': {},
#  'RXN-11474': {},
#  'RXN-11476 (reverse)': {},
#  'RXN-11477': {},
#  'RXN-11478 (reverse)': {},
#  'RXN-11479': {},
#  'RXN-11480 (reverse)': {},
#  'RXN-11481': {},
#  'RXN-11482 (reverse)': {},
#  'RXN-11483': {},
#  'RXN-17018': {},
#  'RXN-9516': {},
#  'RXN-9518 (reverse)': {},
#  'RXN-9520': {},
#  'RXN-9523': {},
#  'RXN-9531': {},
#  'RXN-9532 (reverse)': {},
#  'RXN-9533': {},
#  'RXN-9535': {},
#  'RXN-9536 (reverse)': {},
#  'RXN-9537': {},
#  'RXN-9539': {},
#  'RXN-9655': {},
#  'RXN-9658 (reverse)': {},
#  'RXN-9660 (reverse)': {},
#  'RXN-9661 (reverse)': {},
#  'RXN-9662 (reverse)': {},
#  'RXN-9663 (reverse)': {},
#  'RXN-9787': {},
#  'RXN-9788': {},
#  'RXN-9789': {},
#  'RXN0-5055': {},
#  'RXN0-6705': {},
#  'RXN0-6717': {},
#  'RXN0-722 (reverse)': {},
#  'RXN0-723': {},
#  'RXN0-745': {},
#  'RXN0-746': {},
#  'RXN0-748 (reverse)': {},
#  'THIAZOLSYN2-RXN': {},
#  'THIOREDOXIN-REDUCT-NADPH-RXN (reverse)': {},
#  'TRANS-RXN0-582-FRU/PTSI-PHOSPHORYLATED//FRU1P/PTSI-MONOMER.44.': {0: [('TRANS-RXN',
#     404)]},
#  'UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-RXN': {},
#  'UDPNACETYLGLUCOSAMACYLTRANS-RXN': {},
#  '325-BISPHOSPHATE-NUCLEOTIDASE-RXN__EG10043-MONOMER': {},
#  'ACETOLACTSYN-RXN__ACETOLACTSYNI-CPLX': {},
#  'ALARACECAT-RXN__CPLX0-8202': {},
#  'ASNSYNA-RXN__ASNSYNB-CPLX': {},
#  'ASPARTATEKIN-RXN__ASPKINIHOMOSERDEHYDROGI-CPLX': {},
#  'CATAL-RXN__HYDROPEROXIDI-CPLX': {},
#  'CHORISMATEMUT-RXN__CHORISMUTPREPHENDEHYDROG-CPLX': {},
#  'DAHPSYN-RXN__AROG-CPLX': {},
#  'DAHPSYN-RXN__AROF-CPLX': {},
#  'DAHPSYN-RXN__AROH-CPLX': {},
#  'DALADALALIG-RXN__DALADALALIGB-CPLX': {},
#  'DALADALALIG-RXN__DALADALALIGA-MONOMER': {},
#  'DARAB5PISOM-RXN__CPLX0-1262 (reverse)': {},
#  'F16ALDOLASE-RXN__FRUCBISALD-CLASSII': {},
#  'F16ALDOLASE-RXN__FRUCBISALD-CLASSI': {},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__F16B-CPLX': {},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__EG11239-MONOMER': {},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__CPLX0-303': {},
#  'F16BDEPHOS-RXN[CCO-CYTOSOL]-FRUCTOSE-16-DIPHOSPHATE/WATER//FRUCTOSE-6P/Pi.59.__CPLX0-7776': {},
#  'GLUTDECARBOX-RXN__GLUTDECARBOXB-CPLX': {},
#  'ISOCHORSYN-RXN__ENTC-MONOMER': {},
#  'ISOCHORSYN-RXN__MENF-CPLX': {},
#  'RXN-9535__FABB-CPLX': {},
#  'RXN0-313__CPLX0-201 (reverse)': {},
#  'RXN0-384__H2NEOPTERINP3PYROPHOSPHOHYDRO-MONOMER': {},
#  'RXN0-5186__G7408-MONOMER': {},
#  'SERINE-O-ACETTRAN-RXN__CPLX0-237': {},
#  'SERINE-O-ACETTRAN-RXN__CYSSYNMULTI-CPLX': {},
#  'UNDECAPRENYL-DIPHOSPHATASE-RXN[CCO-CYTOSOL]-UNDECAPRENYL-DIPHOSPHATE/WATER//CPD-9646/Pi/PROTON.64.__PGPPHOSPHAB-MONOMER': {},
#  'URPHOS-RXN__URPHOS-CPLX': {},
#  'maintenance_reaction': {0: [('maintenance_reaction', 404)]}}

# %%
r['ptools-xml']['Reaction']['in-pathway']['Pathway']
# Out:
# [{'@resource': 'getxml?ECOLI:PWY0-1261',
#   '@orgid': 'ECOLI',
#   '@frameid': 'PWY0-1261'},
#  {'@resource': 'getxml?ECOLI:UDPNAGSYN-PWY',
#   '@orgid': 'ECOLI',
#   '@frameid': 'UDPNAGSYN-PWY'}]
