# %%
import polars as pl
import numpy as np
from matplotlib import pyplot as plt
import os
import json
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from scipy.sparse import csr_matrix
os.chdir(os.path.expanduser('~/vEcoli'))

# %%
def read_names(file_path):
    return np.genfromtxt(file_path, dtype=str, delimiter="\n")

def read_matrix(file_path, sparse=False):
    # add sparse matrix reading
    if sparse:
        return csr_matrix(pl.read_csv(file_path, has_header=False).to_numpy())
    else:
        return pl.read_csv(file_path, has_header=False).to_numpy()


Cmatrix = read_matrix("notebooks/mia_notebooks/C_matrix.csv", sparse=True)
complex_ids = list(read_names("notebooks/mia_notebooks/complex_ids.txt"))
monomer_ids = list(read_names("notebooks/mia_notebooks/monomer_ids.txt"))
# Ecocyc data (https://ecocyc.org/groups?tab=SPECIAL&orgid=ECOLI): 
ecocyc_data = pd.read_excel("notebooks/mia_notebooks/All_polypeptides_from_ecocyc_data.xlsx")
# validation data (https://www.sciencedirect.com/science/article/pii/S0092867414002323?via%3Dihub#app1):
validation_data = pd.read_excel("notebooks/mia_notebooks/data_from_li_et_al_2014.xlsx")

# %% [markdown]
# ## Minimal Media Conditions Comparison: Simulation data VS "MOPS minimal" data from Li et al., 2014

# %%
#todo figure out why this no longer works!! for some reason it appears the bulk data is missing things?
# time = '1300'
# date = '2024-04-29'
# experiment = 'validation_experiment'
# entry = f'{experiment}_{time}_{date}'
# folder = f'out/cofactors/{entry}/'

# %%
# new data from simulation on 2024-07-16
time = '1300'
date = '2024-07-16'
experiment = 'metabolism-redux-classic'
entry = f'{experiment}_{time}_{date}'
folder = f'out/cofactors/{entry}/'

# %%
output_all = np.load(folder + '0_output.npy',allow_pickle='TRUE').item()
# output = np.load(r"out/geneRxnVerifData/output_glc.npy", allow_pickle=True, encoding='ASCII').tolist()
output = output_all['agents']['0']
fba = output['listeners']['fba_results']
mass = output['listeners']['mass']
bulk = pl.DataFrame(output['bulk'])

fluxes = np.array(fba['estimated_fluxes'][1:])
exchanges = fba['estimated_exchange_dmdt']

ans = output['listeners']['unique_molecule_counts']['active_ribosome']

# %%
# So say I want to find the names of the proteins themselves, these are functions to implement that do so: 
# TODO ask cyrus about this 
initial_state = json.load(open('data/wcecoli_t0.json'))

bulk_ids = [item[0] for item in initial_state['bulk']]

bulk.columns = bulk_ids

# %%
bulk_ids
# Out:
# ['--TRANS-ACENAPHTHENE-12-DIOL[c]',
#  '1-6-Galactofuran[c]',
#  '1-ACYLGLYCEROL-3-P-ACYLTRANSFER-MONOMER[i]',
#  '1-AMINO-PROPAN-2-OL[c]',
#  '1-AMINO-PROPAN-2-ONE-3-PHOSPHATE[c]',
#  '1-CHLORO-24-DINITROBENZENE[c]',
#  '1-DEOXYXYLONOJIRIMYCIN[c]',
#  '1-ETHYLADENINE[c]',
#  '1-Hydroxy-2-oxolimonenes[c]',
#  '1-KETO-2-METHYLVALERATE[c]',
#  '1-PALMITOYLGLYCEROL-3-PHOSPHATE[c]',
#  '1-PFK[c]',
#  '1-PFK-MONOMER[c]',
#  '10-FORMYL-THF[c]',
#  '10-FORMYL-THF[p]',
#  '10-FORMYL-THF[e]',
#  '11-13-Eicosadienoates[c]',
#  '11-DEOXY-CORTISOL[c]',
#  '11-DEOXYCORTICOSTERONE[c]',
#  '11-HPODE[c]',
#  '11-Hydroxyjasmonates[c]',
#  '12-EPOXYPROPANE[c]',
#  '12-Epoxybutane[c]',
#  '12-Hydroxyjasmonate-Sulfates[c]',
#  '12-Hydroxyjasmonates[c]',
#  '15-ANHYDRO-D-GLUCITOL[c]',
#  '15-ANHYDRO-D-GLUCITOL[p]',
#  '15-ANHYDRO-D-GLUCITOL[e]',
#  '15-DIDEOXY-15-IMINO-D-GALACTITOL[c]',
#  '17-Alpha-Hydroxysteroids[c]',
#  '17-BETA-HYDROXYANDROSTAN-3-ONE[c]',
#  '17-DIAMINOHEPTANE[c]',
#  '17-beta-Hydroxysteroids[c]',
#  '2-3-Butanediols[c]',
#  '2-3-DIHYDROXYBENZOATE[c]',
#  '2-3-DIHYDROXYBENZOATE[p]',
#  '2-3-DIHYDROXYBENZOATE[e]',
#  '2-3-DIHYDROXYPHENYL-PROPIONATE[c]',
#  '2-3-DIHYDROXYPHENYL-PROPIONATE[p]',
#  '2-3-DIHYDROXYPHENYL-PROPIONATE[e]',
#  '2-3-dihydroxypropane-1-sulfonate[c]',
#  '2-5-TRIPHOSPHORIBOSYL-3-DEPHOSPHO-[c]',
#  '2-ACETO-2-HYDROXY-BUTYRATE[c]',
#  '2-ACETO-LACTATE[c]',
#  '2-ALPHA-HYDROXYETHYL-THPP[c]',
#  '2-AMINO-4-OXO-PENTOATE[c]',
#  '2-AMINOACRYLATE[c]',
#  '2-AMINOACRYLATE[p]',
#  '2-AMINOACRYLATE[e]',
#  '2-AMINOMALONATE-SEMIALDEHYDE[c]',
#  '2-AMINOMALONATE-SEMIALDEHYDE[p]',
#  '2-AMINOMALONATE-SEMIALDEHYDE[e]',
#  '2-Aminobutyrate[c]',
#  '2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE[c]',
#  '2-CARBOXYMUCONATE[c]',
#  '2-CARBOXYMUCONATE[p]',
#  '2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE[c]',
#  '2-DEHYDRO-3-DEOXY-D-GALACTONATE[c]',
#  '2-DEHYDRO-3-DEOXY-D-GLUCONATE[c]',
#  '2-DEHYDRO-3-DEOXY-D-GLUCONATE[p]',
#  '2-DEHYDROPANTOATE[c]',
#  '2-DEHYDROPANTOATE-REDUCT-MONOMER[c]',
#  '2-DEHYDROPANTOYL-LACTONE[c]',
#  '2-DEOXY-D-GLUCOSE[c]',
#  '2-DEOXY-D-GLUCOSE[p]',
#  '2-DEOXY-D-GLUCOSE-6-PHOSPHATE[c]',
#  '2-DEOXY-D-GLUCOSE-6-PHOSPHATE[p]',
#  '2-DEOXY-D-GLUCOSE-6-PHOSPHATE[e]',
#  '2-DEOXYGLUCOSE-6-PHOSPHATE[c]',
#  '2-DEOXYRIBOSE[c]',
#  '2-DH-3-DO-D-ARABINONATE[c]',
#  '2-Dehydropyranoses[c]',
#  '2-HYDROXY-2-METHYLPROPANENITRILE[c]',
#  '2-HYDROXYGLUTARIC_ACID[c]',
#  '2-Hydroxy-2-methylbutyronitriles[c]',
#  '2-ISOPROPYLMALATESYN-MONOMER[c]',
#  '2-KETO-3-DEOXY-6-P-GLUCONATE[c]',
#  '2-KETO-3-DEOXY-D-GLUCARATE[c]',
#  '2-KETO-3-METHYL-VALERATE[c]',
#  '2-KETO-3-METHYL-VALERATE[p]',
#  '2-KETO-3-METHYL-VALERATE[e]',
#  '2-KETO-GLUTARAMATE[c]',
#  '2-KETO-ISOVALERATE[c]',
#  '2-KETOGLUTARATE[c]',
#  '2-KETOGLUTARATE[p]',
#  '2-KETOGLUTARATE[e]',
#  '2-MERCAPTOETHANOL[c]',
#  '2-METHYLMALEATE[c]',
#  '2-O-ALPHA-MANNOSYL-D-GLYCERATE[c]',
#  '2-O-ALPHA-MANNOSYL-D-GLYCERATE[p]',
#  '2-OCTAPRENYL-6-HYDROXYPHENOL[c]',
#  '2-OCTAPRENYL-6-METHOXYPHENOL[c]',
#  '2-OCTAPRENYL-6-METHOXYPHENOL[p]',
#  '2-OCTAPRENYL-6-METHOXYPHENOL[e]',
#  '2-OCTAPRENYL-METHOXY-BENZOQ-METH-MONOMER[c]',
#  '2-OCTAPRENYLPHENOL[c]',
#  '2-OCTAPRENYLPHENOL-HYDROX-MONOMER[i]',
#  '2-OH-4-IPCH-1-carboxyl-CoA[c]',
#  '2-OXINDOLE-3-ACETYL-HEXOSE[c]',
#  '2-OXOBUTANOATE[c]',
#  '2-OXOBUTANOATE[p]',
#  '2-Oxo-4-IPCH-1-carboxyl-CoA[c]',
#  '2-PG[c]',
#  '2-PG[p]',
#  '2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET[c]',
#  '2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET[p]',
#  '2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET[e]',
#  '2-PROTOCATECHUOYLPHLOROGLUCINOLCARBOXYLA[c]',
#  '2-Phenyloxirane[c]',
#  '2-THIOURIDINE[c]',
#  '2-THIOURIDINE[p]',
#  '2-THIOURIDINE[e]',
#  '23-DIMERCAPTOPROPAN-1-OL[c]',
#  '23-DIPHOSPHOGLYCERATE[c]',
#  '23-Diaminopropanoate[c]',
#  '23-Didehydropyranoses[c]',
#  '23-PENTANEDIONE[c]',
#  '246-TRINITROBENZENE[c]',
#  '25-DIAMINOPENTANOATE[c]',
#  '25-DIDEHYDRO-D-GLUCONATE[c]',
#  '2C-METH-D-ERYTHRITOL-CYCLODIPHOSPHATE[c]',
#  '2K-4CH3-PENTANOATE[c]',
#  '2K-4CH3-PENTANOATE[p]',
#  '2K-4CH3-PENTANOATE[e]',
#  '2OXOGLUTARATEDEH-CPLX[c]',
#  '3-4-DIHYDROXYBENZOATE[c]',
#  '3-4-DIHYDROXYBENZOATE[p]',
#  '3-4-DIHYDROXYBENZOATE[e]',
#  '3-5-ADP[c]',
#  '3-5-ADP[p]',
#  '3-5-ADP[e]',
#  '3-AMINO-12-PROPANEDIOL[c]',
#  '3-AMINO-6-ACETAMIDOHEXANOATE[c]',
#  '3-AMINO-ISOBUTYRATE[c]',
#  '3-AMINOPROPYL-METHYL-PHOSPHINATE[c]',
#  '3-BETA-D-GLUCOSYLGLUCOSE[c]',
#  '3-BROMOPYRUVATE[c]',
#  '3-CARBOXY-3-HYDROXY-ISOCAPROATE[c]',
#  '3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-MONOMER[c]',
#  '3-CHLORO-D-ALANINE[c]',
#  '3-CHLORO-D-ALANINE[p]',
#  '3-CHLORO-D-ALANINE[e]',
#  '3-CHLORO-DL-ALANINE[c]',
#  '3-DEHYDRO-SHIKIMATE[c]',
#  '3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P[c]',
#  '3-Dehydro-D-Glucopyranose[c]',
#  '3-Dehydropyranoses[c]',
#  '3-ENOLPYRUVYL-SHIKIMATE-5P[c]',
#  '3-ETHYLCATECHOL[c]',
#  '3-ETHYLCATECHOL[p]',
#  '3-ETHYLCATECHOL[e]',
#  '3-HYDROXY-BUTYRATE[c]',
#  '3-HYDROXY-ISOBUTYRATE[c]',
#  '3-HYDROXY-ISOBUTYRYL-COA[c]',
#  '3-HYDROXY-PROPIONATE[c]',
#  '3-HYDROXY-PROPIONATE[p]',
#  '3-HYDROXYADIPYL-COA[c]',
#  '3-HYDROXYBENZOATE[c]',
#  '3-HYDROXYBENZOATE[p]',
#  '3-HYDROXYBENZOATE[e]',
#  '3-HYDROXYPHENYL-PROPIONATE[c]',
#  '3-HYDROXYPHENYL-PROPIONATE[p]',
#  '3-HYDROXYPHENYL-PROPIONATE[e]',
#  '3-HYDROXYPHENYLACETATE[c]',
#  '3-HYDROXYPHENYLACETATE[p]',
#  '3-HYDROXYPHENYLACETATE[e]',
#  '3-HYDROXYPHENYLACETYL-COA[c]',
#  '3-Hydroxy-11-cis-retinal[c]',
#  '3-Hydroxy-11-cis-retinol[c]',
#  '3-Hydroxy-L-aspartate[c]',
#  '3-Hydroxybutanoyl-CoAs[c]',
#  '3-ISOPROPYLMALDEHYDROG-CPLX[c]',
#  '3-ISOPROPYLMALDEHYDROG-MONOMER[c]',
#  '3-ISOPROPYLMALISOM-CPLX[c]',
#  '3-Isopropenyl-4H-hexano-lactones[c]',
#  '3-Isopropenyl-6-oxoheptanoates[c]',
#  '3-KETO-ADIPYL-COA[c]',
#  '3-KETO-L-GULONATE[c]',
#  '3-KETOBUTYRATE[c]',
#  '3-KETOBUTYRATE[p]',
#  '3-Ketomaltose[c]',
#  '3-MERCAPTO-PYRUVATE[c]',
#  '3-METHYL-2-OXOBUT-OHCH3XFER-CPLX[c]',
#  '3-METHYL-CROTONYL-COA[c]',
#  '3-Methyl-Adenines[c]',
#  '3-NITROBENZALDEHYDE[c]',
#  '3-OCTAPRENYL-4-HYDROXYBENZOATE[c]',
#  '3-OXOACYL-ACP-REDUCT-MONOMER[c]',
#  '3-OXOACYL-ACP-SYNTHII-CPLX[c]',
#  '3-OXOACYL-ACP-SYNTHII-MONOMER[c]',
#  '3-OXOPALMITOYL-COA[c]',
#  '3-Oxosteroyl-CoA[c]',
#  '3-P-HYDROXYPYRUVATE[c]',
#  '3-P-SERINE[c]',
#  '3-P-SERINE[p]',
#  '3-P-SERINE[e]',
#  '3-PHENYLPROPIONATE[c]',
#  '3-PHENYLPROPIONATE[p]',
#  '3-PHENYLPROPIONATE[e]',
#  '3-SULFINOALANINE[c]',
#  '3-SULFINOALANINE[p]',
#  '3-SULFINOALANINE[e]',
#  '3-oxo-D-glucose-6-phosphate[c]',
#  '34-DIHYDROXYPHENYLACETALDEHYDE[c]',
#  '34-DIHYDROXYPHENYLACETYL-COA[c]',
#  '34-DIHYDROXYPHENYLPYRUVATE[c]',
#  '34-DIHYDROXYPHENYLPYRUVATE[p]',
#  '34-DIHYDROXYPHENYLPYRUVATE[e]',
#  '3FE-4S[c]',
#  '3OH-4P-OH-ALPHA-KETOBUTYRATE[c]',
#  '3alpha-hydroxysteroyl-CoA[c]',
#  '4-AMINO-4-DEOXY-L-ARABINOSE[c]',
#  '4-AMINO-4-DEOXY-L-ARABINOSE[p]',
#  '4-AMINO-4-DEOXY-L-ARABINOSE[e]',
#  '4-AMINO-4-DEOXYCHORISMATE[c]',
#  '4-AMINO-BUTYRALDEHYDE[c]',
#  '4-AMINO-BUTYRALDEHYDE[p]',
#  '4-AMINO-BUTYRALDEHYDE[e]',
#  '4-AMINO-BUTYRATE[c]',
#  '4-AMINO-BUTYRATE[p]',
#  '4-AMINO-BUTYRATE[e]',
#  '4-CARBOXYBENZALDEHYDE[c]',
#  '4-CYTIDINE-5-DIPHOSPHO-2-C[c]',
#  '4-CYTIDINE-5-DIPHOSPHO-2-C[p]',
#  '4-CYTIDINE-5-DIPHOSPHO-2-C[e]',
#  '4-HYDROXY-2-KETOVALERATE[c]',
#  '4-HYDROXY-BENZYL-ALCOHOL[c]',
#  '4-HYDROXY-BENZYL-ALCOHOL[p]',
#  '4-HYDROXY-BENZYL-ALCOHOL[e]',
#  '4-HYDROXY-BUTYRATE[c]',
#  '4-HYDROXY-BUTYRATE[p]',
#  '4-HYDROXY-BUTYRATE[e]',
#  '4-HYDROXY-L-PROLINE[c]',
#  '4-HYDROXY-L-PROLINE[p]',
#  '4-HYDROXY-L-PROLINE[e]',
#  '4-HYDROXYBENZALDEHYDE[c]',
#  '4-HYDROXYMANDELATE[c]',
#  '4-HYDROXYPHENYLACETATE[c]',
#  '4-HYDROXYPHENYLACETATE[p]',
#  '4-HYDROXYPHENYLACETATE[e]',
#  '4-HYDROXYPHENYLACETYL-COA[c]',
#  '4-HYDROXYPHENYLLACTATE[c]',
#  '4-Hydroxysphing-8-enine-20-1-Ceramides[c]',
#  '4-Hydroxysphing-8-enine-22-0-Ceramides[c]',
#  '4-Hydroxysphing-8-enine-26-0-Ceramides[c]',
#  '4-Isopropenyl-Pimelyl-CoA[c]',
#  '4-NITROANILINE[c]',
#  '4-NITROANILINE[p]',
#  '4-OXALOMESACONATE[c]',
#  '4-P-PANTOTHENATE[c]',
#  '4-PHOSPHONOOXY-THREONINE[c]',
#  '4-hydroxybenzoate[c]',
#  '4-hydroxybenzoate[p]',
#  '4-hydroxybenzoate[e]',
#  '4-isopropenyl-7-methyloxepan-2-one[c]',
#  '4FE-4S[c]',
#  '4Fe-2O-2S-Cluster[c]',
#  '4OHBENZOATE-OCTAPRENYLTRANSFER-MONOMER[i]',
#  '4R-Limonene-1-2-epoxides[c]',
#  '4S-limonene-1-2-epoxides[c]',
#  '5-10-METHENYL-THF[c]',
#  '5-10-METHENYL-THF[p]',
#  '5-10-METHENYL-THF[e]',
#  '5-AMINO-5-DEOXY-D-GALACTOPYRANOSIDE[c]',
#  '5-AMINO-LEVULINATE[c]',
#  '5-AMINOPENTANOATE[c]',
#  '5-AMINOPENTANOATE[p]',
#  '5-AMINOPENTANOATE[e]',
#  '5-BETA-L-THREO-PENTAPYRANOSYL-4-ULOSE-[c]',
#  '5-BETA-L-THREO-PENTAPYRANOSYL-4-ULOSE-[p]',
#  '5-BETA-L-THREO-PENTAPYRANOSYL-4-ULOSE-[e]',
#  '5-CHLOROFORMYCIN[c]',
#  '5-DEHYDROGLUCONATE[c]',
#  '5-DEHYDROGLUCONATE[p]',
#  '5-ETHYLTHIOADENOSINE[c]',
#  '5-FORMYL-THF[c]',
#  '5-FORMYL-THF[p]',
#  '5-FORMYL-THF[e]',
#  '5-HYDROXY-CTP[c]',
#  '5-HYDROXY-CTP[p]',
#  '5-HYDROXY-CTP[e]',
#  '5-HYDROXY-L-LYSINE[c]',
#  '5-HYDROXY-PIPECOLATE[c]',
#  '5-HYDROXYISOURATE[c]',
#  '5-HYDROXYISOURATE[p]',
#  '5-IODOPENTAPHOSPHONATE[c]',
#  '5-IODOPENTAPHOSPHONATE[p]',
#  '5-IODOPENTAPHOSPHONATE[e]',
#  '5-KETO-4-DEOXY-D-GLUCARATE[c]',
#  '5-METHYL-DL-TRYPTOPHAN[c]',
#  '5-METHYL-DL-TRYPTOPHAN[p]',
#  '5-METHYL-DL-TRYPTOPHAN[e]',
#  '5-METHYL-THF[c]',
#  '5-METHYL-THF[p]',
#  '5-METHYL-THF[e]',
#  '5-METHYLAMINOMETHYL-2-SELENOURIDINE[c]',
#  '5-METHYLAMINOMETHYL-2-SELENOURIDINE[p]',
#  '5-METHYLAMINOMETHYL-2-SELENOURIDINE[e]',
#  '5-METHYLAMINOMETHYL-2-THIOURIDINE[c]',
#  '5-METHYLAMINOMETHYL-2-THIOURIDINE[p]',
#  '5-METHYLAMINOMETHYL-2-THIOURIDINE[e]',
#  '5-METHYLTHIOADENOSINE[c]',
#  '5-METHYLTHIOADENOSINE[p]',
#  '5-METHYLTHIOADENOSINE[e]',
#  '5-METHYLTHIOFORMYCIN[c]',
#  '5-METHYLTHIOTUBERCIDIN[c]',
#  '5-N-PROPYLTHIOADENOSINE[c]',
#  '5-OXOPROLINE[c]',
#  '5-P-BETA-D-RIBOSYL-AMINE[c]',
#  '5-P-NITROPHENYLTHIOADENOSINE[c]',
#  '5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE[c]',
#  '5-PHOSPHO-RIBOSYL-GLYCINEAMIDE[c]',
#  '5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE[c]',
#  '5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE[p]',
#  '5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE[e]',
#  '5-PHOSPHORIBOSYL-N-FORMYLGLYCINEAMIDINE[c]',
#  '5678-TETRAHYDROPTERIDINE[c]',
#  '6-7-Dihydrobiopterins[c]',
#  '6-AMINOPENICILLANATE[c]',
#  '6-AMINOPENICILLANATE[p]',
#  '6-AMINOPENICILLANATE[e]',
#  '6-H-5-I-2-methylhexanoates[c]',
#  '6-Hydroxy-3-isopropenylheptanoates[c]',
#  '6-Hydroxy-37-dimethyloctanoate[c]',
#  '6-Hydroxy-Purine-Nucleotides[c]',
#  '6-PYRUVOYL-5678-TETRAHYDROPTERIN[c]',
#  '6-PYRUVOYL-5678-TETRAHYDROPTERIN[p]',
#  '6-PYRUVOYL-5678-TETRAHYDROPTERIN[e]',
#  '6-SELENO-OCTANOATE[c]',
#  '6-THIO-OCTANOATE[c]',
#  '6-isopropenyl-3-methyloxepan-2-one[c]',
#  '6PFK-1-CPX[c]',
#  '6PFK-1-MONOMER[c]',
#  '6PFK-2-CPX[c]',
#  '6PFK-2-MONOMER[c]',
#  '6PGLUCONDEHYDROG-CPLX[c]',
#  '6PGLUCONDEHYDROG-MONOMER[c]',
#  '6PGLUCONOLACT-MONOMER[c]',
#  '6R-6-FLUORO-EPSP[c]',
#  '6S-6-FLUORO-EPSP[c]',
#  '6S-Carveols[c]',
#  '6S-RNA[c]',
#  '7-8-DIHYDROPTEROATE[c]',
#  '7-8-DIHYDROPTEROATE[p]',
#  '7-8-DIHYDROPTEROATE[e]',
#  '7-8-Dihydroneopterins[c]',
#  '7-ALPHA-HYDROXYSTEROID-DEH-CPLX[c]',
#  '7-ALPHA-HYDROXYSTEROID-DEH-MONOMER[c]',
#  '7-AMINOMETHYL-7-DEAZAGUANINE[c]',
#  '7-AMINOMETHYL-7-DEAZAGUANINE[p]',
#  '7-AMINOMETHYL-7-DEAZAGUANINE[e]',
#  '7-CYANO-7-DEAZAGUANINE[c]',
#  '7-CYANO-7-DEAZAGUANINE[p]',
#  '7-Deazapurines[c]',
#  '7-METHYLGUANOSINE-5-PHOSPHATE[c]',
#  '7-isopropyl-4-methyloxepan-2-ones[c]',
#  '78-dihydrobiopterins[c]',
#  '7KAPSYN-CPLX[c]',
#  '7KAPSYN-MONOMER[c]',
#  '8-AMINO-7-OXONONANOATE[c]',
#  '8-HYDROXYQUINOLINE[c]',
#  '8-Oxo-dGTP[c]',
#  '8-Oxo-dGTP[p]',
#  '8-Oxo-dGTP[e]',
#  '8-SELENO-OCTANOATE[c]',
#  '8-THIO-OCTANOATE[c]',
#  '8-hydroxy-dADP[c]',
#  '8-hydroxy-dADP[p]',
#  '8-hydroxy-dADP[e]',
#  '8-hydroxy-dGTP[c]',
#  '8-hydroxy-dGTP[p]',
#  '8-hydroxy-dGTP[e]',
#  '8-oxo-dADP[c]',
#  '8-oxo-dADP[p]',
#  '8-oxo-dADP[e]',
#  'A-Clusters[c]',
#  'A-GLUCOSYLOXYANTHRAQUINONE[c]',
#  'AAS-MONOMER[i]',
#  'ABC-10-CPLX[i]',
#  'ABC-11-CPLX[i]',
#  'ABC-12-CPLX[i]',
#  'ABC-13-CPLX[i]',
#  'ABC-14-CPLX[i]',
#  'ABC-15-CPLX[i]',
#  'ABC-16-CPLX[m]',
#  'ABC-18-CPLX[i]',
#  'ABC-19-CPLX[i]',
#  'ABC-2-CPLX[m]',
#  'ABC-20-CPLX[i]',
#  'ABC-21-CPLX[i]',
#  'ABC-22-CPLX[i]',
#  'ABC-23-CPLX[i]',
#  'ABC-24-CPLX[i]',
#  'ABC-25-CPLX[i]',
#  'ABC-26-CPLX[m]',
#  'ABC-27-CPLX[i]',
#  'ABC-28-CPLX[m]',
#  'ABC-29-CPLX[i]',
#  'ABC-3-CPLX[i]',
#  'ABC-304-CPLX[i]',
#  'ABC-32-CPLX[i]',
#  'ABC-33-CPLX[i]',
#  'ABC-34-CPLX[m]',
#  'ABC-35-CPLX[i]',
#  'ABC-4-CPLX[i]',
#  'ABC-40-CPLX[i]',
#  'ABC-41-CPLX[i]',
#  'ABC-42-CPLX[i]',
#  'ABC-45-CPLX[i]',
#  'ABC-46-CPLX[i]',
#  'ABC-48-CPLX[i]',
#  'ABC-49-CPLX[i]',
#  'ABC-5-CPLX[m]',
#  'ABC-51-CPLX[i]',
#  'ABC-52-CPLX[i]',
#  'ABC-54-CPLX[o]',
#  'ABC-55-CPLX[i]',
#  'ABC-56-CPLX[i]',
#  'ABC-57-CPLX[i]',
#  'ABC-58-CPLX[i]',
#  'ABC-59-CPLX[i]',
#  'ABC-6-CPLX[i]',
#  'ABC-60-CPLX[i]',
#  'ABC-61-CPLX[i]',
#  'ABC-62-CPLX[i]',
#  'ABC-63-CPLX[i]',
#  'ABC-64-CPLX[i]',
#  'ABC-7-CPLX[i]',
#  'ABC-70-CPLX[i]',
#  'ABC-8-CPLX[i]',
#  'ABC-9-CPLX[i]',
#  'ABC-MONOMER[m]',
#  'ABGT-MONOMER[i]',
#  'ACET[c]',
#  'ACET[p]',
#  'ACET[e]',
#  'ACETALD[c]',
#  'ACETALD[p]',
#  'ACETALD[e]',
#  'ACETAMIDE[c]',
#  'ACETAMIDE[p]',
#  'ACETAMIDE[e]',
#  'ACETATEKINA-MONOMER[c]',
#  'ACETOACETYL-COA[c]',
#  'ACETOACETYL-COA-TRANSFER-CPLX[c]',
#  'ACETOIN[c]',
#  'ACETOL[c]',
#  'ACETOLACTSYNI-CPLX[c]',
#  'ACETOLACTSYNII-CPLX[c]',
#  'ACETOLACTSYNIII-CPLX[c]',
#  'ACETOLACTSYNIII-HCHAIN-MONOMER[c]',
#  'ACETOLACTSYNIII-ICHAIN-MONOMER[c]',
#  'ACETYL-COA[c]',
#  'ACETYL-COA-ACETYLTRANSFER-CPLX[c]',
#  'ACETYL-COA-ACETYLTRANSFER-MONOMER[c]',
#  'ACETYL-COA-CARBOXYLTRANSFER-CPLX[c]',
#  'ACETYL-D-GLUCOSAMINYLDIPHOSPHO-UNDECAPRE[c]',
#  'ACETYL-D-GLUCOSAMINYLDIPHOSPHO-UNDECAPRE[p]',
#  'ACETYL-D-GLUCOSAMINYLDIPHOSPHO-UNDECAPRE[e]',
#  'ACETYL-GLU[c]',
#  'ACETYL-GLU[p]',
#  'ACETYL-GLU[e]',
#  'ACETYL-P[c]',
#  'ACETYLGLUTKIN-CPLX[c]',
#  'ACETYLGLUTKIN-MONOMER[c]',
#  'ACETYLMALTOSE[c]',
#  'ACETYLMALTOSE[e]',
#  'ACETYLMURAMYL-ALANYL-ISOGLUTAMINE[c]',
#  'ACETYLMURAMYL-ALANYL-ISOGLUTAMINE[p]',
#  'ACETYLMURAMYL-ALANYL-ISOGLUTAMINE[e]',
#  'ACETYLORNDEACET-CPLX[c]',
#  'ACETYLORNDEACET-MONOMER[c]',
#  'ACETYLORNTRANSAM-CPLX[c]',
#  'ACETYLORNTRANSAM-MONOMER[c]',
#  'ACETYLSERINE[c]',
#  'ACETYLSERINE[p]',
#  'ACETYLSERINE[e]',
#  'ACNEULY-CPLX[c]',
#  'ACNEULY-MONOMER[c]',
#  'ACONITASE-MONOMER[c]',
#  'ACONITATEDEHYDRB-MONOMER[c]',
#  'ACPSUB-MONOMER[c]',
#  'ACRB-MONOMER[m]',
#  'ACRD-MONOMER[i]',
#  'ACRF-MONOMER[m]',
#  'ACRYLYL-COA[c]',
#  'ACS-MONOMER[c]',
#  'ACSERLYA-CPLX[c]',
#  'ACSERLYA-MONOMER[c]',
#  'ACSERLYB-CPLX[c]',
#  'ACSERLYB-MONOMER[c]',
#  'ACYLCOADEHYDROG-MONOMER[c]',
#  'ACYLCOASYN-CPLX[c]',
#  'ACYLCOASYN-MONOMER[c]',
#  'ADCLY-CPLX[c]',
#  'ADCLY-MONOMER[c]',
#  'ADENINE[c]',
#  'ADENINE[p]',
#  'ADENINE[e]',
#  'ADENINE-RING[c]',
#  'ADENODEAMIN-MONOMER[c]',
#  'ADENOSINE[c]',
#  'ADENOSINE[p]',
#  'ADENOSINE[e]',
#  'ADENOSINE5TRIPHOSPHO5ADENOSINE[c]',
#  'ADENOSINE5TRIPHOSPHO5ADENOSINE[p]',
#  'ADENOSINE5TRIPHOSPHO5ADENOSINE[e]',
#  'ADENOSINE_DIPHOSPHATE_RIBOSE[c]',
#  'ADENOSINE_DIPHOSPHATE_RIBOSE[p]',
#  'ADENOSINE_DIPHOSPHATE_RIBOSE[e]',
#  'ADENOSYL-HOMO-CYS[c]',
#  'ADENOSYL-HOMO-CYS[p]',
#  'ADENOSYL-HOMO-CYS[e]',
#  'ADENOSYL-P4[c]',
#  'ADENOSYL-P4[p]',
#  'ADENOSYL-P4[e]',
#  'ADENOSYLCOBALAMIN[c]',
#  'ADENOSYLCOBALAMIN[p]',
#  'ADENOSYLCOBALAMIN[e]',
#  'ADENOSYLCOBALAMIN-5-P[c]',
#  'ADENOSYLCOBALAMIN-5-P[p]',
#  'ADENOSYLCOBALAMIN-5-P[e]',
#  'ADENOSYLCOBINAMIDE[c]',
#  'ADENOSYLCOBINAMIDE[p]',
#  'ADENOSYLCOBINAMIDE[e]',
#  'ADENOSYLCOBINAMIDE-GDP[c]',
#  'ADENOSYLCOBINAMIDE-P[c]',
#  'ADENPRIBOSYLTRAN-CPLX[c]',
#  'ADENPRIBOSYLTRAN-MONOMER[c]',
#  'ADENYL-KIN-MONOMER[c]',
#  'ADENYLATECYC-MONOMER[c]',
#  'ADENYLOSUCC[c]',
#  'ADENYLOSUCC[p]',
#  'ADENYLOSUCC[e]',
#  'ADENYLOSUCCINATE-SYN-DIMER[c]',
#  'ADENYLOSUCCINATE-SYN-MONOMER[c]',
#  'ADENYLYLSULFKIN-CPLX[c]',
#  'ADENYLYLSULFKIN-MONOMER[c]',
#  'ADHC-CPLX[c]',
#  'ADHC-MONOMER[c]',
#  'ADHE-CPLX[c]',
#  'ADHE-MONOMER[c]',
#  'ADHP-MONOMER[c]',
#  'ADIPATE[c]',
#  'ADIPATE[p]',
#  'ADIPATE[e]',
#  'ADP[c]',
#  'ADP[p]',
#  'ADP-D-GLUCOSE[c]',
#  'ADP-D-GLUCOSE[p]',
#  'ADP-D-GLUCOSE[e]',
#  'ADP-D-GLYCERO-D-MANNO-HEPTOSE[c]',
#  'ADP-D-GLYCERO-D-MANNO-HEPTOSE[p]',
#  'ADP-D-GLYCERO-D-MANNO-HEPTOSE[e]',
#  'ADP-GROUP[c]',
#  'ADP-L-GLYCERO-D-MANNO-HEPTOSE[c]',
#  'ADP-L-GLYCERO-D-MANNO-HEPTOSE[p]',
#  'ADP-L-GLYCERO-D-MANNO-HEPTOSE[e]',
#  'ADP-MANNOSE[c]',
#  'ADP-MANNOSE[p]',
#  'ADP-MANNOSE[e]',
#  'AERGLYC3PDEHYDROG-CPLX[i]',
#  'AERGLYC3PDEHYDROG-MONOMER[i]',
#  'AG+[c]',
#  'AG+[p]',
#  'AG+[e]',
#  'AGAA-MONOMER[c]',
#  'AGAB-MONOMER[c]',
#  'AGAC-MONOMER[i]',
#  'AGAD-MONOMER[i]',
#  'AGAX-MONOMER[m]',
#  'AGMATHINE[c]',
#  'AGMATHINE[p]',
#  'AGMATHINE[e]',
#  'AGMATIN-CPLX[c]',
#  'AGMATIN-MONOMER[c]',
#  'AICAR[c]',
#  'AICAR[p]',
#  'AICAR[e]',
#  'AICARTRANSIMPCYCLO-CPLX[c]',
#  'AIRS-CPLX[c]',
#  'AIRS-MONOMER[c]',
#  'AKBLIG-CPLX[c]',
#  'AKBLIG-MONOMER[c]',
#  'ALA-GLY[c]',
#  'ALA-GLY[p]',
#  'ALA-GLY[e]',
#  'ALARACEBIOSYN-MONOMER[c]',
#  'ALARACECAT-MONOMER[c]',
#  'ALAS-CPLX[c]',
#  'ALAS-MONOMER[c]',
#  'ALBENDAZOLE-S-OXIDE[c]',
#  'ALD-CPLX[c]',
#  'ALDDEHYDROGB-MONOMER[c]',
#  'ALDHDEHYDROG-MONOMER[c]',
#  'ALDOSE1EPIM-MONOMER[c]',
#  'ALKAPHOSPHA-CPLX[p]',
#  'ALKAPHOSPHA-MONOMER[p]',
#  'ALL-TRANS-HEPTAPRENYL-DIPHOSPHATE[c]',
#  'ALL-TRANS-HEXAPRENYL-DIPHOSPHATE[c]',
#  'ALL-TRANS-PENTAPRENYL-DIPHOSPHATE[c]',
#  'ALLANTOATE[c]',
#  'ALLANTOATE[p]',
#  'ALLANTOATE[e]',
#  'ALLANTOIN[c]',
#  'ALLANTOIN[p]',
#  'ALLO-THR[c]',
#  'ALLOLACTOSE[c]',
#  'ALLOLACTOSE[p]',
#  'ALLOLACTOSE[e]',
#  'ALPHA-AMYL-CYTO-MONOMER[c]',
#  'ALPHA-AMYL-PERI-MONOMER[p]',
#  'ALPHA-D-GALACTOSE[c]',
#  'ALPHA-D-GALACTOSE[p]',
#  'ALPHA-D-GALACTOSE[e]',
#  'ALPHA-D-MANNOSYL-3-PHOSPHOGLYCERATE[c]',
#  'ALPHA-D-MANNOSYLCHITOBIO[c]',
#  'ALPHA-GLC-6-P[c]',
#  'ALPHA-GLC-6-P[p]',
#  'ALPHA-GLC-6-P[e]',
#  'ALPHA-GLUCOSE[c]',
#  'ALPHA-GLUCOSE[p]',
#  'ALPHA-GLUCOSE[e]',
#  'ALPHA-GLUCOSE-16-BISPHOSPHATE[c]',
#  'ALPHA-METHYLMETHIONINE[c]',
#  'ALPHA-NAPHTHYL-ACETATE[c]',
#  'ALPHA-RIBAZOLE[c]',
#  'ALPHA-RIBAZOLE-5-P[c]',
#  'ALPHA-SUBUNIT-CPLX[m]',
#  'ALPHACOMP-MONOMER[c]',
#  'ALPHAGALACTOSID-CPLX[c]',
#  'ALPHAGALACTOSID-MONOMER[c]',
#  'ALTRO-OXIDOREDUCT-MONOMER[c]',
#  'ALTRODEHYDRAT-MONOMER[c]',
#  'AMINEOXID-CPLX[p]',
#  'AMINEOXID-MONOMER[p]',
#  'AMINO-ACETONE[c]',
#  'AMINO-ACETONE[p]',
#  'AMINO-GROUP[c]',
#  'AMINO-HYDROXYMETHYL-METHYL-PYR-P[c]',
#  'AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP[c]',
#  'AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE[c]',
#  'AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE[p]',
#  'AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE[e]',
#  'AMINO-OXOBUT[c]',
#  'AMINO-OXOBUT[p]',
#  'AMINO-OXOBUT[e]',
#  'AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE[c]',
#  'AMINOMALONATE[c]',
#  'AMINOMALONATE[p]',
#  'AMINOMALONATE[e]',
#  'AMMONIA[c]',
#  'AMMONIA[e]',
#  'AMMONIA[p]',
#  'AMMONIUM[c]',
#  'AMMONIUM[p]',
#  'AMMONIUM[e]',
#  'AMP[c]',
#  'AMP[p]',
#  'AMP[e]',
#  'AMP-GROUP[c]',
#  'AMP-LYSINE[c]',
#  'AMP-LYSINE[p]',
#  'AMP-LYSINE[e]',
#  'AMP-NUCLEOSID-CPLX[c]',
#  'AMP-NUCLEOSID-MONOMER[c]',
#  'AMPG-MONOMER[i]',
#  'AMTB-MONOMER[m]',
#  'AMYLOMALT-MONOMER[c]',
#  'ANDROSTAN-3-ALPHA17-BETA-DIOL[c]',
#  'ANGLYC3PDEHYDROG-CPLX[i]',
#  'ANGLYC3PDEHYDROGSUBUNITA-MONOMER[c]',
#  'ANGLYC3PDEHYDROGSUBUNITB-MONOMER[c]',
#  'ANGLYC3PDEHYDROGSUBUNITC-MONOMER[i]',
#  'ANSA-CPLX[c]',
#  'ANSA-MONOMER[c]',
#  'ANSB-CPLX[p]',
#  'ANSB-MONOMER[p]',
#  'ANSP-MONOMER[i]',
#  'ANTHRANILATE[c]',
#  'ANTHRANILATE[p]',
#  'ANTHRANILATE[e]',
#  'ANTHRANSYN-CPLX[c]',
#  'ANTHRANSYNCOMPI-MONOMER[c]',
#  'ANTHRANSYNCOMPII-MONOMER[c]',
#  'ANTIMONITE[c]',
#  'ANTIMONITE[p]',
#  'ANTIMONITE[e]',
#  'APHA-CPLX[p]',
#  'APHA-MONOMER[p]',
#  'APORNAP-CPLX[c]',
#  'APP-UBIOX-CPLX[o]',
#  'APPA-MONOMER[p]',
#  'APPB-MONOMER[i]',
#  'APPC-MONOMER[i]',
#  'APS[c]',
#  'AQPZ-MONOMER[i]',
#  'ARABINOSE[c]',
#  'ARABINOSE[p]',
#  'ARABINOSE[e]',
#  'ARABINOSE-5P[c]',
#  'ARABINOSE-5P[p]',
#  'ARABINOSE-5P[e]',
#  'ARABISOM-CPLX[c]',
#  'ARABISOM-MONOMER[c]',
#  'ARAE-MONOMER[i]',
#  'ARAF-MONOMER[p]',
#  'ARAG-MONOMER[c]',
#  'ARAH-MONOMER[m]',
#  'ARAJ-MONOMER[i]',
#  'ARCA-MONOMER[c]',
#  'ARCB-CPLX[i]',
#  'ARCB-MONOMER[i]',
#  'ARCB-OXYGEN-CPLX[i]',
#  'ARCD-MONOMER[m]',
#  'ARG[c]',
#  'ARG[p]',
#  'ARG[e]',
#  'ARGDECARBOXBIO-CPLX[p]',
#  'ARGDECARBOXBIO-MONOMER[p]',
#  'ARGDECARBOXDEG-CPLX[c]',
#  'ARGDECARBOXDEG-MONOMER[c]',
#  'ARGS-MONOMER[c]',
#  'ARGSUCCINLYA-MONOMER[c]',
#  'ARGSUCCINSYN-MONOMER[c]',
#  'ARGSUCCTRAN-MONOMER[c]',
#  'ARGT-MONOMER[p]',
#  'AROA-MONOMER[c]',
#  'AROB-MONOMER[c]',
#  'AROC-CPLX[c]',
#  'AROC-MONOMER[c]',
#  'AROD-CPLX[c]',
#  'AROD-MONOMER[c]',
#  'AROE-MONOMER[c]',
#  'AROF-CPLX[c]',
#  'AROF-MONOMER[c]',
#  'AROG-CPLX[c]',
#  'AROG-MONOMER[c]',
#  'AROH-CPLX[c]',
#  'AROH-MONOMER[c]',
#  'AROK-MONOMER[c]',
#  'AROL-MONOMER[c]',
#  'AROP-MONOMER[i]',
#  'ARSENATE[c]',
#  'ARSENATE[p]',
#  'ARSENATE[e]',
#  'ARSF-MONOMER[i]',
#  'ARTI-MONOMER[p]',
#  'ARTJ-MONOMER[p]',
#  'ARTM-MONOMER[i]',
#  'ARTP-MONOMER[i]',
#  'ARTQ-MONOMER[i]',
#  'ARYLSULFAT-MONOMER[p]',
#  'AS+5[c]',
#  'AS+5[p]',
#  'AS+5[e]',
#  'ASCF-MONOMER[i]',
#  'ASCORBATE[c]',
#  'ASCORBATE[p]',
#  'ASL-MONOMER[c]',
#  'ASN[c]',
#  'ASN[p]',
#  'ASN[e]',
#  'ASNS-CPLX[c]',
#  'ASNS-MONOMER[c]',
#  'ASNSYNA-CPLX[c]',
#  'ASNSYNA-MONOMER[c]',
#  'ASNSYNB-CPLX[c]',
#  'ASNSYNB-MONOMER[c]',
#  'ASP-SEMIALDEHYDE-DEHYDROGENASE-CPLX[c]',
#  'ASP-SEMIALDEHYDE-DEHYDROGENASE-MONOMER[c]',
#  'ASPAMINOTRANS-DIMER[c]',
#  'ASPAMINOTRANS-MONOMER[c]',
#  'ASPARTASE-CPLX[c]',
#  'ASPARTASE-MONOMER[c]',
#  'ASPCARBCAT-MONOMER[c]',
#  'ASPCARBCAT-TRIMER[c]',
#  'ASPCARBREG-DIMER[c]',
#  'ASPCARBREG-MONOMER[c]',
#  'ASPCARBTRANS-CPLX[c]',
#  'ASPDECARBOX-MONOMER[c]',
#  'ASPKINIHOMOSERDEHYDROGI-CPLX[c]',
#  'ASPKINIHOMOSERDEHYDROGI-MONOMER[c]',
#  'ASPKINIIHOMOSERDEHYDROGII-CPLX[c]',
#  'ASPKINIIHOMOSERDEHYDROGII-MONOMER[c]',
#  'ASPKINIII-CPLX[c]',
#  'ASPKINIII-MONOMER[c]',
#  'ASPS-CPLX[c]',
#  'ASPS-MONOMER[c]',
#  'ATABRINE[c]',
#  'ATOA-CPLX[c]',
#  'ATOA-MONOMER[c]',
#  'ATOC-MONOMER[c]',
#  'ATOD-CPLX[c]',
#  'ATOD-MONOMER[c]',
#  'ATOS-MONOMER[i]',
#  'ATP[c]',
#  'ATP[p]',
#  'ATP[e]',
#  'ATPA-CPLX[m]',
#  'ATPA-MONOMER[m]',
#  'ATPASE-1-CPLX[i]',
#  'ATPB-MONOMER[i]',
#  'ATPC-MONOMER[m]',
#  'ATPD-CPLX[m]',
#  'ATPD-MONOMER[m]',
#  'ATPE-CPLX[m]',
#  'ATPE-MONOMER[m]',
#  'ATPF-CPLX[m]',
#  'ATPF-MONOMER[m]',
#  'ATPG-MONOMER[m]',
#  'ATPH-MONOMER[m]',
#  'ATPPHOSRIBOSTRANS-MONOMER[c]',
#  'ATPSYN-CPLX[i]',
#  'ATROPINE[c]',
#  'Aldehydo-D-altrose[c]',
#  'Aldehydo-D-altrose[p]',
#  'Aldehydo-D-altrose[e]',
#  'Aldopyranoses[c]',
#  'All-Biopterines[c]',
#  'All-trans-3-hydroxyretinal[c]',
#  'All-trans-3-hydroxyretinol[c]',
#  'Alpha-Hexose-1-Phosphates[c]',
#  'Alpha-lactose[c]',
#  'Alpha-lactose[p]',
#  'Alpha-lactose[e]',
#  'Alpha-pinene[c]',
#  'Anthraquinones[c]',
#  'Arabinofuranoses[c]',
#  'Arabinopyranoses[c]',
#  'B-ALANINE[c]',
#  'B-ALANINE[p]',
#  'B-ALANINE[e]',
#  'B0070-MONOMER[m]',
#  'B0260-MONOMER[i]',
#  'B0270-MONOMER[i]',
#  'B0427-MONOMER[i]',
#  'B0486-MONOMER[i]',
#  'B0511-MONOMER[i]',
#  'B0612-MONOMER[m]',
#  'B0709-MONOMER[i]',
#  'B0752-MONOMER[i]',
#  'B0770-MONOMER[i]',
#  'B0899-MONOMER[c]',
#  'B1-CPLX[c]',
#  'B1006-MONOMER[i]',
#  'B1065-MONOMER[i]',
#  'B1296-MONOMER[i]',
#  'B1433-MONOMER[i]',
#  'B1543-MONOMER[i]',
#  'B1596-MONOMER[i]',
#  'B1599-MONOMER[m]',
#  'B1600-MONOMER[i]',
#  'B1634-MONOMER[i]',
#  'B1657-MONOMER[i]',
#  'B1690-MONOMER[i]',
#  'B1691-MONOMER[i]',
#  'B1775-MONOMER[i]',
#  'B1791-MONOMER[i]',
#  'B1828-MONOMER[i]',
#  'B2-CPLX[c]',
#  'B2075-MONOMER[i]',
#  'B2076-MONOMER[i]',
#  'B2077-MONOMER[i]',
#  'B2098-MONOMER[i]',
#  'B2170-MONOMER[m]',
#  'B2246-MONOMER[i]',
#  'B2322-MONOMER[i]',
#  'B2372-MONOMER[i]',
#  'B2740-MONOMER[i]',
#  'B2771-MONOMER[i]',
#  'B2775-MONOMER[m]',
#  'B2789-MONOMER[i]',
#  'B2845-MONOMER[i]',
#  'B2975-MONOMER[i]',
#  'B3659-MONOMER[i]',
#  'B4141-MONOMER[i]',
#  'BA+2[c]',
#  'BA+2[p]',
#  'BA+2[e]',
#  'BACIMETHRIN[c]',
#  'BADH-CPLX[c]',
#  'BADH-MONOMER[c]',
#  'BAER-MONOMER[c]',
#  'BAES-INDOLE-CPLX[i]',
#  'BAES-MONOMER[i]',
#  'BARA-MONOMER[i]',
#  'BASR-MONOMER[c]',
#  'BASS-FE+3-CPLX[i]',
#  'BASS-MONOMER[i]',
#  'BCCP-MONOMER[c]',
#  'BCR-MONOMER[i]',
#  'BENZALDEHYDE[c]',
#  'BENZALDEHYDE[p]',
#  'BENZALDEHYDE[e]',
#  'BENZENE[c]',
#  'BENZENE[p]',
#  'BENZENE[e]',
#  'BENZOATE[c]',
#  'BENZOATE[p]',
#  'BENZOATE[e]',
#  'BENZOYLCOA[c]',
#  'BENZOYLCOA[p]',
#  'BENZOYLCOA[e]',
#  'BENZYL-ALCOHOL[c]',
#  'BENZYL-ALCOHOL[p]',
#  'BENZYL-ALCOHOL[e]',
#  'BERBERINE[c]',
#  'BETA-D-FRUCTOSE[c]',
#  'BETA-D-FRUCTOSE[p]',
#  'BETA-D-FRUCTOSE[e]',
#  'BETA-D-GAL-1-3-D-GLCNAC[c]',
#  'BETA-D-XYLOSE[c]',
#  'BETA-D-XYLOSE[p]',
#  'BETA-D-XYLOSE[e]',
#  'BETA-GLUCURONID-MONOMER[c]',
#  'BETA-L-ARABINOSE[c]',
#  'BETA-L-ARABINOSE[p]',
#  'BETA-L-ARABINOSE[e]',
#  'BETACOMP-MONOMER[c]',
#  'BETAGALACTOSID-CPLX[c]',
#  'BETAGALACTOSID-MONOMER[c]',
#  'BETAINE[c]',
#  'BETAINE[p]',
#  'BETAINE[e]',
#  'BETAINE-ALDEHYDE-HYDRATE[c]',
#  'BETAINE-ALDEHYDE-HYDRATE[p]',
#  'BETAINE-ALDEHYDE-HYDRATE[e]',
#  'BETAINE_ALDEHYDE[c]',
#  'BETAINE_ALDEHYDE[p]',
#  'BETAINE_ALDEHYDE[e]',
#  'BETT-MONOMER[i]',
#  'BGLF-MONOMER[i]',
#  'BH4NA[c]',
#  'BIO-5-AMP[c]',
#  'BIOTIN[c]',
#  'BIOTIN[p]',
#  'BIOTIN[e]',
#  'BIOTIN-CARBOXYL-CPLX[c]',
#  'BIOTIN-CARBOXYL-MONOMER[c]',
#  'BIOTIN-SYN-CPLX[c]',
#  'BIOTIN-SYN-MONOMER[c]',
#  'BIOTINLIG-MONOMER[c]',
#  'BIS-P-NITROPHENOLPHOSPHATE[c]',
#  'BISGLYCEROPHOSPHOGLYCEROL[c]',
#  'BISOHMYR-GLC[c]',
#  'BISOHMYR-GLC[p]',
#  'BISOHMYR-GLC[e]',
#  'BISOHMYR-GLUCOSAMINYL-1P[c]',
#  'BISOHMYR-GLUCOSAMINYL-1P[p]',
#  'BISOHMYR-GLUCOSAMINYL-1P[e]',
#  'BORATE[c]',
#  'BORATE[p]',
#  'BORATE[e]',
#  'BOROHYDRIDE[c]',
#  'BR-[c]',
#  'BR-[p]',
#  'BR-[e]',
#  'BRANCHED-CHAINAMINOTRANSFER-CPLX[c]',
#  'BRANCHED-CHAINAMINOTRANSFER-MONOMER[c]',
#  'BRIJ97[c]',
#  'BRNQ-MONOMER[i]',
#  'BROMOACETATE[c]',
#  'BTUC-MONOMER[m]',
#  'BTUD-MONOMER[m]',
#  'BTUE-MONOMER[p]',
#  'BUTANAL[c]',
#  'BUTANAL[p]',
#  'BUTANAL[e]',
#  'BUTANEDIOL[c]',
#  'BUTANOL[c]',
#  'BUTANOL[p]',
#  'BUTANOL[e]',
#  'BUTHIONINE-SULFOXIMINE[c]',
#  'BUTHIONINE-SULFOXIMINE[p]',
#  'BUTHIONINE-SULFOXIMINE[e]',
#  'BUTYL-HYDROPEROXIDE[c]',
#  'BUTYLAMINE[c]',
#  'BUTYRIC_ACID[c]',
#  'BUTYRIC_ACID[p]',
#  'BUTYRIC_ACID[e]',
#  'BUTYRYL-COA[c]',
#  'BUTYRYL-COA[p]',
#  'Bacteriochlorins[c]',
#  'Benzoin[c]',
#  'Beta-phellandrene[c]',
#  'Binuclear-Copper-Centers[c]',
#  'Bulgecins[c]',
#  'Butirosins[c]',
#  'C-Clusters[c]',
#  'C-DI-GMP[c]',
#  'C-DI-GMP[p]',
#  'C-DI-GMP[e]',
#  'C0730-RNA[c]',
#  'C1[c]',
#  'C1[p]',
#  'C1[e]',
#  'C28-Steroids[c]',
#  'C29-Steroids[c]',
#  'C3[c]',
#  ...]

# %%
np.shape(bulk.columns)
# Out:
# (16255,)

# %%
# Combine monomers in different compartments into one monomer id: 
id_idx_dict = {id: i for i, id in enumerate(bulk_ids)}
idx_id_dict = {idx: i for i, idx in id_idx_dict.items()}

# take the protein [location] out of the name of the bulk ids: 
ecocyc_ids = []
for id in bulk_ids: 
	ecocyc_ids.append(id[0:-3])

ecocyc_id_idxs = []
for i in range(len(ecocyc_ids)):
	ecocyc_id_idxs.append(i)
	
all_names = [] # ends with 12726 total (down from 16097)
name_groups = []
idx_groups = []

for p in bulk_ids:
	prot = p[0:-3]
	if prot not in all_names:
		indexes = [index for index, item in enumerate(ecocyc_ids) if item == prot]
		for idx in indexes:
			if ecocyc_ids[idx] == prot:
				# confirm the index is correct
				pass
			else:
				# delete the index in case a mistake was made
				indexes.remove(idx)
		name_group = [idx_id_dict.get(name) for name in indexes]
		all_names.append(prot)
		name_groups.append(name_group)
		idx_groups.append(indexes)
		
len(all_names)
len(name_groups)
# Out:
# 12788

# %%
# figure out which proteins from the C matrix match those in the bulk data: 
protein_ids = complex_ids + monomer_ids
protein_counts = np.zeros([bulk.shape[0], len(protein_ids)])
pid_idx_dict = {id: i for i, id in enumerate(protein_ids)}
idx_pid_dict = {idx: i for i, idx in pid_idx_dict.items()}

for p in protein_ids:
	idx = [index for index, item in enumerate(all_names) if item == p]
	if len(idx) == 0:
		protein_counts[:, pid_idx_dict[p]] = 0
	elif len(idx) == 1:
		name = all_names[idx[0]]
		idx_group = idx_groups[idx[0]]
		temp_counts = np.zeros([bulk.shape[0], len(idx_group)])
		for i in range(len(idx_group)):
			selected_data = bulk.select(bulk_ids[idx_group[i]]) 
			temp_counts[:, i] = selected_data.to_numpy().flatten()
		protein_counts[:, pid_idx_dict[p]] = np.sum(temp_counts, axis=1)
	else:
		# make sure there are no bugs in the code
		print(p)
		print("too many")

# %%
np.shape(protein_counts)
# Out:
# (1301, 5527)

# %%
mm_sim_protein_counts = protein_counts @ Cmatrix
# simplify the results accordingly with the time steps: 
mm_avg_sim_data = mm_sim_protein_counts.mean(axis=0)
# TODO: edit this to account for cell age
# create dataframes for the simulation data:
mm_avg_sim_df = pl.DataFrame((monomer_ids, mm_avg_sim_data), schema=["Monomer ID","Sim Protein Counts"])

# %%
mm_avg_sim_df
# Out:
# shape: (4_434, 2)
# ┌─────────────────────────────────┬────────────────────┐
# │ Monomer ID                      ┆ Sim Protein Counts │
# │ ---                             ┆ ---                │
# │ str                             ┆ f64                │
# ╞═════════════════════════════════╪════════════════════╡
# │ 1-ACYLGLYCEROL-3-P-ACYLTRANSFE… ┆ 176.874712         │
# │ 1-PFK-MONOMER                   ┆ 57.001537          │
# │ 2-DEHYDROPANTOATE-REDUCT-MONOM… ┆ 217.187548         │
# │ 2-ISOPROPYLMALATESYN-MONOMER    ┆ 1630.80784         │
# │ 2-OCTAPRENYL-METHOXY-BENZOQ-ME… ┆ 322.077633         │
# │ …                               ┆ …                  │
# │ YTFR-MONOMER                    ┆ 25.0               │
# │ YTFT-MONOMER                    ┆ 21.0               │
# │ ZNUA-MONOMER                    ┆ 570.823213         │
# │ ZNUB-MONOMER                    ┆ 89.010761          │
# │ ZNUC-MONOMER                    ┆ 111.62721          │
# └─────────────────────────────────┴────────────────────┘

# %%
new_df = pl.DataFrame(ecocyc_data).join(mm_avg_sim_df,  how="inner", left_on="Proteins", right_on="Monomer ID")
# TODO: so the length of the original ecocyc data frame is 4481, so I think that it is filtering correctly! 
new_df
# Out:
# shape: (4_321, 5)
# ┌──────────────────────────┬─────────┬─────────────────────┬─────────────┬────────────────────┐
# │ Proteins                 ┆ Genes   ┆ Accession-1 of Gene ┆ Common-Name ┆ Sim Protein Counts │
# │ ---                      ┆ ---     ┆ ---                 ┆ ---         ┆ ---                │
# │ str                      ┆ str     ┆ str                 ┆ str         ┆ f64                │
# ╞══════════════════════════╪═════════╪═════════════════════╪═════════════╪════════════════════╡
# │ EG11817-MONOMER          ┆ EG11817 ┆ b2744               ┆ umpG        ┆ 88.013067          │
# │ MONOMER0-4534            ┆ G6577   ┆ b1120               ┆ cobB        ┆ 262.318217         │
# │ FDOI-MONOMER             ┆ EG11856 ┆ b3892               ┆ fdoI        ┆ 22.0               │
# │ G6991-MONOMER            ┆ G6991   ┆ b1807               ┆ tsaB        ┆ 195.0              │
# │ ADENODEAMIN-MONOMER      ┆ EG10030 ┆ b1623               ┆ add         ┆ 171.176018         │
# │ …                        ┆ …       ┆ …                   ┆ …           ┆ …                  │
# │ G7835-MONOMER            ┆ G7835   ┆ b4145               ┆ yjeJ        ┆ 73.601845          │
# │ GALACTITOLPDEHYD-MONOMER ┆ EG12417 ┆ b2091               ┆ gatD        ┆ 296.885473         │
# │ EG10736-MONOMER          ┆ EG10736 ┆ b0708               ┆ phr         ┆ 19.0               │
# │ EG10853-MONOMER          ┆ EG10853 ┆ b1427               ┆ rimL        ┆ 204.770945         │
# │ EG12344-MONOMER          ┆ EG12344 ┆ b1303               ┆ pspF        ┆ 44.0               │
# └──────────────────────────┴─────────┴─────────────────────┴─────────────┴────────────────────┘

# %%
# Remove rows from validation_data that do not have high confidence (they will contain brackets) in the "MOPS complete" column:
validation_data['MOPS minimal'] = validation_data['MOPS minimal'].astype(str)
validation_data = validation_data[~validation_data['MOPS minimal'].str.contains("[", regex=False)]
validation_data = validation_data[validation_data['MOPS minimal'].str.isdigit()]
validation_data['MOPS minimal'] = validation_data['MOPS minimal'].astype(int)
v_mm_data = validation_data[['Gene', 'MOPS minimal']]
v_mm_data = pl.DataFrame(v_mm_data)
v_mm_data
# Out:
# shape: (3_362, 2)
# ┌──────┬──────────────┐
# │ Gene ┆ MOPS minimal │
# │ ---  ┆ ---          │
# │ str  ┆ i64          │
# ╞══════╪══════════════╡
# │ aaeA ┆ 5            │
# │ aaeR ┆ 79           │
# │ aas  ┆ 80           │
# │ aat  ┆ 111          │
# │ abgA ┆ 12           │
# │ …    ┆ …            │
# │ zraR ┆ 30           │
# │ zraS ┆ 4            │
# │ zupT ┆ 217          │
# │ zur  ┆ 167          │
# │ zwf  ┆ 1928         │
# └──────┴──────────────┘

# %%
# find matches between the simulation minimal media data and validation minimal media data: 
vs_match_mm_df = pl.DataFrame(new_df).join(v_mm_data,  how="inner", left_on="Common-Name", right_on="Gene")
vs_match_mm_df
# Out:
# shape: (3_071, 6)
# ┌─────────────────────┬─────────┬────────────────┬─────────────┬────────────────────┬──────────────┐
# │ Proteins            ┆ Genes   ┆ Accession-1 of ┆ Common-Name ┆ Sim Protein Counts ┆ MOPS minimal │
# │ ---                 ┆ ---     ┆ Gene           ┆ ---         ┆ ---                ┆ ---          │
# │ str                 ┆ str     ┆ ---            ┆ str         ┆ f64                ┆ i64          │
# │                     ┆         ┆ str            ┆             ┆                    ┆              │
# ╞═════════════════════╪═════════╪════════════════╪═════════════╪════════════════════╪══════════════╡
# │ MONOMER0-4534       ┆ G6577   ┆ b1120          ┆ cobB        ┆ 262.318217         ┆ 572          │
# │ FDOI-MONOMER        ┆ EG11856 ┆ b3892          ┆ fdoI        ┆ 22.0               ┆ 16           │
# │ ADENODEAMIN-MONOMER ┆ EG10030 ┆ b1623          ┆ add         ┆ 171.176018         ┆ 265          │
# │ EG10875-MONOMER     ┆ EG10875 ┆ b3310          ┆ rplN        ┆ 11426.142967       ┆ 18836        │
# │ G6605-MONOMER       ┆ G6605   ┆ b1165          ┆ ymgA        ┆ 27.679477          ┆ 43           │
# │ …                   ┆ …       ┆ …              ┆ …           ┆ …                  ┆ …            │
# │ G7835-MONOMER       ┆ G7835   ┆ b4145          ┆ yjeJ        ┆ 73.601845          ┆ 19           │
# │ GALACTITOLPDEHYD-MO ┆ EG12417 ┆ b2091          ┆ gatD        ┆ 296.885473         ┆ 2360         │
# │ NOMER               ┆         ┆                ┆             ┆                    ┆              │
# │ EG10736-MONOMER     ┆ EG10736 ┆ b0708          ┆ phr         ┆ 19.0               ┆ 37           │
# │ EG10853-MONOMER     ┆ EG10853 ┆ b1427          ┆ rimL        ┆ 204.770945         ┆ 217          │
# │ EG12344-MONOMER     ┆ EG12344 ┆ b1303          ┆ pspF        ┆ 44.0               ┆ 66           │
# └─────────────────────┴─────────┴────────────────┴─────────────┴────────────────────┴──────────────┘

# %%
# make a new data frame that holds just the protein names and the Sim Protein Counts and MOPS minimal data and then filter out counts that are less than 10: 
comparison_data = ["Proteins", "Sim Protein Counts", "MOPS minimal"]
comparison_df = vs_match_mm_df.select(comparison_data)
comparison_df = comparison_df.filter((pl.col("Sim Protein Counts") > 10) & (pl.col("MOPS minimal") > 10))
comparison_df
# Out:
# shape: (2_656, 3)
# ┌──────────────────────────┬────────────────────┬──────────────┐
# │ Proteins                 ┆ Sim Protein Counts ┆ MOPS minimal │
# │ ---                      ┆ ---                ┆ ---          │
# │ str                      ┆ f64                ┆ i64          │
# ╞══════════════════════════╪════════════════════╪══════════════╡
# │ MONOMER0-4534            ┆ 262.318217         ┆ 572          │
# │ FDOI-MONOMER             ┆ 22.0               ┆ 16           │
# │ ADENODEAMIN-MONOMER      ┆ 171.176018         ┆ 265          │
# │ EG10875-MONOMER          ┆ 11426.142967       ┆ 18836        │
# │ G6605-MONOMER            ┆ 27.679477          ┆ 43           │
# │ …                        ┆ …                  ┆ …            │
# │ G7835-MONOMER            ┆ 73.601845          ┆ 19           │
# │ GALACTITOLPDEHYD-MONOMER ┆ 296.885473         ┆ 2360         │
# │ EG10736-MONOMER          ┆ 19.0               ┆ 37           │
# │ EG10853-MONOMER          ┆ 204.770945         ┆ 217          │
# │ EG12344-MONOMER          ┆ 44.0               ┆ 66           │
# └──────────────────────────┴────────────────────┴──────────────┘

# %%
np.shape(comparison_df)
# Out:
# (2656, 3)

# %%
# plot the comparison graph:
sns.scatterplot(x="Sim Protein Counts", y="MOPS minimal", data=comparison_df.to_pandas(), s=5)

# find the max value of the plot for making a y=x line: 
max_vals = [max(comparison_df["Sim Protein Counts"]), max(comparison_df["MOPS minimal"])]; max_val = round(max(max_vals))
yxvals = range(10, max_val + 1); 
plt.plot(yxvals, yxvals, linewidth=.8, linestyle="dashed", color="#FF796C"); 

# plot specs
plt.xscale('log')
plt.yscale('log')
plt.axis('square')
plt.title("Comparisons of E.coli Protein Counts in Minimal Media \n from Literature Data and Simulation Data")
# Out:
# Text(0.5, 1.0, 'Comparisons of E.coli Protein Counts in Minimal Media \n from Literature Data and Simulation Data')

# %%
# plot the comparison graph with plotly:
df = comparison_df.to_pandas()
fig = px.scatter(df, x=df["Sim Protein Counts"],y=df["MOPS minimal"], hover_data=["Proteins"], trendline="ols" )
fig.add_trace(go.Scatter(x=[0, max_val], y=[0, max_val], mode="lines",
        line=go.scatter.Line(color="red", dash="dash"),
        showlegend=False));

fig.update_xaxes(type="log")
fig.update_yaxes(type="log")
fig.update_layout(title="Comparisons of E.coli Protein Counts in Minimal Media \nfrom Literature Data (Li, et. al., 2014) and Simulation Data")
# make the figure square and have equal axis numbers
fig.update_layout(width=800, height=800)
fig.update_yaxes(
    scaleanchor="x",
    scaleratio=1,
  )
fig.show()
# Out:
# <div>                            <div id="5968fc39-0683-4c21-93ce-1f39f10c5f87" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5968fc39-0683-4c21-93ce-1f39f10c5f87")) {                    Plotly.newPlot(                        "5968fc39-0683-4c21-93ce-1f39f10c5f87",                        [{"customdata":[["MONOMER0-4534"],["FDOI-MONOMER"],["ADENODEAMIN-MONOMER"],["EG10875-MONOMER"],["G6605-MONOMER"],["HCAC-MONOMER"],["NARG-MONOMER"],["EG10426-MONOMER"],["G7009-MONOMER"],["EG10829-MONOMER"],["EG10996-MONOMER"],["YBBP-MONOMER"],["EG10867-MONOMER"],["EG11153-MONOMER"],["EG10438-MONOMER"],["DALADALALIGB-MONOMER"],["YGJU-MONOMER"],["EG12394-MONOMER"],["IMP-DEHYDROG-MONOMER"],["EG10760-MONOMER"],["G7323-MONOMER"],["EG12242-MONOMER"],["EG10342-MONOMER"],["ADENYLYLSULFKIN-MONOMER"],["EG10776-MONOMER"],["PROW-MONOMER"],["EG12444-MONOMER"],["EG11877-MONOMER"],["GNTT-MONOMER"],["ERYTH4PDEHYDROG-MONOMER"],["TRYPSYN-APROTEIN"],["GLND-MONOMER"],["G7511-MONOMER"],["EG11507-MONOMER"],["G6908-MONOMER"],["EG11488-MONOMER"],["G7543-MONOMER"],["G7871-MONOMER"],["RIBOFLAVIN-SYN-MONOMER"],["G7279-MONOMER"],["EG12410-MONOMER"],["G6181-MONOMER"],["EG11298-MONOMER"],["CYDD-MONOMER"],["EG11725-MONOMER"],["G6811-MONOMER"],["G7068-MONOMER"],["EG10228-MONOMER"],["ILES-MONOMER"],["G6540-MONOMER"],["SDH-MEMB2"],["EG10596-MONOMER"],["EG20249-MONOMER"],["EG10580-MONOMER"],["EG11009-MONOMER"],["EG10912-MONOMER"],["G6889-MONOMER"],["EG10436-MONOMER"],["EG10216-MONOMER"],["EG12202-MONOMER"],["EG12605-MONOMER"],["COBU-MONOMER"],["PD03270"],["EG10507-MONOMER"],["BIOTINLIG-MONOMER"],["MONOMER0-4521"],["TRANSKETOI-MONOMER"],["N-ACETYLTRANSFER-MONOMER"],["EG12251-MONOMER"],["G7356-MONOMER"],["G6325-MONOMER"],["G7108-MONOMER"],["G6464-MONOMER"],["EG12214-MONOMER"],["EG11311-MONOMER"],["KDPD-MONOMER"],["EG12310-MONOMER"],["G6499-MONOMER"],["G6544-MONOMER"],["YLIA-MONOMER"],["G7245-MONOMER"],["KETOBUTFORMLY-INACT-MONOMER"],["EG10833-MONOMER"],["KGTP-MONOMER"],["ERYTHRON4PDEHYDROG-MONOMER"],["NANE-MONOMER"],["DPPA-MONOMER"],["EG10490-MONOMER"],["HEMEOSYN-MONOMER"],["YHES-MONOMER"],["G7864-MONOMER"],["G6720-MONOMER"],["CYOD-MONOMER"],["NHAB-MONOMER"],["EG12044-MONOMER"],["EG11649-MONOMER"],["NUOH-MONOMER"],["UROGENIIISYN-MONOMER"],["AROP-MONOMER"],["G6591-MONOMER"],["G6860-MONOMER"],["G7031-MONOMER"],["KUP-MONOMER"],["EG12267-MONOMER"],["EG11414-MONOMER"],["1-ACYLGLYCEROL-3-P-ACYLTRANSFER-MONOMER"],["GPT-MONOMER"],["EG12104-MONOMER"],["CHAA-MONOMER"],["B0270-MONOMER"],["GSP-MONOMER"],["EG11201-MONOMER"],["EG11179-MONOMER"],["CPXR-MONOMER"],["DIHYDROFOLATEREDUCT-MONOMER"],["G6665-MONOMER"],["EG11276-MONOMER"],["EG10346-MONOMER"],["G6452-MONOMER"],["G7240-MONOMER"],["EG10158-MONOMER"],["EG12004-MONOMER"],["CELC-MONOMER"],["HOMSUCTRAN-MONOMER"],["G6557-MONOMER"],["EG10748-MONOMER"],["EG11829-MONOMER"],["G6805-MONOMER"],["MONOMER0-1562"],["G361-MONOMER"],["EG10456-MONOMER"],["UUP-MONOMER"],["PD03254"],["MONOMER0-2692"],["ANTHRANSYNCOMPI-MONOMER"],["EG11933-MONOMER"],["PD02198"],["G7001-MONOMER"],["MALE-MONOMER"],["EG11410-MONOMER"],["EG10153-MONOMER"],["THIOESTERI-MONOMER"],["EG11011-MONOMER"],["EG11292-MONOMER"],["G7626-MONOMER"],["EG10534-MONOMER"],["FUMC-MONOMER"],["ASPCARBREG-MONOMER"],["G7251-MONOMER"],["EG10460-MONOMER"],["G7242-MONOMER"],["FSR-MONOMER"],["ACRB-MONOMER"],["G7218-MONOMER"],["EG12710-MONOMER"],["EG11008-MONOMER"],["EG12181-MONOMER"],["EG10943-MONOMER"],["G6865-MONOMER"],["EG12203-MONOMER"],["YIDC"],["PHOSNACMURPENTATRANS-MONOMER"],["3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-MONOMER"],["GLUCONREDUCT-MONOMER"],["PD00242"],["EG11058-MONOMER"],["G6658-MONOMER"],["EG11113-MONOMER"],["EG12105-MONOMER"],["ARTP-MONOMER"],["G6986-MONOMER"],["G6769-MONOMER"],["EG12404-MONOMER"],["PROTEIN-PII2"],["G6624-MONOMER"],["G6269-MONOMER"],["G6884 ...

# %% [markdown]
# ## Rich Media Conditions Comparison: Simulation data VS "MOPS complete" data from Li et al., 2014

# %%
# simulation from 2024-06-13 (created with the vivarium-ecoli model, and it does produce an output on the new vEcoli model)
# time = '1300'
# date = '2024-06-13'
# experiment = 'metabolism-redux-classic-rich'
# entry = f'{experiment}_{time}_{date}'
# folder = f'out/cofactors/{entry}/'

# %%
time = '1300'
date = '2024-07-16'
experiment = 'metabolism-redux-classic-rich'
#experiment = 'validation_experiment'
entry = f'{experiment}_{time}_{date}'
folder = f'out/cofactors/{entry}/'

# %%
output_all = np.load(folder + '0_output.npy',allow_pickle='TRUE').item()
# output = np.load(r"out/geneRxnVerifData/output_glc.npy", allow_pickle=True, encoding='ASCII').tolist()
output = output_all['agents']['0']
fba = output['listeners']['fba_results']
mass = output['listeners']['mass']
rm_bulk = pl.DataFrame(output['bulk'])

fluxes = np.array(fba['estimated_fluxes'][1:])
exchanges = fba['estimated_exchange_dmdt']

ans = output['listeners']['unique_molecule_counts']['active_ribosome']

# %%
# So say I want to find the names of the proteins themselves, these are functions to implement that do so: 
initial_state = json.load(open('data/wcecoli_t0.json'))

bulk_ids = [item[0] for item in initial_state['bulk']]

rm_bulk.columns = bulk_ids
# TODO: I need ot re run the sims with the new viv update

# %%
# TODO: do I need this next section in here twice? will it be the same every time? ask cyrus if the same proteins will likely show up out of both sim types, even if they are different conditions

# %%
# Combine monomers in different compartments into one monomer id: 
id_idx_dict = {id: i for i, id in enumerate(bulk_ids)}
idx_id_dict = {idx: i for i, idx in id_idx_dict.items()}

# take the protein [location] out of the name of the bulk ids: 
ecocyc_ids = []
for id in bulk_ids: 
	ecocyc_ids.append(id[0:-3])

ecocyc_id_idxs = []
for i in range(len(ecocyc_ids)):
	ecocyc_id_idxs.append(i)
	
all_names = [] # ends with 12726 total (down from 16097)
name_groups = []
idx_groups = []

for p in bulk_ids:
	prot = p[0:-3]
	if prot not in all_names:
		indexes = [index for index, item in enumerate(ecocyc_ids) if item == prot]
		for idx in indexes:
			if ecocyc_ids[idx] == prot:
				# confirm the index is correct
				pass
			else:
				# delete the index in case a mistake was made
				indexes.remove(idx)
		name_group = [idx_id_dict.get(name) for name in indexes]
		all_names.append(prot)
		name_groups.append(name_group)
		idx_groups.append(indexes)
		
len(all_names)
len(name_groups)
# Out:
# 12788

# %%
# figure out which proteins from the C matrix match those in the bulk data: 
protein_ids = complex_ids + monomer_ids
protein_counts = np.zeros([rm_bulk.shape[0], len(protein_ids)])
pid_idx_dict = {id: i for i, id in enumerate(protein_ids)}
idx_pid_dict = {idx: i for i, idx in pid_idx_dict.items()}

for p in protein_ids:
	idx = [index for index, item in enumerate(all_names) if item == p]
	if len(idx) == 0:
		protein_counts[:, pid_idx_dict[p]] = 0
	elif len(idx) == 1:
		name = all_names[idx[0]]
		idx_group = idx_groups[idx[0]]
		temp_counts = np.zeros([rm_bulk.shape[0], len(idx_group)])
		for i in range(len(idx_group)):
			selected_data = rm_bulk.select(bulk_ids[idx_group[i]]) 
			temp_counts[:, i] = selected_data.to_numpy().flatten()
		protein_counts[:, pid_idx_dict[p]] = np.sum(temp_counts, axis=1)
	else:
		# make sure there are no bugs in the code
		print(p)
		print("too many")

# %%
np.shape(protein_counts)
# Out:
# (1301, 5527)

# %%
rm_sim_protein_counts = protein_counts @ Cmatrix
# simplify the results accordingly with the time steps: 
rm_avg_sim_data = rm_sim_protein_counts.mean(axis=0)
# TODO: edit this to account for cell age
# create dataframes for the simulation data:
rm_avg_sim_df = pl.DataFrame((monomer_ids, rm_avg_sim_data), schema=["Monomer ID","Sim Protein Counts"])

# %%
rm_df = pl.DataFrame(ecocyc_data).join(rm_avg_sim_df,  how="inner", left_on="Proteins", right_on="Monomer ID")
rm_df
# Out:
# shape: (4_321, 5)
# ┌──────────────────────────┬─────────┬─────────────────────┬─────────────┬────────────────────┐
# │ Proteins                 ┆ Genes   ┆ Accession-1 of Gene ┆ Common-Name ┆ Sim Protein Counts │
# │ ---                      ┆ ---     ┆ ---                 ┆ ---         ┆ ---                │
# │ str                      ┆ str     ┆ str                 ┆ str         ┆ f64                │
# ╞══════════════════════════╪═════════╪═════════════════════╪═════════════╪════════════════════╡
# │ EG11817-MONOMER          ┆ EG11817 ┆ b2744               ┆ umpG        ┆ 186.411222         │
# │ MONOMER0-4534            ┆ G6577   ┆ b1120               ┆ cobB        ┆ 937.099923         │
# │ FDOI-MONOMER             ┆ EG11856 ┆ b3892               ┆ fdoI        ┆ 72.946964          │
# │ G6991-MONOMER            ┆ G6991   ┆ b1807               ┆ tsaB        ┆ 547.750961         │
# │ ADENODEAMIN-MONOMER      ┆ EG10030 ┆ b1623               ┆ add         ┆ 364.110684         │
# │ …                        ┆ …       ┆ …                   ┆ …           ┆ …                  │
# │ G7835-MONOMER            ┆ G7835   ┆ b4145               ┆ yjeJ        ┆ 195.53651          │
# │ GALACTITOLPDEHYD-MONOMER ┆ EG12417 ┆ b2091               ┆ gatD        ┆ 846.579554         │
# │ EG10736-MONOMER          ┆ EG10736 ┆ b0708               ┆ phr         ┆ 40.270561          │
# │ EG10853-MONOMER          ┆ EG10853 ┆ b1427               ┆ rimL        ┆ 275.98847          │
# │ EG12344-MONOMER          ┆ EG12344 ┆ b1303               ┆ pspF        ┆ 90.0               │
# └──────────────────────────┴─────────┴─────────────────────┴─────────────┴────────────────────┘

# %%
# Remove rows from validation_data that do not have high confidence (they will contain brackets) in the "MOPS complete" column:
validation_data['MOPS complete'] = validation_data['MOPS complete'].astype(str)
validation_data = validation_data[~validation_data['MOPS complete'].str.contains("[", regex=False)]
validation_data = validation_data[validation_data['MOPS complete'].str.isdigit()]
validation_data['MOPS complete'] = validation_data['MOPS complete'].astype(int)
v_rm_data = validation_data[['Gene', 'MOPS complete']]
v_rm_data = pl.DataFrame(v_rm_data)
v_rm_data
# Out:
# shape: (2_997, 2)
# ┌──────┬───────────────┐
# │ Gene ┆ MOPS complete │
# │ ---  ┆ ---           │
# │ str  ┆ i64           │
# ╞══════╪═══════════════╡
# │ aaeA ┆ 62            │
# │ aaeR ┆ 203           │
# │ aas  ┆ 188           │
# │ aat  ┆ 151           │
# │ abgA ┆ 9             │
# │ …    ┆ …             │
# │ zraR ┆ 98            │
# │ zraS ┆ 8             │
# │ zupT ┆ 407           │
# │ zur  ┆ 333           │
# │ zwf  ┆ 5185          │
# └──────┴───────────────┘

# %%
# find matches between the simulation minimal media data and validation minimal media data: 
vs_match_rm_df = pl.DataFrame(rm_df).join(v_rm_data,  how="inner", left_on="Common-Name", right_on="Gene")
vs_match_rm_df
# Out:
# shape: (2_732, 6)
# ┌─────────────────────┬─────────┬─────────────────────┬─────────────┬──────────────┬───────────────┐
# │ Proteins            ┆ Genes   ┆ Accession-1 of Gene ┆ Common-Name ┆ Sim Protein  ┆ MOPS complete │
# │ ---                 ┆ ---     ┆ ---                 ┆ ---         ┆ Counts       ┆ ---           │
# │ str                 ┆ str     ┆ str                 ┆ str         ┆ ---          ┆ i64           │
# │                     ┆         ┆                     ┆             ┆ f64          ┆               │
# ╞═════════════════════╪═════════╪═════════════════════╪═════════════╪══════════════╪═══════════════╡
# │ MONOMER0-4534       ┆ G6577   ┆ b1120               ┆ cobB        ┆ 937.099923   ┆ 827           │
# │ FDOI-MONOMER        ┆ EG11856 ┆ b3892               ┆ fdoI        ┆ 72.946964    ┆ 221           │
# │ ADENODEAMIN-MONOMER ┆ EG10030 ┆ b1623               ┆ add         ┆ 364.110684   ┆ 724           │
# │ EG10875-MONOMER     ┆ EG10875 ┆ b3310               ┆ rplN        ┆ 23871.555726 ┆ 118153        │
# │ G6605-MONOMER       ┆ G6605   ┆ b1165               ┆ ymgA        ┆ 157.213682   ┆ 48            │
# │ …                   ┆ …       ┆ …                   ┆ …           ┆ …            ┆ …             │
# │ G7835-MONOMER       ┆ G7835   ┆ b4145               ┆ yjeJ        ┆ 195.53651    ┆ 45            │
# │ GALACTITOLPDEHYD-MO ┆ EG12417 ┆ b2091               ┆ gatD        ┆ 846.579554   ┆ 643           │
# │ NOMER               ┆         ┆                     ┆             ┆              ┆               │
# │ EG10736-MONOMER     ┆ EG10736 ┆ b0708               ┆ phr         ┆ 40.270561    ┆ 21            │
# │ EG10853-MONOMER     ┆ EG10853 ┆ b1427               ┆ rimL        ┆ 275.98847    ┆ 174           │
# │ EG12344-MONOMER     ┆ EG12344 ┆ b1303               ┆ pspF        ┆ 90.0         ┆ 121           │
# └─────────────────────┴─────────┴─────────────────────┴─────────────┴──────────────┴───────────────┘

# %%
# make a new data frame that holds just the protein names and the Sim Protein Counts and MOPS minimal data and then filter out counts that are less than 10: 
rm_comparison_data = ["Proteins", "Sim Protein Counts", "MOPS complete"]
rm_comparison_df = vs_match_rm_df.select(rm_comparison_data)
rm_comparison_df = rm_comparison_df.filter((pl.col("Sim Protein Counts") > 10) & (pl.col("MOPS complete") > 10))
rm_comparison_df
# Out:
# shape: (2_624, 3)
# ┌──────────────────────────┬────────────────────┬───────────────┐
# │ Proteins                 ┆ Sim Protein Counts ┆ MOPS complete │
# │ ---                      ┆ ---                ┆ ---           │
# │ str                      ┆ f64                ┆ i64           │
# ╞══════════════════════════╪════════════════════╪═══════════════╡
# │ MONOMER0-4534            ┆ 937.099923         ┆ 827           │
# │ FDOI-MONOMER             ┆ 72.946964          ┆ 221           │
# │ ADENODEAMIN-MONOMER      ┆ 364.110684         ┆ 724           │
# │ EG10875-MONOMER          ┆ 23871.555726       ┆ 118153        │
# │ G6605-MONOMER            ┆ 157.213682         ┆ 48            │
# │ …                        ┆ …                  ┆ …             │
# │ G7835-MONOMER            ┆ 195.53651          ┆ 45            │
# │ GALACTITOLPDEHYD-MONOMER ┆ 846.579554         ┆ 643           │
# │ EG10736-MONOMER          ┆ 40.270561          ┆ 21            │
# │ EG10853-MONOMER          ┆ 275.98847          ┆ 174           │
# │ EG12344-MONOMER          ┆ 90.0               ┆ 121           │
# └──────────────────────────┴────────────────────┴───────────────┘

# %%
np.shape(rm_comparison_df)
# Out:
# (2624, 3)

# %%
# plot the comparison graph:
sns.scatterplot(x="Sim Protein Counts", y="MOPS complete", data=rm_comparison_df.to_pandas(), s=5)

# find the max value of the plot for making a y=x line: 
max_vals = [max(rm_comparison_df["Sim Protein Counts"]), max(rm_comparison_df["MOPS complete"])]; max_val = round(max(max_vals))
yxvals = range(10, max_val + 1); 
plt.plot(yxvals, yxvals, linewidth=.8, linestyle="dashed", color="#FF796C"); 

# plot specs
plt.xscale('log')
plt.yscale('log')
plt.axis('square')
plt.title("Comparisons of E.coli Protein Counts in Rich Media \n from Literature Data (Li, et. al., 2014) and Simulation Data")
# Out:
# Text(0.5, 1.0, 'Comparisons of E.coli Protein Counts in Rich Media \n from Literature Data (Li, et. al., 2014) and Simulation Data')

# %%
# plot the comparison graph with plotly:
df = rm_comparison_df.to_pandas()
fig = px.scatter(df, x=df["Sim Protein Counts"],y=df["MOPS complete"], hover_data=["Proteins"], trendline="ols" )
fig.add_trace(go.Scatter(x=[0, max_val], y=[0, max_val], mode="lines",
        line=go.scatter.Line(color="red", dash="dash"),
        showlegend=False));

fig.update_xaxes(type="log")
fig.update_yaxes(type="log")
fig.update_layout(title="Comparisons of E.coli Protein Counts in Rich Media\nfrom Literature Data (Li, et. al., 2014) and Simulation Data")
# make the figure square and have equal axis numbers
fig.update_layout(width=800, height=800)
fig.update_yaxes(
    scaleanchor="x",
    scaleratio=1,
  )
fig.show()
# Out:
# <div>                            <div id="f889104e-5de8-4291-a978-e3bc9e2a4ce4" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f889104e-5de8-4291-a978-e3bc9e2a4ce4")) {                    Plotly.newPlot(                        "f889104e-5de8-4291-a978-e3bc9e2a4ce4",                        [{"customdata":[["MONOMER0-4534"],["FDOI-MONOMER"],["ADENODEAMIN-MONOMER"],["EG10875-MONOMER"],["G6605-MONOMER"],["G7516-MONOMER"],["EG10426-MONOMER"],["EG10829-MONOMER"],["EG10996-MONOMER"],["YBBP-MONOMER"],["EG10867-MONOMER"],["EG11153-MONOMER"],["EG10438-MONOMER"],["DALADALALIGB-MONOMER"],["YGJU-MONOMER"],["EG12394-MONOMER"],["IMP-DEHYDROG-MONOMER"],["EG10760-MONOMER"],["G7323-MONOMER"],["EG12242-MONOMER"],["EG10342-MONOMER"],["EG10776-MONOMER"],["PROW-MONOMER"],["EG11877-MONOMER"],["GNTT-MONOMER"],["ERYTH4PDEHYDROG-MONOMER"],["TRYPSYN-APROTEIN"],["GLND-MONOMER"],["G7511-MONOMER"],["EG11507-MONOMER"],["G6908-MONOMER"],["EG11488-MONOMER"],["G7543-MONOMER"],["G7871-MONOMER"],["RIBOFLAVIN-SYN-MONOMER"],["G7952-MONOMER"],["G7279-MONOMER"],["EG12410-MONOMER"],["EG11551-MONOMER"],["G6181-MONOMER"],["EG11298-MONOMER"],["CYDD-MONOMER"],["EG11725-MONOMER"],["G6811-MONOMER"],["G7068-MONOMER"],["EG10228-MONOMER"],["ILES-MONOMER"],["G6540-MONOMER"],["SDH-MEMB2"],["EG10596-MONOMER"],["EG20249-MONOMER"],["EG10580-MONOMER"],["EG11009-MONOMER"],["EG10912-MONOMER"],["G6889-MONOMER"],["ARSF-MONOMER"],["EG10436-MONOMER"],["EG10216-MONOMER"],["EG12202-MONOMER"],["EG12605-MONOMER"],["COBU-MONOMER"],["PD03270"],["EG10507-MONOMER"],["BIOTINLIG-MONOMER"],["MONOMER0-4521"],["TRANSKETOI-MONOMER"],["N-ACETYLTRANSFER-MONOMER"],["G7356-MONOMER"],["G6325-MONOMER"],["G7108-MONOMER"],["G6464-MONOMER"],["EG12214-MONOMER"],["EG11311-MONOMER"],["KDPD-MONOMER"],["EG12310-MONOMER"],["G6499-MONOMER"],["YLIA-MONOMER"],["G7575-MONOMER"],["KETOBUTFORMLY-INACT-MONOMER"],["EG10833-MONOMER"],["KGTP-MONOMER"],["ERYTHRON4PDEHYDROG-MONOMER"],["NANE-MONOMER"],["DPPA-MONOMER"],["EG10490-MONOMER"],["HEMEOSYN-MONOMER"],["YHES-MONOMER"],["G7864-MONOMER"],["G6720-MONOMER"],["CYOD-MONOMER"],["NHAB-MONOMER"],["EG12044-MONOMER"],["EG11649-MONOMER"],["NUOH-MONOMER"],["UROGENIIISYN-MONOMER"],["AROP-MONOMER"],["G6860-MONOMER"],["G7031-MONOMER"],["KUP-MONOMER"],["EG12267-MONOMER"],["EG11414-MONOMER"],["1-ACYLGLYCEROL-3-P-ACYLTRANSFER-MONOMER"],["GPT-MONOMER"],["EG12104-MONOMER"],["CHAA-MONOMER"],["B0270-MONOMER"],["GSP-MONOMER"],["FEPG-MONOMER"],["EG11201-MONOMER"],["EG11179-MONOMER"],["CPXR-MONOMER"],["DIHYDROFOLATEREDUCT-MONOMER"],["G6665-MONOMER"],["EG10346-MONOMER"],["G6452-MONOMER"],["G7240-MONOMER"],["EG10158-MONOMER"],["EG12004-MONOMER"],["CELC-MONOMER"],["HOMSUCTRAN-MONOMER"],["G6557-MONOMER"],["EG10748-MONOMER"],["EG11829-MONOMER"],["MONOMER0-1562"],["G361-MONOMER"],["EG10456-MONOMER"],["UUP-MONOMER"],["PD03254"],["TSR-MONOMER"],["MONOMER0-2692"],["ANTHRANSYNCOMPI-MONOMER"],["EG11933-MONOMER"],["BETAGALACTOSID-MONOMER"],["PD02198"],["G7001-MONOMER"],["MALE-MONOMER"],["EG11410-MONOMER"],["EG11355-MONOMER"],["EG10153-MONOMER"],["THIOESTERI-MONOMER"],["EG11011-MONOMER"],["EG12405-MONOMER"],["G7626-MONOMER"],["EG10534-MONOMER"],["FUMC-MONOMER"],["ASPCARBREG-MONOMER"],["G7251-MONOMER"],["EG10460-MONOMER"],["G7242-MONOMER"],["FSR-MONOMER"],["ACRB-MONOMER"],["G7218-MONOMER"],["EG12710-MONOMER"],["EG11008-MONOMER"],["EG12181-MONOMER"],["EG10943-MONOMER"],["G6865-MONOMER"],["EG12203-MONOMER"],["YIDC"],["PHOSNACMURPENTATRANS-MONOMER"],["3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-MONOMER"],["GLUCONREDUCT-MONOMER"],["PD00242"],["EG11058-MONOMER"],["G6658-MONOMER"],["EG11113-MONOMER"],["EG12105-MONOMER"],["ARTP-MONOMER"],["G6986-MONOMER"],["EG12404-MONOMER"],["G6269-MONOMER"],["G6884-MONOMER"],["NRDF-MONOMER"],["SBMA-MONOMER"],["EG11423-MONOMER"],["APPA-MONOMER"],["GARTRANSFO ...

# %% [markdown]
# # Rich Media (without methionine) Conditions Comparison: Simulation data VS "MOPS complete without methionine" data from Li et al., 2014)

# %%
# Remove rows from validation_data that do not have high confidence (they will contain brackets) in the "MOPS complete" column:
validation_data['MOPS complete without methionine'] = validation_data['MOPS complete without methionine'].astype(str)
validation_data = validation_data[~validation_data['MOPS complete without methionine'].str.contains("[", regex=False)]
validation_data = validation_data[validation_data['MOPS complete without methionine'].str.isdigit()]
validation_data['MOPS complete without methionine'] = validation_data['MOPS complete without methionine'].astype(int)
v_rmwom_data = validation_data[['Gene', 'MOPS complete without methionine']]
v_rmwom_data = pl.DataFrame(v_rmwom_data)
v_rmwom_data
# Out:
# shape: (2_222, 2)
# ┌──────┬─────────────────────────────────┐
# │ Gene ┆ MOPS complete without methioni… │
# │ ---  ┆ ---                             │
# │ str  ┆ i64                             │
# ╞══════╪═════════════════════════════════╡
# │ aaeR ┆ 141                             │
# │ aas  ┆ 162                             │
# │ aat  ┆ 123                             │
# │ accA ┆ 4753                            │
# │ accB ┆ 13718                           │
# │ …    ┆ …                               │
# │ znuC ┆ 1322                            │
# │ zraR ┆ 50                              │
# │ zupT ┆ 295                             │
# │ zur  ┆ 582                             │
# │ zwf  ┆ 3262                            │
# └──────┴─────────────────────────────────┘

# %%
# find matches between the simulation minimal media data and validation minimal media data: 
vs_match_rmwom_df = pl.DataFrame(rm_df).join(v_rmwom_data,  how="inner", left_on="Common-Name", right_on="Gene")
vs_match_rmwom_df
# Out:
# shape: (2_017, 6)
# ┌─────────────────────┬─────────┬────────────────┬─────────────┬──────────────┬────────────────────┐
# │ Proteins            ┆ Genes   ┆ Accession-1 of ┆ Common-Name ┆ Sim Protein  ┆ MOPS complete      │
# │ ---                 ┆ ---     ┆ Gene           ┆ ---         ┆ Counts       ┆ without methioni…  │
# │ str                 ┆ str     ┆ ---            ┆ str         ┆ ---          ┆ ---                │
# │                     ┆         ┆ str            ┆             ┆ f64          ┆ i64                │
# ╞═════════════════════╪═════════╪════════════════╪═════════════╪══════════════╪════════════════════╡
# │ MONOMER0-4534       ┆ G6577   ┆ b1120          ┆ cobB        ┆ 937.099923   ┆ 666                │
# │ ADENODEAMIN-MONOMER ┆ EG10030 ┆ b1623          ┆ add         ┆ 364.110684   ┆ 548                │
# │ EG10875-MONOMER     ┆ EG10875 ┆ b3310          ┆ rplN        ┆ 23871.555726 ┆ 79079              │
# │ EG10426-MONOMER     ┆ EG10426 ┆ b0962          ┆ helD        ┆ 243.17525    ┆ 166                │
# │ EG10829-MONOMER     ┆ EG10829 ┆ b3652          ┆ recG        ┆ 156.356649   ┆ 85                 │
# │ …                   ┆ …       ┆ …              ┆ …           ┆ …            ┆ …                  │
# │ EG11547-MONOMER     ┆ EG11547 ┆ b1652          ┆ rnt         ┆ 599.524212   ┆ 345                │
# │ G7835-MONOMER       ┆ G7835   ┆ b4145          ┆ yjeJ        ┆ 195.53651    ┆ 71                 │
# │ GALACTITOLPDEHYD-MO ┆ EG12417 ┆ b2091          ┆ gatD        ┆ 846.579554   ┆ 465                │
# │ NOMER               ┆         ┆                ┆             ┆              ┆                    │
# │ EG10853-MONOMER     ┆ EG10853 ┆ b1427          ┆ rimL        ┆ 275.98847    ┆ 88                 │
# │ EG12344-MONOMER     ┆ EG12344 ┆ b1303          ┆ pspF        ┆ 90.0         ┆ 119                │
# └─────────────────────┴─────────┴────────────────┴─────────────┴──────────────┴────────────────────┘

# %%
# make a new data frame that holds just the protein names and the Sim Protein Counts and MOPS minimal data and then filter out counts that are less than 10: 
rmwom_comparison_data = ["Proteins", "Sim Protein Counts", "MOPS complete without methionine"]
rmwom_comparison_df = vs_match_rmwom_df.select(rmwom_comparison_data)
rmwom_comparison_df = rmwom_comparison_df.filter((pl.col("Sim Protein Counts") > 10) & (pl.col("MOPS complete without methionine") > 10))
rmwom_comparison_df
# Out:
# shape: (1_978, 3)
# ┌──────────────────────────┬────────────────────┬─────────────────────────────────┐
# │ Proteins                 ┆ Sim Protein Counts ┆ MOPS complete without methioni… │
# │ ---                      ┆ ---                ┆ ---                             │
# │ str                      ┆ f64                ┆ i64                             │
# ╞══════════════════════════╪════════════════════╪═════════════════════════════════╡
# │ MONOMER0-4534            ┆ 937.099923         ┆ 666                             │
# │ ADENODEAMIN-MONOMER      ┆ 364.110684         ┆ 548                             │
# │ EG10875-MONOMER          ┆ 23871.555726       ┆ 79079                           │
# │ EG10426-MONOMER          ┆ 243.17525          ┆ 166                             │
# │ EG10829-MONOMER          ┆ 156.356649         ┆ 85                              │
# │ …                        ┆ …                  ┆ …                               │
# │ EG11547-MONOMER          ┆ 599.524212         ┆ 345                             │
# │ G7835-MONOMER            ┆ 195.53651          ┆ 71                              │
# │ GALACTITOLPDEHYD-MONOMER ┆ 846.579554         ┆ 465                             │
# │ EG10853-MONOMER          ┆ 275.98847          ┆ 88                              │
# │ EG12344-MONOMER          ┆ 90.0               ┆ 119                             │
# └──────────────────────────┴────────────────────┴─────────────────────────────────┘

# %%
np.shape(rmwom_comparison_df)
# Out:
# (1978, 3)

# %%
# plot the comparison graph:
sns.scatterplot(x="Sim Protein Counts", y="MOPS complete without methionine", data=rmwom_comparison_df.to_pandas(), s=5)

# find the max value of the plot for making a y=x line: 
max_vals = [max(rmwom_comparison_df["Sim Protein Counts"]), max(rmwom_comparison_df["MOPS complete without methionine"])]; max_val = round(max(max_vals))
yxvals = range(10, max_val + 1); 
plt.plot(yxvals, yxvals, linewidth=.8, linestyle="dashed", color="#FF796C"); 

# plot specs
plt.xscale('log')
plt.yscale('log')
plt.axis('square')
plt.title("Comparisons of E.coli Protein Counts in Rich Media (without Methionine) \n from Literature Data (Li, et. al., 2014) and Simulation Data")
# Out:
# Text(0.5, 1.0, 'Comparisons of E.coli Protein Counts in Rich Media (without Methionine) \n from Literature Data (Li, et. al., 2014) and Simulation Data')

# %%
# plot the comparison graph with plotly:
df = rmwom_comparison_df.to_pandas()
fig = px.scatter(df, x=df["Sim Protein Counts"],y=df["MOPS complete without methionine"], hover_data=["Proteins"], trendline="ols" )
fig.add_trace(go.Scatter(x=[0, max_val], y=[0, max_val], mode="lines",
        line=go.scatter.Line(color="red", dash="dash"),
        showlegend=False));

fig.update_xaxes(type="log")
fig.update_yaxes(type="log")
fig.update_layout(title="Comparisons of E.coli Protein Counts in Rich Media (w/o methionine) \nfrom Literature Data (Li, et. al., 2014) and Simulation Data")
# make the figure square and have equal axis numbers
fig.update_layout(width=800, height=800)
fig.update_yaxes(
    scaleanchor="x",
    scaleratio=1,
  )
fig.show()
# Out:
# <div>                            <div id="59013b46-0379-4eb2-bfe4-36c0a2eee159" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59013b46-0379-4eb2-bfe4-36c0a2eee159")) {                    Plotly.newPlot(                        "59013b46-0379-4eb2-bfe4-36c0a2eee159",                        [{"customdata":[["MONOMER0-4534"],["ADENODEAMIN-MONOMER"],["EG10875-MONOMER"],["EG10426-MONOMER"],["EG10829-MONOMER"],["EG10996-MONOMER"],["YBBP-MONOMER"],["EG10867-MONOMER"],["EG11153-MONOMER"],["EG10438-MONOMER"],["DALADALALIGB-MONOMER"],["YGJU-MONOMER"],["EG12394-MONOMER"],["IMP-DEHYDROG-MONOMER"],["EG10760-MONOMER"],["G7323-MONOMER"],["EG12242-MONOMER"],["EG10342-MONOMER"],["EG10776-MONOMER"],["PROW-MONOMER"],["EG11877-MONOMER"],["ERYTH4PDEHYDROG-MONOMER"],["TRYPSYN-APROTEIN"],["GLND-MONOMER"],["G7511-MONOMER"],["EG11507-MONOMER"],["G6908-MONOMER"],["G7871-MONOMER"],["RIBOFLAVIN-SYN-MONOMER"],["G7279-MONOMER"],["EG12410-MONOMER"],["EG11298-MONOMER"],["CYDD-MONOMER"],["G6811-MONOMER"],["G7068-MONOMER"],["ILES-MONOMER"],["G6540-MONOMER"],["SDH-MEMB2"],["EG10596-MONOMER"],["EG20249-MONOMER"],["EG10580-MONOMER"],["EG11009-MONOMER"],["EG10912-MONOMER"],["EG10436-MONOMER"],["EG10216-MONOMER"],["EG12202-MONOMER"],["EG12605-MONOMER"],["COBU-MONOMER"],["PD03270"],["BIOTINLIG-MONOMER"],["MONOMER0-4521"],["TRANSKETOI-MONOMER"],["G7356-MONOMER"],["G6325-MONOMER"],["G7108-MONOMER"],["G6464-MONOMER"],["EG12214-MONOMER"],["EG11311-MONOMER"],["KDPD-MONOMER"],["EG12310-MONOMER"],["G6499-MONOMER"],["YLIA-MONOMER"],["G7575-MONOMER"],["KETOBUTFORMLY-INACT-MONOMER"],["EG10833-MONOMER"],["KGTP-MONOMER"],["ERYTHRON4PDEHYDROG-MONOMER"],["DPPA-MONOMER"],["EG10490-MONOMER"],["HEMEOSYN-MONOMER"],["YHES-MONOMER"],["G7864-MONOMER"],["G6720-MONOMER"],["CYOD-MONOMER"],["NHAB-MONOMER"],["EG12044-MONOMER"],["EG11649-MONOMER"],["NUOH-MONOMER"],["UROGENIIISYN-MONOMER"],["AROP-MONOMER"],["G6860-MONOMER"],["KUP-MONOMER"],["EG11414-MONOMER"],["1-ACYLGLYCEROL-3-P-ACYLTRANSFER-MONOMER"],["GPT-MONOMER"],["EG12104-MONOMER"],["CHAA-MONOMER"],["GSP-MONOMER"],["EG11201-MONOMER"],["EG11179-MONOMER"],["CPXR-MONOMER"],["DIHYDROFOLATEREDUCT-MONOMER"],["G6665-MONOMER"],["EG10346-MONOMER"],["EG10158-MONOMER"],["HOMSUCTRAN-MONOMER"],["EG10748-MONOMER"],["EG11829-MONOMER"],["EG10456-MONOMER"],["UUP-MONOMER"],["PD03254"],["MONOMER0-2692"],["ANTHRANSYNCOMPI-MONOMER"],["PD02198"],["G7001-MONOMER"],["MALE-MONOMER"],["EG11410-MONOMER"],["EG10153-MONOMER"],["THIOESTERI-MONOMER"],["EG11011-MONOMER"],["EG10534-MONOMER"],["FUMC-MONOMER"],["ASPCARBREG-MONOMER"],["EG10460-MONOMER"],["G7242-MONOMER"],["FSR-MONOMER"],["ACRB-MONOMER"],["G7218-MONOMER"],["EG12710-MONOMER"],["EG11008-MONOMER"],["EG12181-MONOMER"],["EG10943-MONOMER"],["G6865-MONOMER"],["YIDC"],["PHOSNACMURPENTATRANS-MONOMER"],["3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-MONOMER"],["PD00242"],["EG11058-MONOMER"],["EG11113-MONOMER"],["ARTP-MONOMER"],["EG12404-MONOMER"],["G6269-MONOMER"],["G6884-MONOMER"],["EG11423-MONOMER"],["GARTRANSFORMYL2-MONOMER"],["EG11517-MONOMER"],["EG12128-MONOMER"],["EG10003-MONOMER"],["EG10155-MONOMER"],["EG12094-MONOMER"],["EG10689-MONOMER"],["G7834-MONOMER"],["PD00347"],["EMRE-MONOMER"],["PHOSACETYLTRANS-MONOMER"],["EG10746-MONOMER"],["EG12207-MONOMER"],["VALINE-PYRUVATE-AMINOTRANSFER-MONOMER"],["YHIH-MONOMER"],["EG10665-MONOMER"],["PANTOATE-BETA-ALANINE-LIG-MONOMER"],["TYRB-MONOMER"],["IMIDPHOSPHADEHYDHISTIDPHOSPHA-MONOMER"],["EG12273-MONOMER"],["PSTB-MONOMER"],["EG12042-MONOMER"],["EG12345-MONOMER"],["EG11969-MONOMER"],["DEOXYGLUCONOKIN-MONOMER"],["EG10043-MONOMER"],["NAG1P-URIDYLTRANS-MONOMER"],["G7128-MONOMER"],["G7296-MONOMER"],["ARTI-MONOMER"],["ATPH-MONOMER"],["PD00200"],["EG11277-MONOMER"],["EG11665-MONOMER"],["EG11984-MONOMER"],["EG10244-MONOMER"],["GCVH-MONOMER"],["EG10125-MONO ...
